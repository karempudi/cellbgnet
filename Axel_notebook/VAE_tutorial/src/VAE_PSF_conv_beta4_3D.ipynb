# %%
import torch
import torchvision
import torch.optim as optim
import argparse
import matplotlib
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import model
import model_conv
import model_conv_bigger
from tqdm import tqdm
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision.utils import save_image
matplotlib.style.use('ggplot')

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

import os

os.chdir('/home/axtr7550/Chromosome_project/cellbgnet/')
import cellbgnet
import cellbgnet.utils

from cellbgnet.datasets import DataSimulator
from cellbgnet.utils.hardware import cpu, gpu
from cellbgnet.model import CellBGModel
from cellbgnet.simulation.psf_kernel import SMAPSplineCoefficient
from cellbgnet.generic.emitter import EmitterSet
from cellbgnet.train_loss_infer import generate_probmap_cells

os.chdir('/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/src')

from skimage.io import imread
from skimage.measure import label
import random
import edt
from skimage.filters import gaussian
from scipy.ndimage import rotate
import random
import pickle
import pathlib
from pathlib import Path
#%matplotlib qt5

# %%
print(os.getcwd())
# Out:
# /home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/src

# %%
param_file = '../../../cellbgnet/utils/reference_files/reference_Axel.yaml'
param = cellbgnet.utils.param_io.ParamHandling().load_params(param_file)

# %%
psf_params = param.PSF.to_dict()
simulation_params = param.Simulation.to_dict()
hardware_params = param.Hardware.to_dict()
train_size = simulation_params['train_size']
calib_file = psf_params['calib_file']

# %%
psf_size = 41
xextent = [-0.5, 127.5]
yextent = [-0.5, 127.5]
zextent = [-400, 400]
scale = torch.tensor([(xextent[1] - xextent[0]),
                      (yextent[1] - yextent[0]),
                      (zextent[1] - zextent[0])])
shift = torch.tensor([xextent[0], yextent[0], zextent[0]])

# %%
psf = SMAPSplineCoefficient(calib_file=calib_file).init_spline(
xextent=[-0.5, 63.5], yextent=[-0.5, 63.5], img_shape=[64, 64], device='cuda', 
roi_size=None, roi_auto_center=None, normalize=True)
# Out:
# INITIATING CUDA IMPLEMENTATION

# %%
epochs = 40
batch_size = 128
lr = 0.0001
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# transforms
transform = transforms.Compose([
    transforms.ToTensor(),
])

# %%
# train and validation data
train_data = datasets.MNIST(
    root='../input/data',
    train=True,
    download=True,
    transform=transform
)
val_data = datasets.MNIST(
    root='../input/data',
    train=False,
    download=True,
    transform=transform
)

# %%
def create_psf_batch(size=64, batch_size=128):
    xyz = torch.normal(float(size/2), float(size/5), (batch_size,3))
    xyz[...,2] = torch.normal(0.0, 250.0, (batch_size, ))
    xyz = xyz.view(1, -1, 3)
    photon_scale = 100
    #photons = torch.rand((xyz.shape[1], 1))*photon_scale
    photons = torch.ones((xyz.shape[1], 1))*photon_scale
    frames = torch.cat([psf.forward(xyz[:,i,...], photons[i]) for i in range(xyz.shape[1])])
    max_val = torch.max(frames)
    frames = frames/max_val
    frames = frames.view(frames.shape[0],1,frames.shape[1], frames.shape[2])
    return frames, xyz, photons

# %%
frames,_, _ = create_psf_batch()

# %%
def create_batch(size=28, batch_size=64):
    batch = torch.zeros([batch_size,1,size,size])
    xys = torch.tensor([[0], [0]])
    xs = torch.randint(0, size, (batch_size,))
    ys = torch.randint(0, size,  (batch_size,))
    xys = torch.concatenate([xs.view(-1,1), ys.view(-1,1)], dim=1)
    batch[torch.arange(batch.shape[0]),0, xs, ys] = 1
    return batch, xys

# %%
model = torch.load("/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/models/VAE_3D_conv_B4.pt")
lr = 0.0001
#model = model_conv_bigger.VAE(zDim=3, imsize=(64,64)).to(device)
optimizer = optim.AdamW(model.parameters(), lr=lr)
criterion = nn.BCELoss(reduction='sum')

# %%
#model = torch.load("/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/models/VAE_conv_PSF_1.pt")

# %%
def final_loss(bce_loss, mu, logvar):
    """
    This function will add the reconstruction loss (BCELoss) and the 
    KL-Divergence.
    KL-Divergence = 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)

    A beta here will affect how much the KLD matters

    :param bce_loss: recontruction loss
    :param mu: the mean from the latent vector
    :param logvar: log variance from the latent vector
    """
    BCE = bce_loss 
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

    return BCE + KLD*4, BCE, KLD

# %%
def fit(model, dataloader):
    model.train()
    running_loss = 0.0
    for i in range((64*64)//batch_size):
        data = create_psf_batch()
        data, xyz, _ = data
        data = data.to(device)
        #data = data.view(data.size(0), -1)
        optimizer.zero_grad()
        reconstruction, mu, logvar = model(data)
        bce_loss = criterion(reconstruction, data)
        loss, BCE, KLD = final_loss(bce_loss, mu, logvar)
        running_loss += loss.item()
        loss.backward()
        optimizer.step()

    train_loss = running_loss/(64*64)
    return train_loss

# %%
def validate(model, dataloader):
    model.eval()
    running_loss = 0.0
    running_BCE = 0.0
    running_KLD = 0.0
    with torch.no_grad():
        for i in range((64*64)//batch_size):
            data = create_psf_batch()
            data, xys, _ = data
            data = data.to(device)
            #data = data.view(data.size(0), -1)
            reconstruction, mu, logvar = model(data)
            bce_loss = criterion(reconstruction, data)
            loss, BCE, KLD = final_loss(bce_loss, mu, logvar)
            running_loss += loss.item()
            running_BCE += BCE.item()
            running_KLD += KLD.item()
            # save the last batch input and output of every epoch
            if ((64*64)//batch_size - 1) and (epoch % 600 == 0):
                #plt.imshow(data.view(batch_size, 1, 64, 64)[0,0,...].cpu().detach().numpy(), cmap='gray')
                num_rows = 8
                both = torch.cat((data.view(batch_size, 1, 64, 64)[:8], 
                                  reconstruction.view(batch_size, 1, 64, 64)[:8]))
                save_image(both.cpu(), f"../outputs/conv_out/psf_beta4_conv_3D_output{epoch}.png", nrow=num_rows, pad_value=1)

    val_loss = running_loss/(64*64)
    bce_loss_tot = running_BCE/(64*64)
    kld_loss = running_KLD/(64*64)
    return val_loss, mu, xys, bce_loss_tot, kld_loss

# %%
model = torch.load("/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/models/VAE_3D_conv_B4.pt")

lr = 0.0001
#model = model_conv_bigger.VAE(zDim=3, imsize=(64,64)).to(device)
optimizer = optim.AdamW(model.parameters(), lr=lr)
criterion = nn.BCELoss(reduction='sum')

# %%
#train_loss = []
#val_loss = []
#bce_loss_list = []
#kld_loss_list = []
curr = 15682
epochs = 1000
batch_size = 128
for epoch in range(curr, curr+epochs+1):
    print(f"Epoch {epoch+1} of {epochs}")
    train_epoch_loss = fit(model, 0)
    val_epoch_loss, mu, xys, bce_loss, kld_loss = validate(model, 0)
    bce_loss_list.append(bce_loss)
    kld_loss_list.append(kld_loss)
    train_loss.append(train_epoch_loss)
    val_loss.append(val_epoch_loss)
    print(f"Train Loss: {train_epoch_loss:.4f}")
    print(f"BCE: {bce_loss:.4f}, KLD: {kld_loss:.4f}")
    if epoch % 4000 == 0:
        torch.save(model.state_dict(), f"/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/models/VAE_3D_conv_B4_{epoch}.pt")
# Out:
# Epoch 15683 of 1000
# Train Loss: 167.9964
# BCE: 147.8647, KLD: 5.2073
# Epoch 15684 of 1000
# Train Loss: 168.6572
# BCE: 146.6301, KLD: 5.3920
# Epoch 15685 of 1000
# Train Loss: 168.1088
# BCE: 147.0727, KLD: 5.2919
# Epoch 15686 of 1000
# Train Loss: 168.5581
# BCE: 147.1180, KLD: 5.3521
# Epoch 15687 of 1000
# Train Loss: 167.7936
# BCE: 147.6959, KLD: 5.2330
# Epoch 15688 of 1000
# Train Loss: 168.8843
# BCE: 146.4850, KLD: 5.2862
# Epoch 15689 of 1000
# Train Loss: 168.2079
# BCE: 146.9369, KLD: 5.3477
# Epoch 15690 of 1000
# Train Loss: 167.8114
# BCE: 147.4026, KLD: 5.2755
# Epoch 15691 of 1000
# Train Loss: 168.2496
# BCE: 148.0301, KLD: 5.2037
# Epoch 15692 of 1000
# Train Loss: 167.8918
# BCE: 146.7202, KLD: 5.3018
# Epoch 15693 of 1000
# Train Loss: 167.5220
# BCE: 146.2996, KLD: 5.3283
# Epoch 15694 of 1000
# Train Loss: 167.8863
# BCE: 147.6133, KLD: 5.2429
# Epoch 15695 of 1000
# Train Loss: 167.9188
# BCE: 146.6592, KLD: 5.3045
# Epoch 15696 of 1000
# Train Loss: 168.1986
# BCE: 146.9345, KLD: 5.4066
# Epoch 15697 of 1000
# Train Loss: 168.0915
# BCE: 146.7501, KLD: 5.3174
# Epoch 15698 of 1000
# Train Loss: 168.3002
# BCE: 147.2292, KLD: 5.3851
# Epoch 15699 of 1000
# Train Loss: 168.3993
# BCE: 147.1436, KLD: 5.3311
# Epoch 15700 of 1000
# Train Loss: 168.7103
# BCE: 146.6850, KLD: 5.2624
# Epoch 15701 of 1000
# Train Loss: 167.4142
# BCE: 147.0193, KLD: 5.2655
# Epoch 15702 of 1000
# Train Loss: 168.0362
# BCE: 147.5645, KLD: 5.2062
# Epoch 15703 of 1000
# Train Loss: 168.3992
# BCE: 146.6688, KLD: 5.2647
# Epoch 15704 of 1000
# Train Loss: 168.0396
# BCE: 146.3748, KLD: 5.3814
# Epoch 15705 of 1000
# Train Loss: 168.0545
# BCE: 147.4206, KLD: 5.2249
# Epoch 15706 of 1000
# Train Loss: 167.8564
# BCE: 146.4805, KLD: 5.3318
# Epoch 15707 of 1000
# Train Loss: 168.4537
# BCE: 147.0838, KLD: 5.2979
# Epoch 15708 of 1000
# Train Loss: 168.0304
# BCE: 147.1315, KLD: 5.2755
# Epoch 15709 of 1000
# Train Loss: 168.1946
# BCE: 147.2677, KLD: 5.3080
# Epoch 15710 of 1000
# Train Loss: 168.6578
# BCE: 146.4951, KLD: 5.2720
# Epoch 15711 of 1000
# Train Loss: 168.2469
# BCE: 146.7515, KLD: 5.3271
# Epoch 15712 of 1000
# Train Loss: 168.1884
# BCE: 147.5790, KLD: 5.2223
# Epoch 15713 of 1000
# Train Loss: 168.2959
# BCE: 147.2717, KLD: 5.2865
# Epoch 15714 of 1000
# Train Loss: 167.9762
# BCE: 147.0244, KLD: 5.2249
# Epoch 15715 of 1000
# Train Loss: 167.5916
# BCE: 147.1587, KLD: 5.2447
# Epoch 15716 of 1000
# Train Loss: 168.1216
# BCE: 147.0782, KLD: 5.3738
# Epoch 15717 of 1000
# Train Loss: 168.5224
# BCE: 146.4592, KLD: 5.2645
# Epoch 15718 of 1000
# Train Loss: 168.3293
# BCE: 146.1550, KLD: 5.3617
# Epoch 15719 of 1000
# Train Loss: 169.0573
# BCE: 147.7917, KLD: 5.2013
# Epoch 15720 of 1000
# Train Loss: 168.8809
# BCE: 146.4335, KLD: 5.3769
# Epoch 15721 of 1000
# Train Loss: 167.6612
# BCE: 146.9793, KLD: 5.2646
# Epoch 15722 of 1000
# Train Loss: 168.8198
# BCE: 147.0895, KLD: 5.4355
# Epoch 15723 of 1000
# Train Loss: 168.0493
# BCE: 146.4447, KLD: 5.2816
# Epoch 15724 of 1000
# Train Loss: 168.8549
# BCE: 146.4890, KLD: 5.3365
# Epoch 15725 of 1000
# Train Loss: 168.8827
# BCE: 147.0013, KLD: 5.4233
# Epoch 15726 of 1000
# Train Loss: 167.9955
# BCE: 146.8280, KLD: 5.3353
# Epoch 15727 of 1000
# Train Loss: 167.8933
# BCE: 147.3334, KLD: 5.4067
# Epoch 15728 of 1000
# Train Loss: 168.2684
# BCE: 146.8217, KLD: 5.3300
# Epoch 15729 of 1000
# Train Loss: 168.1924
# BCE: 147.3225, KLD: 5.2458
# Epoch 15730 of 1000
# Train Loss: 167.7912
# BCE: 146.5905, KLD: 5.3012
# Epoch 15731 of 1000
# Train Loss: 168.6232
# BCE: 146.2687, KLD: 5.2533
# Epoch 15732 of 1000
# Train Loss: 167.8661
# BCE: 146.0824, KLD: 5.3056
# Epoch 15733 of 1000
# Train Loss: 168.0866
# BCE: 145.7945, KLD: 5.4277
# Epoch 15734 of 1000
# Train Loss: 168.8130
# BCE: 146.5908, KLD: 5.4024
# Epoch 15735 of 1000
# Train Loss: 167.9332
# BCE: 147.4053, KLD: 5.2981
# Epoch 15736 of 1000
# Train Loss: 168.2223
# BCE: 146.8664, KLD: 5.3547
# Epoch 15737 of 1000
# Train Loss: 167.6626
# BCE: 146.9247, KLD: 5.2565
# Epoch 15738 of 1000
# Train Loss: 168.2071
# BCE: 146.6669, KLD: 5.2796
# Epoch 15739 of 1000
# Train Loss: 168.9674
# BCE: 147.1227, KLD: 5.2337
# Epoch 15740 of 1000
# Train Loss: 168.4778
# BCE: 146.7244, KLD: 5.2848
# Epoch 15741 of 1000
# Train Loss: 167.6075
# BCE: 147.0062, KLD: 5.2622
# Epoch 15742 of 1000
# Train Loss: 167.6205
# BCE: 146.8705, KLD: 5.2308
# Epoch 15743 of 1000
# Train Loss: 168.0225
# BCE: 147.0016, KLD: 5.2311
# Epoch 15744 of 1000
# Train Loss: 167.4832
# BCE: 147.4408, KLD: 5.2224
# Epoch 15745 of 1000
# Train Loss: 167.6321
# BCE: 147.5215, KLD: 5.2605
# Epoch 15746 of 1000
# Train Loss: 167.9141
# BCE: 146.8102, KLD: 5.3288
# Epoch 15747 of 1000
# Train Loss: 168.1551
# BCE: 146.8270, KLD: 5.2562
# Epoch 15748 of 1000
# Train Loss: 168.3354
# BCE: 147.1636, KLD: 5.3822
# Epoch 15749 of 1000
# Train Loss: 168.0392
# BCE: 147.4210, KLD: 5.2159
# Epoch 15750 of 1000
# Train Loss: 168.1379
# BCE: 146.1954, KLD: 5.3297
# Epoch 15751 of 1000
# Train Loss: 168.0202
# BCE: 147.4668, KLD: 5.3967
# Epoch 15752 of 1000
# Train Loss: 168.1484
# BCE: 147.2145, KLD: 5.3224
# Epoch 15753 of 1000
# Train Loss: 167.8996
# BCE: 146.3091, KLD: 5.3514
# Epoch 15754 of 1000
# Train Loss: 168.3239
# BCE: 146.2472, KLD: 5.2992
# Epoch 15755 of 1000
# Train Loss: 167.6649
# BCE: 147.0145, KLD: 5.3357
# Epoch 15756 of 1000
# Train Loss: 167.8514
# BCE: 147.0640, KLD: 5.3225
# Epoch 15757 of 1000
# Train Loss: 168.4503
# BCE: 146.9559, KLD: 5.3296
# Epoch 15758 of 1000
# Train Loss: 168.5031
# BCE: 147.3710, KLD: 5.2781
# Epoch 15759 of 1000
# Train Loss: 168.6123
# BCE: 147.4838, KLD: 5.2453
# Epoch 15760 of 1000
# Train Loss: 167.7840
# BCE: 147.0839, KLD: 5.2726
# Epoch 15761 of 1000
# Train Loss: 168.4682
# BCE: 147.7565, KLD: 5.2843
# Epoch 15762 of 1000
# Train Loss: 168.0479
# BCE: 146.7718, KLD: 5.2832
# Epoch 15763 of 1000
# Train Loss: 168.3763
# BCE: 146.6407, KLD: 5.2776
# Epoch 15764 of 1000
# Train Loss: 168.4085
# BCE: 146.8226, KLD: 5.2871
# Epoch 15765 of 1000
# Train Loss: 168.8469
# BCE: 146.9364, KLD: 5.3011
# Epoch 15766 of 1000
# Train Loss: 168.1659
# BCE: 146.8138, KLD: 5.3386
# Epoch 15767 of 1000
# Train Loss: 167.9736
# BCE: 148.0790, KLD: 5.1866
# Epoch 15768 of 1000
# Train Loss: 167.8310
# BCE: 147.5152, KLD: 5.2522
# Epoch 15769 of 1000
# Train Loss: 167.9383
# BCE: 147.3299, KLD: 5.2578
# Epoch 15770 of 1000
# Train Loss: 167.6984
# BCE: 146.6010, KLD: 5.3791
# Epoch 15771 of 1000
# Train Loss: 168.4561
# BCE: 147.0716, KLD: 5.2648
# Epoch 15772 of 1000
# Train Loss: 168.6220
# BCE: 146.9227, KLD: 5.2987
# Epoch 15773 of 1000
# Train Loss: 167.6227
# BCE: 146.9586, KLD: 5.2888
# Epoch 15774 of 1000
# Train Loss: 168.0044
# BCE: 146.7751, KLD: 5.2143
# Epoch 15775 of 1000
# Train Loss: 167.6496
# BCE: 146.9233, KLD: 5.2503
# Epoch 15776 of 1000
# Train Loss: 167.4335
# BCE: 147.4309, KLD: 5.2076
# Epoch 15777 of 1000
# Train Loss: 168.9741
# BCE: 146.8661, KLD: 5.2370
# Epoch 15778 of 1000
# Train Loss: 168.5810
# BCE: 147.1732, KLD: 5.4347
# Epoch 15779 of 1000
# Train Loss: 168.3106
# BCE: 148.1087, KLD: 5.2052
# Epoch 15780 of 1000
# Train Loss: 168.3403
# BCE: 146.2619, KLD: 5.3373
# Epoch 15781 of 1000
# Train Loss: 168.2509
# BCE: 146.8577, KLD: 5.3814
# Epoch 15782 of 1000
# Train Loss: 167.8871
# BCE: 146.4562, KLD: 5.3108
# Epoch 15783 of 1000
# Train Loss: 167.6940
# BCE: 147.1708, KLD: 5.3256
# Epoch 15784 of 1000
# Train Loss: 168.0288
# BCE: 147.1545, KLD: 5.3578
# Epoch 15785 of 1000
# Train Loss: 167.7587
# BCE: 146.7732, KLD: 5.3680
# Epoch 15786 of 1000
# Train Loss: 168.2981
# BCE: 146.5243, KLD: 5.3209
# Epoch 15787 of 1000
# Train Loss: 167.8823
# BCE: 146.7417, KLD: 5.3645
# Epoch 15788 of 1000
# Train Loss: 168.5557
# BCE: 147.4495, KLD: 5.2982
# Epoch 15789 of 1000
# Train Loss: 168.3627
# BCE: 146.7463, KLD: 5.2916
# Epoch 15790 of 1000
# Train Loss: 168.2875
# BCE: 147.3773, KLD: 5.2363
# Epoch 15791 of 1000
# Train Loss: 168.2324
# BCE: 147.4843, KLD: 5.2868
# Epoch 15792 of 1000
# Train Loss: 167.7175
# BCE: 146.4367, KLD: 5.3140
# Epoch 15793 of 1000
# Train Loss: 168.0682
# BCE: 147.1166, KLD: 5.2401
# Epoch 15794 of 1000
# Train Loss: 167.9036
# BCE: 146.4010, KLD: 5.3105
# Epoch 15795 of 1000
# Train Loss: 167.2799
# BCE: 147.3094, KLD: 5.2322
# Epoch 15796 of 1000
# Train Loss: 167.6033
# BCE: 146.4530, KLD: 5.3247
# Epoch 15797 of 1000
# Train Loss: 168.4514
# BCE: 146.4608, KLD: 5.3362
# Epoch 15798 of 1000
# Train Loss: 169.0941
# BCE: 147.4465, KLD: 5.3143
# Epoch 15799 of 1000
# Train Loss: 167.5759
# BCE: 146.6097, KLD: 5.3078
# Epoch 15800 of 1000
# Train Loss: 167.9612
# BCE: 146.9277, KLD: 5.3816
# Epoch 15801 of 1000
# Train Loss: 168.3148
# BCE: 146.5933, KLD: 5.3233
# Epoch 15802 of 1000
# Train Loss: 167.3242
# BCE: 147.3836, KLD: 5.2542
# Epoch 15803 of 1000
# Train Loss: 168.2217
# BCE: 147.7229, KLD: 5.2496
# Epoch 15804 of 1000
# Train Loss: 168.1639
# BCE: 146.9867, KLD: 5.3798
# Epoch 15805 of 1000
# Train Loss: 168.2324
# BCE: 147.6148, KLD: 5.3272
# Epoch 15806 of 1000
# Train Loss: 167.9562
# BCE: 146.9369, KLD: 5.3355
# Epoch 15807 of 1000
# Train Loss: 168.1189
# BCE: 147.1021, KLD: 5.4312
# Epoch 15808 of 1000
# Train Loss: 167.7164
# BCE: 146.9065, KLD: 5.3185
# Epoch 15809 of 1000
# Train Loss: 168.3853
# BCE: 147.1383, KLD: 5.2448
# Epoch 15810 of 1000
# Train Loss: 167.5178
# BCE: 147.6582, KLD: 5.3298
# Epoch 15811 of 1000
# Train Loss: 167.6048
# BCE: 146.6931, KLD: 5.3377
# Epoch 15812 of 1000
# Train Loss: 168.1629
# BCE: 148.0483, KLD: 5.2656
# Epoch 15813 of 1000
# Train Loss: 167.4015
# BCE: 146.4254, KLD: 5.4429
# Epoch 15814 of 1000
# Train Loss: 168.1879
# BCE: 146.9461, KLD: 5.2890
# Epoch 15815 of 1000
# Train Loss: 167.9446
# BCE: 146.7805, KLD: 5.3087
# Epoch 15816 of 1000
# Train Loss: 169.1068
# BCE: 146.4893, KLD: 5.3348
# Epoch 15817 of 1000
# Train Loss: 166.8093
# BCE: 146.7446, KLD: 5.2478
# Epoch 15818 of 1000
# Train Loss: 168.7535
# BCE: 146.6232, KLD: 5.2784
# Epoch 15819 of 1000
# Train Loss: 168.5590
# BCE: 146.6227, KLD: 5.3551
# Epoch 15820 of 1000
# Train Loss: 168.2201
# BCE: 147.4888, KLD: 5.2749
# Epoch 15821 of 1000
# Train Loss: 168.4254
# BCE: 147.3898, KLD: 5.3577
# Epoch 15822 of 1000
# Train Loss: 167.9610
# BCE: 148.2577, KLD: 5.2752
# Epoch 15823 of 1000
# Train Loss: 167.6009
# BCE: 147.1697, KLD: 5.2330
# Epoch 15824 of 1000
# Train Loss: 168.7343
# BCE: 147.0725, KLD: 5.2979
# Epoch 15825 of 1000
# Train Loss: 168.0127
# BCE: 146.7521, KLD: 5.3956
# Epoch 15826 of 1000
# Train Loss: 168.1916
# BCE: 147.5608, KLD: 5.2482
# Epoch 15827 of 1000
# Train Loss: 168.7595
# BCE: 146.5223, KLD: 5.3711
# Epoch 15828 of 1000
# Train Loss: 167.8004
# BCE: 147.4140, KLD: 5.2798
# Epoch 15829 of 1000
# Train Loss: 167.8761
# BCE: 147.2057, KLD: 5.2561
# Epoch 15830 of 1000
# Train Loss: 168.2635
# BCE: 146.5525, KLD: 5.2335
# Epoch 15831 of 1000
# Train Loss: 168.0422
# BCE: 146.8932, KLD: 5.3220
# Epoch 15832 of 1000
# Train Loss: 168.1653
# BCE: 147.9411, KLD: 5.2215
# Epoch 15833 of 1000
# Train Loss: 168.4416
# BCE: 146.9535, KLD: 5.3143
# Epoch 15834 of 1000
# Train Loss: 168.0129
# BCE: 147.4632, KLD: 5.2969
# Epoch 15835 of 1000
# Train Loss: 168.7273
# BCE: 147.5089, KLD: 5.2786
# Epoch 15836 of 1000
# Train Loss: 168.3657
# BCE: 147.3431, KLD: 5.3204
# Epoch 15837 of 1000
# Train Loss: 168.0681
# BCE: 147.3261, KLD: 5.2552
# Epoch 15838 of 1000
# Train Loss: 169.0115
# BCE: 147.7146, KLD: 5.2040
# Epoch 15839 of 1000
# Train Loss: 168.3786
# BCE: 147.2843, KLD: 5.2636
# Epoch 15840 of 1000
# Train Loss: 167.4709
# BCE: 147.3704, KLD: 5.2956
# Epoch 15841 of 1000
# Train Loss: 168.2289
# BCE: 147.0844, KLD: 5.2409
# Epoch 15842 of 1000
# Train Loss: 168.0766
# BCE: 146.8281, KLD: 5.2059
# Epoch 15843 of 1000
# Train Loss: 168.0393
# BCE: 147.4192, KLD: 5.2965
# Epoch 15844 of 1000
# Train Loss: 168.0923
# BCE: 146.4482, KLD: 5.3805
# Epoch 15845 of 1000
# Train Loss: 168.4099
# BCE: 146.6616, KLD: 5.3481
# Epoch 15846 of 1000
# Train Loss: 167.9296
# BCE: 146.7010, KLD: 5.2953
# Epoch 15847 of 1000
# Train Loss: 167.7879
# BCE: 146.9957, KLD: 5.3166
# Epoch 15848 of 1000
# Train Loss: 168.2046
# BCE: 147.5506, KLD: 5.2854
# Epoch 15849 of 1000
# Train Loss: 168.7844
# BCE: 146.8890, KLD: 5.2745
# Epoch 15850 of 1000
# Train Loss: 168.7798
# BCE: 147.7709, KLD: 5.3037
# Epoch 15851 of 1000
# Train Loss: 167.5591
# BCE: 147.6358, KLD: 5.2291
# Epoch 15852 of 1000
# Train Loss: 167.7565
# BCE: 147.0996, KLD: 5.3736
# Epoch 15853 of 1000
# Train Loss: 167.8113
# BCE: 147.1629, KLD: 5.2830
# Epoch 15854 of 1000
# Train Loss: 168.2069
# BCE: 146.8454, KLD: 5.2920
# Epoch 15855 of 1000
# Train Loss: 168.4928
# BCE: 146.4777, KLD: 5.3625
# Epoch 15856 of 1000
# Train Loss: 168.7865
# BCE: 146.3082, KLD: 5.3852
# Epoch 15857 of 1000
# Train Loss: 168.0220
# BCE: 147.4948, KLD: 5.2427
# Epoch 15858 of 1000
# Train Loss: 168.2533
# BCE: 145.9866, KLD: 5.3573
# Epoch 15859 of 1000
# Train Loss: 167.9393
# BCE: 147.3054, KLD: 5.2678
# Epoch 15860 of 1000
# Train Loss: 167.5324
# BCE: 147.0792, KLD: 5.2512
# Epoch 15861 of 1000
# Train Loss: 168.4789
# BCE: 146.7613, KLD: 5.3582
# Epoch 15862 of 1000
# Train Loss: 167.8057
# BCE: 146.8999, KLD: 5.3574
# Epoch 15863 of 1000
# Train Loss: 167.7656
# BCE: 146.3989, KLD: 5.2881
# Epoch 15864 of 1000
# Train Loss: 168.4104
# BCE: 147.9537, KLD: 5.2383
# Epoch 15865 of 1000
# Train Loss: 168.2584
# BCE: 146.7435, KLD: 5.3550
# Epoch 15866 of 1000
# Train Loss: 167.9820
# BCE: 147.0613, KLD: 5.3147
# Epoch 15867 of 1000
# Train Loss: 167.6521
# BCE: 147.5186, KLD: 5.2868
# Epoch 15868 of 1000
# Train Loss: 169.2203
# BCE: 147.0456, KLD: 5.2410
# Epoch 15869 of 1000
# Train Loss: 168.0778
# BCE: 146.8824, KLD: 5.2301
# Epoch 15870 of 1000
# Train Loss: 168.4818
# BCE: 147.0087, KLD: 5.2898
# Epoch 15871 of 1000
# Train Loss: 168.4984
# BCE: 146.9653, KLD: 5.2571
# Epoch 15872 of 1000
# Train Loss: 168.7220
# BCE: 146.9285, KLD: 5.3001
# Epoch 15873 of 1000
# Train Loss: 167.3017
# BCE: 147.1924, KLD: 5.3733
# Epoch 15874 of 1000
# Train Loss: 168.5498
# BCE: 147.8794, KLD: 5.2421
# Epoch 15875 of 1000
# Train Loss: 168.5127
# BCE: 147.7479, KLD: 5.1715
# Epoch 15876 of 1000
# Train Loss: 167.9602
# BCE: 146.9000, KLD: 5.3260
# Epoch 15877 of 1000
# Train Loss: 168.3388
# BCE: 147.2766, KLD: 5.3660
# Epoch 15878 of 1000
# Train Loss: 168.1047
# BCE: 146.4788, KLD: 5.3873
# Epoch 15879 of 1000
# Train Loss: 168.7547
# BCE: 146.7190, KLD: 5.3145
# Epoch 15880 of 1000
# Train Loss: 168.2371
# BCE: 146.3483, KLD: 5.3487
# Epoch 15881 of 1000
# Train Loss: 167.3272
# BCE: 147.2011, KLD: 5.2803
# Epoch 15882 of 1000
# Train Loss: 168.3517
# BCE: 147.3056, KLD: 5.2566
# Epoch 15883 of 1000
# Train Loss: 168.1896
# BCE: 147.2140, KLD: 5.3327
# Epoch 15884 of 1000
# Train Loss: 167.7623
# BCE: 146.5344, KLD: 5.4071
# Epoch 15885 of 1000
# Train Loss: 168.4875
# BCE: 146.2332, KLD: 5.3756
# Epoch 15886 of 1000
# Train Loss: 168.6505
# BCE: 146.9244, KLD: 5.2471
# Epoch 15887 of 1000
# Train Loss: 167.7592
# BCE: 146.9088, KLD: 5.3054
# Epoch 15888 of 1000
# Train Loss: 168.2780
# BCE: 146.9922, KLD: 5.3188
# Epoch 15889 of 1000
# Train Loss: 168.4908
# BCE: 147.1553, KLD: 5.2347
# Epoch 15890 of 1000
# Train Loss: 168.2563
# BCE: 147.8538, KLD: 5.2816
# Epoch 15891 of 1000
# Train Loss: 167.8368
# BCE: 147.0341, KLD: 5.2851
# Epoch 15892 of 1000
# Train Loss: 167.4796
# BCE: 147.0058, KLD: 5.2859
# Epoch 15893 of 1000
# Train Loss: 167.5304
# BCE: 147.5596, KLD: 5.2661
# Epoch 15894 of 1000
# Train Loss: 168.2547
# BCE: 146.7074, KLD: 5.3546
# Epoch 15895 of 1000
# Train Loss: 168.8718
# BCE: 146.2989, KLD: 5.3755
# Epoch 15896 of 1000
# Train Loss: 168.1720
# BCE: 146.7152, KLD: 5.3627
# Epoch 15897 of 1000
# Train Loss: 168.3178
# BCE: 147.1123, KLD: 5.2873
# Epoch 15898 of 1000
# Train Loss: 167.9908
# BCE: 146.0675, KLD: 5.3402
# Epoch 15899 of 1000
# Train Loss: 167.9963
# BCE: 147.4627, KLD: 5.2213
# Epoch 15900 of 1000
# Train Loss: 168.6219
# BCE: 145.5803, KLD: 5.4340
# Epoch 15901 of 1000
# Train Loss: 167.8900
# BCE: 147.0230, KLD: 5.2790
# Epoch 15902 of 1000
# Train Loss: 167.7474
# BCE: 146.7428, KLD: 5.2650
# Epoch 15903 of 1000
# Train Loss: 168.4839
# BCE: 147.2354, KLD: 5.2966
# Epoch 15904 of 1000
# Train Loss: 168.0257
# BCE: 146.8548, KLD: 5.3039
# Epoch 15905 of 1000
# Train Loss: 167.4415
# BCE: 146.7351, KLD: 5.4205
# Epoch 15906 of 1000
# Train Loss: 167.7521
# BCE: 147.1293, KLD: 5.3137
# Epoch 15907 of 1000
# Train Loss: 168.5107
# BCE: 147.4440, KLD: 5.2441
# Epoch 15908 of 1000
# Train Loss: 168.0532
# BCE: 146.5470, KLD: 5.3492
# Epoch 15909 of 1000
# Train Loss: 167.8232
# BCE: 147.1313, KLD: 5.2897
# Epoch 15910 of 1000
# Train Loss: 167.7235
# BCE: 146.8885, KLD: 5.2188
# Epoch 15911 of 1000
# Train Loss: 168.9872
# BCE: 146.6021, KLD: 5.3460
# Epoch 15912 of 1000
# Train Loss: 167.2601
# BCE: 147.0433, KLD: 5.2444
# Epoch 15913 of 1000
# Train Loss: 167.8206
# BCE: 147.0312, KLD: 5.2718
# Epoch 15914 of 1000
# Train Loss: 167.4197
# BCE: 146.6594, KLD: 5.2711
# Epoch 15915 of 1000
# Train Loss: 168.3891
# BCE: 147.2525, KLD: 5.2108
# Epoch 15916 of 1000
# Train Loss: 168.5314
# BCE: 147.7774, KLD: 5.1644
# Epoch 15917 of 1000
# Train Loss: 168.3695
# BCE: 146.5706, KLD: 5.2990
# Epoch 15918 of 1000
# Train Loss: 168.3122
# BCE: 147.3961, KLD: 5.2811
# Epoch 15919 of 1000
# Train Loss: 168.2168
# BCE: 146.6245, KLD: 5.3155
# Epoch 15920 of 1000
# Train Loss: 168.0257
# BCE: 147.6242, KLD: 5.2486
# Epoch 15921 of 1000
# Train Loss: 168.0811
# BCE: 147.4446, KLD: 5.2295
# Epoch 15922 of 1000
# Train Loss: 168.1603
# BCE: 146.3234, KLD: 5.3862
# Epoch 15923 of 1000
# Train Loss: 167.3365
# BCE: 147.3819, KLD: 5.2694
# Epoch 15924 of 1000
# Train Loss: 167.9100
# BCE: 146.8986, KLD: 5.2900
# Epoch 15925 of 1000
# Train Loss: 168.0504
# BCE: 146.8123, KLD: 5.4332
# Epoch 15926 of 1000
# Train Loss: 168.4458
# BCE: 147.6031, KLD: 5.2290
# Epoch 15927 of 1000
# Train Loss: 167.5666
# BCE: 147.8505, KLD: 5.2029
# Epoch 15928 of 1000
# Train Loss: 168.2600
# BCE: 146.9262, KLD: 5.2455
# Epoch 15929 of 1000
# Train Loss: 168.0007
# BCE: 146.8553, KLD: 5.2864
# Epoch 15930 of 1000
# Train Loss: 167.8416
# BCE: 147.2630, KLD: 5.3007
# Epoch 15931 of 1000
# Train Loss: 168.7396
# BCE: 147.0065, KLD: 5.2975
# Epoch 15932 of 1000
# Train Loss: 168.1332
# BCE: 147.6424, KLD: 5.2475
# Epoch 15933 of 1000
# Train Loss: 167.9333
# BCE: 147.7275, KLD: 5.2729
# Epoch 15934 of 1000
# Train Loss: 167.9352
# BCE: 146.7784, KLD: 5.2559
# Epoch 15935 of 1000
# Train Loss: 167.4399
# BCE: 146.7605, KLD: 5.3389
# Epoch 15936 of 1000
# Train Loss: 168.4006
# BCE: 147.1863, KLD: 5.2884
# Epoch 15937 of 1000
# Train Loss: 168.2195
# BCE: 147.6380, KLD: 5.2258
# Epoch 15938 of 1000
# Train Loss: 168.6923
# BCE: 146.4333, KLD: 5.4046
# Epoch 15939 of 1000
# Train Loss: 168.0949
# BCE: 147.2442, KLD: 5.3037
# Epoch 15940 of 1000
# Train Loss: 168.3277
# BCE: 146.3868, KLD: 5.3825
# Epoch 15941 of 1000
# Train Loss: 168.2525
# BCE: 147.7152, KLD: 5.1927
# Epoch 15942 of 1000
# Train Loss: 168.5244
# BCE: 146.3445, KLD: 5.3795
# Epoch 15943 of 1000
# Train Loss: 167.9962
# BCE: 146.6330, KLD: 5.3279
# Epoch 15944 of 1000
# Train Loss: 168.4546
# BCE: 147.7185, KLD: 5.2429
# Epoch 15945 of 1000
# Train Loss: 167.9116
# BCE: 146.8773, KLD: 5.3233
# Epoch 15946 of 1000
# Train Loss: 168.5921
# BCE: 147.2303, KLD: 5.2221
# Epoch 15947 of 1000
# Train Loss: 168.3336
# BCE: 146.7769, KLD: 5.2367
# Epoch 15948 of 1000
# Train Loss: 167.7558
# BCE: 146.7691, KLD: 5.2680
# Epoch 15949 of 1000
# Train Loss: 167.9473
# BCE: 147.3315, KLD: 5.3228
# Epoch 15950 of 1000
# Train Loss: 168.0430
# BCE: 146.3955, KLD: 5.3738
# Epoch 15951 of 1000
# Train Loss: 167.7999
# BCE: 146.9148, KLD: 5.3529
# Epoch 15952 of 1000
# Train Loss: 168.4421
# BCE: 147.2692, KLD: 5.2025
# Epoch 15953 of 1000
# Train Loss: 167.8837
# BCE: 146.7575, KLD: 5.4065
# Epoch 15954 of 1000
# Train Loss: 167.6433
# BCE: 147.3331, KLD: 5.2221
# Epoch 15955 of 1000
# Train Loss: 167.4442
# BCE: 146.7108, KLD: 5.2506
# Epoch 15956 of 1000
# Train Loss: 167.9347
# BCE: 147.3089, KLD: 5.3096
# Epoch 15957 of 1000
# Train Loss: 167.5195
# BCE: 146.8570, KLD: 5.2467
# Epoch 15958 of 1000
# Train Loss: 168.9767
# BCE: 146.4680, KLD: 5.3841
# Epoch 15959 of 1000
# Train Loss: 168.1292
# BCE: 146.6012, KLD: 5.4159
# Epoch 15960 of 1000
# Train Loss: 168.2023
# BCE: 146.7415, KLD: 5.3339
# Epoch 15961 of 1000
# Train Loss: 167.6820
# BCE: 146.2127, KLD: 5.3398
# Epoch 15962 of 1000
# Train Loss: 168.6477
# BCE: 146.7498, KLD: 5.2970
# Epoch 15963 of 1000
# Train Loss: 169.0877
# BCE: 146.9849, KLD: 5.2749
# Epoch 15964 of 1000
# Train Loss: 168.0684
# BCE: 146.3674, KLD: 5.3011
# Epoch 15965 of 1000
# Train Loss: 167.6715
# BCE: 147.7664, KLD: 5.3610
# Epoch 15966 of 1000
# Train Loss: 168.1708
# BCE: 147.2819, KLD: 5.3790
# Epoch 15967 of 1000
# Train Loss: 168.5132
# BCE: 147.1261, KLD: 5.2482
# Epoch 15968 of 1000
# Train Loss: 167.8873
# BCE: 147.0445, KLD: 5.3168
# Epoch 15969 of 1000
# Train Loss: 167.9341
# BCE: 146.3593, KLD: 5.4298
# Epoch 15970 of 1000
# Train Loss: 168.4761
# BCE: 147.2431, KLD: 5.2691
# Epoch 15971 of 1000
# Train Loss: 168.4566
# BCE: 146.1015, KLD: 5.3606
# Epoch 15972 of 1000
# Train Loss: 167.7296
# BCE: 147.3576, KLD: 5.2763
# Epoch 15973 of 1000
# Train Loss: 168.7234
# BCE: 147.0558, KLD: 5.3170
# Epoch 15974 of 1000
# Train Loss: 168.3804
# BCE: 147.9957, KLD: 5.1906
# Epoch 15975 of 1000
# Train Loss: 167.7933
# BCE: 147.1000, KLD: 5.2176
# Epoch 15976 of 1000
# Train Loss: 168.6390
# BCE: 146.6287, KLD: 5.2996
# Epoch 15977 of 1000
# Train Loss: 167.8777
# BCE: 147.4241, KLD: 5.2277
# Epoch 15978 of 1000
# Train Loss: 168.2288
# BCE: 146.8962, KLD: 5.2921
# Epoch 15979 of 1000
# Train Loss: 168.2362
# BCE: 148.4358, KLD: 5.1582
# Epoch 15980 of 1000
# Train Loss: 167.5860
# BCE: 146.9248, KLD: 5.2391
# Epoch 15981 of 1000
# Train Loss: 167.8056
# BCE: 147.3237, KLD: 5.2694
# Epoch 15982 of 1000
# Train Loss: 167.8277
# BCE: 147.0003, KLD: 5.2581
# Epoch 15983 of 1000
# Train Loss: 168.2287
# BCE: 147.2387, KLD: 5.3145
# Epoch 15984 of 1000
# Train Loss: 168.6460
# BCE: 145.9040, KLD: 5.3457
# Epoch 15985 of 1000
# Train Loss: 168.1621
# BCE: 146.9113, KLD: 5.3018
# Epoch 15986 of 1000
# Train Loss: 168.5077
# BCE: 147.2616, KLD: 5.2777
# Epoch 15987 of 1000
# Train Loss: 167.7179
# BCE: 146.7804, KLD: 5.2748
# Epoch 15988 of 1000
# Train Loss: 168.0354
# BCE: 147.1631, KLD: 5.2029
# Epoch 15989 of 1000
# Train Loss: 167.8917
# BCE: 146.5958, KLD: 5.2833
# Epoch 15990 of 1000
# Train Loss: 167.8772
# BCE: 147.1215, KLD: 5.2782
# Epoch 15991 of 1000
# Train Loss: 168.0625
# BCE: 146.1025, KLD: 5.3915
# Epoch 15992 of 1000
# Train Loss: 167.7002
# BCE: 147.2635, KLD: 5.2170
# Epoch 15993 of 1000
# Train Loss: 168.6840
# BCE: 146.7526, KLD: 5.2907
# Epoch 15994 of 1000
# Train Loss: 168.4880
# BCE: 147.5342, KLD: 5.2779
# Epoch 15995 of 1000
# Train Loss: 167.9858
# BCE: 147.4859, KLD: 5.2334
# Epoch 15996 of 1000
# Train Loss: 168.8257
# BCE: 146.6065, KLD: 5.3822
# Epoch 15997 of 1000
# Train Loss: 167.9999
# BCE: 146.4259, KLD: 5.3639
# Epoch 15998 of 1000
# Train Loss: 168.8329
# BCE: 147.1962, KLD: 5.3289
# Epoch 15999 of 1000
# Train Loss: 168.6075
# BCE: 147.4968, KLD: 5.2437
# Epoch 16000 of 1000
# Train Loss: 168.3128
# BCE: 146.3914, KLD: 5.3603
# Epoch 16001 of 1000
# Train Loss: 168.1154
# BCE: 147.6693, KLD: 5.2775
# Epoch 16002 of 1000
# Train Loss: 168.2264
# BCE: 147.3518, KLD: 5.2626
# Epoch 16003 of 1000
# Train Loss: 168.8794
# BCE: 146.6409, KLD: 5.2571
# Epoch 16004 of 1000
# Train Loss: 168.6051
# BCE: 146.9118, KLD: 5.3060
# Epoch 16005 of 1000
# Train Loss: 168.0551
# BCE: 147.0887, KLD: 5.2593
# Epoch 16006 of 1000
# Train Loss: 168.5683
# BCE: 146.3688, KLD: 5.2920
# Epoch 16007 of 1000
# Train Loss: 167.9922
# BCE: 146.9801, KLD: 5.2310
# Epoch 16008 of 1000
# Train Loss: 167.9456
# BCE: 146.5696, KLD: 5.2875
# Epoch 16009 of 1000
# Train Loss: 167.8554
# BCE: 147.0189, KLD: 5.3294
# Epoch 16010 of 1000
# Train Loss: 168.2515
# BCE: 146.1039, KLD: 5.4045
# Epoch 16011 of 1000
# Train Loss: 167.5675
# BCE: 147.3200, KLD: 5.2760
# Epoch 16012 of 1000
# Train Loss: 168.1068
# BCE: 147.0414, KLD: 5.3375
# Epoch 16013 of 1000
# Train Loss: 168.5695
# BCE: 147.1651, KLD: 5.3110
# Epoch 16014 of 1000
# Train Loss: 168.4017
# BCE: 147.0336, KLD: 5.2609
# Epoch 16015 of 1000
# Train Loss: 168.0089
# BCE: 146.8186, KLD: 5.2881
# Epoch 16016 of 1000
# Train Loss: 168.0068
# BCE: 146.0346, KLD: 5.2819
# Epoch 16017 of 1000
# Train Loss: 168.1302
# BCE: 145.9314, KLD: 5.3121
# Epoch 16018 of 1000
# Train Loss: 167.7526
# BCE: 146.3096, KLD: 5.2922
# Epoch 16019 of 1000
# Train Loss: 167.5506
# BCE: 147.1095, KLD: 5.3513
# Epoch 16020 of 1000
# Train Loss: 169.0609
# BCE: 147.3176, KLD: 5.3332
# Epoch 16021 of 1000
# Train Loss: 167.7424
# BCE: 147.5469, KLD: 5.2862
# Epoch 16022 of 1000
# Train Loss: 168.2108
# BCE: 146.3632, KLD: 5.3060
# Epoch 16023 of 1000
# Train Loss: 167.8666
# BCE: 147.0334, KLD: 5.1421
# Epoch 16024 of 1000
# Train Loss: 167.9453
# BCE: 146.1850, KLD: 5.3663
# Epoch 16025 of 1000
# Train Loss: 168.1026
# BCE: 147.1118, KLD: 5.2577
# Epoch 16026 of 1000
# Train Loss: 168.6490
# BCE: 146.9402, KLD: 5.4567
# Epoch 16027 of 1000
# Train Loss: 167.9817
# BCE: 146.5925, KLD: 5.2375
# Epoch 16028 of 1000
# Train Loss: 167.6832
# BCE: 147.0915, KLD: 5.2929
# Epoch 16029 of 1000
# Train Loss: 168.1164
# BCE: 147.8534, KLD: 5.2220
# Epoch 16030 of 1000
# Train Loss: 168.6956
# BCE: 147.2044, KLD: 5.2347
# Epoch 16031 of 1000
# Train Loss: 168.8832
# BCE: 146.2630, KLD: 5.4188
# Epoch 16032 of 1000
# Train Loss: 167.9314
# BCE: 146.9323, KLD: 5.3027
# Epoch 16033 of 1000
# Train Loss: 167.0469
# BCE: 147.0158, KLD: 5.2798
# Epoch 16034 of 1000
# Train Loss: 168.2954
# BCE: 146.7194, KLD: 5.3123
# Epoch 16035 of 1000
# Train Loss: 168.2018
# BCE: 147.6995, KLD: 5.1994
# Epoch 16036 of 1000
# Train Loss: 167.8304
# BCE: 147.1744, KLD: 5.2963
# Epoch 16037 of 1000
# Train Loss: 167.2774
# BCE: 146.6447, KLD: 5.3263
# Epoch 16038 of 1000
# Train Loss: 168.4906
# BCE: 147.5998, KLD: 5.2169
# Epoch 16039 of 1000
# Train Loss: 168.3013
# BCE: 146.7508, KLD: 5.2805
# Epoch 16040 of 1000
# Train Loss: 167.9593
# BCE: 147.2903, KLD: 5.2746
# Epoch 16041 of 1000
# Train Loss: 167.6687
# BCE: 146.9298, KLD: 5.2769
# Epoch 16042 of 1000
# Train Loss: 168.1913
# BCE: 146.7258, KLD: 5.2372
# Epoch 16043 of 1000
# Train Loss: 168.1317
# BCE: 147.2151, KLD: 5.4003
# Epoch 16044 of 1000
# Train Loss: 168.1861
# BCE: 147.2317, KLD: 5.2188
# Epoch 16045 of 1000
# Train Loss: 167.7809
# BCE: 146.8235, KLD: 5.3935
# Epoch 16046 of 1000
# Train Loss: 167.7904
# BCE: 147.3528, KLD: 5.3744
# Epoch 16047 of 1000
# Train Loss: 167.7744
# BCE: 146.9221, KLD: 5.2584
# Epoch 16048 of 1000
# Train Loss: 167.6687
# BCE: 146.6628, KLD: 5.3199
# Epoch 16049 of 1000
# Train Loss: 168.1960
# BCE: 147.1224, KLD: 5.2852
# Epoch 16050 of 1000
# Train Loss: 168.2673
# BCE: 146.4501, KLD: 5.3541
# Epoch 16051 of 1000
# Train Loss: 168.3623
# BCE: 147.0986, KLD: 5.2711
# Epoch 16052 of 1000
# Train Loss: 168.1308
# BCE: 147.2138, KLD: 5.3420
# Epoch 16053 of 1000
# Train Loss: 167.9541
# BCE: 147.8341, KLD: 5.2339
# Epoch 16054 of 1000
# Train Loss: 168.3394
# BCE: 146.0704, KLD: 5.2073
# Epoch 16055 of 1000
# Train Loss: 167.7321
# BCE: 146.7059, KLD: 5.3896
# Epoch 16056 of 1000
# Train Loss: 168.0905
# BCE: 146.8010, KLD: 5.3060
# Epoch 16057 of 1000
# Train Loss: 168.2242
# BCE: 147.2573, KLD: 5.2495
# Epoch 16058 of 1000
# Train Loss: 168.0479
# BCE: 146.5306, KLD: 5.3084
# Epoch 16059 of 1000
# Train Loss: 168.1837
# BCE: 147.1485, KLD: 5.2285
# Epoch 16060 of 1000
# Train Loss: 168.0217
# BCE: 146.7340, KLD: 5.3061
# Epoch 16061 of 1000
# Train Loss: 168.1981
# BCE: 146.7884, KLD: 5.2193
# Epoch 16062 of 1000
# Train Loss: 168.2134
# BCE: 147.1676, KLD: 5.2795
# Epoch 16063 of 1000
# Train Loss: 167.4358
# BCE: 147.7349, KLD: 5.2780
# Epoch 16064 of 1000
# Train Loss: 168.5235
# BCE: 146.5740, KLD: 5.2637
# Epoch 16065 of 1000
# Train Loss: 167.6985
# BCE: 146.7462, KLD: 5.3408
# Epoch 16066 of 1000
# Train Loss: 168.0865
# BCE: 147.2382, KLD: 5.4189
# Epoch 16067 of 1000
# Train Loss: 167.9184
# BCE: 146.4466, KLD: 5.3863
# Epoch 16068 of 1000
# Train Loss: 168.1631
# BCE: 146.8432, KLD: 5.2789
# Epoch 16069 of 1000
# Train Loss: 168.2352
# BCE: 146.3022, KLD: 5.3343
# Epoch 16070 of 1000
# Train Loss: 168.0321
# BCE: 147.3379, KLD: 5.1977
# Epoch 16071 of 1000
# Train Loss: 168.4929
# BCE: 147.2042, KLD: 5.3139
# Epoch 16072 of 1000
# Train Loss: 168.2362
# BCE: 146.7676, KLD: 5.3927
# Epoch 16073 of 1000
# Train Loss: 168.3822
# BCE: 146.9601, KLD: 5.2992
# Epoch 16074 of 1000
# Train Loss: 168.9509
# BCE: 146.2919, KLD: 5.3763
# Epoch 16075 of 1000
# Train Loss: 168.4670
# BCE: 146.4913, KLD: 5.3746
# Epoch 16076 of 1000
# Train Loss: 168.4819
# BCE: 147.5345, KLD: 5.2184
# Epoch 16077 of 1000
# Train Loss: 168.7417
# BCE: 147.1663, KLD: 5.2483
# Epoch 16078 of 1000
# Train Loss: 167.7115
# BCE: 146.9332, KLD: 5.2959
# Epoch 16079 of 1000
# Train Loss: 168.4052
# BCE: 147.2184, KLD: 5.3079
# Epoch 16080 of 1000
# Train Loss: 168.5972
# BCE: 146.8783, KLD: 5.3157
# Epoch 16081 of 1000
# Train Loss: 167.8655
# BCE: 146.8136, KLD: 5.3799
# Epoch 16082 of 1000
# Train Loss: 167.2819
# BCE: 146.8193, KLD: 5.2613
# Epoch 16083 of 1000
# Train Loss: 168.8395
# BCE: 146.0570, KLD: 5.2691
# Epoch 16084 of 1000
# Train Loss: 168.2903
# BCE: 147.4415, KLD: 5.4093
# Epoch 16085 of 1000
# Train Loss: 168.6827
# BCE: 147.4746, KLD: 5.2578
# Epoch 16086 of 1000
# Train Loss: 168.2607
# BCE: 146.9242, KLD: 5.2569
# Epoch 16087 of 1000
# Train Loss: 168.9895
# BCE: 147.5901, KLD: 5.2797
# Epoch 16088 of 1000
# Train Loss: 168.1764
# BCE: 147.9083, KLD: 5.1825
# Epoch 16089 of 1000
# Train Loss: 167.5067
# BCE: 146.4948, KLD: 5.3294
# Epoch 16090 of 1000
# Train Loss: 167.6160
# BCE: 146.7167, KLD: 5.2910
# Epoch 16091 of 1000
# Train Loss: 168.1598
# BCE: 147.6910, KLD: 5.2637
# Epoch 16092 of 1000
# Train Loss: 168.1572
# BCE: 147.0051, KLD: 5.2576
# Epoch 16093 of 1000
# Train Loss: 168.6506
# BCE: 146.6605, KLD: 5.3635
# Epoch 16094 of 1000
# Train Loss: 168.3231
# BCE: 146.9633, KLD: 5.1949
# Epoch 16095 of 1000
# Train Loss: 168.2708
# BCE: 147.0877, KLD: 5.3339
# Epoch 16096 of 1000
# Train Loss: 168.4635
# BCE: 146.4019, KLD: 5.4093
# Epoch 16097 of 1000
# Train Loss: 168.0588
# BCE: 146.8175, KLD: 5.2983
# Epoch 16098 of 1000
# Train Loss: 168.5523
# BCE: 146.5517, KLD: 5.3029
# Epoch 16099 of 1000
# Train Loss: 167.6260
# BCE: 147.0576, KLD: 5.3448
# Epoch 16100 of 1000
# Train Loss: 167.7599
# BCE: 146.8154, KLD: 5.2019
# Epoch 16101 of 1000
# Train Loss: 168.5185
# BCE: 147.6209, KLD: 5.2949
# Epoch 16102 of 1000
# Train Loss: 168.1898
# BCE: 147.4316, KLD: 5.2544
# Epoch 16103 of 1000
# Train Loss: 167.7300
# BCE: 147.4547, KLD: 5.3579
# Epoch 16104 of 1000
# Train Loss: 168.4116
# BCE: 146.9263, KLD: 5.3638
# Epoch 16105 of 1000
# Train Loss: 168.0994
# BCE: 147.1022, KLD: 5.2890
# Epoch 16106 of 1000
# Train Loss: 168.2897
# BCE: 146.9216, KLD: 5.2241
# Epoch 16107 of 1000
# Train Loss: 168.0070
# BCE: 146.1123, KLD: 5.4629
# Epoch 16108 of 1000
# Train Loss: 169.0794
# BCE: 148.0210, KLD: 5.2713
# Epoch 16109 of 1000
# Train Loss: 167.6655
# BCE: 146.3802, KLD: 5.3028
# Epoch 16110 of 1000
# Train Loss: 167.9414
# BCE: 147.3843, KLD: 5.2549
# Epoch 16111 of 1000
# Train Loss: 168.0611
# BCE: 147.7867, KLD: 5.2348
# Epoch 16112 of 1000
# Train Loss: 168.2069
# BCE: 147.5662, KLD: 5.3725
# Epoch 16113 of 1000
# Train Loss: 167.8030
# BCE: 145.9636, KLD: 5.3775
# Epoch 16114 of 1000
# Train Loss: 167.6744
# BCE: 147.2415, KLD: 5.2241
# Epoch 16115 of 1000
# Train Loss: 168.6325
# BCE: 147.0038, KLD: 5.3069
# Epoch 16116 of 1000
# Train Loss: 167.8552
# BCE: 146.6723, KLD: 5.3218
# Epoch 16117 of 1000
# Train Loss: 167.9384
# BCE: 147.5655, KLD: 5.2959
# Epoch 16118 of 1000
# Train Loss: 168.5329
# BCE: 147.4598, KLD: 5.3104
# Epoch 16119 of 1000
# Train Loss: 168.1669
# BCE: 147.0990, KLD: 5.2654
# Epoch 16120 of 1000
# Train Loss: 168.5013
# BCE: 146.4293, KLD: 5.3697
# Epoch 16121 of 1000
# Train Loss: 168.0619
# BCE: 147.3345, KLD: 5.2202
# Epoch 16122 of 1000
# Train Loss: 167.8379
# BCE: 148.0377, KLD: 5.2843
# Epoch 16123 of 1000
# Train Loss: 168.3799
# BCE: 146.7483, KLD: 5.3116
# Epoch 16124 of 1000
# Train Loss: 168.7491
# BCE: 146.1320, KLD: 5.4143
# Epoch 16125 of 1000
# Train Loss: 168.2938
# BCE: 147.4493, KLD: 5.2672
# Epoch 16126 of 1000
# Train Loss: 167.8165
# BCE: 146.9521, KLD: 5.2884
# Epoch 16127 of 1000
# Train Loss: 168.2008
# BCE: 147.0633, KLD: 5.3656
# Epoch 16128 of 1000
# Train Loss: 168.5229
# BCE: 147.8454, KLD: 5.2767
# Epoch 16129 of 1000
# Train Loss: 167.8320
# BCE: 146.8002, KLD: 5.2526
# Epoch 16130 of 1000
# Train Loss: 168.2846
# BCE: 146.8054, KLD: 5.3512
# Epoch 16131 of 1000
# Train Loss: 167.8273
# BCE: 146.7884, KLD: 5.2995
# Epoch 16132 of 1000
# Train Loss: 168.2328
# BCE: 146.2623, KLD: 5.2934
# Epoch 16133 of 1000
# Train Loss: 168.3112
# BCE: 147.2208, KLD: 5.2726
# Epoch 16134 of 1000
# Train Loss: 167.8159
# BCE: 147.1063, KLD: 5.3388
# Epoch 16135 of 1000
# Train Loss: 168.5909
# BCE: 146.4710, KLD: 5.3653
# Epoch 16136 of 1000
# Train Loss: 168.3782
# BCE: 146.3849, KLD: 5.2790
# Epoch 16137 of 1000
# Train Loss: 167.4554
# BCE: 146.7305, KLD: 5.2232
# Epoch 16138 of 1000
# Train Loss: 168.9787
# BCE: 146.5007, KLD: 5.3297
# Epoch 16139 of 1000
# Train Loss: 168.8439
# BCE: 146.8972, KLD: 5.2780
# Epoch 16140 of 1000
# Train Loss: 168.0405
# BCE: 147.1973, KLD: 5.2888
# Epoch 16141 of 1000
# Train Loss: 167.7617
# BCE: 146.8618, KLD: 5.3009
# Epoch 16142 of 1000
# Train Loss: 168.1508
# BCE: 147.9868, KLD: 5.1545
# Epoch 16143 of 1000
# Train Loss: 168.2609
# BCE: 147.1793, KLD: 5.2787
# Epoch 16144 of 1000
# Train Loss: 168.1745
# BCE: 147.5480, KLD: 5.2740
# Epoch 16145 of 1000
# Train Loss: 167.8772
# BCE: 147.8351, KLD: 5.2721
# Epoch 16146 of 1000
# Train Loss: 167.4452
# BCE: 147.0438, KLD: 5.2464
# Epoch 16147 of 1000
# Train Loss: 167.8028
# BCE: 146.9007, KLD: 5.2996
# Epoch 16148 of 1000
# Train Loss: 167.7589
# BCE: 147.2727, KLD: 5.2338
# Epoch 16149 of 1000
# Train Loss: 167.9647
# BCE: 147.6596, KLD: 5.2249
# Epoch 16150 of 1000
# Train Loss: 168.5906
# BCE: 146.4957, KLD: 5.3053
# Epoch 16151 of 1000
# Train Loss: 168.4044
# BCE: 147.3756, KLD: 5.2892
# Epoch 16152 of 1000
# Train Loss: 168.1726
# BCE: 147.2797, KLD: 5.2334
# Epoch 16153 of 1000
# Train Loss: 168.4050
# BCE: 147.6614, KLD: 5.2349
# Epoch 16154 of 1000
# Train Loss: 167.7076
# BCE: 146.4114, KLD: 5.3717
# Epoch 16155 of 1000
# Train Loss: 168.7545
# BCE: 147.6280, KLD: 5.2645
# Epoch 16156 of 1000
# Train Loss: 168.2189
# BCE: 146.9733, KLD: 5.3486
# Epoch 16157 of 1000
# Train Loss: 168.4337
# BCE: 147.1607, KLD: 5.3838
# Epoch 16158 of 1000
# Train Loss: 168.7701
# BCE: 147.3082, KLD: 5.2095
# Epoch 16159 of 1000
# Train Loss: 168.0887
# BCE: 146.5457, KLD: 5.3885
# Epoch 16160 of 1000
# Train Loss: 168.8706
# BCE: 146.8688, KLD: 5.3462
# Epoch 16161 of 1000
# Train Loss: 168.4591
# BCE: 147.3062, KLD: 5.1960
# Epoch 16162 of 1000
# Train Loss: 168.3827
# BCE: 147.5375, KLD: 5.2132
# Epoch 16163 of 1000
# Train Loss: 168.4352
# BCE: 147.0907, KLD: 5.3137
# Epoch 16164 of 1000
# Train Loss: 168.7099
# BCE: 146.4487, KLD: 5.4125
# Epoch 16165 of 1000
# Train Loss: 167.9984
# BCE: 147.3266, KLD: 5.3080
# Epoch 16166 of 1000
# Train Loss: 168.4552
# BCE: 146.7131, KLD: 5.3356
# Epoch 16167 of 1000
# Train Loss: 168.2010
# BCE: 146.5342, KLD: 5.3950
# Epoch 16168 of 1000
# Train Loss: 168.0412
# BCE: 147.5319, KLD: 5.2621
# Epoch 16169 of 1000
# Train Loss: 168.0690
# BCE: 147.3953, KLD: 5.3199
# Epoch 16170 of 1000
# Train Loss: 168.3884
# BCE: 147.5415, KLD: 5.3641
# Epoch 16171 of 1000
# Train Loss: 167.6765
# BCE: 148.2062, KLD: 5.1700
# Epoch 16172 of 1000
# Train Loss: 168.2716
# BCE: 146.5367, KLD: 5.3259
# Epoch 16173 of 1000
# Train Loss: 168.3107
# BCE: 147.4159, KLD: 5.3947
# Epoch 16174 of 1000
# Train Loss: 168.5246
# BCE: 147.0792, KLD: 5.2637
# Epoch 16175 of 1000
# Train Loss: 168.3765
# BCE: 147.9574, KLD: 5.2057
# Epoch 16176 of 1000
# Train Loss: 168.4830
# BCE: 147.0639, KLD: 5.2533
# Epoch 16177 of 1000
# Train Loss: 167.4607
# BCE: 147.1955, KLD: 5.3639
# Epoch 16178 of 1000
# Train Loss: 168.5958
# BCE: 146.4928, KLD: 5.2818
# Epoch 16179 of 1000
# Train Loss: 168.6839
# BCE: 146.6227, KLD: 5.2710
# Epoch 16180 of 1000
# Train Loss: 167.9439
# BCE: 146.0316, KLD: 5.3447
# Epoch 16181 of 1000
# Train Loss: 168.5199
# BCE: 146.6766, KLD: 5.3219
# Epoch 16182 of 1000
# Train Loss: 168.2696
# BCE: 146.9933, KLD: 5.4152
# Epoch 16183 of 1000
# Train Loss: 168.2824
# BCE: 147.2104, KLD: 5.3865
# Epoch 16184 of 1000
# Train Loss: 169.1656
# BCE: 147.2759, KLD: 5.2543
# Epoch 16185 of 1000
# Train Loss: 168.3077
# BCE: 147.2771, KLD: 5.3549
# Epoch 16186 of 1000
# Train Loss: 168.4758
# BCE: 146.5485, KLD: 5.2951
# Epoch 16187 of 1000
# Train Loss: 168.4528
# BCE: 147.4315, KLD: 5.3150
# Epoch 16188 of 1000
# Train Loss: 168.8257
# BCE: 147.9610, KLD: 5.1994
# Epoch 16189 of 1000
# Train Loss: 168.4217
# BCE: 146.6414, KLD: 5.2741
# Epoch 16190 of 1000
# Train Loss: 167.7041
# BCE: 147.1886, KLD: 5.3424
# Epoch 16191 of 1000
# Train Loss: 168.5606
# BCE: 147.8418, KLD: 5.2278
# Epoch 16192 of 1000
# Train Loss: 167.9071
# BCE: 147.9000, KLD: 5.2286
# Epoch 16193 of 1000
# Train Loss: 168.2433
# BCE: 147.1049, KLD: 5.3587
# Epoch 16194 of 1000
# Train Loss: 168.4622
# BCE: 147.7021, KLD: 5.2441
# Epoch 16195 of 1000
# Train Loss: 168.1662
# BCE: 147.9656, KLD: 5.2706
# Epoch 16196 of 1000
# Train Loss: 168.2912
# BCE: 147.0300, KLD: 5.3334
# Epoch 16197 of 1000
# Train Loss: 168.4566
# BCE: 146.8871, KLD: 5.3315
# Epoch 16198 of 1000
# Train Loss: 168.3508
# BCE: 147.2033, KLD: 5.2342
# Epoch 16199 of 1000
# Train Loss: 167.8660
# BCE: 147.0688, KLD: 5.3208
# Epoch 16200 of 1000
# Train Loss: 168.1240
# BCE: 147.0294, KLD: 5.2856
# Epoch 16201 of 1000
# Train Loss: 168.4942
# BCE: 146.2616, KLD: 5.3773
# Epoch 16202 of 1000
# Train Loss: 168.1366
# BCE: 146.5767, KLD: 5.2959
# Epoch 16203 of 1000
# Train Loss: 168.6253
# BCE: 147.2948, KLD: 5.2910
# Epoch 16204 of 1000
# Train Loss: 168.6119
# BCE: 147.2222, KLD: 5.3049
# Epoch 16205 of 1000
# Train Loss: 168.4640
# BCE: 146.6817, KLD: 5.3451
# Epoch 16206 of 1000
# Train Loss: 168.6120
# BCE: 147.5185, KLD: 5.2123
# Epoch 16207 of 1000
# Train Loss: 168.2576
# BCE: 147.6620, KLD: 5.1702
# Epoch 16208 of 1000
# Train Loss: 168.0952
# BCE: 146.8182, KLD: 5.2630
# Epoch 16209 of 1000
# Train Loss: 167.5105
# BCE: 146.4438, KLD: 5.2744
# Epoch 16210 of 1000
# Train Loss: 168.5022
# BCE: 147.2699, KLD: 5.3667
# Epoch 16211 of 1000
# Train Loss: 167.9207
# BCE: 146.7482, KLD: 5.3390
# Epoch 16212 of 1000
# Train Loss: 168.0442
# BCE: 146.1281, KLD: 5.4195
# Epoch 16213 of 1000
# Train Loss: 168.5325
# BCE: 147.5706, KLD: 5.1887
# Epoch 16214 of 1000
# Train Loss: 168.4477
# BCE: 146.7222, KLD: 5.3482
# Epoch 16215 of 1000
# Train Loss: 168.1652
# BCE: 146.3805, KLD: 5.3729
# Epoch 16216 of 1000
# Train Loss: 167.7596
# BCE: 147.1015, KLD: 5.2942
# Epoch 16217 of 1000
# Train Loss: 168.5532
# BCE: 146.9096, KLD: 5.2695
# Epoch 16218 of 1000
# Train Loss: 168.1562
# BCE: 146.6448, KLD: 5.3345
# Epoch 16219 of 1000
# Train Loss: 169.0323
# BCE: 147.1289, KLD: 5.2552
# Epoch 16220 of 1000
# Train Loss: 167.9716
# BCE: 147.0511, KLD: 5.2567
# Epoch 16221 of 1000
# Train Loss: 168.4587
# BCE: 147.0350, KLD: 5.2949
# Epoch 16222 of 1000
# Train Loss: 168.7964
# BCE: 147.0427, KLD: 5.3253
# Epoch 16223 of 1000
# Train Loss: 167.5939
# BCE: 145.9701, KLD: 5.3012
# Epoch 16224 of 1000
# Train Loss: 168.1114
# BCE: 147.4337, KLD: 5.2660
# Epoch 16225 of 1000
# Train Loss: 168.2514
# BCE: 146.2116, KLD: 5.3334
# Epoch 16226 of 1000
# Train Loss: 167.9158
# BCE: 146.2691, KLD: 5.3189
# Epoch 16227 of 1000
# Train Loss: 168.4418
# BCE: 146.8480, KLD: 5.2738
# Epoch 16228 of 1000
# Train Loss: 168.0028
# BCE: 147.6287, KLD: 5.1558
# Epoch 16229 of 1000
# Train Loss: 168.0837
# BCE: 147.4680, KLD: 5.3560
# Epoch 16230 of 1000
# Train Loss: 168.4508
# BCE: 146.9561, KLD: 5.2456
# Epoch 16231 of 1000
# Train Loss: 168.0415
# BCE: 146.5980, KLD: 5.3386
# Epoch 16232 of 1000
# Train Loss: 167.6649
# BCE: 146.5474, KLD: 5.3341
# Epoch 16233 of 1000
# Train Loss: 168.8224
# BCE: 147.0235, KLD: 5.2763
# Epoch 16234 of 1000
# Train Loss: 168.2912
# BCE: 147.2201, KLD: 5.3330
# Epoch 16235 of 1000
# Train Loss: 167.6240
# BCE: 147.3810, KLD: 5.3474
# Epoch 16236 of 1000
# Train Loss: 168.2051
# BCE: 147.0413, KLD: 5.2952
# Epoch 16237 of 1000
# Train Loss: 168.1344
# BCE: 146.6904, KLD: 5.2679
# Epoch 16238 of 1000
# Train Loss: 168.0496
# BCE: 147.0751, KLD: 5.2701
# Epoch 16239 of 1000
# Train Loss: 168.0096
# BCE: 146.5134, KLD: 5.3020
# Epoch 16240 of 1000
# Train Loss: 167.8402
# BCE: 147.3444, KLD: 5.1996
# Epoch 16241 of 1000
# Train Loss: 167.5795
# BCE: 146.0588, KLD: 5.3638
# Epoch 16242 of 1000
# Train Loss: 168.3483
# BCE: 147.1321, KLD: 5.1452
# Epoch 16243 of 1000
# Train Loss: 167.5958
# BCE: 147.5664, KLD: 5.3106
# Epoch 16244 of 1000
# Train Loss: 167.0467
# BCE: 147.9034, KLD: 5.2602
# Epoch 16245 of 1000
# Train Loss: 167.7945
# BCE: 146.9298, KLD: 5.2917
# Epoch 16246 of 1000
# Train Loss: 168.7605
# BCE: 147.6451, KLD: 5.4034
# Epoch 16247 of 1000
# Train Loss: 168.5955
# BCE: 146.8040, KLD: 5.2561
# Epoch 16248 of 1000
# Train Loss: 168.3999
# BCE: 147.4636, KLD: 5.2054
# Epoch 16249 of 1000
# Train Loss: 167.5568
# BCE: 147.5065, KLD: 5.2470
# Epoch 16250 of 1000
# Train Loss: 167.1827
# BCE: 147.5999, KLD: 5.2078
# Epoch 16251 of 1000
# Train Loss: 167.9911
# BCE: 146.8161, KLD: 5.2973
# Epoch 16252 of 1000
# Train Loss: 168.1314
# BCE: 147.2183, KLD: 5.2585
# Epoch 16253 of 1000
# Train Loss: 169.1048
# BCE: 147.5702, KLD: 5.2780
# Epoch 16254 of 1000
# Train Loss: 167.8193
# BCE: 147.0304, KLD: 5.3586
# Epoch 16255 of 1000
# Train Loss: 168.4601
# BCE: 147.1212, KLD: 5.2121
# Epoch 16256 of 1000
# Train Loss: 168.2901
# BCE: 146.5522, KLD: 5.2972
# Epoch 16257 of 1000
# Train Loss: 168.5892
# BCE: 147.2443, KLD: 5.3041
# Epoch 16258 of 1000
# Train Loss: 168.5177
# BCE: 146.9321, KLD: 5.3047
# Epoch 16259 of 1000
# Train Loss: 167.8005
# BCE: 147.1081, KLD: 5.3106
# Epoch 16260 of 1000
# Train Loss: 167.8887
# BCE: 147.3362, KLD: 5.3203
# Epoch 16261 of 1000
# Train Loss: 168.1140
# BCE: 147.3129, KLD: 5.2009
# Epoch 16262 of 1000
# Train Loss: 167.9162
# BCE: 146.8842, KLD: 5.3069
# Epoch 16263 of 1000
# Train Loss: 168.2657
# BCE: 146.6499, KLD: 5.2809
# Epoch 16264 of 1000
# Train Loss: 168.3453
# BCE: 146.4906, KLD: 5.3638
# Epoch 16265 of 1000
# Train Loss: 168.3023
# BCE: 147.2327, KLD: 5.3074
# Epoch 16266 of 1000
# Train Loss: 167.5259
# BCE: 147.2870, KLD: 5.3030
# Epoch 16267 of 1000
# Train Loss: 168.2746
# BCE: 147.1919, KLD: 5.2695
# Epoch 16268 of 1000
# Train Loss: 168.2980
# BCE: 147.2954, KLD: 5.2445
# Epoch 16269 of 1000
# Train Loss: 167.9228
# BCE: 146.3182, KLD: 5.3230
# Epoch 16270 of 1000
# Train Loss: 167.8276
# BCE: 147.3590, KLD: 5.2099
# Epoch 16271 of 1000
# Train Loss: 167.7616
# BCE: 148.1370, KLD: 5.1840
# Epoch 16272 of 1000
# Train Loss: 167.8612
# BCE: 147.0567, KLD: 5.2899
# Epoch 16273 of 1000
# Train Loss: 167.9055
# BCE: 148.3161, KLD: 5.1933
# Epoch 16274 of 1000
# Train Loss: 168.0700
# BCE: 146.9995, KLD: 5.2937
# Epoch 16275 of 1000
# Train Loss: 167.6539
# BCE: 147.5227, KLD: 5.2237
# Epoch 16276 of 1000
# Train Loss: 168.2470
# BCE: 146.5660, KLD: 5.3328
# Epoch 16277 of 1000
# Train Loss: 167.9877
# BCE: 146.2011, KLD: 5.4063
# Epoch 16278 of 1000
# Train Loss: 167.6194
# BCE: 147.3828, KLD: 5.2706
# Epoch 16279 of 1000
# Train Loss: 167.7980
# BCE: 147.1165, KLD: 5.2594
# Epoch 16280 of 1000
# Train Loss: 168.0393
# BCE: 147.2691, KLD: 5.2455
# Epoch 16281 of 1000
# Train Loss: 169.0221
# BCE: 146.8868, KLD: 5.2771
# Epoch 16282 of 1000
# Train Loss: 168.7842
# BCE: 147.1243, KLD: 5.1695
# Epoch 16283 of 1000
# Train Loss: 168.1220
# BCE: 146.5388, KLD: 5.3864
# Epoch 16284 of 1000
# Train Loss: 168.6397
# BCE: 146.7789, KLD: 5.3969
# Epoch 16285 of 1000
# Train Loss: 167.4219
# BCE: 147.3455, KLD: 5.2625
# Epoch 16286 of 1000
# Train Loss: 168.1418
# BCE: 147.4065, KLD: 5.2766
# Epoch 16287 of 1000
# Train Loss: 167.8977
# BCE: 146.8314, KLD: 5.2435
# Epoch 16288 of 1000
# Train Loss: 168.1621
# BCE: 146.8655, KLD: 5.2577
# Epoch 16289 of 1000
# Train Loss: 168.6041
# BCE: 146.7265, KLD: 5.3430
# Epoch 16290 of 1000
# Train Loss: 168.5633
# BCE: 146.2643, KLD: 5.3843
# Epoch 16291 of 1000
# Train Loss: 168.1168
# BCE: 147.5584, KLD: 5.2194
# Epoch 16292 of 1000
# Train Loss: 168.4234
# BCE: 147.4396, KLD: 5.3505
# Epoch 16293 of 1000
# Train Loss: 167.5398
# BCE: 146.8657, KLD: 5.3485
# Epoch 16294 of 1000
# Train Loss: 167.8663
# BCE: 147.6861, KLD: 5.2087
# Epoch 16295 of 1000
# Train Loss: 168.4387
# BCE: 146.9248, KLD: 5.3121
# Epoch 16296 of 1000
# Train Loss: 168.1916
# BCE: 147.7121, KLD: 5.2093
# Epoch 16297 of 1000
# Train Loss: 168.5728
# BCE: 146.2757, KLD: 5.3456
# Epoch 16298 of 1000
# Train Loss: 168.2885
# BCE: 147.9694, KLD: 5.2155
# Epoch 16299 of 1000
# Train Loss: 168.0259
# BCE: 147.4941, KLD: 5.2628
# Epoch 16300 of 1000
# Train Loss: 168.2625
# BCE: 147.3888, KLD: 5.2010
# Epoch 16301 of 1000
# Train Loss: 168.1560
# BCE: 146.6897, KLD: 5.3713
# Epoch 16302 of 1000
# Train Loss: 169.0186
# BCE: 147.1908, KLD: 5.3198
# Epoch 16303 of 1000
# Train Loss: 168.5453
# BCE: 147.5031, KLD: 5.2067
# Epoch 16304 of 1000
# Train Loss: 168.0839
# BCE: 147.4713, KLD: 5.2674
# Epoch 16305 of 1000
# Train Loss: 168.0590
# BCE: 147.3370, KLD: 5.2369
# Epoch 16306 of 1000
# Train Loss: 168.3262
# BCE: 147.4719, KLD: 5.2652
# Epoch 16307 of 1000
# Train Loss: 168.0742
# BCE: 145.9348, KLD: 5.4035
# Epoch 16308 of 1000
# Train Loss: 167.9282
# BCE: 147.3167, KLD: 5.3223
# Epoch 16309 of 1000
# Train Loss: 168.5478
# BCE: 147.5977, KLD: 5.2242
# Epoch 16310 of 1000
# Train Loss: 168.7512
# BCE: 145.7719, KLD: 5.4319
# Epoch 16311 of 1000
# Train Loss: 167.9613
# BCE: 146.7609, KLD: 5.3715
# Epoch 16312 of 1000
# Train Loss: 168.1143
# BCE: 147.4334, KLD: 5.2750
# Epoch 16313 of 1000
# Train Loss: 169.1647
# BCE: 145.9267, KLD: 5.4046
# Epoch 16314 of 1000
# Train Loss: 168.5567
# BCE: 147.4723, KLD: 5.3141
# Epoch 16315 of 1000
# Train Loss: 168.1659
# BCE: 146.8010, KLD: 5.2513
# Epoch 16316 of 1000
# Train Loss: 168.2712
# BCE: 146.5794, KLD: 5.3500
# Epoch 16317 of 1000
# Train Loss: 167.9508
# BCE: 147.0275, KLD: 5.3008
# Epoch 16318 of 1000
# Train Loss: 167.9587
# BCE: 146.8252, KLD: 5.3959
# Epoch 16319 of 1000
# Train Loss: 168.2436
# BCE: 147.1748, KLD: 5.3461
# Epoch 16320 of 1000
# Train Loss: 168.2452
# BCE: 146.4069, KLD: 5.2802
# Epoch 16321 of 1000
# Train Loss: 168.6177
# BCE: 147.1882, KLD: 5.4019
# Epoch 16322 of 1000
# Train Loss: 168.5614
# BCE: 146.8370, KLD: 5.3570
# Epoch 16323 of 1000
# Train Loss: 168.3226
# BCE: 147.3567, KLD: 5.2814
# Epoch 16324 of 1000
# Train Loss: 168.2944
# BCE: 147.6037, KLD: 5.3595
# Epoch 16325 of 1000
# Train Loss: 167.7603
# BCE: 147.3911, KLD: 5.2366
# Epoch 16326 of 1000
# Train Loss: 168.3228
# BCE: 147.8091, KLD: 5.2502
# Epoch 16327 of 1000
# Train Loss: 168.9924
# BCE: 147.4209, KLD: 5.2644
# Epoch 16328 of 1000
# Train Loss: 168.7996
# BCE: 147.2794, KLD: 5.2760
# Epoch 16329 of 1000
# Train Loss: 168.9364
# BCE: 147.1688, KLD: 5.3332
# Epoch 16330 of 1000
# Train Loss: 168.3746
# BCE: 146.9107, KLD: 5.2401
# Epoch 16331 of 1000
# Train Loss: 167.4781
# BCE: 146.8016, KLD: 5.2019
# Epoch 16332 of 1000
# Train Loss: 168.4626
# BCE: 146.9851, KLD: 5.3770
# Epoch 16333 of 1000
# Train Loss: 168.4155
# BCE: 146.5633, KLD: 5.3306
# Epoch 16334 of 1000
# Train Loss: 168.0206
# BCE: 146.1201, KLD: 5.3816
# Epoch 16335 of 1000
# Train Loss: 168.3517
# BCE: 147.0416, KLD: 5.2641
# Epoch 16336 of 1000
# Train Loss: 168.6341
# BCE: 146.6460, KLD: 5.3410
# Epoch 16337 of 1000
# Train Loss: 167.9981
# BCE: 147.3805, KLD: 5.3325
# Epoch 16338 of 1000
# Train Loss: 167.6317
# BCE: 147.2534, KLD: 5.3246
# Epoch 16339 of 1000
# Train Loss: 167.3856
# BCE: 146.4905, KLD: 5.3165
# Epoch 16340 of 1000
# Train Loss: 168.0043
# BCE: 146.8012, KLD: 5.3222
# Epoch 16341 of 1000
# Train Loss: 167.2801
# BCE: 147.3715, KLD: 5.2542
# Epoch 16342 of 1000
# Train Loss: 168.5346
# BCE: 146.4293, KLD: 5.3073
# Epoch 16343 of 1000
# Train Loss: 168.2596
# BCE: 146.6917, KLD: 5.3293
# Epoch 16344 of 1000
# Train Loss: 168.1831
# BCE: 147.7241, KLD: 5.3030
# Epoch 16345 of 1000
# Train Loss: 167.9788
# BCE: 146.4085, KLD: 5.3714
# Epoch 16346 of 1000
# Train Loss: 168.4657
# BCE: 146.7881, KLD: 5.3427
# Epoch 16347 of 1000
# Train Loss: 168.7589
# BCE: 147.2610, KLD: 5.3482
# Epoch 16348 of 1000
# Train Loss: 168.6954
# BCE: 145.9338, KLD: 5.3604
# Epoch 16349 of 1000
# Train Loss: 168.3371
# BCE: 146.1670, KLD: 5.3385
# Epoch 16350 of 1000
# Train Loss: 168.0222
# BCE: 147.5075, KLD: 5.3474
# Epoch 16351 of 1000
# Train Loss: 167.8953
# BCE: 147.3593, KLD: 5.3127
# Epoch 16352 of 1000
# Train Loss: 168.7943
# BCE: 147.0031, KLD: 5.2917
# Epoch 16353 of 1000
# Train Loss: 168.2706
# BCE: 147.0616, KLD: 5.2849
# Epoch 16354 of 1000
# Train Loss: 168.0037
# BCE: 147.0120, KLD: 5.3716
# Epoch 16355 of 1000
# Train Loss: 168.4917
# BCE: 146.8712, KLD: 5.3657
# Epoch 16356 of 1000
# Train Loss: 168.4023
# BCE: 146.7242, KLD: 5.3088
# Epoch 16357 of 1000
# Train Loss: 167.9908
# BCE: 146.2861, KLD: 5.2814
# Epoch 16358 of 1000
# Train Loss: 167.7166
# BCE: 147.0448, KLD: 5.2838
# Epoch 16359 of 1000
# Train Loss: 168.4116
# BCE: 147.6062, KLD: 5.2832
# Epoch 16360 of 1000
# Train Loss: 168.3912
# BCE: 147.1656, KLD: 5.2506
# Epoch 16361 of 1000
# Train Loss: 167.7389
# BCE: 147.4540, KLD: 5.2031
# Epoch 16362 of 1000
# Train Loss: 167.2665
# BCE: 147.4958, KLD: 5.2555
# Epoch 16363 of 1000
# Train Loss: 168.4095
# BCE: 147.2766, KLD: 5.3110
# Epoch 16364 of 1000
# Train Loss: 168.3957
# BCE: 147.4359, KLD: 5.1821
# Epoch 16365 of 1000
# Train Loss: 168.2753
# BCE: 146.8698, KLD: 5.1979
# Epoch 16366 of 1000
# Train Loss: 168.1502
# BCE: 146.7444, KLD: 5.3546
# Epoch 16367 of 1000
# Train Loss: 168.1838
# BCE: 147.9398, KLD: 5.1961
# Epoch 16368 of 1000
# Train Loss: 167.2964
# BCE: 146.1717, KLD: 5.4006
# Epoch 16369 of 1000
# Train Loss: 167.9345
# BCE: 148.1408, KLD: 5.2080
# Epoch 16370 of 1000
# Train Loss: 168.5689
# BCE: 147.0661, KLD: 5.3310
# Epoch 16371 of 1000
# Train Loss: 168.2405
# BCE: 146.5870, KLD: 5.3387
# Epoch 16372 of 1000
# Train Loss: 168.0394
# BCE: 147.4049, KLD: 5.3050
# Epoch 16373 of 1000
# Train Loss: 168.3809
# BCE: 147.2304, KLD: 5.3573
# Epoch 16374 of 1000
# Train Loss: 168.4410
# BCE: 147.2440, KLD: 5.3310
# Epoch 16375 of 1000
# Train Loss: 169.0462
# BCE: 146.6094, KLD: 5.3045
# Epoch 16376 of 1000
# Train Loss: 167.7706
# BCE: 148.0532, KLD: 5.2711
# Epoch 16377 of 1000
# Train Loss: 167.7867
# BCE: 147.5546, KLD: 5.2158
# Epoch 16378 of 1000
# Train Loss: 167.6001
# BCE: 146.2046, KLD: 5.3233
# Epoch 16379 of 1000
# Train Loss: 167.9637
# BCE: 146.6456, KLD: 5.3147
# Epoch 16380 of 1000
# Train Loss: 167.5767
# BCE: 147.4835, KLD: 5.3560
# Epoch 16381 of 1000
# Train Loss: 168.1167
# BCE: 147.5485, KLD: 5.1733
# Epoch 16382 of 1000
# Train Loss: 167.9270
# BCE: 147.5614, KLD: 5.2656
# Epoch 16383 of 1000
# Train Loss: 168.6312
# BCE: 146.6544, KLD: 5.3237
# Epoch 16384 of 1000
# Train Loss: 168.4424
# BCE: 147.4396, KLD: 5.1878
# Epoch 16385 of 1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[123], line 10
#       8 for epoch in range(curr, curr+epochs+1):
#       9     print(f"Epoch {epoch+1} of {epochs}")
# ---> 10     train_epoch_loss = fit(model, 0)
#      11     val_epoch_loss, mu, xys, bce_loss, kld_loss = validate(model, 0)
#      12     bce_loss_list.append(bce_loss)
#
# Cell In[63], line 10, in fit(model, dataloader)
#       8 #data = data.view(data.size(0), -1)
#       9 optimizer.zero_grad()
# ---> 10 reconstruction, mu, logvar = model(data)
#      11 bce_loss = criterion(reconstruction, data)
#      12 loss, BCE, KLD = final_loss(bce_loss, mu, logvar)
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/src/model_conv_bigger.py:74, in VAE.forward(self, x)
#      72 mu, logVar = self.encoder(x)
#      73 z = self.reparameterize(mu, logVar)
# ---> 74 out = self.decoder(z)
#      75 return out, mu, logVar
#
# File ~/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/src/model_conv_bigger.py:64, in VAE.decoder(self, z)
#      62 x = F.relu(self.decConv1(x))
#      63 x = F.relu(self.decConv2(x))
# ---> 64 x = torch.sigmoid(self.decConv3(x))
#      66 return x
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/torch/nn/modules/conv.py:956, in ConvTranspose2d.forward(self, input, output_size)
#     951 num_spatial_dims = 2
#     952 output_padding = self._output_padding(
#     953     input, output_size, self.stride, self.padding, self.kernel_size,  # type: ignore[arg-type]
#     954     num_spatial_dims, self.dilation)  # type: ignore[arg-type]
# --> 956 return F.conv_transpose2d(
#     957     input, self.weight, self.bias, self.stride, self.padding,
#     958     output_padding, self.groups, self.dilation)
#
# KeyboardInterrupt:

# %%
# Out:
# 346112.0

# %%
torch.save(model, "/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/models/VAE_3D_conv_B4.pt")
torch.save(model.state_dict(), "/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/models/VAE_3D_conv_B4_sd.pt")

# %%
plt.plot(list(range(len(train_loss[2000:]))), train_loss[2000:])

# %%
plt.plot(list(range(len(train_loss))), train_loss)

# %%
torch.cuda.empty_cache()

# %%
all_xys.shape
all_mus.shape
# Out:
# torch.Size([11000, 2])

# %%
images, xys, _ = create_psf_batch(batch_size=100)
model.eval()
images = images.to(device)
reconstruction, mu, logvar = model(images)
all_xys = xys
all_mus = mu
for i in range(30):
    images, xys, _ = create_psf_batch(batch_size=100)
    model.eval()
    images = images.to(device)
    reconstruction, mu, logvar = model(images)
    del reconstruction
    del images

    all_xys = torch.cat((all_xys, xys), dim=1)
    del xys
    all_mus = torch.cat((all_mus, mu), dim=0)
    del mu

# %%
yin = (all_xys[0,:,1]>-1) & (all_xys[0,:,1]<64)
xin = (all_xys[0,:,0]>-1) & (all_xys[0,:,0]<64)
zin = (all_xys[0,:,2]>-500) & (all_xys[0,:,2]<500)

both_in = xin&yin&zin

# %%
predicted = all_mus[both_in,1].cpu().detach().numpy()
x = all_xys[0,both_in,1]
plt.plot(predicted, x, 'o', alpha=0.1)

# %%
predicted = all_mus[both_in,0].cpu().detach().numpy()
x = all_xys[0,both_in,0]
plt.plot(predicted, x, 'o', alpha=0.1)

# %%
predicted = all_mus[both_in,2].cpu().detach().numpy()
x = all_xys[0,both_in,2]
plt.plot(predicted, x, 'o', alpha=0.1)

# %%
plt.plot(all_mus[:,1].cpu().detach().numpy(), all_mus[:,2].cpu().detach().numpy(), 'o', alpha=1)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

plt.plot(all_xys[0,:,0].cpu().detach().numpy(), all_xys[0,:,1].cpu().detach().numpy(), 'o', alpha=1)

# %%
images.max()
# Out:
# tensor(2.1374, device='cuda:0')

# %%
#both = torch.cat((data.view(batch_size, 1, 64, 64)[:8], 
                    reconstruction.view(batch_size, 1, 64, 64)[:8]))
#save_image(both.cpu(), f"../outputs/psf_output{epoch}.png", nrow=num_rows)

# %%
model.eval()
fig, axs = plt.subplots(8,8, sharex=True, sharey=True)
# decoding
fig.tight_layout()
for i in range(-4,4):
    for j in range(-4,4):
        z = torch.tensor([[float(i),float(j)]]).cuda()
        axs[i,j].imshow(reconstruction.view((64, 64)).cpu().detach().numpy(), cmap='gray')

plt.show()

# %%
reconstruction.view((64, 64))
# Out:
# tensor([[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.0368e-01, 3.2587e-01,
#          2.6970e-01],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 6.7344e-01, 4.9652e-01,
#          3.5723e-01],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 9.4673e-01, 8.1915e-01,
#          6.0063e-01],
#         ...,
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 2.4258e-36, 3.9615e-36,
#          4.5398e-36],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 5.4501e-39, 7.5286e-39,
#          5.2027e-39],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00]], device='cuda:0', grad_fn=<ViewBackward0>)

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
from statsmodels.formula.api import ols
predictions = all_mus[both_in,:].cpu().detach().numpy()
X = np.array(all_xys[0,both_in,:2])



train_X, test_X, train_Y, test_Y = skl.model_selection.train_test_split(predictions, X, test_size=0.2)
reg = LinearRegression().fit(np.concatenate([train_X, train_X**2], axis=1), train_Y)
error = np.sqrt(np.mean((reg.predict(np.concatenate([test_X, test_X**2], axis=1)) - test_Y)**2))
print(error)
# Out:
# 10.768504

# %%
df = pd.DataFrame(np.concatenate([predictions, X], axis=1), columns=["mux", "muy", "X", "Y"])
df
# Out:
#            mux       muy          X          Y
# 0     0.590835 -1.088881  33.769619  43.261154
# 1    -0.235529 -0.463075  54.439774  59.142441
# 2    -0.100780  0.574154  11.446047  17.861872
# 3     0.686940 -0.091562  28.948713  24.942631
# 4    -0.082744  0.470603  13.443804  19.228218
# ...        ...       ...        ...        ...
# 9241  0.283223 -1.349000  38.934818  42.622536
# 9242  0.330101 -0.425184  28.774563  54.524624
# 9243  0.308841  0.478308  13.271326  27.912254
# 9244 -0.767542  2.720012  50.244900  12.440348
# 9245 -0.893434  1.210410  36.103371   0.557209
#
# [9246 rows x 4 columns]

# %%
model = ols("X, Y ~ mux + muy", data=df)
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 model = ols("X, Y ~ mux + muy", data=df)
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/statsmodels/base/model.py:200, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     197 if missing == 'none':  # with patsy it's drop or raise. let's raise.
#     198     missing = 'raise'
# --> 200 tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     201                           missing=missing)
#     202 ((endog, exog), missing_idx, design_info) = tmp
#     203 max_endog = cls._formula_max_endog
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/statsmodels/formula/formulatools.py:63, in handle_formula_data(Y, X, formula, depth, missing)
#      61 else:
#      62     if data_util._is_using_pandas(Y, None):
# ---> 63         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                            NA_action=na_action)
#      65     else:
#      66         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      67                            NA_action=na_action)
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/patsy/highlevel.py:309, in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     299 """Construct two design matrices given a formula_like and data.
#     300
#     301 This function is identical to :func:`dmatrix`, except that it requires
#    (...)
#     306 See :func:`dmatrix` for details.
#     307 """
#     308 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 309 (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     310                                   NA_action, return_type)
#     311 if lhs.shape[1] == 0:
#     312     raise PatsyError("model is missing required outcome variables")
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/patsy/highlevel.py:167, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     164 design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                   NA_action)
#     166 if design_infos is not None:
# --> 167     return build_design_matrices(design_infos, data,
#     168                                  NA_action=NA_action,
#     169                                  return_type=return_type)
#     170 else:
#     171     # No builders, but maybe we can still get matrices
#     172     if isinstance(formula_like, tuple):
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/patsy/build.py:893, in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     891 name = factor_info.factor.name()
#     892 origin = factor_info.factor.origin
# --> 893 rows_checker.check(value.shape[0], name, origin)
#     894 if (have_pandas
#     895     and isinstance(value, (pandas.Series, pandas.DataFrame))):
#     896     index_checker.check(value.index, name, origin)
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/patsy/build.py:795, in _CheckMatch.check(self, seen_value, desc, origin)
#     792     msg += " (%r versus %r)" % (self.value, seen_value)
#     793 # XX FIXME: this is a case where having discontiguous Origins
#     794 # would be useful...
# --> 795 raise PatsyError(msg, origin)
#
# PatsyError: Number of rows mismatch between data argument and X, Y (9246 versus 2)
#     X, Y ~ mux + muy
#     ^^^^

# %%
mus = torch.cat((torch.arange(-2,3,0.5).repeat(10).view(-1,1),torch.arange(-2,3,0.5).repeat_interleave(10).view(-1,1)),1)

# %%
model.eval()
z = mus.float().cuda()

reconstruction = model.decoder(z)

# %%
save_image(reconstruction.view((10*10, 1, 64,64)).cpu(), f"../outputs/conv_out/psf_beta4_test_values.png", nrow=10, pad_value=1)

# %%
reconstruction.shape
# Out:
# torch.Size([169, 4096])

# %%
from model_2_layer import simple_nn
simple_model = simple_nn()
lr = 0.001
optimizer_simple = optim.Adam(simple_model.parameters(), lr=lr)
loss_simple = nn.MSELoss()
# Out:
# Hej

# %%
def fit_simple(simple_model, train_X, train_Y):
    simple_model.train()
    running_loss = 0.0
    train_X = train_X.to(device)
    train_Y = train_Y.to(device)    
    batch_size = 64
    for i in range(len(train_X)//batch_size):
        data = train_X[i*batch_size:(i+1)*batch_size]
        gt = train_Y[i*batch_size:(i+1)*batch_size]
        optimizer_simple.zero_grad()
        output = simple_model(data)
        loss = loss_simple(output, gt)
        running_loss += loss.item()
        loss.backward()
        optimizer_simple.step()

    train_loss = running_loss/len(train_X)
    return train_loss

# %%
def validate_simple(model, test_X, test_y):
    model.eval()
    running_loss = 0.0
    batch_size = 64
    test_X = test_X.to(device)
    test_y = test_y.to(device)    


    with torch.no_grad():
        for i in range(len(test_X)//batch_size):
            data = test_X[i*batch_size:(i+1)*batch_size]
            gt = test_y[i*batch_size:(i+1)*batch_size]
            output = simple_model(data)
            loss = loss_simple(output, gt)
            running_loss += loss.item()

    val_loss = running_loss/len(test_X)
    return val_loss

# %%
import sklearn.model_selection as model_selection

predictions = all_mus[both_in,:]
X = all_xys[0,both_in,:2]
train_X, test_X, train_Y, test_Y = model_selection.train_test_split(predictions, X, test_size=0.2, shuffle=True, random_state=42)
#loss_vec = []
#val_loss_vec = []
simple_model.to(device)
train_X = train_X.detach()
test_X = test_X.detach()
for epoch in range(80):
    loss = fit_simple(simple_model, train_X, train_Y)
    loss_vec.append(loss)
    val_loss = validate_simple(simple_model, test_X, test_Y)
    val_loss_vec.append(val_loss)

# %%
plt.plot(list(range(len(loss_vec))), loss_vec)
plt.plot(list(range(len(loss_vec))), val_loss_vec)

# %%
np.sqrt(val_loss_vec[-1])
# Out:
# 0.6587733752300137
