# %%
import torch
import torchvision
import torch.optim as optim
import argparse
import matplotlib
import torch.nn as nn
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import model
import model_conv
import model_conv_bigger
from tqdm import tqdm
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision.utils import save_image
matplotlib.style.use('ggplot')

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

import os

os.chdir('/home/axtr7550/Chromosome_project/cellbgnet/')
import cellbgnet
import cellbgnet.utils

from cellbgnet.datasets import DataSimulator
from cellbgnet.utils.hardware import cpu, gpu
from cellbgnet.model import CellBGModel
from cellbgnet.simulation.psf_kernel import SMAPSplineCoefficient
from cellbgnet.generic.emitter import EmitterSet
from cellbgnet.train_loss_infer import generate_probmap_cells

os.chdir('/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/src')

from skimage.io import imread
from skimage.measure import label
import random
import edt
from skimage.filters import gaussian
from scipy.ndimage import rotate
import random
import pickle
import pathlib
from pathlib import Path
#%matplotlib qt5

# %%
print(os.getcwd())
# Out:
# /home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/src

# %%
param_file = '../../../cellbgnet/utils/reference_files/reference_Axel.yaml'
param = cellbgnet.utils.param_io.ParamHandling().load_params(param_file)

# %%
psf_params = param.PSF.to_dict()
simulation_params = param.Simulation.to_dict()
hardware_params = param.Hardware.to_dict()
train_size = simulation_params['train_size']
calib_file = psf_params['calib_file']

# %%
psf_size = 41
xextent = [-0.5, 127.5]
yextent = [-0.5, 127.5]
zextent = [-400, 400]
scale = torch.tensor([(xextent[1] - xextent[0]),
                      (yextent[1] - yextent[0]),
                      (zextent[1] - zextent[0])])
shift = torch.tensor([xextent[0], yextent[0], zextent[0]])

# %%
psf = SMAPSplineCoefficient(calib_file=calib_file).init_spline(
xextent=[-0.5, 63.5], yextent=[-0.5, 63.5], img_shape=[64, 64], device='cuda', 
roi_size=None, roi_auto_center=None, normalize=True)
# Out:
# INITIATING CUDA IMPLEMENTATION

# %%
epochs = 40
batch_size = 128
lr = 0.0001
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# transforms
transform = transforms.Compose([
    transforms.ToTensor(),
])

# %%
# train and validation data
train_data = datasets.MNIST(
    root='../input/data',
    train=True,
    download=True,
    transform=transform
)
val_data = datasets.MNIST(
    root='../input/data',
    train=False,
    download=True,
    transform=transform
)

# %%
def create_psf_batch(size=64, batch_size=128, noise_scale=0.5):
    #xyz = torch.rand((batch_size,3))*64
    xyz = torch.ones((batch_size,3))*32
    xyz[...,2] = (torch.rand((batch_size, ))-0.5)*1000
    xyz = xyz.view(1, -1, 3)
    photon_scale = 1000
    #photons = torch.rand((xyz.shape[1], 1))*photon_scale
    photons = torch.ones((xyz.shape[1], 1))*photon_scale
    frames = torch.cat([psf.forward(xyz[:,i,...], photons[i]) for i in range(xyz.shape[1])])
    max_val = torch.max(frames)
    frames = frames/max(21.28, max_val)
    
    frames = frames.view(frames.shape[0],1,frames.shape[1], frames.shape[2])
    noisy = frames + noise
    return frames, noisy, xyz, photons

# %%
frames,_, _ = create_psf_batch()
frames.max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 frames,_, _ = create_psf_batch()
#       2 frames.max()
#
# Cell In[11], line 14, in create_psf_batch(size, batch_size, noise_scale)
#      11 frames = frames/max(21.28, max_val)
#      13 frames = frames.view(frames.shape[0],1,frames.shape[1], frames.shape[2])
# ---> 14 noisy = frames + noise
#      15 return frames, noisy, xyz, photons
#
# NameError: name 'noise' is not defined

# %%
def create_batch(size=28, batch_size=64):
    batch = torch.zeros([batch_size,1,size,size])
    xys = torch.tensor([[0], [0]])
    xs = torch.randint(0, size, (batch_size,))
    ys = torch.randint(0, size,  (batch_size,))
    xys = torch.concatenate([xs.view(-1,1), ys.view(-1,1)], dim=1)
    batch[torch.arange(batch.shape[0]),0, xs, ys] = 1
    return batch, xys

# %%
#model = torch.load("/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/models/VAE_3D_conv_B4.pt")
lr = 0.001
model = model_conv_bigger.VAE_CNN_version_2().to(device)
optimizer = optim.AdamW(model.parameters(), lr=lr)
criterion = nn.BCELoss(reduction='sum')
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                         mode='min',
                                                         factor=0.2,
                                                         patience=20,
                                                         min_lr=5e-5)
# Out:
# 173056
# (64, 64)

# %%
#model = torch.load("/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/models/VAE_conv_PSF_1.pt")

# %%
def final_loss(bce_loss, mu, logvar, beta=1):
    """
    This function will add the reconstruction loss (BCELoss) and the 
    KL-Divergence.
    KL-Divergence = 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)

    A beta here will affect how much the KLD matters

    :param bce_loss: recontruction loss
    :param mu: the mean from the latent vector
    :param logvar: log variance from the latent vector
    """
    BCE = bce_loss 
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    

    return BCE + KLD*beta, BCE, KLD

# %%
def fit(model, dataloader, beta=1):
    model.train()
    running_loss = 0.0
    for i in range((64*64)//batch_size):
        data = create_psf_batch()
        data, xyz, _ = data
        data = data.to(device)
        #data = data.view(data.size(0), -1)
        optimizer.zero_grad()
        reconstruction, mu, logvar = model(data)
        bce_loss = criterion(reconstruction, data)
        loss, BCE, KLD = final_loss(bce_loss, mu, logvar, beta)
        running_loss += loss.item()
        loss.backward()
        optimizer.step()

    train_loss = running_loss/(64*64)
    return train_loss

# %%
def validate(model, dataloader):
    model.eval()
    running_loss = 0.0
    running_BCE = 0.0
    running_KLD = 0.0
    with torch.no_grad():
        for i in range((64*64)//batch_size):
            data = create_psf_batch()
            data, xys, _ = data
            data = data.to(device)
            #data = data.view(data.size(0), -1)
            reconstruction, mu, logvar = model(data)
            bce_loss = criterion(reconstruction, data)
            loss, BCE, KLD = final_loss(bce_loss, mu, logvar)
            running_loss += loss.item()
            running_BCE += BCE.item()
            running_KLD += KLD.item()
            # save the last batch input and output of every epoch
            save_mod = (1+1*epoch//10) if epoch < 100 else 10
            if ((64*64)//batch_size - 1) and (epoch % save_mod == 0):
                #plt.imshow(data.view(batch_size, 1, 64, 64)[0,0,...].cpu().detach().numpy(), cmap='gray')
                num_rows = 8
                both = torch.cat((data.view(batch_size, 1, 64, 64)[:8], 
                                  reconstruction.view(batch_size, 1, 64, 64)[:8]))
                save_image(both.cpu(), f"/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/resnet_conv/psf_resnet_zonly_B{beta}_{epoch}.png", nrow=num_rows, pad_value=1)

    val_loss = running_loss/(64*64)
    bce_loss_tot = running_BCE/(64*64)
    kld_loss = running_KLD/(64*64)
    return val_loss, mu, xys, bce_loss_tot, kld_loss

# %%
#train_loss = []
#val_loss = []
#bce_loss_list = []
#kld_loss_list = []


betas = [1, 2, 4, 6]
train_losses = [[] for i in range(len(betas))]
for i in range(len(betas)):
    beta = betas[i]
    batch_size = 128


    
    curr = 0
    epochs = 200

    lr = 0.001
    model = model_conv_bigger.VAE_CNN_version_2(zDim=1).to(device)
    optimizer = optim.AdamW(model.parameters(), lr=lr)
    criterion = nn.BCELoss(reduction='sum')
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                        mode='min',
                                                        factor=0.2,
                                                        patience=20,
                                                        min_lr=5e-5)


    for epoch in range(curr, curr+epochs+1):
        print(f"Epoch {epoch+1} of {epochs},beta = {beta}")
        train_epoch_loss = fit(model, 0, beta=beta)
        val_epoch_loss, mu, xys, bce_loss, kld_loss = validate(model, 0)
        bce_loss_list.append(bce_loss)
        kld_loss_list.append(kld_loss)
        train_losses[i].append(train_epoch_loss)
        val_loss.append(val_epoch_loss)
        print(f"Train Loss: {train_epoch_loss:.4f}")
        print(f"BCE: {bce_loss:.4f}, KLD: {kld_loss:.4f}")
        if epoch % 100 == 0:
            torch.save(model.state_dict(), f"/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/models/Resnet_B{beta}_VAE_z_only_{epoch}.pt")
# Out:
# 173056
# (64, 64)
# Epoch 1 of 200,beta = 1
# Train Loss: 3331.1045
# BCE: 2688.7684, KLD: 1.2968
# Epoch 2 of 200,beta = 1
# Train Loss: 2206.3267
# BCE: 1893.4329, KLD: 2.6153
# Epoch 3 of 200,beta = 1
# Train Loss: 1509.1396
# BCE: 1247.5636, KLD: 2.8197
# Epoch 4 of 200,beta = 1
# Train Loss: 1036.7889
# BCE: 865.6854, KLD: 2.7700
# Epoch 5 of 200,beta = 1
# Train Loss: 752.1289
# BCE: 644.6423, KLD: 2.5449
# Epoch 6 of 200,beta = 1
# Train Loss: 574.9620
# BCE: 505.5444, KLD: 2.4295
# Epoch 7 of 200,beta = 1
# Train Loss: 460.5645
# BCE: 413.3626, KLD: 2.3368
# Epoch 8 of 200,beta = 1
# Train Loss: 384.6931
# BCE: 352.8577, KLD: 2.2715
# Epoch 9 of 200,beta = 1
# Train Loss: 333.4951
# BCE: 311.4624, KLD: 2.1338
# Epoch 10 of 200,beta = 1
# Train Loss: 297.6168
# BCE: 281.5014, KLD: 2.0295
# Epoch 11 of 200,beta = 1
# Train Loss: 271.7325
# BCE: 259.6153, KLD: 1.9455
# Epoch 12 of 200,beta = 1
# Train Loss: 252.8394
# BCE: 243.0442, KLD: 1.8711
# Epoch 13 of 200,beta = 1
# Train Loss: 238.1617
# BCE: 229.8656, KLD: 1.9010
# Epoch 14 of 200,beta = 1
# Train Loss: 225.9445
# BCE: 218.9465, KLD: 2.1507
# Epoch 15 of 200,beta = 1
# Train Loss: 216.3215
# BCE: 210.6369, KLD: 2.2480
# Epoch 16 of 200,beta = 1
# Train Loss: 208.9935
# BCE: 203.9819, KLD: 2.2599
# Epoch 17 of 200,beta = 1
# Train Loss: 202.9987
# BCE: 198.5738, KLD: 2.2847
# Epoch 18 of 200,beta = 1
# Train Loss: 197.9120
# BCE: 194.2242, KLD: 2.2858
# Epoch 19 of 200,beta = 1
# Train Loss: 194.1815
# BCE: 190.6195, KLD: 2.2498
# Epoch 20 of 200,beta = 1
# Train Loss: 190.6178
# BCE: 186.7670, KLD: 2.2317
# Epoch 21 of 200,beta = 1
# Train Loss: 187.5553
# BCE: 184.6105, KLD: 2.2569
# Epoch 22 of 200,beta = 1
# Train Loss: 184.7813
# BCE: 181.4458, KLD: 2.2364
# Epoch 23 of 200,beta = 1
# Train Loss: 182.7757
# BCE: 179.5440, KLD: 2.2417
# Epoch 24 of 200,beta = 1
# Train Loss: 180.7330
# BCE: 176.9698, KLD: 2.2989
# Epoch 25 of 200,beta = 1
# Train Loss: 179.2769
# BCE: 175.7937, KLD: 2.3347
# Epoch 26 of 200,beta = 1
# Train Loss: 177.3025
# BCE: 174.4768, KLD: 2.3068
# Epoch 27 of 200,beta = 1
# Train Loss: 176.6029
# BCE: 173.2695, KLD: 2.3095
# Epoch 28 of 200,beta = 1
# Train Loss: 174.8324
# BCE: 172.2428, KLD: 2.3533
# Epoch 29 of 200,beta = 1
# Train Loss: 173.6698
# BCE: 170.7315, KLD: 2.2837
# Epoch 30 of 200,beta = 1
# Train Loss: 172.8308
# BCE: 170.4708, KLD: 2.2951
# Epoch 31 of 200,beta = 1
# Train Loss: 171.5929
# BCE: 168.8479, KLD: 2.2777
# Epoch 32 of 200,beta = 1
# Train Loss: 170.7093
# BCE: 168.5935, KLD: 2.2561
# Epoch 33 of 200,beta = 1
# Train Loss: 170.6128
# BCE: 167.7468, KLD: 2.2651
# Epoch 34 of 200,beta = 1
# Train Loss: 169.9381
# BCE: 167.4033, KLD: 2.2412
# Epoch 35 of 200,beta = 1
# Train Loss: 169.3708
# BCE: 166.3380, KLD: 2.2313
# Epoch 36 of 200,beta = 1
# Train Loss: 168.8947
# BCE: 166.2799, KLD: 2.1887
# Epoch 37 of 200,beta = 1
# Train Loss: 168.0098
# BCE: 165.2131, KLD: 2.1662
# Epoch 38 of 200,beta = 1
# Train Loss: 167.6016
# BCE: 164.9756, KLD: 2.2243
# Epoch 39 of 200,beta = 1
# Train Loss: 167.3964
# BCE: 165.6663, KLD: 2.1630
# Epoch 40 of 200,beta = 1
# Train Loss: 166.8858
# BCE: 164.8964, KLD: 2.1457
# Epoch 41 of 200,beta = 1
# Train Loss: 166.1002
# BCE: 164.3199, KLD: 2.1348
# Epoch 42 of 200,beta = 1
# Train Loss: 166.4108
# BCE: 163.9765, KLD: 2.1287
# Epoch 43 of 200,beta = 1
# Train Loss: 165.9796
# BCE: 163.7632, KLD: 2.1180
# Epoch 44 of 200,beta = 1
# Train Loss: 165.6763
# BCE: 163.9604, KLD: 2.1115
# Epoch 45 of 200,beta = 1
# Train Loss: 164.8636
# BCE: 163.5844, KLD: 2.0855
# Epoch 46 of 200,beta = 1
# Train Loss: 165.1371
# BCE: 162.9968, KLD: 2.0958
# Epoch 47 of 200,beta = 1
# Train Loss: 164.7315
# BCE: 162.4064, KLD: 2.0953
# Epoch 48 of 200,beta = 1
# Train Loss: 164.7667
# BCE: 162.6461, KLD: 1.9828
# Epoch 49 of 200,beta = 1
# Train Loss: 164.7018
# BCE: 162.3836, KLD: 2.0677
# Epoch 50 of 200,beta = 1
# Train Loss: 164.4508
# BCE: 162.4817, KLD: 2.0166
# Epoch 51 of 200,beta = 1
# Train Loss: 163.9024
# BCE: 162.2955, KLD: 1.9835
# Epoch 52 of 200,beta = 1
# Train Loss: 163.8719
# BCE: 161.9795, KLD: 2.0434
# Epoch 53 of 200,beta = 1
# Train Loss: 163.7038
# BCE: 161.7553, KLD: 1.9985
# Epoch 54 of 200,beta = 1
# Train Loss: 163.8257
# BCE: 161.0027, KLD: 1.9984
# Epoch 55 of 200,beta = 1
# Train Loss: 163.3298
# BCE: 161.5232, KLD: 1.9802
# Epoch 56 of 200,beta = 1
# Train Loss: 163.1753
# BCE: 161.4223, KLD: 1.8965
# Epoch 57 of 200,beta = 1
# Train Loss: 162.8900
# BCE: 160.9776, KLD: 1.9255
# Epoch 58 of 200,beta = 1
# Train Loss: 162.8880
# BCE: 160.6871, KLD: 1.9399
# Epoch 59 of 200,beta = 1
# Train Loss: 162.6431
# BCE: 160.5903, KLD: 1.9600
# Epoch 60 of 200,beta = 1
# Train Loss: 162.5886
# BCE: 161.1143, KLD: 1.8875
# Epoch 61 of 200,beta = 1
# Train Loss: 162.6764
# BCE: 160.5279, KLD: 1.9002
# Epoch 62 of 200,beta = 1
# Train Loss: 162.4564
# BCE: 160.1488, KLD: 1.9418
# Epoch 63 of 200,beta = 1
# Train Loss: 162.5793
# BCE: 160.7076, KLD: 1.8696
# Epoch 64 of 200,beta = 1
# Train Loss: 162.4736
# BCE: 159.9654, KLD: 1.8348
# Epoch 65 of 200,beta = 1
# Train Loss: 162.1800
# BCE: 159.9591, KLD: 1.8822
# Epoch 66 of 200,beta = 1
# Train Loss: 162.2163
# BCE: 160.6516, KLD: 1.8359
# Epoch 67 of 200,beta = 1
# Train Loss: 162.0013
# BCE: 159.9724, KLD: 1.8221
# Epoch 68 of 200,beta = 1
# Train Loss: 162.0241
# BCE: 160.3658, KLD: 1.8509
# Epoch 69 of 200,beta = 1
# Train Loss: 161.4829
# BCE: 159.8119, KLD: 1.8491
# Epoch 70 of 200,beta = 1
# Train Loss: 162.2283
# BCE: 159.8519, KLD: 1.8393
# Epoch 71 of 200,beta = 1
# Train Loss: 161.3795
# BCE: 159.6372, KLD: 1.8740
# Epoch 72 of 200,beta = 1
# Train Loss: 161.6859
# BCE: 159.8884, KLD: 1.8167
# Epoch 73 of 200,beta = 1
# Train Loss: 161.9682
# BCE: 159.8916, KLD: 1.7867
# Epoch 74 of 200,beta = 1
# Train Loss: 161.5180
# BCE: 159.3400, KLD: 1.7435
# Epoch 75 of 200,beta = 1
# Train Loss: 161.3908
# BCE: 159.9978, KLD: 1.7868
# Epoch 76 of 200,beta = 1
# Train Loss: 161.6105
# BCE: 159.7918, KLD: 1.7352
# Epoch 77 of 200,beta = 1
# Train Loss: 161.3129
# BCE: 159.7821, KLD: 1.7672
# Epoch 78 of 200,beta = 1
# Train Loss: 161.0450
# BCE: 159.0049, KLD: 1.7907
# Epoch 79 of 200,beta = 1
# Train Loss: 161.6861
# BCE: 159.4744, KLD: 1.8196
# Epoch 80 of 200,beta = 1
# Train Loss: 161.6668
# BCE: 159.1784, KLD: 1.7631
# Epoch 81 of 200,beta = 1
# Train Loss: 161.0383
# BCE: 159.4466, KLD: 1.7370
# Epoch 82 of 200,beta = 1
# Train Loss: 160.6118
# BCE: 159.4938, KLD: 1.7466
# Epoch 83 of 200,beta = 1
# Train Loss: 161.0149
# BCE: 159.3325, KLD: 1.7194
# Epoch 84 of 200,beta = 1
# Train Loss: 161.1326
# BCE: 159.6915, KLD: 1.8158
# Epoch 85 of 200,beta = 1
# Train Loss: 160.5489
# BCE: 159.0168, KLD: 1.7630
# Epoch 86 of 200,beta = 1
# Train Loss: 160.4928
# BCE: 159.0142, KLD: 1.7214
# Epoch 87 of 200,beta = 1
# Train Loss: 160.9830
# BCE: 159.4393, KLD: 1.7180
# Epoch 88 of 200,beta = 1
# Train Loss: 160.6102
# BCE: 159.0407, KLD: 1.7028
# Epoch 89 of 200,beta = 1
# Train Loss: 160.9541
# BCE: 158.6812, KLD: 1.6907
# Epoch 90 of 200,beta = 1
# Train Loss: 161.0841
# BCE: 159.1948, KLD: 1.7576
# Epoch 91 of 200,beta = 1
# Train Loss: 160.6465
# BCE: 159.4303, KLD: 1.7176
# Epoch 92 of 200,beta = 1
# Train Loss: 160.5883
# BCE: 159.0435, KLD: 1.6699
# Epoch 93 of 200,beta = 1
# Train Loss: 160.5640
# BCE: 159.3373, KLD: 1.6602
# Epoch 94 of 200,beta = 1
# Train Loss: 161.1924
# BCE: 158.9748, KLD: 1.7290
# Epoch 95 of 200,beta = 1
# Train Loss: 160.4346
# BCE: 159.0395, KLD: 1.6639
# Epoch 96 of 200,beta = 1
# Train Loss: 160.8425
# BCE: 159.0975, KLD: 1.6954
# Epoch 97 of 200,beta = 1
# Train Loss: 160.3600
# BCE: 158.8536, KLD: 1.7228
# Epoch 98 of 200,beta = 1
# Train Loss: 160.1554
# BCE: 159.0132, KLD: 1.6429
# Epoch 99 of 200,beta = 1
# Train Loss: 160.7566
# BCE: 158.4983, KLD: 1.6838
# Epoch 100 of 200,beta = 1
# Train Loss: 160.2738
# BCE: 158.5086, KLD: 1.6591
# Epoch 101 of 200,beta = 1
# Train Loss: 160.3247
# BCE: 158.7885, KLD: 1.7231
# Epoch 102 of 200,beta = 1
# Train Loss: 160.3988
# BCE: 158.7384, KLD: 1.6922
# Epoch 103 of 200,beta = 1
# Train Loss: 160.2425
# BCE: 158.7204, KLD: 1.6987
# Epoch 104 of 200,beta = 1
# Train Loss: 160.1885
# BCE: 158.1220, KLD: 1.6705
# Epoch 105 of 200,beta = 1
# Train Loss: 160.4518
# BCE: 158.6365, KLD: 1.6924
# Epoch 106 of 200,beta = 1
# Train Loss: 160.5685
# BCE: 159.1776, KLD: 1.6414
# Epoch 107 of 200,beta = 1
# Train Loss: 160.3461
# BCE: 158.6186, KLD: 1.6769
# Epoch 108 of 200,beta = 1
# Train Loss: 160.4597
# BCE: 158.4381, KLD: 1.7044
# Epoch 109 of 200,beta = 1
# Train Loss: 160.0165
# BCE: 158.9046, KLD: 1.6472
# Epoch 110 of 200,beta = 1
# Train Loss: 160.2999
# BCE: 158.5912, KLD: 1.6689
# Epoch 111 of 200,beta = 1
# Train Loss: 160.4894
# BCE: 158.6935, KLD: 1.6642
# Epoch 112 of 200,beta = 1
# Train Loss: 160.1800
# BCE: 158.4159, KLD: 1.6934
# Epoch 113 of 200,beta = 1
# Train Loss: 159.8506
# BCE: 158.6346, KLD: 1.6249
# Epoch 114 of 200,beta = 1
# Train Loss: 159.9893
# BCE: 158.1834, KLD: 1.7574
# Epoch 115 of 200,beta = 1
# Train Loss: 160.3942
# BCE: 158.4020, KLD: 1.6594
# Epoch 116 of 200,beta = 1
# Train Loss: 159.8129
# BCE: 158.2260, KLD: 1.6430
# Epoch 117 of 200,beta = 1
# Train Loss: 160.1008
# BCE: 158.1461, KLD: 1.6515
# Epoch 118 of 200,beta = 1
# Train Loss: 159.7506
# BCE: 158.3581, KLD: 1.6507
# Epoch 119 of 200,beta = 1
# Train Loss: 159.8797
# BCE: 158.5905, KLD: 1.6631
# Epoch 120 of 200,beta = 1
# Train Loss: 159.9586
# BCE: 158.5228, KLD: 1.6719
# Epoch 121 of 200,beta = 1
# Train Loss: 159.9105
# BCE: 158.0443, KLD: 1.6889
# Epoch 122 of 200,beta = 1
# Train Loss: 160.5719
# BCE: 158.0134, KLD: 1.7137
# Epoch 123 of 200,beta = 1
# Train Loss: 159.7724
# BCE: 158.3322, KLD: 1.6474
# Epoch 124 of 200,beta = 1
# Train Loss: 160.1975
# BCE: 158.6305, KLD: 1.6741
# Epoch 125 of 200,beta = 1
# Train Loss: 160.3799
# BCE: 158.3142, KLD: 1.7425
# Epoch 126 of 200,beta = 1
# Train Loss: 160.1442
# BCE: 157.8117, KLD: 1.6613
# Epoch 127 of 200,beta = 1
# Train Loss: 160.5226
# BCE: 158.1137, KLD: 1.6570
# Epoch 128 of 200,beta = 1
# Train Loss: 160.2282
# BCE: 158.2443, KLD: 1.6195
# Epoch 129 of 200,beta = 1
# Train Loss: 159.8542
# BCE: 158.3319, KLD: 1.5841
# Epoch 130 of 200,beta = 1
# Train Loss: 159.7989
# BCE: 158.1792, KLD: 1.7136
# Epoch 131 of 200,beta = 1
# Train Loss: 160.0258
# BCE: 158.0584, KLD: 1.7002
# Epoch 132 of 200,beta = 1
# Train Loss: 159.9618
# BCE: 158.3428, KLD: 1.6168
# Epoch 133 of 200,beta = 1
# Train Loss: 160.1038
# BCE: 158.1160, KLD: 1.6388
# Epoch 134 of 200,beta = 1
# Train Loss: 159.6007
# BCE: 158.0206, KLD: 1.6924
# Epoch 135 of 200,beta = 1
# Train Loss: 159.7909
# BCE: 157.9246, KLD: 1.6800
# Epoch 136 of 200,beta = 1
# Train Loss: 159.9474
# BCE: 158.1835, KLD: 1.6618
# Epoch 137 of 200,beta = 1
# Train Loss: 159.9076
# BCE: 158.0803, KLD: 1.6939
# Epoch 138 of 200,beta = 1
# Train Loss: 159.6431
# BCE: 158.2390, KLD: 1.6434
# Epoch 139 of 200,beta = 1
# Train Loss: 159.8920
# BCE: 158.0031, KLD: 1.6900
# Epoch 140 of 200,beta = 1
# Train Loss: 160.3174
# BCE: 158.6895, KLD: 1.5590
# Epoch 141 of 200,beta = 1
# Train Loss: 160.0374
# BCE: 158.1254, KLD: 1.6545
# Epoch 142 of 200,beta = 1
# Train Loss: 160.0581
# BCE: 158.4710, KLD: 1.5584
# Epoch 143 of 200,beta = 1
# Train Loss: 160.1464
# BCE: 158.6099, KLD: 1.6595
# Epoch 144 of 200,beta = 1
# Train Loss: 159.7975
# BCE: 158.1796, KLD: 1.6719
# Epoch 145 of 200,beta = 1
# Train Loss: 159.8238
# BCE: 157.9205, KLD: 1.6702
# Epoch 146 of 200,beta = 1
# Train Loss: 159.1200
# BCE: 158.2180, KLD: 1.6257
# Epoch 147 of 200,beta = 1
# Train Loss: 159.3944
# BCE: 158.3429, KLD: 1.6593
# Epoch 148 of 200,beta = 1
# Train Loss: 159.9809
# BCE: 158.0581, KLD: 1.6262
# Epoch 149 of 200,beta = 1
# Train Loss: 159.6368
# BCE: 158.2664, KLD: 1.6345
# Epoch 150 of 200,beta = 1
# Train Loss: 159.4962
# BCE: 157.9130, KLD: 1.6084
# Epoch 151 of 200,beta = 1
# Train Loss: 159.5605
# BCE: 157.6497, KLD: 1.7234
# Epoch 152 of 200,beta = 1
# Train Loss: 159.3811
# BCE: 158.1987, KLD: 1.6698
# Epoch 153 of 200,beta = 1
# Train Loss: 159.2960
# BCE: 158.1158, KLD: 1.7362
# Epoch 154 of 200,beta = 1
# Train Loss: 159.4272
# BCE: 157.8038, KLD: 1.6259
# Epoch 155 of 200,beta = 1
# Train Loss: 159.3598
# BCE: 157.8276, KLD: 1.6650
# Epoch 156 of 200,beta = 1
# Train Loss: 159.4947
# BCE: 158.0816, KLD: 1.7052
# Epoch 157 of 200,beta = 1
# Train Loss: 159.7737
# BCE: 157.9803, KLD: 1.5941
# Epoch 158 of 200,beta = 1
# Train Loss: 159.8623
# BCE: 157.9624, KLD: 1.6968
# Epoch 159 of 200,beta = 1
# Train Loss: 159.4151
# BCE: 157.8225, KLD: 1.6765
# Epoch 160 of 200,beta = 1
# Train Loss: 159.7406
# BCE: 157.9666, KLD: 1.6109
# Epoch 161 of 200,beta = 1
# Train Loss: 158.9594
# BCE: 157.7231, KLD: 1.6752
# Epoch 162 of 200,beta = 1
# Train Loss: 159.7601
# BCE: 158.6301, KLD: 1.5800
# Epoch 163 of 200,beta = 1
# Train Loss: 159.8436
# BCE: 158.7624, KLD: 1.7246
# Epoch 164 of 200,beta = 1
# Train Loss: 159.5363
# BCE: 158.3317, KLD: 1.7426
# Epoch 165 of 200,beta = 1
# Train Loss: 159.6047
# BCE: 157.9460, KLD: 1.6164
# Epoch 166 of 200,beta = 1
# Train Loss: 159.2776
# BCE: 157.9702, KLD: 1.6348
# Epoch 167 of 200,beta = 1
# Train Loss: 159.9128
# BCE: 158.3329, KLD: 1.7042
# Epoch 168 of 200,beta = 1
# Train Loss: 159.7991
# BCE: 158.1632, KLD: 1.6998
# Epoch 169 of 200,beta = 1
# Train Loss: 159.4510
# BCE: 157.8916, KLD: 1.6340
# Epoch 170 of 200,beta = 1
# Train Loss: 159.4077
# BCE: 158.2369, KLD: 1.5921
# Epoch 171 of 200,beta = 1
# Train Loss: 159.6337
# BCE: 157.8028, KLD: 1.6342
# Epoch 172 of 200,beta = 1
# Train Loss: 159.6659
# BCE: 157.7378, KLD: 1.6117
# Epoch 173 of 200,beta = 1
# Train Loss: 159.4498
# BCE: 157.7473, KLD: 1.6707
# Epoch 174 of 200,beta = 1
# Train Loss: 159.9798
# BCE: 157.5910, KLD: 1.6687
# Epoch 175 of 200,beta = 1
# Train Loss: 159.4556
# BCE: 158.1141, KLD: 1.7101
# Epoch 176 of 200,beta = 1
# Train Loss: 159.6918
# BCE: 158.1034, KLD: 1.6662
# Epoch 177 of 200,beta = 1
# Train Loss: 159.8921
# BCE: 158.3305, KLD: 1.6389
# Epoch 178 of 200,beta = 1
# Train Loss: 160.1506
# BCE: 158.0972, KLD: 1.7303
# Epoch 179 of 200,beta = 1
# Train Loss: 159.7962
# BCE: 157.7340, KLD: 1.5731
# Epoch 180 of 200,beta = 1
# Train Loss: 159.3700
# BCE: 158.1734, KLD: 1.7019
# Epoch 181 of 200,beta = 1
# Train Loss: 159.4249
# BCE: 157.6532, KLD: 1.6319
# Epoch 182 of 200,beta = 1
# Train Loss: 159.5892
# BCE: 157.9443, KLD: 1.6509
# Epoch 183 of 200,beta = 1
# Train Loss: 159.3788
# BCE: 158.3060, KLD: 1.6513
# Epoch 184 of 200,beta = 1
# Train Loss: 159.2589
# BCE: 157.6331, KLD: 1.7174
# Epoch 185 of 200,beta = 1
# Train Loss: 159.5004
# BCE: 158.2136, KLD: 1.7037
# Epoch 186 of 200,beta = 1
# Train Loss: 159.6636
# BCE: 157.6100, KLD: 1.6024
# Epoch 187 of 200,beta = 1
# Train Loss: 159.2622
# BCE: 158.0066, KLD: 1.6341
# Epoch 188 of 200,beta = 1
# Train Loss: 159.1431
# BCE: 157.5219, KLD: 1.6495
# Epoch 189 of 200,beta = 1
# Train Loss: 159.0321
# BCE: 158.1186, KLD: 1.6661
# Epoch 190 of 200,beta = 1
# Train Loss: 159.4193
# BCE: 157.4737, KLD: 1.7127
# Epoch 191 of 200,beta = 1
# Train Loss: 159.9870
# BCE: 157.5713, KLD: 1.6491
# Epoch 192 of 200,beta = 1
# Train Loss: 159.7114
# BCE: 157.9794, KLD: 1.5842
# Epoch 193 of 200,beta = 1
# Train Loss: 159.5818
# BCE: 158.1206, KLD: 1.6373
# Epoch 194 of 200,beta = 1
# Train Loss: 159.4189
# BCE: 157.7769, KLD: 1.6393
# Epoch 195 of 200,beta = 1
# Train Loss: 159.5762
# BCE: 157.6130, KLD: 1.7321
# Epoch 196 of 200,beta = 1
# Train Loss: 159.3227
# BCE: 157.9168, KLD: 1.6867
# Epoch 197 of 200,beta = 1
# Train Loss: 159.3674
# BCE: 157.9271, KLD: 1.7167
# Epoch 198 of 200,beta = 1
# Train Loss: 159.3346
# BCE: 157.8308, KLD: 1.6531
# Epoch 199 of 200,beta = 1
# Train Loss: 159.6736
# BCE: 158.1483, KLD: 1.6576
# Epoch 200 of 200,beta = 1
# Train Loss: 159.5322
# BCE: 157.7386, KLD: 1.6431
# Epoch 201 of 200,beta = 1
# Train Loss: 159.3897
# BCE: 157.7645, KLD: 1.6664
# 173056
# (64, 64)
# Epoch 1 of 200,beta = 2
# Train Loss: 2494.7873
# BCE: 1978.6111, KLD: 0.5131
# Epoch 2 of 200,beta = 2
# Train Loss: 1584.3766
# BCE: 1351.7493, KLD: 1.7595
# Epoch 3 of 200,beta = 2
# Train Loss: 1103.5295
# BCE: 922.3538, KLD: 2.0711
# Epoch 4 of 200,beta = 2
# Train Loss: 774.8035
# BCE: 659.8273, KLD: 1.9545
# Epoch 5 of 200,beta = 2
# Train Loss: 572.7024
# BCE: 503.6185, KLD: 1.8173
# Epoch 6 of 200,beta = 2
# Train Loss: 450.2503
# BCE: 404.5237, KLD: 1.7121
# Epoch 7 of 200,beta = 2
# Train Loss: 372.4744
# BCE: 341.2280, KLD: 1.6312
# Epoch 8 of 200,beta = 2
# Train Loss: 321.8232
# BCE: 299.1408, KLD: 1.5716
# Epoch 9 of 200,beta = 2
# Train Loss: 286.3831
# BCE: 269.5620, KLD: 1.4946
# Epoch 10 of 200,beta = 2
# Train Loss: 261.1911
# BCE: 248.4554, KLD: 1.4330
# Epoch 11 of 200,beta = 2
# Train Loss: 242.8678
# BCE: 232.9836, KLD: 1.3706
# Epoch 12 of 200,beta = 2
# Train Loss: 228.9210
# BCE: 221.2777, KLD: 1.2381
# Epoch 13 of 200,beta = 2
# Train Loss: 218.9183
# BCE: 211.5303, KLD: 1.2356
# Epoch 14 of 200,beta = 2
# Train Loss: 209.9929
# BCE: 204.9125, KLD: 1.2126
# Epoch 15 of 200,beta = 2
# Train Loss: 203.6997
# BCE: 198.9414, KLD: 1.2670
# Epoch 16 of 200,beta = 2
# Train Loss: 198.5880
# BCE: 194.0308, KLD: 1.3453
# Epoch 17 of 200,beta = 2
# Train Loss: 193.6709
# BCE: 189.3321, KLD: 1.3592
# Epoch 18 of 200,beta = 2
# Train Loss: 189.7731
# BCE: 185.7634, KLD: 1.3902
# Epoch 19 of 200,beta = 2
# Train Loss: 186.8833
# BCE: 182.6634, KLD: 1.4758
# Epoch 20 of 200,beta = 2
# Train Loss: 184.7543
# BCE: 181.2631, KLD: 1.3671
# Epoch 21 of 200,beta = 2
# Train Loss: 182.4613
# BCE: 178.6136, KLD: 1.3452
# Epoch 22 of 200,beta = 2
# Train Loss: 180.2586
# BCE: 177.8719, KLD: 1.3230
# Epoch 23 of 200,beta = 2
# Train Loss: 178.8335
# BCE: 175.1080, KLD: 1.3049
# Epoch 24 of 200,beta = 2
# Train Loss: 177.6396
# BCE: 174.0405, KLD: 1.3671
# Epoch 25 of 200,beta = 2
# Train Loss: 176.0985
# BCE: 173.1026, KLD: 1.3137
# Epoch 26 of 200,beta = 2
# Train Loss: 174.9115
# BCE: 171.6906, KLD: 1.3549
# Epoch 27 of 200,beta = 2
# Train Loss: 174.1933
# BCE: 170.8644, KLD: 1.2902
# Epoch 28 of 200,beta = 2
# Train Loss: 172.6351
# BCE: 170.5149, KLD: 1.3236
# Epoch 29 of 200,beta = 2
# Train Loss: 172.4297
# BCE: 169.1127, KLD: 1.3445
# Epoch 30 of 200,beta = 2
# Train Loss: 171.4341
# BCE: 168.1106, KLD: 1.4041
# Epoch 31 of 200,beta = 2
# Train Loss: 170.4632
# BCE: 167.2782, KLD: 1.3749
# Epoch 32 of 200,beta = 2
# Train Loss: 169.7979
# BCE: 166.4540, KLD: 1.3534
# Epoch 33 of 200,beta = 2
# Train Loss: 169.2413
# BCE: 166.5936, KLD: 1.3929
# Epoch 34 of 200,beta = 2
# Train Loss: 169.0033
# BCE: 166.1816, KLD: 1.3621
# Epoch 35 of 200,beta = 2
# Train Loss: 168.2711
# BCE: 165.7369, KLD: 1.3248
# Epoch 36 of 200,beta = 2
# Train Loss: 167.9670
# BCE: 164.8502, KLD: 1.3697
# Epoch 37 of 200,beta = 2
# Train Loss: 167.4706
# BCE: 164.7321, KLD: 1.3421
# Epoch 38 of 200,beta = 2
# Train Loss: 167.0685
# BCE: 163.8342, KLD: 1.3218
# Epoch 39 of 200,beta = 2
# Train Loss: 166.6868
# BCE: 164.0432, KLD: 1.3532
# Epoch 40 of 200,beta = 2
# Train Loss: 166.7870
# BCE: 163.7827, KLD: 1.4001
# Epoch 41 of 200,beta = 2
# Train Loss: 166.2481
# BCE: 163.5569, KLD: 1.3208
# Epoch 42 of 200,beta = 2
# Train Loss: 165.8896
# BCE: 163.6595, KLD: 1.2984
# Epoch 43 of 200,beta = 2
# Train Loss: 165.7454
# BCE: 163.3992, KLD: 1.2856
# Epoch 44 of 200,beta = 2
# Train Loss: 165.4730
# BCE: 162.3994, KLD: 1.3456
# Epoch 45 of 200,beta = 2
# Train Loss: 165.4387
# BCE: 162.8760, KLD: 1.3077
# Epoch 46 of 200,beta = 2
# Train Loss: 165.0454
# BCE: 162.8181, KLD: 1.2863
# Epoch 47 of 200,beta = 2
# Train Loss: 165.0203
# BCE: 163.1084, KLD: 1.2678
# Epoch 48 of 200,beta = 2
# Train Loss: 164.8772
# BCE: 162.2330, KLD: 1.2320
# Epoch 49 of 200,beta = 2
# Train Loss: 165.2297
# BCE: 161.9522, KLD: 1.3097
# Epoch 50 of 200,beta = 2
# Train Loss: 164.6104
# BCE: 161.7438, KLD: 1.2723
# Epoch 51 of 200,beta = 2
# Train Loss: 164.4184
# BCE: 161.8178, KLD: 1.3314
# Epoch 52 of 200,beta = 2
# Train Loss: 164.1491
# BCE: 161.9260, KLD: 1.3244
# Epoch 53 of 200,beta = 2
# Train Loss: 164.1281
# BCE: 162.1840, KLD: 1.2716
# Epoch 54 of 200,beta = 2
# Train Loss: 164.1512
# BCE: 161.5157, KLD: 1.2583
# Epoch 55 of 200,beta = 2
# Train Loss: 163.6950
# BCE: 160.9471, KLD: 1.3001
# Epoch 56 of 200,beta = 2
# Train Loss: 163.5951
# BCE: 161.6791, KLD: 1.2830
# Epoch 57 of 200,beta = 2
# Train Loss: 163.4574
# BCE: 161.2660, KLD: 1.3288
# Epoch 58 of 200,beta = 2
# Train Loss: 163.3524
# BCE: 161.0453, KLD: 1.3050
# Epoch 59 of 200,beta = 2
# Train Loss: 163.7249
# BCE: 160.9239, KLD: 1.2179
# Epoch 60 of 200,beta = 2
# Train Loss: 163.1372
# BCE: 160.8307, KLD: 1.2917
# Epoch 61 of 200,beta = 2
# Train Loss: 163.6220
# BCE: 160.6718, KLD: 1.2665
# Epoch 62 of 200,beta = 2
# Train Loss: 163.3897
# BCE: 160.3055, KLD: 1.3962
# Epoch 63 of 200,beta = 2
# Train Loss: 163.3581
# BCE: 161.6508, KLD: 1.1561
# Epoch 64 of 200,beta = 2
# Train Loss: 163.4276
# BCE: 160.5398, KLD: 1.2769
# Epoch 65 of 200,beta = 2
# Train Loss: 162.6268
# BCE: 160.3030, KLD: 1.2034
# Epoch 66 of 200,beta = 2
# Train Loss: 162.9079
# BCE: 160.4821, KLD: 1.2304
# Epoch 67 of 200,beta = 2
# Train Loss: 162.5706
# BCE: 160.5808, KLD: 1.2391
# Epoch 68 of 200,beta = 2
# Train Loss: 162.7777
# BCE: 160.1567, KLD: 1.2158
# Epoch 69 of 200,beta = 2
# Train Loss: 162.7236
# BCE: 160.1318, KLD: 1.2366
# Epoch 70 of 200,beta = 2
# Train Loss: 163.0559
# BCE: 160.0475, KLD: 1.2617
# Epoch 71 of 200,beta = 2
# Train Loss: 162.4309
# BCE: 160.5914, KLD: 1.3246
# Epoch 72 of 200,beta = 2
# Train Loss: 162.9703
# BCE: 160.2151, KLD: 1.2681
# Epoch 73 of 200,beta = 2
# Train Loss: 162.6429
# BCE: 159.8636, KLD: 1.2538
# Epoch 74 of 200,beta = 2
# Train Loss: 162.5604
# BCE: 160.4186, KLD: 1.2568
# Epoch 75 of 200,beta = 2
# Train Loss: 162.4496
# BCE: 159.9821, KLD: 1.2334
# Epoch 76 of 200,beta = 2
# Train Loss: 162.5556
# BCE: 160.3992, KLD: 1.2626
# Epoch 77 of 200,beta = 2
# Train Loss: 162.2045
# BCE: 160.3144, KLD: 1.3106
# Epoch 78 of 200,beta = 2
# Train Loss: 162.3173
# BCE: 159.8954, KLD: 1.2621
# Epoch 79 of 200,beta = 2
# Train Loss: 162.7803
# BCE: 159.5737, KLD: 1.2668
# Epoch 80 of 200,beta = 2
# Train Loss: 162.7476
# BCE: 159.5390, KLD: 1.3079
# Epoch 81 of 200,beta = 2
# Train Loss: 162.3714
# BCE: 159.8217, KLD: 1.2209
# Epoch 82 of 200,beta = 2
# Train Loss: 162.2638
# BCE: 159.6651, KLD: 1.3212
# Epoch 83 of 200,beta = 2
# Train Loss: 162.1712
# BCE: 159.6382, KLD: 1.2561
# Epoch 84 of 200,beta = 2
# Train Loss: 162.5401
# BCE: 159.5329, KLD: 1.2292
# Epoch 85 of 200,beta = 2
# Train Loss: 162.1650
# BCE: 159.7742, KLD: 1.2254
# Epoch 86 of 200,beta = 2
# Train Loss: 161.8832
# BCE: 159.4964, KLD: 1.2431
# Epoch 87 of 200,beta = 2
# Train Loss: 161.6640
# BCE: 159.6554, KLD: 1.2016
# Epoch 88 of 200,beta = 2
# Train Loss: 161.6217
# BCE: 160.0077, KLD: 1.2473
# Epoch 89 of 200,beta = 2
# Train Loss: 162.0899
# BCE: 159.3247, KLD: 1.2626
# Epoch 90 of 200,beta = 2
# Train Loss: 162.2370
# BCE: 159.5861, KLD: 1.2427
# Epoch 91 of 200,beta = 2
# Train Loss: 161.4796
# BCE: 159.6676, KLD: 1.2519
# Epoch 92 of 200,beta = 2
# Train Loss: 162.1585
# BCE: 159.1943, KLD: 1.3056
# Epoch 93 of 200,beta = 2
# Train Loss: 162.3500
# BCE: 159.3014, KLD: 1.2570
# Epoch 94 of 200,beta = 2
# Train Loss: 162.0606
# BCE: 159.7801, KLD: 1.2478
# Epoch 95 of 200,beta = 2
# Train Loss: 161.4120
# BCE: 158.8320, KLD: 1.2771
# Epoch 96 of 200,beta = 2
# Train Loss: 161.7238
# BCE: 159.2490, KLD: 1.2087
# Epoch 97 of 200,beta = 2
# Train Loss: 161.7706
# BCE: 158.9814, KLD: 1.2115
# Epoch 98 of 200,beta = 2
# Train Loss: 162.0832
# BCE: 159.6158, KLD: 1.1768
# Epoch 99 of 200,beta = 2
# Train Loss: 161.6591
# BCE: 159.4561, KLD: 1.2499
# Epoch 100 of 200,beta = 2
# Train Loss: 161.9933
# BCE: 159.0792, KLD: 1.2858
# Epoch 101 of 200,beta = 2
# Train Loss: 161.6521
# BCE: 158.7862, KLD: 1.2506
# Epoch 102 of 200,beta = 2
# Train Loss: 161.3777
# BCE: 158.8486, KLD: 1.2430
# Epoch 103 of 200,beta = 2
# Train Loss: 161.5530
# BCE: 159.0941, KLD: 1.2044
# Epoch 104 of 200,beta = 2
# Train Loss: 161.6388
# BCE: 158.9146, KLD: 1.1980
# Epoch 105 of 200,beta = 2
# Train Loss: 161.9286
# BCE: 158.9498, KLD: 1.3349
# Epoch 106 of 200,beta = 2
# Train Loss: 161.6490
# BCE: 159.0232, KLD: 1.2186
# Epoch 107 of 200,beta = 2
# Train Loss: 161.3170
# BCE: 158.7317, KLD: 1.2354
# Epoch 108 of 200,beta = 2
# Train Loss: 161.6695
# BCE: 159.4171, KLD: 1.1594
# Epoch 109 of 200,beta = 2
# Train Loss: 161.7213
# BCE: 159.3833, KLD: 1.1633
# Epoch 110 of 200,beta = 2
# Train Loss: 162.0617
# BCE: 159.1105, KLD: 1.2152
# Epoch 111 of 200,beta = 2
# Train Loss: 161.9596
# BCE: 158.6585, KLD: 1.2221
# Epoch 112 of 200,beta = 2
# Train Loss: 161.6630
# BCE: 158.9012, KLD: 1.2649
# Epoch 113 of 200,beta = 2
# Train Loss: 161.3195
# BCE: 159.1597, KLD: 1.3000
# Epoch 114 of 200,beta = 2
# Train Loss: 161.5226
# BCE: 159.1959, KLD: 1.2361
# Epoch 115 of 200,beta = 2
# Train Loss: 161.4304
# BCE: 159.0192, KLD: 1.3459
# Epoch 116 of 200,beta = 2
# Train Loss: 161.3156
# BCE: 159.0317, KLD: 1.2436
# Epoch 117 of 200,beta = 2
# Train Loss: 161.2874
# BCE: 159.1299, KLD: 1.1877
# Epoch 118 of 200,beta = 2
# Train Loss: 161.4696
# BCE: 158.6587, KLD: 1.2863
# Epoch 119 of 200,beta = 2
# Train Loss: 160.9544
# BCE: 158.9516, KLD: 1.2065
# Epoch 120 of 200,beta = 2
# Train Loss: 161.5130
# BCE: 158.9433, KLD: 1.1917
# Epoch 121 of 200,beta = 2
# Train Loss: 161.2622
# BCE: 158.9150, KLD: 1.2065
# Epoch 122 of 200,beta = 2
# Train Loss: 161.6213
# BCE: 158.5276, KLD: 1.3114
# Epoch 123 of 200,beta = 2
# Train Loss: 161.4803
# BCE: 159.1551, KLD: 1.2281
# Epoch 124 of 200,beta = 2
# Train Loss: 161.0305
# BCE: 158.6918, KLD: 1.2603
# Epoch 125 of 200,beta = 2
# Train Loss: 161.0141
# BCE: 158.9248, KLD: 1.2419
# Epoch 126 of 200,beta = 2
# Train Loss: 162.0207
# BCE: 159.1596, KLD: 1.3058
# Epoch 127 of 200,beta = 2
# Train Loss: 161.1700
# BCE: 158.3714, KLD: 1.2679
# Epoch 128 of 200,beta = 2
# Train Loss: 160.8198
# BCE: 158.9927, KLD: 1.2219
# Epoch 129 of 200,beta = 2
# Train Loss: 161.7043
# BCE: 158.8591, KLD: 1.2890
# Epoch 130 of 200,beta = 2
# Train Loss: 161.0087
# BCE: 158.9755, KLD: 1.2484
# Epoch 131 of 200,beta = 2
# Train Loss: 161.6179
# BCE: 158.1222, KLD: 1.2324
# Epoch 132 of 200,beta = 2
# Train Loss: 161.3154
# BCE: 158.3392, KLD: 1.2508
# Epoch 133 of 200,beta = 2
# Train Loss: 160.8401
# BCE: 158.6993, KLD: 1.2518
# Epoch 134 of 200,beta = 2
# Train Loss: 161.4606
# BCE: 158.5866, KLD: 1.2631
# Epoch 135 of 200,beta = 2
# Train Loss: 161.2750
# BCE: 159.3232, KLD: 1.2073
# Epoch 136 of 200,beta = 2
# Train Loss: 161.3909
# BCE: 158.5983, KLD: 1.2897
# Epoch 137 of 200,beta = 2
# Train Loss: 161.9691
# BCE: 158.9755, KLD: 1.3421
# Epoch 138 of 200,beta = 2
# Train Loss: 161.1751
# BCE: 159.1539, KLD: 1.2335
# Epoch 139 of 200,beta = 2
# Train Loss: 161.1855
# BCE: 158.5948, KLD: 1.2200
# Epoch 140 of 200,beta = 2
# Train Loss: 161.5630
# BCE: 158.6511, KLD: 1.2510
# Epoch 141 of 200,beta = 2
# Train Loss: 161.4605
# BCE: 158.7268, KLD: 1.2513
# Epoch 142 of 200,beta = 2
# Train Loss: 161.0506
# BCE: 158.7692, KLD: 1.2321
# Epoch 143 of 200,beta = 2
# Train Loss: 161.2911
# BCE: 158.6947, KLD: 1.1950
# Epoch 144 of 200,beta = 2
# Train Loss: 160.8700
# BCE: 158.4072, KLD: 1.3559
# Epoch 145 of 200,beta = 2
# Train Loss: 161.7383
# BCE: 158.2667, KLD: 1.2799
# Epoch 146 of 200,beta = 2
# Train Loss: 161.0850
# BCE: 158.4611, KLD: 1.2420
# Epoch 147 of 200,beta = 2
# Train Loss: 161.0213
# BCE: 158.4172, KLD: 1.2561
# Epoch 148 of 200,beta = 2
# Train Loss: 161.8428
# BCE: 158.4813, KLD: 1.2647
# Epoch 149 of 200,beta = 2
# Train Loss: 161.3030
# BCE: 158.7777, KLD: 1.2415
# Epoch 150 of 200,beta = 2
# Train Loss: 161.0286
# BCE: 158.7858, KLD: 1.1854
# Epoch 151 of 200,beta = 2
# Train Loss: 161.0784
# BCE: 158.5428, KLD: 1.2070
# Epoch 152 of 200,beta = 2
# Train Loss: 160.7347
# BCE: 158.7119, KLD: 1.1965
# Epoch 153 of 200,beta = 2
# Train Loss: 160.8114
# BCE: 158.5864, KLD: 1.2199
# Epoch 154 of 200,beta = 2
# Train Loss: 160.8171
# BCE: 158.9174, KLD: 1.1818
# Epoch 155 of 200,beta = 2
# Train Loss: 161.1317
# BCE: 158.6748, KLD: 1.2299
# Epoch 156 of 200,beta = 2
# Train Loss: 160.9509
# BCE: 158.7882, KLD: 1.2291
# Epoch 157 of 200,beta = 2
# Train Loss: 161.3962
# BCE: 158.4519, KLD: 1.3165
# Epoch 158 of 200,beta = 2
# Train Loss: 161.3474
# BCE: 158.4652, KLD: 1.2588
# Epoch 159 of 200,beta = 2
# Train Loss: 161.2060
# BCE: 158.7671, KLD: 1.2386
# Epoch 160 of 200,beta = 2
# Train Loss: 160.8676
# BCE: 158.5862, KLD: 1.3423
# Epoch 161 of 200,beta = 2
# Train Loss: 161.2517
# BCE: 158.0914, KLD: 1.3011
# Epoch 162 of 200,beta = 2
# Train Loss: 161.5167
# BCE: 157.8255, KLD: 1.3137
# Epoch 163 of 200,beta = 2
# Train Loss: 161.3018
# BCE: 158.6056, KLD: 1.2875
# Epoch 164 of 200,beta = 2
# Train Loss: 161.5082
# BCE: 159.1316, KLD: 1.2221
# Epoch 165 of 200,beta = 2
# Train Loss: 161.5085
# BCE: 159.0411, KLD: 1.2752
# Epoch 166 of 200,beta = 2
# Train Loss: 160.9554
# BCE: 158.2908, KLD: 1.2368
# Epoch 167 of 200,beta = 2
# Train Loss: 161.3077
# BCE: 158.7179, KLD: 1.2112
# Epoch 168 of 200,beta = 2
# Train Loss: 161.0942
# BCE: 158.9754, KLD: 1.2105
# Epoch 169 of 200,beta = 2
# Train Loss: 160.7914
# BCE: 158.3141, KLD: 1.2404
# Epoch 170 of 200,beta = 2
# Train Loss: 161.2484
# BCE: 158.7390, KLD: 1.2799
# Epoch 171 of 200,beta = 2
# Train Loss: 160.7028
# BCE: 158.4747, KLD: 1.2899
# Epoch 172 of 200,beta = 2
# Train Loss: 161.0925
# BCE: 158.6123, KLD: 1.2938
# Epoch 173 of 200,beta = 2
# Train Loss: 161.2559
# BCE: 158.6298, KLD: 1.2715
# Epoch 174 of 200,beta = 2
# Train Loss: 161.1433
# BCE: 159.0824, KLD: 1.2320
# Epoch 175 of 200,beta = 2
# Train Loss: 161.0589
# BCE: 158.0027, KLD: 1.2648
# Epoch 176 of 200,beta = 2
# Train Loss: 161.2669
# BCE: 158.3450, KLD: 1.3691
# Epoch 177 of 200,beta = 2
# Train Loss: 160.6974
# BCE: 158.5028, KLD: 1.2012
# Epoch 178 of 200,beta = 2
# Train Loss: 161.5991
# BCE: 158.1174, KLD: 1.3256
# Epoch 179 of 200,beta = 2
# Train Loss: 161.1350
# BCE: 158.0505, KLD: 1.2247
# Epoch 180 of 200,beta = 2
# Train Loss: 160.6798
# BCE: 158.8146, KLD: 1.2236
# Epoch 181 of 200,beta = 2
# Train Loss: 160.8552
# BCE: 158.2411, KLD: 1.2156
# Epoch 182 of 200,beta = 2
# Train Loss: 160.8611
# BCE: 158.3060, KLD: 1.2129
# Epoch 183 of 200,beta = 2
# Train Loss: 160.3554
# BCE: 158.1886, KLD: 1.2894
# Epoch 184 of 200,beta = 2
# Train Loss: 161.1825
# BCE: 158.8189, KLD: 1.2655
# Epoch 185 of 200,beta = 2
# Train Loss: 160.9645
# BCE: 158.4660, KLD: 1.3536
# Epoch 186 of 200,beta = 2
# Train Loss: 161.2033
# BCE: 157.8768, KLD: 1.2211
# Epoch 187 of 200,beta = 2
# Train Loss: 160.7416
# BCE: 158.9611, KLD: 1.3682
# Epoch 188 of 200,beta = 2
# Train Loss: 161.2871
# BCE: 158.3506, KLD: 1.2626
# Epoch 189 of 200,beta = 2
# Train Loss: 160.9981
# BCE: 157.6919, KLD: 1.3016
# Epoch 190 of 200,beta = 2
# Train Loss: 161.4225
# BCE: 158.2299, KLD: 1.3394
# Epoch 191 of 200,beta = 2
# Train Loss: 160.6615
# BCE: 158.5665, KLD: 1.3430
# Epoch 192 of 200,beta = 2
# Train Loss: 161.5521
# BCE: 159.1994, KLD: 1.2131
# Epoch 193 of 200,beta = 2
# Train Loss: 161.2817
# BCE: 158.7536, KLD: 1.2606
# Epoch 194 of 200,beta = 2
# Train Loss: 161.4815
# BCE: 158.5679, KLD: 1.2324
# Epoch 195 of 200,beta = 2
# Train Loss: 161.2581
# BCE: 158.6213, KLD: 1.3578
# Epoch 196 of 200,beta = 2
# Train Loss: 160.4862
# BCE: 158.5653, KLD: 1.3985
# Epoch 197 of 200,beta = 2
# Train Loss: 160.0483
# BCE: 158.5194, KLD: 1.2695
# Epoch 198 of 200,beta = 2
# Train Loss: 160.5167
# BCE: 158.6828, KLD: 1.2302
# Epoch 199 of 200,beta = 2
# Train Loss: 160.5977
# BCE: 158.7179, KLD: 1.2960
# Epoch 200 of 200,beta = 2
# Train Loss: 160.7232
# BCE: 158.3978, KLD: 1.2300
# Epoch 201 of 200,beta = 2
# Train Loss: 160.6632
# BCE: 158.8753, KLD: 1.1621
# 173056
# (64, 64)
# Epoch 1 of 200,beta = 4
# Train Loss: 3672.4210
# BCE: 2941.4077, KLD: 0.5532
# Epoch 2 of 200,beta = 4
# Train Loss: 2359.3440
# BCE: 1952.4168, KLD: 1.5321
# Epoch 3 of 200,beta = 4
# Train Loss: 1627.4600
# BCE: 1343.3059, KLD: 1.7756
# Epoch 4 of 200,beta = 4
# Train Loss: 1157.6773
# BCE: 975.0024, KLD: 1.7227
# Epoch 5 of 200,beta = 4
# Train Loss: 857.5515
# BCE: 730.2483, KLD: 1.6455
# Epoch 6 of 200,beta = 4
# Train Loss: 659.2148
# BCE: 570.1098, KLD: 1.5955
# Epoch 7 of 200,beta = 4
# Train Loss: 526.4955
# BCE: 465.0123, KLD: 1.4486
# Epoch 8 of 200,beta = 4
# Train Loss: 437.7285
# BCE: 395.0212, KLD: 1.3547
# Epoch 9 of 200,beta = 4
# Train Loss: 376.6539
# BCE: 345.6940, KLD: 1.2947
# Epoch 10 of 200,beta = 4
# Train Loss: 333.3291
# BCE: 309.9022, KLD: 1.2354
# Epoch 11 of 200,beta = 4
# Train Loss: 301.6376
# BCE: 284.3164, KLD: 1.1887
# Epoch 12 of 200,beta = 4
# Train Loss: 277.9982
# BCE: 264.2077, KLD: 1.1023
# Epoch 13 of 200,beta = 4
# Train Loss: 259.6351
# BCE: 248.3594, KLD: 0.9830
# Epoch 14 of 200,beta = 4
# Train Loss: 245.6943
# BCE: 235.7467, KLD: 0.9832
# Epoch 15 of 200,beta = 4
# Train Loss: 233.9693
# BCE: 225.8956, KLD: 0.9947
# Epoch 16 of 200,beta = 4
# Train Loss: 225.4104
# BCE: 217.3638, KLD: 0.9285
# Epoch 17 of 200,beta = 4
# Train Loss: 217.7214
# BCE: 211.1939, KLD: 0.9104
# Epoch 18 of 200,beta = 4
# Train Loss: 211.1388
# BCE: 204.6714, KLD: 0.8844
# Epoch 19 of 200,beta = 4
# Train Loss: 205.8077
# BCE: 200.6524, KLD: 0.8562
# Epoch 20 of 200,beta = 4
# Train Loss: 201.1913
# BCE: 195.5900, KLD: 0.9006
# Epoch 21 of 200,beta = 4
# Train Loss: 197.2331
# BCE: 192.7268, KLD: 0.8955
# Epoch 22 of 200,beta = 4
# Train Loss: 193.6752
# BCE: 189.8172, KLD: 0.8918
# Epoch 23 of 200,beta = 4
# Train Loss: 191.2220
# BCE: 187.1216, KLD: 0.8321
# Epoch 24 of 200,beta = 4
# Train Loss: 189.3705
# BCE: 184.5893, KLD: 0.8172
# Epoch 25 of 200,beta = 4
# Train Loss: 186.2865
# BCE: 182.7573, KLD: 0.7913
# Epoch 26 of 200,beta = 4
# Train Loss: 185.3353
# BCE: 181.3104, KLD: 0.7528
# Epoch 27 of 200,beta = 4
# Train Loss: 182.8853
# BCE: 180.3501, KLD: 0.7104
# Epoch 28 of 200,beta = 4
# Train Loss: 182.1658
# BCE: 178.0074, KLD: 0.7417
# Epoch 29 of 200,beta = 4
# Train Loss: 180.1000
# BCE: 177.5565, KLD: 0.7270
# Epoch 30 of 200,beta = 4
# Train Loss: 179.3240
# BCE: 176.0610, KLD: 0.6866
# Epoch 31 of 200,beta = 4
# Train Loss: 178.0073
# BCE: 175.3353, KLD: 0.6363
# Epoch 32 of 200,beta = 4
# Train Loss: 177.2655
# BCE: 173.6979, KLD: 0.6945
# Epoch 33 of 200,beta = 4
# Train Loss: 176.1422
# BCE: 172.6590, KLD: 0.6782
# Epoch 34 of 200,beta = 4
# Train Loss: 175.4228
# BCE: 172.3872, KLD: 0.7082
# Epoch 35 of 200,beta = 4
# Train Loss: 174.8465
# BCE: 171.3672, KLD: 0.6899
# Epoch 36 of 200,beta = 4
# Train Loss: 174.2377
# BCE: 170.8947, KLD: 0.7033
# Epoch 37 of 200,beta = 4
# Train Loss: 172.9673
# BCE: 170.2265, KLD: 0.6881
# Epoch 38 of 200,beta = 4
# Train Loss: 172.4489
# BCE: 169.9162, KLD: 0.6960
# Epoch 39 of 200,beta = 4
# Train Loss: 171.5810
# BCE: 169.0122, KLD: 0.7056
# Epoch 40 of 200,beta = 4
# Train Loss: 171.4619
# BCE: 169.0168, KLD: 0.7230
# Epoch 41 of 200,beta = 4
# Train Loss: 171.5483
# BCE: 167.6258, KLD: 0.6939
# Epoch 42 of 200,beta = 4
# Train Loss: 170.8136
# BCE: 167.7030, KLD: 0.7169
# Epoch 43 of 200,beta = 4
# Train Loss: 170.5984
# BCE: 167.1945, KLD: 0.7685
# Epoch 44 of 200,beta = 4
# Train Loss: 170.5608
# BCE: 166.6754, KLD: 0.7898
# Epoch 45 of 200,beta = 4
# Train Loss: 170.2821
# BCE: 166.4241, KLD: 0.7929
# Epoch 46 of 200,beta = 4
# Train Loss: 169.2060
# BCE: 166.5742, KLD: 0.6876
# Epoch 47 of 200,beta = 4
# Train Loss: 169.4268
# BCE: 166.3593, KLD: 0.7281
# Epoch 48 of 200,beta = 4
# Train Loss: 168.8773
# BCE: 166.0391, KLD: 0.7313
# Epoch 49 of 200,beta = 4
# Train Loss: 168.1603
# BCE: 165.9802, KLD: 0.7459
# Epoch 50 of 200,beta = 4
# Train Loss: 168.5539
# BCE: 165.3624, KLD: 0.7218
# Epoch 51 of 200,beta = 4
# Train Loss: 168.0021
# BCE: 164.5978, KLD: 0.8473
# Epoch 52 of 200,beta = 4
# Train Loss: 168.1163
# BCE: 164.6768, KLD: 0.7621
# Epoch 53 of 200,beta = 4
# Train Loss: 167.7454
# BCE: 164.6938, KLD: 0.6968
# Epoch 54 of 200,beta = 4
# Train Loss: 167.3685
# BCE: 164.8993, KLD: 0.7401
# Epoch 55 of 200,beta = 4
# Train Loss: 167.4802
# BCE: 163.6098, KLD: 0.7184
# Epoch 56 of 200,beta = 4
# Train Loss: 166.8266
# BCE: 164.0936, KLD: 0.7756
# Epoch 57 of 200,beta = 4
# Train Loss: 166.5288
# BCE: 163.7598, KLD: 0.7034
# Epoch 58 of 200,beta = 4
# Train Loss: 166.5603
# BCE: 163.6867, KLD: 0.7453
# Epoch 59 of 200,beta = 4
# Train Loss: 166.5015
# BCE: 163.8078, KLD: 0.6836
# Epoch 60 of 200,beta = 4
# Train Loss: 166.4625
# BCE: 163.8406, KLD: 0.7152
# Epoch 61 of 200,beta = 4
# Train Loss: 166.8484
# BCE: 163.6546, KLD: 0.7260
# Epoch 62 of 200,beta = 4
# Train Loss: 166.6167
# BCE: 163.0377, KLD: 0.8033
# Epoch 63 of 200,beta = 4
# Train Loss: 166.0379
# BCE: 163.5579, KLD: 0.6663
# Epoch 64 of 200,beta = 4
# Train Loss: 166.4428
# BCE: 162.7687, KLD: 0.7076
# Epoch 65 of 200,beta = 4
# Train Loss: 165.9526
# BCE: 162.9859, KLD: 0.7106
# Epoch 66 of 200,beta = 4
# Train Loss: 165.8581
# BCE: 163.0649, KLD: 0.7233
# Epoch 67 of 200,beta = 4
# Train Loss: 165.8722
# BCE: 163.2298, KLD: 0.7049
# Epoch 68 of 200,beta = 4
# Train Loss: 166.0954
# BCE: 162.7953, KLD: 0.7336
# Epoch 69 of 200,beta = 4
# Train Loss: 165.5826
# BCE: 162.6761, KLD: 0.7798
# Epoch 70 of 200,beta = 4
# Train Loss: 165.0403
# BCE: 162.4751, KLD: 0.7206
# Epoch 71 of 200,beta = 4
# Train Loss: 165.8629
# BCE: 162.1349, KLD: 0.7325
# Epoch 72 of 200,beta = 4
# Train Loss: 165.2613
# BCE: 162.1843, KLD: 0.7884
# Epoch 73 of 200,beta = 4
# Train Loss: 165.1453
# BCE: 162.1494, KLD: 0.7056
# Epoch 74 of 200,beta = 4
# Train Loss: 165.1704
# BCE: 162.6646, KLD: 0.7115
# Epoch 75 of 200,beta = 4
# Train Loss: 165.6627
# BCE: 161.7187, KLD: 0.7734
# Epoch 76 of 200,beta = 4
# Train Loss: 164.8990
# BCE: 162.0327, KLD: 0.7669
# Epoch 77 of 200,beta = 4
# Train Loss: 165.5476
# BCE: 161.7838, KLD: 0.7812
# Epoch 78 of 200,beta = 4
# Train Loss: 164.8906
# BCE: 161.7468, KLD: 0.8132
# Epoch 79 of 200,beta = 4
# Train Loss: 164.8386
# BCE: 161.8520, KLD: 0.7708
# Epoch 80 of 200,beta = 4
# Train Loss: 164.5921
# BCE: 161.6493, KLD: 0.6779
# Epoch 81 of 200,beta = 4
# Train Loss: 164.6072
# BCE: 161.4869, KLD: 0.7485
# Epoch 82 of 200,beta = 4
# Train Loss: 164.5846
# BCE: 161.4464, KLD: 0.7095
# Epoch 83 of 200,beta = 4
# Train Loss: 164.6158
# BCE: 161.7602, KLD: 0.7308
# Epoch 84 of 200,beta = 4
# Train Loss: 164.2179
# BCE: 161.7349, KLD: 0.7036
# Epoch 85 of 200,beta = 4
# Train Loss: 164.4386
# BCE: 162.0447, KLD: 0.7057
# Epoch 86 of 200,beta = 4
# Train Loss: 164.5547
# BCE: 162.3964, KLD: 0.6643
# Epoch 87 of 200,beta = 4
# Train Loss: 164.5215
# BCE: 161.0213, KLD: 0.8196
# Epoch 88 of 200,beta = 4
# Train Loss: 164.4902
# BCE: 161.5069, KLD: 0.7981
# Epoch 89 of 200,beta = 4
# Train Loss: 164.3512
# BCE: 161.3315, KLD: 0.7371
# Epoch 90 of 200,beta = 4
# Train Loss: 164.2643
# BCE: 161.2692, KLD: 0.7231
# Epoch 91 of 200,beta = 4
# Train Loss: 164.2805
# BCE: 161.5937, KLD: 0.6934
# Epoch 92 of 200,beta = 4
# Train Loss: 164.8323
# BCE: 161.5753, KLD: 0.6756
# Epoch 93 of 200,beta = 4
# Train Loss: 164.3788
# BCE: 161.8437, KLD: 0.7385
# Epoch 94 of 200,beta = 4
# Train Loss: 163.8484
# BCE: 161.2129, KLD: 0.7801
# Epoch 95 of 200,beta = 4
# Train Loss: 164.6359
# BCE: 161.4474, KLD: 0.7542
# Epoch 96 of 200,beta = 4
# Train Loss: 164.2548
# BCE: 160.8172, KLD: 0.7080
# Epoch 97 of 200,beta = 4
# Train Loss: 164.1371
# BCE: 161.0505, KLD: 0.7128
# Epoch 98 of 200,beta = 4
# Train Loss: 164.1881
# BCE: 160.8109, KLD: 0.7272
# Epoch 99 of 200,beta = 4
# Train Loss: 163.7181
# BCE: 160.8661, KLD: 0.7508
# Epoch 100 of 200,beta = 4
# Train Loss: 163.7632
# BCE: 161.2443, KLD: 0.7750
# Epoch 101 of 200,beta = 4
# Train Loss: 163.7987
# BCE: 160.7346, KLD: 0.6958
# Epoch 102 of 200,beta = 4
# Train Loss: 164.0252
# BCE: 161.0556, KLD: 0.7432
# Epoch 103 of 200,beta = 4
# Train Loss: 163.7226
# BCE: 161.0876, KLD: 0.7521
# Epoch 104 of 200,beta = 4
# Train Loss: 163.8294
# BCE: 161.1037, KLD: 0.7148
# Epoch 105 of 200,beta = 4
# Train Loss: 164.1312
# BCE: 160.8411, KLD: 0.7572
# Epoch 106 of 200,beta = 4
# Train Loss: 163.8798
# BCE: 161.3632, KLD: 0.7015
# Epoch 107 of 200,beta = 4
# Train Loss: 163.4818
# BCE: 160.9548, KLD: 0.7427
# Epoch 108 of 200,beta = 4
# Train Loss: 163.7121
# BCE: 160.9089, KLD: 0.7095
# Epoch 109 of 200,beta = 4
# Train Loss: 164.1159
# BCE: 161.1607, KLD: 0.7590
# Epoch 110 of 200,beta = 4
# Train Loss: 163.6829
# BCE: 160.3441, KLD: 0.7549
# Epoch 111 of 200,beta = 4
# Train Loss: 163.9634
# BCE: 160.5559, KLD: 0.7513
# Epoch 112 of 200,beta = 4
# Train Loss: 163.6909
# BCE: 161.1440, KLD: 0.7251
# Epoch 113 of 200,beta = 4
# Train Loss: 163.8921
# BCE: 160.6567, KLD: 0.7884
# Epoch 114 of 200,beta = 4
# Train Loss: 163.3473
# BCE: 160.5706, KLD: 0.7656
# Epoch 115 of 200,beta = 4
# Train Loss: 163.0996
# BCE: 161.3529, KLD: 0.6981
# Epoch 116 of 200,beta = 4
# Train Loss: 163.6011
# BCE: 160.6433, KLD: 0.6385
# Epoch 117 of 200,beta = 4
# Train Loss: 163.7661
# BCE: 160.6995, KLD: 0.6926
# Epoch 118 of 200,beta = 4
# Train Loss: 163.5212
# BCE: 160.9892, KLD: 0.7494
# Epoch 119 of 200,beta = 4
# Train Loss: 163.3624
# BCE: 160.4411, KLD: 0.7126
# Epoch 120 of 200,beta = 4
# Train Loss: 163.6995
# BCE: 161.0466, KLD: 0.7716
# Epoch 121 of 200,beta = 4
# Train Loss: 163.5647
# BCE: 160.3343, KLD: 0.7717
# Epoch 122 of 200,beta = 4
# Train Loss: 163.5016
# BCE: 160.4945, KLD: 0.6961
# Epoch 123 of 200,beta = 4
# Train Loss: 163.6004
# BCE: 160.4962, KLD: 0.7772
# Epoch 124 of 200,beta = 4
# Train Loss: 163.2493
# BCE: 160.3500, KLD: 0.7466
# Epoch 125 of 200,beta = 4
# Train Loss: 163.1846
# BCE: 160.5771, KLD: 0.6651
# Epoch 126 of 200,beta = 4
# Train Loss: 163.6304
# BCE: 160.3058, KLD: 0.7545
# Epoch 127 of 200,beta = 4
# Train Loss: 163.8011
# BCE: 161.2526, KLD: 0.7023
# Epoch 128 of 200,beta = 4
# Train Loss: 163.5030
# BCE: 161.0819, KLD: 0.6874
# Epoch 129 of 200,beta = 4
# Train Loss: 163.4497
# BCE: 161.2870, KLD: 0.6580
# Epoch 130 of 200,beta = 4
# Train Loss: 163.6095
# BCE: 160.8035, KLD: 0.7563
# Epoch 131 of 200,beta = 4
# Train Loss: 163.9707
# BCE: 160.4636, KLD: 0.7567
# Epoch 132 of 200,beta = 4
# Train Loss: 163.3579
# BCE: 159.6685, KLD: 0.7726
# Epoch 133 of 200,beta = 4
# Train Loss: 163.3149
# BCE: 160.8649, KLD: 0.7472
# Epoch 134 of 200,beta = 4
# Train Loss: 163.4975
# BCE: 160.0611, KLD: 0.8338
# Epoch 135 of 200,beta = 4
# Train Loss: 163.9223
# BCE: 160.8058, KLD: 0.7268
# Epoch 136 of 200,beta = 4
# Train Loss: 163.6013
# BCE: 160.3236, KLD: 0.7229
# Epoch 137 of 200,beta = 4
# Train Loss: 162.9736
# BCE: 160.6139, KLD: 0.7253
# Epoch 138 of 200,beta = 4
# Train Loss: 163.0308
# BCE: 160.4847, KLD: 0.7531
# Epoch 139 of 200,beta = 4
# Train Loss: 163.6541
# BCE: 160.4587, KLD: 0.7030
# Epoch 140 of 200,beta = 4
# Train Loss: 162.8408
# BCE: 160.2435, KLD: 0.7334
# Epoch 141 of 200,beta = 4
# Train Loss: 164.0606
# BCE: 160.6170, KLD: 0.7595
# Epoch 142 of 200,beta = 4
# Train Loss: 163.7210
# BCE: 160.4930, KLD: 0.7519
# Epoch 143 of 200,beta = 4
# Train Loss: 163.6227
# BCE: 160.2963, KLD: 0.7264
# Epoch 144 of 200,beta = 4
# Train Loss: 163.7057
# BCE: 160.5367, KLD: 0.7340
# Epoch 145 of 200,beta = 4
# Train Loss: 163.5917
# BCE: 160.6026, KLD: 0.6731
# Epoch 146 of 200,beta = 4
# Train Loss: 163.6405
# BCE: 159.7760, KLD: 0.7833
# Epoch 147 of 200,beta = 4
# Train Loss: 164.0340
# BCE: 160.6396, KLD: 0.7113
# Epoch 148 of 200,beta = 4
# Train Loss: 163.2192
# BCE: 160.0278, KLD: 0.7445
# Epoch 149 of 200,beta = 4
# Train Loss: 163.1565
# BCE: 160.8489, KLD: 0.7308
# Epoch 150 of 200,beta = 4
# Train Loss: 163.6686
# BCE: 160.3858, KLD: 0.7148
# Epoch 151 of 200,beta = 4
# Train Loss: 163.4451
# BCE: 159.7529, KLD: 0.7730
# Epoch 152 of 200,beta = 4
# Train Loss: 163.6997
# BCE: 160.4512, KLD: 0.7355
# Epoch 153 of 200,beta = 4
# Train Loss: 163.0922
# BCE: 160.4978, KLD: 0.7455
# Epoch 154 of 200,beta = 4
# Train Loss: 163.2570
# BCE: 160.8051, KLD: 0.7091
# Epoch 155 of 200,beta = 4
# Train Loss: 163.8324
# BCE: 160.6699, KLD: 0.7618
# Epoch 156 of 200,beta = 4
# Train Loss: 163.4102
# BCE: 161.1684, KLD: 0.6550
# Epoch 157 of 200,beta = 4
# Train Loss: 163.2462
# BCE: 159.8334, KLD: 0.7935
# Epoch 158 of 200,beta = 4
# Train Loss: 163.1307
# BCE: 160.3982, KLD: 0.7277
# Epoch 159 of 200,beta = 4
# Train Loss: 163.6234
# BCE: 160.2152, KLD: 0.7193
# Epoch 160 of 200,beta = 4
# Train Loss: 163.5131
# BCE: 159.8501, KLD: 0.8161
# Epoch 161 of 200,beta = 4
# Train Loss: 162.8721
# BCE: 159.9084, KLD: 0.7744
# Epoch 162 of 200,beta = 4
# Train Loss: 163.4601
# BCE: 160.3793, KLD: 0.7507
# Epoch 163 of 200,beta = 4
# Train Loss: 163.3307
# BCE: 160.3237, KLD: 0.7200
# Epoch 164 of 200,beta = 4
# Train Loss: 163.2388
# BCE: 159.9142, KLD: 0.7931
# Epoch 165 of 200,beta = 4
# Train Loss: 163.3130
# BCE: 159.6755, KLD: 0.7568
# Epoch 166 of 200,beta = 4
# Train Loss: 163.1790
# BCE: 160.4947, KLD: 0.7323
# Epoch 167 of 200,beta = 4
# Train Loss: 163.1817
# BCE: 160.1245, KLD: 0.7871
# Epoch 168 of 200,beta = 4
# Train Loss: 162.7659
# BCE: 159.8204, KLD: 0.7946
# Epoch 169 of 200,beta = 4
# Train Loss: 163.2136
# BCE: 160.6283, KLD: 0.7745
# Epoch 170 of 200,beta = 4
# Train Loss: 163.7945
# BCE: 160.3790, KLD: 0.7429
# Epoch 171 of 200,beta = 4
# Train Loss: 163.3971
# BCE: 160.4896, KLD: 0.7608
# Epoch 172 of 200,beta = 4
# Train Loss: 163.1641
# BCE: 159.7964, KLD: 0.8233
# Epoch 173 of 200,beta = 4
# Train Loss: 163.1993
# BCE: 160.0850, KLD: 0.7599
# Epoch 174 of 200,beta = 4
# Train Loss: 162.9037
# BCE: 160.1681, KLD: 0.6937
# Epoch 175 of 200,beta = 4
# Train Loss: 162.9607
# BCE: 159.8076, KLD: 0.7732
# Epoch 176 of 200,beta = 4
# Train Loss: 163.2746
# BCE: 160.3829, KLD: 0.6947
# Epoch 177 of 200,beta = 4
# Train Loss: 163.3140
# BCE: 160.0506, KLD: 0.7619
# Epoch 178 of 200,beta = 4
# Train Loss: 162.8749
# BCE: 160.3962, KLD: 0.7458
# Epoch 179 of 200,beta = 4
# Train Loss: 163.1663
# BCE: 160.8568, KLD: 0.6247
# Epoch 180 of 200,beta = 4
# Train Loss: 163.1340
# BCE: 160.2519, KLD: 0.7800
# Epoch 181 of 200,beta = 4
# Train Loss: 163.5783
# BCE: 160.4624, KLD: 0.6215
# Epoch 182 of 200,beta = 4
# Train Loss: 163.0108
# BCE: 160.7264, KLD: 0.6671
# Epoch 183 of 200,beta = 4
# Train Loss: 163.3354
# BCE: 160.3557, KLD: 0.8121
# Epoch 184 of 200,beta = 4
# Train Loss: 163.1544
# BCE: 159.9982, KLD: 0.7118
# Epoch 185 of 200,beta = 4
# Train Loss: 163.4239
# BCE: 159.9833, KLD: 0.7964
# Epoch 186 of 200,beta = 4
# Train Loss: 163.5499
# BCE: 159.5463, KLD: 0.7621
# Epoch 187 of 200,beta = 4
# Train Loss: 163.2042
# BCE: 160.3590, KLD: 0.6891
# Epoch 188 of 200,beta = 4
# Train Loss: 163.3257
# BCE: 160.0362, KLD: 0.7014
# Epoch 189 of 200,beta = 4
# Train Loss: 162.8440
# BCE: 160.4684, KLD: 0.7951
# Epoch 190 of 200,beta = 4
# Train Loss: 162.8902
# BCE: 159.7342, KLD: 0.8019
# Epoch 191 of 200,beta = 4
# Train Loss: 162.8007
# BCE: 160.1702, KLD: 0.7608
# Epoch 192 of 200,beta = 4
# Train Loss: 163.4338
# BCE: 160.4888, KLD: 0.7130
# Epoch 193 of 200,beta = 4
# Train Loss: 162.9003
# BCE: 159.7469, KLD: 0.8298
# Epoch 194 of 200,beta = 4
# Train Loss: 163.3932
# BCE: 159.5050, KLD: 0.7443
# Epoch 195 of 200,beta = 4
# Train Loss: 163.0104
# BCE: 160.1298, KLD: 0.7297
# Epoch 196 of 200,beta = 4
# Train Loss: 163.1836
# BCE: 160.2291, KLD: 0.7254
# Epoch 197 of 200,beta = 4
# Train Loss: 162.7019
# BCE: 160.3862, KLD: 0.7356
# Epoch 198 of 200,beta = 4
# Train Loss: 163.5940
# BCE: 160.4678, KLD: 0.6976
# Epoch 199 of 200,beta = 4
# Train Loss: 163.1032
# BCE: 159.9823, KLD: 0.7804
# Epoch 200 of 200,beta = 4
# Train Loss: 162.7835
# BCE: 159.9255, KLD: 0.6911
# Epoch 201 of 200,beta = 4
# Train Loss: 163.2388
# BCE: 159.3429, KLD: 0.8067
# 173056
# (64, 64)
# Epoch 1 of 200,beta = 6
# Train Loss: 3584.5698
# BCE: 2975.4383, KLD: 0.4369
# Epoch 2 of 200,beta = 6
# Train Loss: 2416.6384
# BCE: 2045.0087, KLD: 1.3414
# Epoch 3 of 200,beta = 6
# Train Loss: 1659.3908
# BCE: 1363.6550, KLD: 1.5551
# Epoch 4 of 200,beta = 6
# Train Loss: 1114.5569
# BCE: 915.9192, KLD: 1.4832
# Epoch 5 of 200,beta = 6
# Train Loss: 789.3842
# BCE: 661.2226, KLD: 1.4179
# Epoch 6 of 200,beta = 6
# Train Loss: 592.2480
# BCE: 506.9334, KLD: 1.2326
# Epoch 7 of 200,beta = 6
# Train Loss: 467.7262
# BCE: 412.1900, KLD: 1.1722
# Epoch 8 of 200,beta = 6
# Train Loss: 387.5380
# BCE: 350.0531, KLD: 1.0442
# Epoch 9 of 200,beta = 6
# Train Loss: 334.0907
# BCE: 306.7243, KLD: 0.8771
# Epoch 10 of 200,beta = 6
# Train Loss: 296.8615
# BCE: 277.4209, KLD: 0.8739
# Epoch 11 of 200,beta = 6
# Train Loss: 270.8398
# BCE: 256.1257, KLD: 0.8881
# Epoch 12 of 200,beta = 6
# Train Loss: 251.0892
# BCE: 240.4065, KLD: 0.7513
# Epoch 13 of 200,beta = 6
# Train Loss: 236.5213
# BCE: 228.4863, KLD: 0.6335
# Epoch 14 of 200,beta = 6
# Train Loss: 225.5375
# BCE: 218.2391, KLD: 0.5560
# Epoch 15 of 200,beta = 6
# Train Loss: 216.2351
# BCE: 210.3597, KLD: 0.5236
# Epoch 16 of 200,beta = 6
# Train Loss: 209.0402
# BCE: 203.9323, KLD: 0.5325
# Epoch 17 of 200,beta = 6
# Train Loss: 204.0374
# BCE: 198.5566, KLD: 0.4571
# Epoch 18 of 200,beta = 6
# Train Loss: 199.0291
# BCE: 194.6515, KLD: 0.3897
# Epoch 19 of 200,beta = 6
# Train Loss: 195.5223
# BCE: 190.7489, KLD: 0.3352
# Epoch 20 of 200,beta = 6
# Train Loss: 191.7744
# BCE: 188.5604, KLD: 0.3587
# Epoch 21 of 200,beta = 6
# Train Loss: 188.8684
# BCE: 185.9498, KLD: 0.2650
# Epoch 22 of 200,beta = 6
# Train Loss: 186.9138
# BCE: 184.1201, KLD: 0.2696
# Epoch 23 of 200,beta = 6
# Train Loss: 184.5968
# BCE: 182.3626, KLD: 0.2865
# Epoch 24 of 200,beta = 6
# Train Loss: 182.8828
# BCE: 180.4964, KLD: 0.1815
# Epoch 25 of 200,beta = 6
# Train Loss: 180.8352
# BCE: 179.5932, KLD: 0.1888
# Epoch 26 of 200,beta = 6
# Train Loss: 179.5657
# BCE: 178.7338, KLD: 0.1758
# Epoch 27 of 200,beta = 6
# Train Loss: 177.9784
# BCE: 176.7365, KLD: 0.1809
# Epoch 28 of 200,beta = 6
# Train Loss: 177.7335
# BCE: 175.8442, KLD: 0.1043
# Epoch 29 of 200,beta = 6
# Train Loss: 175.7683
# BCE: 175.4059, KLD: 0.1647
# Epoch 30 of 200,beta = 6
# Train Loss: 175.5922
# BCE: 174.5895, KLD: 0.0963
# Epoch 31 of 200,beta = 6
# Train Loss: 174.9552
# BCE: 173.1012, KLD: 0.1131
# Epoch 32 of 200,beta = 6
# Train Loss: 173.7345
# BCE: 172.7433, KLD: 0.0949
# Epoch 33 of 200,beta = 6
# Train Loss: 173.2218
# BCE: 172.4100, KLD: 0.0887
# Epoch 34 of 200,beta = 6
# Train Loss: 172.1022
# BCE: 172.2577, KLD: 0.0610
# Epoch 35 of 200,beta = 6
# Train Loss: 171.8113
# BCE: 171.4661, KLD: 0.0700
# Epoch 36 of 200,beta = 6
# Train Loss: 171.7346
# BCE: 171.7405, KLD: 0.0774
# Epoch 37 of 200,beta = 6
# Train Loss: 171.5022
# BCE: 170.6901, KLD: 0.0943
# Epoch 38 of 200,beta = 6
# Train Loss: 170.7060
# BCE: 170.0221, KLD: 0.0675
# Epoch 39 of 200,beta = 6
# Train Loss: 171.0040
# BCE: 170.1290, KLD: 0.0562
# Epoch 40 of 200,beta = 6
# Train Loss: 170.3669
# BCE: 170.0078, KLD: 0.0721
# Epoch 41 of 200,beta = 6
# Train Loss: 169.9682
# BCE: 169.0760, KLD: 0.0592
# Epoch 42 of 200,beta = 6
# Train Loss: 169.7440
# BCE: 169.3750, KLD: 0.0554
# Epoch 43 of 200,beta = 6
# Train Loss: 168.6143
# BCE: 169.2404, KLD: 0.0645
# Epoch 44 of 200,beta = 6
# Train Loss: 168.9166
# BCE: 168.6993, KLD: 0.0904
# Epoch 45 of 200,beta = 6
# Train Loss: 168.2946
# BCE: 168.5024, KLD: 0.0637
# Epoch 46 of 200,beta = 6
# Train Loss: 168.6246
# BCE: 167.0989, KLD: 0.0904
# Epoch 47 of 200,beta = 6
# Train Loss: 168.1720
# BCE: 167.9012, KLD: 0.0833
# Epoch 48 of 200,beta = 6
# Train Loss: 167.8077
# BCE: 168.1422, KLD: 0.0569
# Epoch 49 of 200,beta = 6
# Train Loss: 168.1473
# BCE: 167.5041, KLD: 0.0907
# Epoch 50 of 200,beta = 6
# Train Loss: 167.7443
# BCE: 167.4553, KLD: 0.0764
# Epoch 51 of 200,beta = 6
# Train Loss: 168.1346
# BCE: 166.8323, KLD: 0.1013
# Epoch 52 of 200,beta = 6
# Train Loss: 167.4824
# BCE: 166.9388, KLD: 0.0800
# Epoch 53 of 200,beta = 6
# Train Loss: 168.0215
# BCE: 166.6904, KLD: 0.0680
# Epoch 54 of 200,beta = 6
# Train Loss: 167.2131
# BCE: 166.2167, KLD: 0.0554
# Epoch 55 of 200,beta = 6
# Train Loss: 166.8687
# BCE: 166.2854, KLD: 0.0580
# Epoch 56 of 200,beta = 6
# Train Loss: 166.8970
# BCE: 166.6723, KLD: 0.0733
# Epoch 57 of 200,beta = 6
# Train Loss: 166.8539
# BCE: 166.3114, KLD: 0.0652
# Epoch 58 of 200,beta = 6
# Train Loss: 166.2278
# BCE: 166.1333, KLD: 0.0826
# Epoch 59 of 200,beta = 6
# Train Loss: 166.1976
# BCE: 165.8445, KLD: 0.0981
# Epoch 60 of 200,beta = 6
# Train Loss: 166.2560
# BCE: 166.0432, KLD: 0.1057
# Epoch 61 of 200,beta = 6
# Train Loss: 166.3387
# BCE: 166.1665, KLD: 0.0975
# Epoch 62 of 200,beta = 6
# Train Loss: 166.3960
# BCE: 165.9394, KLD: 0.0842
# Epoch 63 of 200,beta = 6
# Train Loss: 166.5193
# BCE: 166.1505, KLD: 0.0883
# Epoch 64 of 200,beta = 6
# Train Loss: 166.7888
# BCE: 165.7004, KLD: 0.1140
# Epoch 65 of 200,beta = 6
# Train Loss: 166.1103
# BCE: 165.7922, KLD: 0.1041
# Epoch 66 of 200,beta = 6
# Train Loss: 165.8360
# BCE: 165.7555, KLD: 0.0916
# Epoch 67 of 200,beta = 6
# Train Loss: 165.9008
# BCE: 165.6447, KLD: 0.0888
# Epoch 68 of 200,beta = 6
# Train Loss: 165.6980
# BCE: 165.4610, KLD: 0.0617
# Epoch 69 of 200,beta = 6
# Train Loss: 165.8447
# BCE: 164.7935, KLD: 0.0736
# Epoch 70 of 200,beta = 6
# Train Loss: 165.9782
# BCE: 165.3731, KLD: 0.0920
# Epoch 71 of 200,beta = 6
# Train Loss: 166.0953
# BCE: 165.0517, KLD: 0.0916
# Epoch 72 of 200,beta = 6
# Train Loss: 165.3981
# BCE: 165.5943, KLD: 0.0918
# Epoch 73 of 200,beta = 6
# Train Loss: 165.5790
# BCE: 164.6478, KLD: 0.0854
# Epoch 74 of 200,beta = 6
# Train Loss: 165.3228
# BCE: 165.0701, KLD: 0.0791
# Epoch 75 of 200,beta = 6
# Train Loss: 165.1068
# BCE: 164.5949, KLD: 0.0744
# Epoch 76 of 200,beta = 6
# Train Loss: 165.6500
# BCE: 164.6325, KLD: 0.0921
# Epoch 77 of 200,beta = 6
# Train Loss: 165.8223
# BCE: 164.8190, KLD: 0.0695
# Epoch 78 of 200,beta = 6
# Train Loss: 165.2044
# BCE: 165.1807, KLD: 0.0861
# Epoch 79 of 200,beta = 6
# Train Loss: 165.1721
# BCE: 164.7632, KLD: 0.0937
# Epoch 80 of 200,beta = 6
# Train Loss: 164.7863
# BCE: 164.6570, KLD: 0.0974
# Epoch 81 of 200,beta = 6
# Train Loss: 165.0686
# BCE: 164.4494, KLD: 0.0864
# Epoch 82 of 200,beta = 6
# Train Loss: 165.0104
# BCE: 164.8667, KLD: 0.0700
# Epoch 83 of 200,beta = 6
# Train Loss: 165.2501
# BCE: 165.4314, KLD: 0.0702
# Epoch 84 of 200,beta = 6
# Train Loss: 165.6661
# BCE: 164.6827, KLD: 0.0914
# Epoch 85 of 200,beta = 6
# Train Loss: 165.2689
# BCE: 164.8160, KLD: 0.1009
# Epoch 86 of 200,beta = 6
# Train Loss: 165.3104
# BCE: 164.5858, KLD: 0.0722
# Epoch 87 of 200,beta = 6
# Train Loss: 164.6001
# BCE: 164.5343, KLD: 0.0863
# Epoch 88 of 200,beta = 6
# Train Loss: 165.4837
# BCE: 163.9268, KLD: 0.0740
# Epoch 89 of 200,beta = 6
# Train Loss: 165.1305
# BCE: 164.6705, KLD: 0.0801
# Epoch 90 of 200,beta = 6
# Train Loss: 165.0503
# BCE: 164.0275, KLD: 0.0965
# Epoch 91 of 200,beta = 6
# Train Loss: 164.6476
# BCE: 164.6319, KLD: 0.0853
# Epoch 92 of 200,beta = 6
# Train Loss: 165.2892
# BCE: 163.5180, KLD: 0.1201
# Epoch 93 of 200,beta = 6
# Train Loss: 165.2897
# BCE: 163.8466, KLD: 0.0975
# Epoch 94 of 200,beta = 6
# Train Loss: 164.7007
# BCE: 163.9830, KLD: 0.0894
# Epoch 95 of 200,beta = 6
# Train Loss: 164.9471
# BCE: 164.5470, KLD: 0.0863
# Epoch 96 of 200,beta = 6
# Train Loss: 164.1380
# BCE: 163.7662, KLD: 0.0970
# Epoch 97 of 200,beta = 6
# Train Loss: 164.6408
# BCE: 163.7444, KLD: 0.1047
# Epoch 98 of 200,beta = 6
# Train Loss: 164.5253
# BCE: 164.2940, KLD: 0.0746
# Epoch 99 of 200,beta = 6
# Train Loss: 165.2028
# BCE: 164.0443, KLD: 0.0891
# Epoch 100 of 200,beta = 6
# Train Loss: 164.9195
# BCE: 163.9666, KLD: 0.0823
# Epoch 101 of 200,beta = 6
# Train Loss: 164.7257
# BCE: 164.3530, KLD: 0.0742
# Epoch 102 of 200,beta = 6
# Train Loss: 164.9937
# BCE: 164.1262, KLD: 0.0695
# Epoch 103 of 200,beta = 6
# Train Loss: 164.8270
# BCE: 163.8215, KLD: 0.0642
# Epoch 104 of 200,beta = 6
# Train Loss: 164.5627
# BCE: 164.1276, KLD: 0.0704
# Epoch 105 of 200,beta = 6
# Train Loss: 164.3946
# BCE: 163.8690, KLD: 0.1142
# Epoch 106 of 200,beta = 6
# Train Loss: 164.7106
# BCE: 163.7942, KLD: 0.0802
# Epoch 107 of 200,beta = 6
# Train Loss: 164.1319
# BCE: 164.2157, KLD: 0.0901
# Epoch 108 of 200,beta = 6
# Train Loss: 164.0832
# BCE: 164.6824, KLD: 0.0634
# Epoch 109 of 200,beta = 6
# Train Loss: 164.3773
# BCE: 163.8605, KLD: 0.0899
# Epoch 110 of 200,beta = 6
# Train Loss: 164.1463
# BCE: 164.2214, KLD: 0.0639
# Epoch 111 of 200,beta = 6
# Train Loss: 164.6545
# BCE: 163.9022, KLD: 0.1016
# Epoch 112 of 200,beta = 6
# Train Loss: 164.3304
# BCE: 163.7208, KLD: 0.1128
# Epoch 113 of 200,beta = 6
# Train Loss: 164.3171
# BCE: 163.9550, KLD: 0.0789
# Epoch 114 of 200,beta = 6
# Train Loss: 164.0938
# BCE: 163.1832, KLD: 0.0917
# Epoch 115 of 200,beta = 6
# Train Loss: 163.9040
# BCE: 164.2501, KLD: 0.0653
# Epoch 116 of 200,beta = 6
# Train Loss: 163.9525
# BCE: 163.7574, KLD: 0.0693
# Epoch 117 of 200,beta = 6
# Train Loss: 164.1833
# BCE: 163.6532, KLD: 0.0872
# Epoch 118 of 200,beta = 6
# Train Loss: 164.2432
# BCE: 164.5444, KLD: 0.0803
# Epoch 119 of 200,beta = 6
# Train Loss: 164.7266
# BCE: 164.1227, KLD: 0.0841
# Epoch 120 of 200,beta = 6
# Train Loss: 164.2398
# BCE: 163.3908, KLD: 0.1050
# Epoch 121 of 200,beta = 6
# Train Loss: 164.9148
# BCE: 163.6133, KLD: 0.0951
# Epoch 122 of 200,beta = 6
# Train Loss: 164.1766
# BCE: 163.9097, KLD: 0.0915
# Epoch 123 of 200,beta = 6
# Train Loss: 165.1826
# BCE: 163.9446, KLD: 0.0901
# Epoch 124 of 200,beta = 6
# Train Loss: 164.6214
# BCE: 163.8825, KLD: 0.0664
# Epoch 125 of 200,beta = 6
# Train Loss: 164.3075
# BCE: 163.9417, KLD: 0.0920
# Epoch 126 of 200,beta = 6
# Train Loss: 164.6110
# BCE: 163.2755, KLD: 0.0951
# Epoch 127 of 200,beta = 6
# Train Loss: 164.0781
# BCE: 163.3460, KLD: 0.0962
# Epoch 128 of 200,beta = 6
# Train Loss: 164.1522
# BCE: 163.4489, KLD: 0.0901
# Epoch 129 of 200,beta = 6
# Train Loss: 164.2115
# BCE: 163.2271, KLD: 0.0915
# Epoch 130 of 200,beta = 6
# Train Loss: 164.3867
# BCE: 163.6476, KLD: 0.0911
# Epoch 131 of 200,beta = 6
# Train Loss: 164.5595
# BCE: 163.2484, KLD: 0.0934
# Epoch 132 of 200,beta = 6
# Train Loss: 163.6491
# BCE: 163.7169, KLD: 0.0803
# Epoch 133 of 200,beta = 6
# Train Loss: 164.3410
# BCE: 163.4640, KLD: 0.0827
# Epoch 134 of 200,beta = 6
# Train Loss: 164.1467
# BCE: 163.3567, KLD: 0.1060
# Epoch 135 of 200,beta = 6
# Train Loss: 164.1070
# BCE: 163.4203, KLD: 0.0991
# Epoch 136 of 200,beta = 6
# Train Loss: 164.2983
# BCE: 163.7127, KLD: 0.1023
# Epoch 137 of 200,beta = 6
# Train Loss: 164.4542
# BCE: 163.5402, KLD: 0.0695
# Epoch 138 of 200,beta = 6
# Train Loss: 165.0075
# BCE: 163.6052, KLD: 0.0837
# Epoch 139 of 200,beta = 6
# Train Loss: 164.3328
# BCE: 163.6031, KLD: 0.0739
# Epoch 140 of 200,beta = 6
# Train Loss: 164.4669
# BCE: 163.3987, KLD: 0.0708
# Epoch 141 of 200,beta = 6
# Train Loss: 164.1998
# BCE: 163.4405, KLD: 0.0671
# Epoch 142 of 200,beta = 6
# Train Loss: 164.1358
# BCE: 163.8746, KLD: 0.0618
# Epoch 143 of 200,beta = 6
# Train Loss: 163.9474
# BCE: 163.7723, KLD: 0.0644
# Epoch 144 of 200,beta = 6
# Train Loss: 163.8795
# BCE: 163.2279, KLD: 0.1107
# Epoch 145 of 200,beta = 6
# Train Loss: 164.3678
# BCE: 163.0000, KLD: 0.1095
# Epoch 146 of 200,beta = 6
# Train Loss: 163.8595
# BCE: 163.1133, KLD: 0.0699
# Epoch 147 of 200,beta = 6
# Train Loss: 163.9103
# BCE: 163.8570, KLD: 0.0648
# Epoch 148 of 200,beta = 6
# Train Loss: 164.0921
# BCE: 163.5033, KLD: 0.1024
# Epoch 149 of 200,beta = 6
# Train Loss: 164.4166
# BCE: 163.5013, KLD: 0.0953
# Epoch 150 of 200,beta = 6
# Train Loss: 164.4394
# BCE: 163.7862, KLD: 0.0948
# Epoch 151 of 200,beta = 6
# Train Loss: 164.4960
# BCE: 163.6331, KLD: 0.0935
# Epoch 152 of 200,beta = 6
# Train Loss: 164.5525
# BCE: 163.4471, KLD: 0.0807
# Epoch 153 of 200,beta = 6
# Train Loss: 164.3486
# BCE: 163.6101, KLD: 0.0702
# Epoch 154 of 200,beta = 6
# Train Loss: 163.9317
# BCE: 163.6651, KLD: 0.0703
# Epoch 155 of 200,beta = 6
# Train Loss: 164.2146
# BCE: 163.6645, KLD: 0.1025
# Epoch 156 of 200,beta = 6
# Train Loss: 164.3549
# BCE: 163.7808, KLD: 0.0706
# Epoch 157 of 200,beta = 6
# Train Loss: 164.1065
# BCE: 163.7365, KLD: 0.1043
# Epoch 158 of 200,beta = 6
# Train Loss: 163.7049
# BCE: 163.3876, KLD: 0.1002
# Epoch 159 of 200,beta = 6
# Train Loss: 164.0174
# BCE: 163.4319, KLD: 0.0948
# Epoch 160 of 200,beta = 6
# Train Loss: 164.2001
# BCE: 162.8405, KLD: 0.1060
# Epoch 161 of 200,beta = 6
# Train Loss: 163.9302
# BCE: 163.4338, KLD: 0.1137
# Epoch 162 of 200,beta = 6
# Train Loss: 164.1946
# BCE: 162.5655, KLD: 0.1167
# Epoch 163 of 200,beta = 6
# Train Loss: 163.6951
# BCE: 163.2783, KLD: 0.0809
# Epoch 164 of 200,beta = 6
# Train Loss: 163.8694
# BCE: 163.8740, KLD: 0.1057
# Epoch 165 of 200,beta = 6
# Train Loss: 163.7262
# BCE: 163.7504, KLD: 0.0778
# Epoch 166 of 200,beta = 6
# Train Loss: 164.1704
# BCE: 163.6430, KLD: 0.1006
# Epoch 167 of 200,beta = 6
# Train Loss: 164.2854
# BCE: 163.5568, KLD: 0.0683
# Epoch 168 of 200,beta = 6
# Train Loss: 162.9808
# BCE: 163.1196, KLD: 0.0908
# Epoch 169 of 200,beta = 6
# Train Loss: 163.8067
# BCE: 163.7321, KLD: 0.0586
# Epoch 170 of 200,beta = 6
# Train Loss: 163.9598
# BCE: 163.7629, KLD: 0.0568
# Epoch 171 of 200,beta = 6
# Train Loss: 164.2823
# BCE: 163.9522, KLD: 0.0737
# Epoch 172 of 200,beta = 6
# Train Loss: 163.9787
# BCE: 163.3517, KLD: 0.0856
# Epoch 173 of 200,beta = 6
# Train Loss: 164.1125
# BCE: 163.6447, KLD: 0.0743
# Epoch 174 of 200,beta = 6
# Train Loss: 164.1615
# BCE: 163.6206, KLD: 0.0643
# Epoch 175 of 200,beta = 6
# Train Loss: 163.8888
# BCE: 163.1607, KLD: 0.0898
# Epoch 176 of 200,beta = 6
# Train Loss: 164.3451
# BCE: 163.5759, KLD: 0.0780
# Epoch 177 of 200,beta = 6
# Train Loss: 164.2704
# BCE: 163.7229, KLD: 0.0742
# Epoch 178 of 200,beta = 6
# Train Loss: 163.8744
# BCE: 163.6482, KLD: 0.0664
# Epoch 179 of 200,beta = 6
# Train Loss: 164.4520
# BCE: 163.3348, KLD: 0.0913
# Epoch 180 of 200,beta = 6
# Train Loss: 164.4958
# BCE: 163.5468, KLD: 0.1069
# Epoch 181 of 200,beta = 6
# Train Loss: 164.0260
# BCE: 162.8716, KLD: 0.0986
# Epoch 182 of 200,beta = 6
# Train Loss: 163.8205
# BCE: 162.6274, KLD: 0.1149
# Epoch 183 of 200,beta = 6
# Train Loss: 164.0030
# BCE: 163.4732, KLD: 0.1068
# Epoch 184 of 200,beta = 6
# Train Loss: 163.7772
# BCE: 163.5271, KLD: 0.0934
# Epoch 185 of 200,beta = 6
# Train Loss: 163.4756
# BCE: 163.4105, KLD: 0.0967
# Epoch 186 of 200,beta = 6
# Train Loss: 164.0901
# BCE: 163.0455, KLD: 0.1211
# Epoch 187 of 200,beta = 6
# Train Loss: 164.1954
# BCE: 163.4797, KLD: 0.1212
# Epoch 188 of 200,beta = 6
# Train Loss: 163.7465
# BCE: 163.2849, KLD: 0.0952
# Epoch 189 of 200,beta = 6
# Train Loss: 163.7970
# BCE: 163.3703, KLD: 0.1286
# Epoch 190 of 200,beta = 6
# Train Loss: 163.8331
# BCE: 163.2827, KLD: 0.1002
# Epoch 191 of 200,beta = 6
# Train Loss: 163.9708
# BCE: 163.7282, KLD: 0.1047
# Epoch 192 of 200,beta = 6
# Train Loss: 164.3259
# BCE: 163.0987, KLD: 0.0975
# Epoch 193 of 200,beta = 6
# Train Loss: 163.6694
# BCE: 163.4114, KLD: 0.0840
# Epoch 194 of 200,beta = 6
# Train Loss: 163.8053
# BCE: 162.5773, KLD: 0.0919
# Epoch 195 of 200,beta = 6
# Train Loss: 164.2466
# BCE: 163.3335, KLD: 0.1029
# Epoch 196 of 200,beta = 6
# Train Loss: 164.0610
# BCE: 163.2104, KLD: 0.1013
# Epoch 197 of 200,beta = 6
# Train Loss: 163.6260
# BCE: 163.3140, KLD: 0.0995
# Epoch 198 of 200,beta = 6
# Train Loss: 163.6228
# BCE: 163.3527, KLD: 0.0666
# Epoch 199 of 200,beta = 6
# Train Loss: 163.5707
# BCE: 163.0233, KLD: 0.0925
# Epoch 200 of 200,beta = 6
# Train Loss: 164.1317
# BCE: 162.9301, KLD: 0.1039
# Epoch 201 of 200,beta = 6
# Train Loss: 164.1198
# BCE: 163.2868, KLD: 0.1282

# %%
lr = 0.001
model = model_conv_bigger.VAE_CNN_version_2().to(device)
optimizer = optim.AdamW(model.parameters(), lr=lr)
criterion = nn.BCELoss(reduction='sum')
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                         mode='min',
                                                         factor=0.2,
                                                         patience=20,
                                                         min_lr=5e-5)
# Out:
# 346112.0

# %%
model = model_conv_bigger.VAE_CNN_version_2(zDim=1).to(device)
state_dict = torch.load("/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/models/Resnet_B2_VAE_z_only_200.pt")
model.load_state_dict(state_dict)
# Out:
# 173056
# (64, 64)
# <All keys matched successfully>

# %%
n_steps =20

xyz = torch.ones((n_steps,3))*32
zs = torch.linspace(-2, 2, n_steps).view(-1,1).to(device)

model.eval()

images = model.decoder(zs)
mus, logvar = model.encoder(images)
images = images.cpu().detach().numpy()
std = torch.sqrt(torch.exp(logvar))

fig, axs = plt.subplots(4,5, figsize=(20,20))
for i in range(images.shape[0]):
    ax = axs[i//5][i%5]
    ax.imshow(images[i,0,...], cmap='gray')
    ax.axis('off')
    ax.set_title(f'z = {zs[i].item():.2} ({mus[i].item():.2}), ({std[i].item():.2})')

# %%
model.eval()
z = 0.0
noise_scale = 0.0
#xyz = torch.rand((batch_size,3))*64
xyz = torch.ones((1,3))*32
xyz[...,2] = z
xyz = xyz.view(1, -1, 3)
photon_scale = 1000
#photons = torch.rand((xyz.shape[1], 1))*photon_scale
photons = torch.ones((xyz.shape[1], 1))*photon_scale
frames = torch.cat([psf.forward(xyz[:,i,...], photons[i]) for i in range(xyz.shape[1])])
max_val = torch.max(frames)
frames = frames/max(21.28, max_val)
frames = frames.view(frames.shape[0],1,frames.shape[1], frames.shape[2])
noise = torch.rand((frames.shape))*noise_scale
frames = frames + noise
plt.imshow(frames[0,0,:,:], cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
torch.save(model, "/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/models/VAE_z_only_resnet_conv_beta4.pt")
torch.save(model.state_dict(), "/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/models/VAE_only_resnet_conv_beta4_sd.pt")

# %%
plt.plot(list(range(len(train_loss[100:]))), train_loss[100:])

# %%
plt.plot(list(range(len(train_losses[0]))), train_losses[0])

# %%
torch.cuda.empty_cache()

# %%
all_xys.shape
all_mus.shape
# Out:
# torch.Size([11000, 2])

# %%
model.eval()
# Out:
# tensor(21.2703)
# tensor(0., device='cuda:0')

# %%
plt.imshow(images[0, 0,:, :].cpu(), cmap='gray')
plt.show()
plt.imshow(reconstruction[0, 0,:, :].detach().cpu(), cmap='gray')

# %%
# Out:
# (array([[64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [58.,  6.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [55.,  9.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [47., 17.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [42., 22.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [36., 28.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [32., 29.,  3.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [30., 30.,  4.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [28., 31.,  5.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [27., 24., 13.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [27., 21., 13.,  3.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [25., 19., 15.,  3.,  2.,  0.,  0.,  0.,  0.,  0.],
#         [25., 11., 13., 10.,  5.,  0.,  0.,  0.,  0.,  0.],
#         [26.,  9.,  8.,  7.,  4., 10.,  0.,  0.,  0.,  0.],
#         [26.,  9.,  5.,  5.,  4.,  3.,  3.,  9.,  0.,  0.],
#         [27.,  8.,  6.,  4.,  3.,  3.,  2.,  2.,  4.,  5.],
#         [28.,  8.,  5.,  5.,  4.,  2.,  3.,  2.,  3.,  4.],
#         [29.,  9.,  6.,  4.,  5.,  4.,  3.,  4.,  0.,  0.],
#         [31.,  9.,  7.,  7.,  8.,  2.,  0.,  0.,  0.,  0.],
#         [32., 11., 20.,  1.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [35., 14., 15.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [38., 26.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [44., 20.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [49., 15.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [63.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [64.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]]),
#  array([0.        , 0.04646846, 0.09293692, 0.13940537, 0.18587384,
#         0.23234229, 0.27881074, 0.32527921, 0.37174767, 0.41821611,
#         0.46468458]),
#  <a list of 64 BarContainer objects>)

# %%
#model = model_conv_bigger.VAE_CNN_version_2().to(device)

#model.load_state_dict(torch.load("/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/models/Resnet_B2_VAE_4000.pt"))


images, xys, _ = create_psf_batch(batch_size=100)
model.eval()
images = images.to(device)
reconstruction, mu, logvar = model(images)
all_xys = xys
all_mus = mu
for i in range(100):
    images, xys, _ = create_psf_batch(batch_size=100)
    model.eval()
    images = images.to(device)
    reconstruction, mu, logvar = model(images)
    del reconstruction
    del images

    all_xys = torch.cat((all_xys, xys), dim=1)
    del xys
    all_mus = torch.cat((all_mus, mu), dim=0)
    del mu

# %%
yin = (all_xys[0,:,1]>-1) & (all_xys[0,:,1]<64)
xin = (all_xys[0,:,0]>-1) & (all_xys[0,:,0]<64)
zin = (all_xys[0,:,2]>-500) & (all_xys[0,:,2]<500)

both_in = xin&yin&zin

# %%
fig, axs = plt.subplots(3, 3)

for i in range(3):
    for j in range(3):
            predicted = all_mus[both_in,i].cpu().detach().numpy()
            x = all_xys[0,both_in,j]
            axs[i, j].plot(predicted, x, 'o', alpha=0.02)
            axs[i, j].axis('off')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[248], line 5
#       3 for i in range(3):
#       4     for j in range(3):
# ----> 5             predicted = all_mus[both_in,i].cpu().detach().numpy()
#       6             x = all_xys[0,both_in,j]
#       7             axs[i, j].plot(predicted, x, 'o', alpha=0.02)
#
# IndexError: index 1 is out of bounds for dimension 1 with size 1

# %%
noise_scales = [0,0.01, 0.1, 0.2, 0.5, 0.7]
import seaborn as sb
fig, axs = plt.subplots(3,2, constrained_layout=True, sharex=True)

beta = 2
for j in range(len(noise_scales)):
    noise_scale = noise_scales[j]
    model = model_conv_bigger.VAE_CNN_version_2(zDim=1).to(device)
    # beta = betas[j]
    model.load_state_dict(torch.load(f"/home/axtr7550/Chromosome_project/cellbgnet/Axel_notebook/VAE_tutorial/outputs/models/Resnet_B{beta}_VAE_z_only_200.pt"))

    images, xys, _ = create_psf_batch(batch_size=10)
    model.eval()
    noise = torch.rand((frames.shape))*noise_scale
    images = images + noise
    images = images.to(device)
    reconstruction, mu, logvar, _ = model(images)
    all_xys = xys
    all_mus = mu
    for i in range(100):
        images, xys, _ = create_psf_batch(batch_size=50)
        model.eval()
        noise = torch.rand((frames.shape))*noise_scale
        images = images + noise

        images = images.to(device)
        reconstruction, mu, logvar, _ = model(images)
        del reconstruction
        del images

        all_xys = torch.cat((all_xys, xys), dim=1)
        del xys
        all_mus = torch.cat((all_mus, mu), dim=0)


    predicted = all_mus[:,0].cpu().detach().numpy()
    x = all_xys[0,:,2]
    axs[j//2][j%2].plot(predicted, x,'o', alpha=0.1)
    axs[j//2][j%2].set_title(f"beta={beta}, noise: {noise_scale}")
    
fig.suptitle("VAE z only trained with 0 noise")
# Out:
# 173056
# (64, 64)
# 173056
# (64, 64)
# 173056
# (64, 64)
# 173056
# (64, 64)
# 173056
# (64, 64)
# 173056
# (64, 64)
# Text(0.5, 0.98, 'VAE z only trained with 0 noise')

# %%
-0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
# Out:
# tensor(1.2636, device='cuda:0', grad_fn=<MulBackward0>)

# %%
plt.hist(all_mus[:,0].cpu().detach().numpy())
# Out:
# (array([284.,  72.,  63.,  51.,  55.,  48.,  31.,  47.,  65., 294.]),
#  array([-0.46525842, -0.34745276, -0.2296471 , -0.11184144,  0.00596422,
#          0.12376988,  0.24157554,  0.3593812 ,  0.47718686,  0.59499252,
#          0.71279818]),
#  <BarContainer object of 10 artists>)

# %%
predicted = all_mus[both_in,1].cpu().detach().numpy()
x = all_xys[0,both_in,0]
plt.plot(predicted, x, 'o', alpha=0.1)

# %%
predicted = all_mus[both_in,2].cpu().detach().numpy()
x = all_xys[0,both_in,1]
plt.plot(predicted, x, 'o', alpha=0.1)

# %%
plt.plot(all_mus[:,1].cpu().detach().numpy(), all_mus[:,2].cpu().detach().numpy(), 'o', alpha=1)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

plt.plot(all_xys[0,:,0].cpu().detach().numpy(), all_xys[0,:,1].cpu().detach().numpy(), 'o', alpha=1)

# %%
images.max()
# Out:
# tensor(2.1374, device='cuda:0')

# %%
#both = torch.cat((data.view(batch_size, 1, 64, 64)[:8], 
                    reconstruction.view(batch_size, 1, 64, 64)[:8]))
#save_image(both.cpu(), f"../outputs/psf_output{epoch}.png", nrow=num_rows)

# %%
model.eval()
fig, axs = plt.subplots(8,8, sharex=True, sharey=True)
# decoding
fig.tight_layout()
for i in range(-4,4):
    for j in range(-4,4):
        z = torch.tensor([[float(i),float(j)]]).cuda()
        axs[i,j].imshow(reconstruction.view((64, 64)).cpu().detach().numpy(), cmap='gray')

plt.show()

# %%
reconstruction.view((64, 64))
# Out:
# tensor([[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 4.0368e-01, 3.2587e-01,
#          2.6970e-01],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 6.7344e-01, 4.9652e-01,
#          3.5723e-01],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 9.4673e-01, 8.1915e-01,
#          6.0063e-01],
#         ...,
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 2.4258e-36, 3.9615e-36,
#          4.5398e-36],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 5.4501e-39, 7.5286e-39,
#          5.2027e-39],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00]], device='cuda:0', grad_fn=<ViewBackward0>)

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
from statsmodels.formula.api import ols
predictions = all_mus[both_in,:].cpu().detach().numpy()
X = np.array(all_xys[0,both_in,:2])



train_X, test_X, train_Y, test_Y = skl.model_selection.train_test_split(predictions, X, test_size=0.2)
reg = LinearRegression().fit(np.concatenate([train_X, train_X**2], axis=1), train_Y)
error = np.sqrt(np.mean((reg.predict(np.concatenate([test_X, test_X**2], axis=1)) - test_Y)**2))
print(error)
# Out:
# 10.768504

# %%
df = pd.DataFrame(np.concatenate([predictions, X], axis=1), columns=["mux", "muy", "X", "Y"])
df
# Out:
#            mux       muy          X          Y
# 0     0.590835 -1.088881  33.769619  43.261154
# 1    -0.235529 -0.463075  54.439774  59.142441
# 2    -0.100780  0.574154  11.446047  17.861872
# 3     0.686940 -0.091562  28.948713  24.942631
# 4    -0.082744  0.470603  13.443804  19.228218
# ...        ...       ...        ...        ...
# 9241  0.283223 -1.349000  38.934818  42.622536
# 9242  0.330101 -0.425184  28.774563  54.524624
# 9243  0.308841  0.478308  13.271326  27.912254
# 9244 -0.767542  2.720012  50.244900  12.440348
# 9245 -0.893434  1.210410  36.103371   0.557209
#
# [9246 rows x 4 columns]

# %%
model = ols("X, Y ~ mux + muy", data=df)
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 model = ols("X, Y ~ mux + muy", data=df)
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/statsmodels/base/model.py:200, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     197 if missing == 'none':  # with patsy it's drop or raise. let's raise.
#     198     missing = 'raise'
# --> 200 tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     201                           missing=missing)
#     202 ((endog, exog), missing_idx, design_info) = tmp
#     203 max_endog = cls._formula_max_endog
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/statsmodels/formula/formulatools.py:63, in handle_formula_data(Y, X, formula, depth, missing)
#      61 else:
#      62     if data_util._is_using_pandas(Y, None):
# ---> 63         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                            NA_action=na_action)
#      65     else:
#      66         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      67                            NA_action=na_action)
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/patsy/highlevel.py:309, in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     299 """Construct two design matrices given a formula_like and data.
#     300
#     301 This function is identical to :func:`dmatrix`, except that it requires
#    (...)
#     306 See :func:`dmatrix` for details.
#     307 """
#     308 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 309 (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     310                                   NA_action, return_type)
#     311 if lhs.shape[1] == 0:
#     312     raise PatsyError("model is missing required outcome variables")
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/patsy/highlevel.py:167, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     164 design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                   NA_action)
#     166 if design_infos is not None:
# --> 167     return build_design_matrices(design_infos, data,
#     168                                  NA_action=NA_action,
#     169                                  return_type=return_type)
#     170 else:
#     171     # No builders, but maybe we can still get matrices
#     172     if isinstance(formula_like, tuple):
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/patsy/build.py:893, in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     891 name = factor_info.factor.name()
#     892 origin = factor_info.factor.origin
# --> 893 rows_checker.check(value.shape[0], name, origin)
#     894 if (have_pandas
#     895     and isinstance(value, (pandas.Series, pandas.DataFrame))):
#     896     index_checker.check(value.index, name, origin)
#
# File ~/anaconda3/envs/compile_spline/lib/python3.11/site-packages/patsy/build.py:795, in _CheckMatch.check(self, seen_value, desc, origin)
#     792     msg += " (%r versus %r)" % (self.value, seen_value)
#     793 # XX FIXME: this is a case where having discontiguous Origins
#     794 # would be useful...
# --> 795 raise PatsyError(msg, origin)
#
# PatsyError: Number of rows mismatch between data argument and X, Y (9246 versus 2)
#     X, Y ~ mux + muy
#     ^^^^

# %%
mus = torch.cat((torch.arange(-2,3,0.5).repeat(10).view(-1,1),torch.arange(-2,3,0.5).repeat_interleave(10).view(-1,1)),1)

# %%
model.eval()
z = mus.float().cuda()

reconstruction = model.decoder(z)

# %%
save_image(reconstruction.view((10*10, 1, 64,64)).cpu(), f"../outputs/conv_out/psf_beta4_test_values.png", nrow=10, pad_value=1)

# %%
reconstruction.shape
# Out:
# torch.Size([169, 4096])

# %%
from model_2_layer import simple_nn
simple_model = simple_nn(in_features=1, out_features=1)
lr = 0.001
optimizer_simple = optim.Adam(simple_model.parameters(), lr=lr)
loss_simple = nn.MSELoss()
# Out:
# Hej

# %%
def fit_simple(simple_model, train_X, train_Y):
    simple_model.train()
    running_loss = 0.0
    train_X = train_X.to(device)
    train_Y = train_Y.to(device)    
    batch_size = 64
    for i in range(len(train_X)//batch_size):
        data = train_X[i*batch_size:(i+1)*batch_size]
        gt = train_Y[i*batch_size:(i+1)*batch_size]
        optimizer_simple.zero_grad()
        output = simple_model(data)
        loss = loss_simple(output, gt)
        running_loss += loss.item()
        loss.backward()
        optimizer_simple.step()

    train_loss = running_loss/len(train_X)
    return train_loss

# %%
def validate_simple(model, test_X, test_y):
    model.eval()
    running_loss = 0.0
    batch_size = 64
    test_X = test_X.to(device)
    test_y = test_y.to(device)    


    with torch.no_grad():
        for i in range(len(test_X)//batch_size):
            data = test_X[i*batch_size:(i+1)*batch_size]
            gt = test_y[i*batch_size:(i+1)*batch_size]
            output = simple_model(data)
            loss = loss_simple(output, gt)
            running_loss += loss.item()

    val_loss = running_loss/len(test_X)
    return val_loss

# %%
import sklearn.model_selection as model_selection

predictions = all_mus[both_in,:]
X = all_xys[0,both_in,:2]
train_X, test_X, train_Y, test_Y = model_selection.train_test_split(predictions, X, test_size=0.2, shuffle=True, random_state=42)
#loss_vec = []
#val_loss_vec = []
simple_model.to(device)
train_X = train_X.detach()
test_X = test_X.detach()
for epoch in range(80):
    loss = fit_simple(simple_model, train_X, train_Y)
    loss_vec.append(loss)
    val_loss = validate_simple(simple_model, test_X, test_Y)
    val_loss_vec.append(val_loss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 import sklearn.model_selection as model_selection
# ----> 3 predictions = all_mus[both_in,:]
#       4 X = all_xys[0,both_in,:2]
#       5 train_X, test_X, train_Y, test_Y = model_selection.train_test_split(predictions, X, test_size=0.2, shuffle=True, random_state=42)
#
# NameError: name 'all_mus' is not defined

# %%
plt.plot(list(range(len(loss_vec))), loss_vec)
plt.plot(list(range(len(loss_vec))), val_loss_vec)

# %%
np.sqrt(val_loss_vec[-1])
# Out:
# 0.6587733752300137

# %%
# funktion y = 2x

x = torch.rand((64, 1))*100
shift = (torch.rand((64,1))-0.5)*50
x_shifted = x + shift

# %%
# Out:
# Hej

# %%
y = bigger_model(x)
y_shifted = bigger_model(x_shifted)

# %%
alphas = (y_shifted-y)/shift
alpha = alphas.mean()

# %%
alpha
# Out:
# tensor(7.6124e-06, grad_fn=<MeanBackward0>)

# %%
plt.plot(x.detach(), y.detach(), 'o')
plt.plot(x_shifted.detach(), y_shifted.detach(), 'o')

# %%
plt.plot(x.detach(), x.detach()*alpha.detach(), 'o')
plt.plot(x.detach(), y.detach(), 'o')
plt.plot(x_shifted.detach(), x.detach()*alpha.detach() + shift*alpha.detach(), 'o')
plt.plot(x_shifted.detach(), y_shifted.detach(), 'o')

# %%
def fit_bigger(model, batch_size=128):
    model.train()
    running_loss = 0.0
    x = torch.rand((batch_size, 2))*100
    x = x.to(device)
    shift = (torch.rand((batch_size,2))-0.5)*50
    indeces = torch.rand((batch_size)) > 0.5
    shift[indeces, 0] = 0
    shift[(indeces==0), 1] = 0

    shift = shift.to(device)
    x_shifted = x + shift 
    x_shifted = x_shifted.to(device)
    
    optimizer_bigger.zero_grad()

    y = model(x)
    y_shifted = model(x_shifted)

    temp = shift.clone()
    temp[temp==0] = 1
    alphas = (y_shifted-y)/temp
    alpha = alphas.mean(axis=0)
    alphas = alphas.to(device)
    alpha = alpha.to(device)
    
    #lossx = torch.mean((x*alpha - y)**2)
    loss_shifted = torch.mean((shift*alpha - (y_shifted-y))**2)
    spread_loss = torch.mean((1-torch.std(y, axis=0))**2)
    loss = (loss_shifted + spread_loss)/2
    
    running_loss += loss.item()
    loss.backward()
    optimizer_bigger.step()
    train_loss = running_loss/batch_size
    return train_loss, x, y, alpha

# %%
from model_2_layer import bigger_nn
bigger_model = bigger_nn(in_features=2, out_features=2)
lr = 0.0001
optimizer_bigger = optim.Adam(bigger_model.parameters(), lr=lr)
# Out:
# Hej

# %%
loss_vec = []
bigger_model.to(device)
for i in range(10000):
    train_loss, x, y, alpha = fit_bigger(bigger_model)
    loss_vec.append(train_loss)
    if i%1000 ==0:
        plt.plot(x.detach().cpu(), y.detach().cpu(), 'o')
        plt.title(f'{i}, alpha = {alpha[0].item()}')
        plt.show()

plt.plot(list(range(len(loss_vec)))[5:], loss_vec[5:], 'o')

# %%
1-torch.std(y, axis=0)
# Out:
# tensor([0.2173, 0.2536], device='cuda:0', grad_fn=<RsubBackward1>)

# %%
# Out:
# tensor([5.7839e-06, 1.0097e-05], device='cuda:0', grad_fn=<MeanBackward1>)
