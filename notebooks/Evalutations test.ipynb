# %%
# %reload_ext autoreload
# %autoreload 2
# %reload_ext notexbook
# %texify
# Out:
# <style type="text/css">
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
# */
#
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#                          FONTS
#
#     FONT WEIGHT MAP:
#     ----------------
#     100: Ultra Light
#     200: Thin
#     300: Light
#     400: Regular (normal)
#     500: Medium
#     600: Semi-bold
#     700: Bold
#     800: Heavy
#     900: Black
#
#     Font faces:
#         - ====================================|=======================
#         -              Scope                  | Font Family Name
#         - ====================================| ======================
#         - Markdown Display (Computer Modern)    (CMU Serif)
#         - Markdown Display monospace            (CMU Typewriter Text)
#         - Markdown Edit    monospace            (Hack)
#         - Source Code      monospace            (Fira Code)
#         - ====================================| =======================
#
#  ======================================================  */
#
# /* Roboto Slab */
# @import url("https://fonts.googleapis.com/css2?family=Roboto+Slab:wght@100;200;300;400;500;600;700;800;900&display=swap");
# /*md-display-computer-modern --> CMU Serif*/
# @import url("https://fonts.cdnfonts.com/css/cmu-serif?styles=30038,30039,30037,30036");
# /*md-display-monospace --> CMU Typewriter Text*/
# @import url("https://fonts.cdnfonts.com/css/cmu-typewriter-text?styles=24833,24829,24830,24831,24832,24834");
# /*code-monospace --> Fira Code*/
# @import url("https://fonts.googleapis.com/css2?family=Fira+Code:wght@300;400;500&display=swap");
# /*md-edit-monospace --> Hack*/
# @import url("https://fonts.cdnfonts.com/css/hack?styles=20708,20707,20705,20706");
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
# ======================================================
#
#
#     ---------------------------------
#     Code Mirror - Code Cell Highlight
#     ---------------------------------
#
#     Define the Style for Code **and** Markdown editors (Themes)
#     Theme files are all located in the "themes" folder, and the
#     different styles for the Code and Markdown editors are
#     distinguished by a common prefix in the file names:
#
#         --> Code editors Themes: "themes/code_*"
#         --> Markdown Editor Themes: "themes/md_*"
#
#     Styles can be imported as separate CSS modules.
#
#     Current stylesheet (editor.css) defines the CSS rules
#     for notebook tags and classes. These rules are
#     all based to colors defined in external Theme files.
#
#     This would ease the definition of other custom CSS Editor themes
# */
#
# /* Code Editor theme */
#
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#
# The color palette is inspired by Light
#  Material Design theme
# Repo: https://github.com/JonaDuran/Material-Light-Theme/
# */
#
# :root {
#     /* Color Palette */
#     --ml-white: #ffffff;
#     --ml-light-white: #FAFAFA;
#     --ml-black: #24292E;
#     --ml-dark-blue : #01579B11;
#     --ml-dark-blue-2: #01579B22;
#     --ml-blue: #1565C0;
#     --ml-green: #2E7D32;
#     --ml-yellow: #A8601A;
#     --ml-cyan: #00838f;
#     --ml-magenta: #9C00B0;
#     --ml-red: #C0392B;
#     --ml-grey: #9E9E9E;
#     --ml-light-blue: #78909c;
#
#
#     /* Editor Theme */
#     --code-background-color: var(--ml-light-white);
#     --gutter-background: var(--ml-light-white);
#     --selection-background-color: var(--ml-dark-blue-2);
#     --line-numbers: var(--ml-grey);
#     --cursor: var(--ml-black);
#     --bracket: var(--ml-black);
#     --matching-bracket: var(--ml-blue);
#     --code-text-color: var(--ml-black);
#     --keywords: var(--ml-magenta);
#     --types: var(--ml-magenta);
#     --variables: var(--code-text-color);
#     --variables2: var(--ml-green);
#     --def: var(--ml-blue);
#     --property: var(--ml-blue);
#     --meta: var(--ml-light-blue);
#     --builtin: var(--ml-blue);
#     --attribute: var(--ml-blue);
#     --strings: var(--ml-yellow);
#     --strings2: var(--ml-grey);
#     --comments: var(--ml-grey);
#     --operator: var(--ml-magenta);
#     --numbers: var(--ml-red);
#     /* Dataframe */
#     --dataframe: var(--code-text-color);
#     --df-bg: var(--ml-light-white);
#     --df-thead: var(--ml-blue);
#     --df-thead-border: var(--ml-black);
#     --df-tr-hover: var(--selection-background-color);
#     --df-border: var(--ml-white);
#     --df-border-right: var(--ml-grey);
#     --df-th-bg: var(--ml-white);
#     /*ANSI Colours*/
#     --ansi-red: var(--ml-red);
#     --ansi-green: var(--ml-green);
#     --ansi-green-intense: var(--ml-grey);
#     --ansi-cyan: var(--ml-cyan);
#     --ansi-blue: var(--ml-blue);
# }
#
#
#
# /* Markdown Editor theme */
#
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#
#     Custom Theme for Markdown Editor
#     based on Material Clear Theme.
#
#  */
#
# :root {
#     /* Color Palette */
#     --md-ml-red: #C0392B;
#     --md-ml-yellow: #A8601A;
#     --md-ml-black: #24292E;
#     --md-ml-grey: #9E9E9E;
#     --md-ml-blue: #1565C0;
#     --md-ml-dark-blue: #01579B;
#     --md-ml-light-blue: #78909c;
#
#     /*  Editor Theme  */
#     --editor-text: var(--md-ml-black);
#     --header: var(--md-ml-dark-blue);
#     --quote: var(--md-ml-grey);
#     --link: var(--md-ml-blue);
#     --attribute: var(--md-ml-red);
#     --tag: var(--md-ml-yellow);
#     --string: var(--md-ml-yellow);
#     --delimiter: var(--md-ml-black);
#     --monospace: var(--md-ml-light-blue);
# }
#
#
#
#
#
#
#
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
# */
#
# /*
#     =================
#     Code Editor Theme
#     =================
# */
# div.output_error pre,
# div.output_result pre,
# div.output_stream pre {
#     color: var(--code-text-color) !important;
# }
#
# .cm-s-ipython.CodeMirror,
# .cm-s-jupyter.CodeMirror {
#     background: var(--code-background-color);
#     color: var(--code-text-color);
# }
#
# .cm-s-ipython div.CodeMirror-selected,
# .cm-s-jupyter div.CodeMirror-selected {
#     cursor: pointer;
#     background: var(--selection-background-color);
# }
#
# .cm-s-ipython .CodeMirror-gutters,
# .cm-s-jupyter .CodeMirror-gutters {
#     background: var(--gutter-background);
#     border-right: 0;
# }
#
# .cm-s-ipython .CodeMirror-linenumber,
# .cm-s-jupyter .CodeMirror-linenumber {
#     color: var(--line-numbers);
# }
#
# .cm-s-ipython .CodeMirror-cursor,
# .cm-s-jupyter .CodeMirror-cursor {
#     border-left: 1px solid var(--cursor) !important;
# }
#
# .cm-s-ipython span.cm-bracket,
# .cm-s-jupyter span.cm-bracket {
#     /*color: #828282;*/
#     color: var(--bracket);
# }
#
# span.CodeMirror-matchingbracket {
#     text-decoration: underline !important;
#     text-decoration-color: var(--matching-bracket) !important;
#     color: var(--matching-bracket) !important;
# }
#
# .cm-s-ipython span.cm-keyword,
# .cm-s-jupyter span.cm-keyword {
#     color: var(--keywords);
#     font-weight: 400;
# }
#
# .cm-s-ipython span.cm-variable,
# .cm-s-jupyter span.cm-variable {
#     color: var(--variables);
# }
#
# .cm-s-ipython span.cm-variable-2,
# .cm-s-jupyter span.cm-variable-2 {
#     color: var(--variables2);
# }
#
# .cm-s-ipython span.cm-def,
# .cm-s-jupyter span.cm-def {
#     color: var(--def);
# }
#
# .cm-s-ipython span.cm-property,
# .cm-s-jupyter span.cm-property {
#     color: var(--property);
# }
#
# .cm-s-ipython span.cm-meta,
# .cm-s-jupyter span.cm-meta {
#     color: var(--meta);
# }
#
# .cm-s-ipython span.cm-attribute,
# .cm-s-jupyter span.cm-attribute {
#     color: var(--attribute);
# }
#
# .cm-s-ipython span.cm-builtin,
# .cm-s-jupyter span.cm-builtin {
#     color: var(--builtin)
# }
#
# .cm-s-ipython span.cm-string,
# .cm-s-jupyter span.cm-string {
#     color: var(--strings);
# }
#
# .cm-s-ipython span.cm-string-2,
# .cm-s-jupyter span.cm-string-2 {
#     color

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import time
import sys
sys.setrecursionlimit(10000)
# %matplotlib qt5

# %%
import cellbgnet
import cellbgnet.utils
from cellbgnet.datasets import DataSimulator
from cellbgnet.utils.hardware import cpu, gpu
from cellbgnet.model import CellBGModel

# %%
param_file = '../cellbgnet/utils/reference_files/reference.yaml'
param = cellbgnet.utils.param_io.ParamHandling().load_params(param_file)

# %%
psf_params = param.PSF.to_dict()
simulation_params = param.Simulation.to_dict()
hardware_params = param.Hardware.to_dict()
eval_params = param.Evaluation.to_dict()
train_size = simulation_params['train_size']

# %%
model = cellbgnet.model.CellBGModel(param)

# %%
model.init_recorder()
model.init_eval_data()
# Out:
# Already simulated 1024 evaluation images
# eval images shape: (1024, 128, 128) contain 4073 molecules,

# %%
model.evaluation_params['eval_imgs'].shape
# Out:
# (1024, 128, 128)

# %%
start_time = time.time()
model.fit(batch_size=32, max_iters=20000, print_output=True, print_freq=100)
duration = time.time() - start_time
# Out:
# Started training ....
#  || Cost: 253.512 || Time Upd.: 175.9 ms  || BatchNr.: 100
#  || Cost: 37.478 || Time Upd.: 160.6 ms  || BatchNr.: 200
#  || Cost: 23.961 || Time Upd.: 166.6 ms  || BatchNr.: 300
#  || Cost: 18.517 || Time Upd.: 166.3 ms  || BatchNr.: 400
#  || Cost: 14.827 || Time Upd.: 163.9 ms  || BatchNr.: 500
#  || Cost: 12.270 || Time Upd.: 162.0 ms  || BatchNr.: 600
#  || Cost: 7.011 || Time Upd.: 164.1 ms  || BatchNr.: 700
#  || Cost: 4.861 || Time Upd.: 163.5 ms  || BatchNr.: 800
#  || Cost: 4.325 || Time Upd.: 168.8 ms  || BatchNr.: 900
#  || Cost: 2.171 || Time Upd.: 162.9 ms  || BatchNr.: 1000
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:14797
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13043
# JoR: 2.554 || Eff_3d: 72.966 || Jaccard: 0.891 || Factor: 3.881 || RMSE_lat: 34.893 || RMSE_ax: 27.442 || RMSE_x: 24.904 || RMSE_y: 24.440 || Cost: 1.111 || Recall: 0.899 || Precision: 0.990 || BatchNr.: 1100 || Time Upd.: 161.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 72.966 || 34.893 || 27.442 || 1100
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15754
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13871
# JoR: 2.581 || Eff_3d: 75.007 || Jaccard: 0.924 || Factor: 4.127 || RMSE_lat: 35.811 || RMSE_ax: 22.038 || RMSE_x: 25.595 || RMSE_y: 25.047 || Cost: 0.396 || Recall: 0.944 || Precision: 0.977 || BatchNr.: 1200 || Time Upd.: 160.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 75.007 || 35.811 || 22.038 || 1200
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15160
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13340
# JoR: 2.655 || Eff_3d: 75.110 || Jaccard: 0.904 || Factor: 3.930 || RMSE_lat: 34.058 || RMSE_ax: 21.525 || RMSE_x: 24.594 || RMSE_y: 23.560 || Cost: -1.246 || Recall: 0.916 || Precision: 0.986 || BatchNr.: 1300 || Time Upd.: 159.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 75.110 || 34.058 || 21.525 || 1300
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15514
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13644
# JoR: 2.588 || Eff_3d: 74.513 || Jaccard: 0.921 || Factor: 4.069 || RMSE_lat: 35.606 || RMSE_ax: 24.389 || RMSE_x: 25.145 || RMSE_y: 25.210 || Cost: -2.252 || Recall: 0.935 || Precision: 0.984 || BatchNr.: 1400 || Time Upd.: 160.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 74.513 || 35.606 || 24.389 || 1400
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15590
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13733
# JoR: 2.366 || Eff_3d: 74.222 || Jaccard: 0.922 || Factor: 4.074 || RMSE_lat: 38.949 || RMSE_ax: 17.690 || RMSE_x: 28.944 || RMSE_y: 26.064 || Cost: -0.677 || Recall: 0.938 || Precision: 0.981 || BatchNr.: 1500 || Time Upd.: 162.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 74.222 || 38.949 || 17.690 || 1500
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15162
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13377
# JoR: 2.148 || Eff_3d: 72.080 || Jaccard: 0.914 || Factor: 3.931 || RMSE_lat: 42.560 || RMSE_ax: 17.939 || RMSE_x: 30.034 || RMSE_y: 30.155 || Cost: -0.384 || Recall: 0.923 || Precision: 0.990 || BatchNr.: 1600 || Time Upd.: 158.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 72.080 || 42.560 || 17.939 || 1600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15480
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13636
# JoR: 2.539 || Eff_3d: 75.734 || Jaccard: 0.924 || Factor: 4.009 || RMSE_lat: 36.379 || RMSE_ax: 16.806 || RMSE_x: 25.876 || RMSE_y: 25.570 || Cost: -2.359 || Recall: 0.936 || Precision: 0.985 || BatchNr.: 1700 || Time Upd.: 174.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 75.734 || 36.379 || 16.806 || 1700
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:14986
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13242
# JoR: 2.404 || Eff_3d: 73.674 || Jaccard: 0.912 || Factor: 3.855 || RMSE_lat: 37.924 || RMSE_ax: 21.026 || RMSE_x: 27.291 || RMSE_y: 26.332 || Cost: -2.449 || Recall: 0.917 || Precision: 0.994 || BatchNr.: 1800 || Time Upd.: 172.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 73.674 || 37.924 || 21.026 || 1800
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15747
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13861
# JoR: 2.631 || Eff_3d: 76.268 || Jaccard: 0.936 || Factor: 4.079 || RMSE_lat: 35.585 || RMSE_ax: 18.664 || RMSE_x: 25.481 || RMSE_y: 24.840 || Cost: -2.718 || Recall: 0.950 || Precision: 0.984 || BatchNr.: 1900 || Time Upd.: 164.6 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 76.268 || 35.585 || 18.664 || 1900
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15407
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13565
# JoR: 2.365 || Eff_3d: 74.202 || Jaccard: 0.926 || Factor: 3.945 || RMSE_lat: 39.145 || RMSE_ax: 18.238 || RMSE_x: 29.190 || RMSE_y: 26.082 || Cost: -4.177 || Recall: 0.935 || Precision: 0.989 || BatchNr.: 2000 || Time Upd.: 168.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 74.202 || 39.145 || 18.238 || 2000
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15673
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13747
# JoR: 2.761 || Eff_3d: 77.522 || Jaccard: 0.935 || Factor: 4.050 || RMSE_lat: 33.866 || RMSE_ax: 16.459 || RMSE_x: 24.290 || RMSE_y: 23.599 || Cost: -5.520 || Recall: 0.946 || Precision: 0.988 || BatchNr.: 2100 || Time Upd.: 166.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.522 || 33.866 || 16.459 || 2100
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16264
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14272
# JoR: 2.318 || Eff_3d: 73.223 || Jaccard: 0.943 || Factor: 4.234 || RMSE_lat: 40.684 || RMSE_ax: 22.201 || RMSE_x: 28.982 || RMSE_y: 28.552 || Cost: -6.535 || Recall: 0.968 || Precision: 0.973 || BatchNr.: 2200 || Time Upd.: 172.5 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 73.223 || 40.684 || 22.201 || 2200
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15510
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13618
# JoR: 2.489 || Eff_3d: 74.890 || Jaccard: 0.935 || Factor: 3.968 || RMSE_lat: 37.549 || RMSE_ax: 20.370 || RMSE_x: 26.380 || RMSE_y: 26.722 || Cost: -4.486 || Recall: 0.941 || Precision: 0.992 || BatchNr.: 2300 || Time Upd.: 162.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 74.890 || 37.549 || 20.370 || 2300
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15581
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13713
# JoR: 2.600 || Eff_3d: 75.472 || Jaccard: 0.931 || Factor: 3.998 || RMSE_lat: 35.796 || RMSE_ax: 21.017 || RMSE_x: 25.541 || RMSE_y: 25.080 || Cost: -6.460 || Recall: 0.943 || Precision: 0.987 || BatchNr.: 2400 || Time Upd.: 161.0 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 75.472 || 35.796 || 21.017 || 2400
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15665
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13740
# JoR: 2.577 || Eff_3d: 76.446 || Jaccard: 0.937 || Factor: 4.036 || RMSE_lat: 36.350 || RMSE_ax: 15.999 || RMSE_x: 25.917 || RMSE_y: 25.487 || Cost: -6.964 || Recall: 0.947 || Precision: 0.989 || BatchNr.: 2500 || Time Upd.: 162.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 76.446 || 36.350 || 15.999 || 2500
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16710
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14638
# JoR: 2.468 || Eff_3d: 74.935 || Jaccard: 0.940 || Factor: 4.335 || RMSE_lat: 38.081 || RMSE_ax: 19.772 || RMSE_x: 27.341 || RMSE_y: 26.507 || Cost: -6.767 || Recall: 0.979 || Precision: 0.959 || BatchNr.: 2600 || Time Upd.: 171.7 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 74.935 || 38.081 || 19.772 || 2600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15741
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13833
# JoR: 2.614 || Eff_3d: 76.672 || Jaccard: 0.948 || Factor: 4.041 || RMSE_lat: 36.270 || RMSE_ax: 17.110 || RMSE_x: 26.195 || RMSE_y: 25.087 || Cost: -7.337 || Recall: 0.956 || Precision: 0.992 || BatchNr.: 2700 || Time Upd.: 165.0 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 76.672 || 36.270 || 17.110 || 2700
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15532
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13635
# JoR: 2.558 || Eff_3d: 76.520 || Jaccard: 0.941 || Factor: 3.945 || RMSE_lat: 36.802 || RMSE_ax: 15.419 || RMSE_x: 26.602 || RMSE_y: 25.431 || Cost: -7.560 || Recall: 0.946 || Precision: 0.995 || BatchNr.: 2800 || Time Upd.: 167.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 76.520 || 36.802 || 15.419 || 2800
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15680
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13757
# JoR: 2.783 || Eff_3d: 77.762 || Jaccard: 0.950 || Factor: 3.990 || RMSE_lat: 34.134 || RMSE_ax: 17.268 || RMSE_x: 24.363 || RMSE_y: 23.908 || Cost: -7.431 || Recall: 0.954 || Precision: 0.995 || BatchNr.: 2900 || Time Upd.: 160.0 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.762 || 34.134 || 17.268 || 2900
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16269
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14236
# JoR: 2.760 || Eff_3d: 77.383 || Jaccard: 0.957 || Factor: 4.174 || RMSE_lat: 34.665 || RMSE_ax: 18.712 || RMSE_x: 24.692 || RMSE_y: 24.330 || Cost: -8.457 || Recall: 0.974 || Precision: 0.982 || BatchNr.: 3000 || Time Upd.: 160.0 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.383 || 34.665 || 18.712 || 3000
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15604
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13724
# JoR: 2.778 || Eff_3d: 77.450 || Jaccard: 0.950 || Factor: 3.942 || RMSE_lat: 34.180 || RMSE_ax: 18.537 || RMSE_x: 24.513 || RMSE_y: 23.820 || Cost: -8.827 || Recall: 0.953 || Precision: 0.996 || BatchNr.: 3100 || Time Upd.: 160.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.450 || 34.180 || 18.537 || 3100
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16130
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14166
# JoR: 2.753 || Eff_3d: 77.884 || Jaccard: 0.959 || Factor: 4.120 || RMSE_lat: 34.817 || RMSE_ax: 16.373 || RMSE_x: 25.070 || RMSE_y: 24.160 || Cost: -8.547 || Recall: 0.973 || Precision: 0.985 || BatchNr.: 3200 || Time Upd.: 161.3 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.884 || 34.817 || 16.373 || 3200
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15613
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13750
# JoR: 2.653 || Eff_3d: 77.061 || Jaccard: 0.949 || Factor: 3.942 || RMSE_lat: 35.790 || RMSE_ax: 16.639 || RMSE_x: 25.725 || RMSE_y: 24.883 || Cost: -6.194 || Recall: 0.954 || Precision: 0.995 || BatchNr.: 3300 || Time Upd.: 159.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.061 || 35.790 || 16.639 || 3300
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16088
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14120
# JoR: 2.662 || Eff_3d: 77.452 || Jaccard: 0.967 || Factor: 4.096 || RMSE_lat: 36.309 || RMSE_ax: 15.918 || RMSE_x: 26.151 || RMSE_y: 25.188 || Cost: -8.431 || Recall: 0.975 || Precision: 0.991 || BatchNr.: 3400 || Time Upd.: 160.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.452 || 36.309 || 15.918 || 3400
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15928
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13972
# JoR: 2.729 || Eff_3d: 77.348 || Jaccard: 0.963 || Factor: 4.056 || RMSE_lat: 35.277 || RMSE_ax: 18.195 || RMSE_x: 25.283 || RMSE_y: 24.601 || Cost: -7.025 || Recall: 0.968 || Precision: 0.994 || BatchNr.: 3500 || Time Upd.: 159.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.348 || 35.277 || 18.195 || 3500
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15972
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14038
# JoR: 2.741 || Eff_3d: 77.647 || Jaccard: 0.961 || Factor: 4.037 || RMSE_lat: 35.055 || RMSE_ax: 17.156 || RMSE_x: 25.133 || RMSE_y: 24.437 || Cost: -7.741 || Recall: 0.969 || Precision: 0.991 || BatchNr.: 3600 || Time Upd.: 158.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.647 || 35.055 || 17.156 || 3600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15869
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13930
# JoR: 2.628 || Eff_3d: 77.056 || Jaccard: 0.964 || Factor: 4.020 || RMSE_lat: 36.699 || RMSE_ax: 16.560 || RMSE_x: 26.252 || RMSE_y: 25.644 || Cost: -7.212 || Recall: 0.967 || Precision: 0.997 || BatchNr.: 3700 || Time Upd.: 159.6 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.056 || 36.699 || 16.560 || 3700
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16101
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14125
# JoR: 2.743 || Eff_3d: 77.639 || Jaccard: 0.965 || Factor: 4.092 || RMSE_lat: 35.193 || RMSE_ax: 17.394 || RMSE_x: 25.252 || RMSE_y: 24.513 || Cost: -9.440 || Recall: 0.975 || Precision: 0.990 || BatchNr.: 3800 || Time Upd.: 159.6 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.639 || 35.193 || 17.394 || 3800
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16171
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14171
# JoR: 2.678 || Eff_3d: 77.265 || Jaccard: 0.969 || Factor: 4.122 || RMSE_lat: 36.180 || RMSE_ax: 17.208 || RMSE_x: 25.181 || RMSE_y: 25.979 || Cost: -9.439 || Recall: 0.978 || Precision: 0.990 || BatchNr.: 3900 || Time Upd.: 161.7 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.265 || 36.180 || 17.208 || 3900
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16029
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14100
# JoR: 2.750 || Eff_3d: 77.884 || Jaccard: 0.974 || Factor: 4.051 || RMSE_lat: 35.406 || RMSE_ax: 16.641 || RMSE_x: 25.095 || RMSE_y: 24.976 || Cost: -8.614 || Recall: 0.978 || Precision: 0.995 || BatchNr.: 4000 || Time Upd.: 159.7 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.884 || 35.406 || 16.641 || 4000
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16006
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14099
# JoR: 2.681 || Eff_3d: 77.185 || Jaccard: 0.967 || Factor: 4.082 || RMSE_lat: 36.069 || RMSE_ax: 17.640 || RMSE_x: 25.449 || RMSE_y: 25.560 || Cost: -9.645 || Recall: 0.975 || Precision: 0.992 || BatchNr.: 4100 || Time Upd.: 160.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.185 || 36.069 || 17.640 || 4100
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15892
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13981
# JoR: 2.740 || Eff_3d: 77.943 || Jaccard: 0.963 || Factor: 4.027 || RMSE_lat: 35.157 || RMSE_ax: 15.940 || RMSE_x: 24.925 || RMSE_y: 24.794 || Cost: -9.257 || Recall: 0.969 || Precision: 0.994 || BatchNr.: 4200 || Time Upd.: 159.7 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.943 || 35.157 || 15.940 || 4200
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16022
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14090
# JoR: 2.792 || Eff_3d: 78.262 || Jaccard: 0.972 || Factor: 4.072 || RMSE_lat: 34.802 || RMSE_ax: 16.143 || RMSE_x: 24.805 || RMSE_y: 24.411 || Cost: -10.299 || Recall: 0.977 || Precision: 0.995 || BatchNr.: 4300 || Time Upd.: 159.7 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.262 || 34.802 || 16.143 || 4300
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15731
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13853
# JoR: 2.672 || Eff_3d: 77.482 || Jaccard: 0.961 || Factor: 3.910 || RMSE_lat: 35.954 || RMSE_ax: 15.903 || RMSE_x: 25.404 || RMSE_y: 25.443 || Cost: -10.169 || Recall: 0.963 || Precision: 0.998 || BatchNr.: 4400 || Time Upd.: 160.0 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.482 || 35.954 || 15.903 || 4400
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15776
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13876
# JoR: 2.717 || Eff_3d: 77.955 || Jaccard: 0.962 || Factor: 3.952 || RMSE_lat: 35.408 || RMSE_ax: 15.167 || RMSE_x: 25.406 || RMSE_y: 24.663 || Cost: -11.083 || Recall: 0.964 || Precision: 0.997 || BatchNr.: 4500 || Time Upd.: 164.0 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.955 || 35.408 || 15.167 || 4500
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15831
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13939
# JoR: 2.776 || Eff_3d: 78.223 || Jaccard: 0.966 || Factor: 3.947 || RMSE_lat: 34.819 || RMSE_ax: 15.776 || RMSE_x: 24.573 || RMSE_y: 24.668 || Cost: -10.460 || Recall: 0.969 || Precision: 0.997 || BatchNr.: 4600 || Time Upd.: 170.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.223 || 34.819 || 15.776 || 4600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16310
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14334
# JoR: 2.731 || Eff_3d: 77.988 || Jaccard: 0.974 || Factor: 4.163 || RMSE_lat: 35.643 || RMSE_ax: 15.700 || RMSE_x: 25.274 || RMSE_y: 25.132 || Cost: -9.910 || Recall: 0.986 || Precision: 0.987 || BatchNr.: 4700 || Time Upd.: 178.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.988 || 35.643 || 15.700 || 4700
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16082
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14162
# JoR: 2.780 || Eff_3d: 78.371 || Jaccard: 0.975 || Factor: 4.076 || RMSE_lat: 35.071 || RMSE_ax: 15.408 || RMSE_x: 24.866 || RMSE_y: 24.732 || Cost: -10.584 || Recall: 0.981 || Precision: 0.994 || BatchNr.: 4800 || Time Upd.: 170.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.371 || 35.071 || 15.408 || 4800
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15787
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13904
# JoR: 2.524 || Eff_3d: 75.875 || Jaccard: 0.964 || Factor: 3.944 || RMSE_lat: 38.196 || RMSE_ax: 18.422 || RMSE_x: 26.554 || RMSE_y: 27.456 || Cost: -9.846 || Recall: 0.966 || Precision: 0.998 || BatchNr.: 4900 || Time Upd.: 164.3 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 75.875 || 38.196 || 18.422 || 4900
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16108
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14165
# JoR: 2.538 || Eff_3d: 76.643 || Jaccard: 0.972 || Factor: 4.104 || RMSE_lat: 38.308 || RMSE_ax: 15.672 || RMSE_x: 26.973 || RMSE_y: 27.203 || Cost: -10.127 || Recall: 0.980 || Precision: 0.993 || BatchNr.: 5000 || Time Upd.: 173.7 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 76.643 || 38.308 || 15.672 || 5000
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16260
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14305
# JoR: 2.770 || Eff_3d: 78.270 || Jaccard: 0.974 || Factor: 4.142 || RMSE_lat: 35.159 || RMSE_ax: 15.567 || RMSE_x: 25.221 || RMSE_y: 24.497 || Cost: -10.185 || Recall: 0.985 || Precision: 0.988 || BatchNr.: 5100 || Time Upd.: 160.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.270 || 35.159 || 15.567 || 5100
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16059
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14122
# JoR: 2.676 || Eff_3d: 77.770 || Jaccard: 0.977 || Factor: 4.050 || RMSE_lat: 36.510 || RMSE_ax: 15.075 || RMSE_x: 26.597 || RMSE_y: 25.012 || Cost: -11.509 || Recall: 0.980 || Precision: 0.996 || BatchNr.: 5200 || Time Upd.: 164.0 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.770 || 36.510 || 15.075 || 5200
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15902
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14008
# JoR: 2.792 || Eff_3d: 78.783 || Jaccard: 0.971 || Factor: 3.965 || RMSE_lat: 34.765 || RMSE_ax: 13.902 || RMSE_x: 24.922 || RMSE_y: 24.239 || Cost: -11.619 || Recall: 0.973 || Precision: 0.997 || BatchNr.: 5300 || Time Upd.: 159.5 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.783 || 34.765 || 13.902 || 5300
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15900
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14015
# JoR: 2.702 || Eff_3d: 77.863 || Jaccard: 0.970 || Factor: 3.998 || RMSE_lat: 35.887 || RMSE_ax: 15.362 || RMSE_x: 25.746 || RMSE_y: 25.001 || Cost: -11.996 || Recall: 0.973 || Precision: 0.996 || BatchNr.: 5400 || Time Upd.: 161.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.863 || 35.887 || 15.362 || 5400
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15947
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14037
# JoR: 2.807 || Eff_3d: 78.760 || Jaccard: 0.974 || Factor: 3.976 || RMSE_lat: 34.687 || RMSE_ax: 14.456 || RMSE_x: 24.473 || RMSE_y: 24.582 || Cost: -10.686 || Recall: 0.976 || Precision: 0.998 || BatchNr.: 5500 || Time Upd.: 162.0 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.760 || 34.687 || 14.456 || 5500
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16030
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14109
# JoR: 2.860 || Eff_3d: 78.805 || Jaccard: 0.977 || Factor: 4.017 || RMSE_lat: 34.161 || RMSE_ax: 15.641 || RMSE_x: 24.428 || RMSE_y: 23.880 || Cost: -12.006 || Recall: 0.980 || Precision: 0.997 || BatchNr.: 5600 || Time Upd.: 162.6 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.805 || 34.161 || 15.641 || 5600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15929
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14024
# JoR: 2.723 || Eff_3d: 78.333 || Jaccard: 0.972 || Factor: 3.972 || RMSE_lat: 35.707 || RMSE_ax: 13.998 || RMSE_x: 25.942 || RMSE_y: 24.536 || Cost: -11.162 || Recall: 0.975 || Precision: 0.998 || BatchNr.: 5700 || Time Upd.: 160.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.333 || 35.707 || 13.998 || 5700
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16134
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14214
# JoR: 2.764 || Eff_3d: 78.463 || Jaccard: 0.976 || Factor: 4.072 || RMSE_lat: 35.324 || RMSE_ax: 14.591 || RMSE_x: 25.239 || RMSE_y: 24.715 || Cost: -11.897 || Recall: 0.983 || Precision: 0.993 || BatchNr.: 5800 || Time Upd.: 165.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.463 || 35.324 || 14.591 || 5800
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16240
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14277
# JoR: 2.628 || Eff_3d: 77.539 || Jaccard: 0.973 || Factor: 4.128 || RMSE_lat: 37.020 || RMSE_ax: 14.650 || RMSE_x: 26.192 || RMSE_y: 26.161 || Cost: -11.777 || Recall: 0.984 || Precision: 0.989 || BatchNr.: 5900 || Time Upd.: 159.6 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.539 || 37.020 || 14.650 || 5900
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15842
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 13966
# JoR: 2.793 || Eff_3d: 78.796 || Jaccard: 0.969 || Factor: 3.941 || RMSE_lat: 34.686 || RMSE_ax: 13.826 || RMSE_x: 24.773 || RMSE_y: 24.277 || Cost: -10.903 || Recall: 0.971 || Precision: 0.998 || BatchNr.: 6000 || Time Upd.: 159.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.796 || 34.686 || 13.826 || 6000
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15911
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14019
# JoR: 2.822 || Eff_3d: 78.461 || Jaccard: 0.969 || Factor: 3.976 || RMSE_lat: 34.344 || RMSE_ax: 16.055 || RMSE_x: 24.699 || RMSE_y: 23.864 || Cost: -12.598 || Recall: 0.973 || Precision: 0.996 || BatchNr.: 6100 || Time Upd.: 160.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.461 || 34.344 || 16.055 || 6100
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15945
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14040
# JoR: 2.797 || Eff_3d: 78.908 || Jaccard: 0.974 || Factor: 3.959 || RMSE_lat: 34.810 || RMSE_ax: 13.569 || RMSE_x: 25.005 || RMSE_y: 24.217 || Cost: -11.877 || Recall: 0.976 || Precision: 0.998 || BatchNr.: 6200 || Time Upd.: 160.6 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.908 || 34.810 || 13.569 || 6200
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16230
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14267
# JoR: 2.754 || Eff_3d: 78.441 || Jaccard: 0.979 || Factor: 4.135 || RMSE_lat: 35.548 || RMSE_ax: 14.410 || RMSE_x: 25.448 || RMSE_y: 24.821 || Cost: -11.622 || Recall: 0.986 || Precision: 0.992 || BatchNr.: 6300 || Time Upd.: 159.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.441 || 35.548 || 14.410 || 6300
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16111
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14172
# JoR: 2.696 || Eff_3d: 77.939 || Jaccard: 0.981 || Factor: 4.055 || RMSE_lat: 36.386 || RMSE_ax: 14.905 || RMSE_x: 25.885 || RMSE_y: 25.571 || Cost: -11.606 || Recall: 0.984 || Precision: 0.997 || BatchNr.: 6400 || Time Upd.: 161.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 77.939 || 36.386 || 14.905 || 6400
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16048
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14147
# JoR: 2.838 || Eff_3d: 78.738 || Jaccard: 0.980 || Factor: 4.016 || RMSE_lat: 34.529 || RMSE_ax: 15.349 || RMSE_x: 24.461 || RMSE_y: 24.371 || Cost: -11.106 || Recall: 0.983 || Precision: 0.997 || BatchNr.: 6500 || Time Upd.: 164.5 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.738 || 34.529 || 15.349 || 6500
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16016
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14106
# JoR: 2.820 || Eff_3d: 79.094 || Jaccard: 0.978 || Factor: 4.018 || RMSE_lat: 34.683 || RMSE_ax: 13.407 || RMSE_x: 24.474 || RMSE_y: 24.574 || Cost: -11.986 || Recall: 0.980 || Precision: 0.997 || BatchNr.: 6600 || Time Upd.: 173.0 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.094 || 34.683 || 13.407 || 6600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15982
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14089
# JoR: 2.768 || Eff_3d: 78.006 || Jaccard: 0.975 || Factor: 3.993 || RMSE_lat: 35.232 || RMSE_ax: 16.612 || RMSE_x: 25.454 || RMSE_y: 24.359 || Cost: -12.403 || Recall: 0.978 || Precision: 0.997 || BatchNr.: 6700 || Time Upd.: 164.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.006 || 35.232 || 16.612 || 6700
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15978
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14075
# JoR: 2.824 || Eff_3d: 79.146 || Jaccard: 0.976 || Factor: 3.983 || RMSE_lat: 34.576 || RMSE_ax: 13.293 || RMSE_x: 24.627 || RMSE_y: 24.269 || Cost: -11.730 || Recall: 0.979 || Precision: 0.998 || BatchNr.: 6800 || Time Upd.: 165.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.146 || 34.576 || 13.293 || 6800
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16140
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14187
# JoR: 2.764 || Eff_3d: 78.494 || Jaccard: 0.982 || Factor: 4.062 || RMSE_lat: 35.508 || RMSE_ax: 14.451 || RMSE_x: 25.416 || RMSE_y: 24.796 || Cost: -11.986 || Recall: 0.985 || Precision: 0.996 || BatchNr.: 6900 || Time Upd.: 164.0 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.494 || 35.508 || 14.451 || 6900
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16132
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14195
# JoR: 2.800 || Eff_3d: 78.788 || Jaccard: 0.979 || Factor: 4.062 || RMSE_lat: 34.978 || RMSE_ax: 14.176 || RMSE_x: 24.905 || RMSE_y: 24.560 || Cost: -12.290 || Recall: 0.984 || Precision: 0.995 || BatchNr.: 7000 || Time Upd.: 160.0 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.788 || 34.978 || 14.176 || 7000
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16045
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14115
# JoR: 2.859 || Eff_3d: 79.333 || Jaccard: 0.978 || Factor: 4.015 || RMSE_lat: 34.204 || RMSE_ax: 13.415 || RMSE_x: 24.373 || RMSE_y: 23.997 || Cost: -12.586 || Recall: 0.981 || Precision: 0.997 || BatchNr.: 7100 || Time Upd.: 168.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.333 || 34.204 || 13.415 || 7100
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15960
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14055
# JoR: 2.770 || Eff_3d: 78.539 || Jaccard: 0.976 || Factor: 3.969 || RMSE_lat: 35.226 || RMSE_ax: 14.421 || RMSE_x: 24.918 || RMSE_y: 24.899 || Cost: -12.629 || Recall: 0.977 || Precision: 0.998 || BatchNr.: 7200 || Time Upd.: 165.7 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.539 || 35.226 || 14.421 || 7200
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16004
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14097
# JoR: 2.701 || Eff_3d: 78.269 || Jaccard: 0.978 || Factor: 3.964 || RMSE_lat: 36.208 || RMSE_ax: 13.672 || RMSE_x: 26.152 || RMSE_y: 25.042 || Cost: -12.578 || Recall: 0.980 || Precision: 0.998 || BatchNr.: 7300 || Time Upd.: 167.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.269 || 36.208 || 13.672 || 7300
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15924
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14023
# JoR: 2.854 || Eff_3d: 78.989 || Jaccard: 0.972 || Factor: 3.959 || RMSE_lat: 34.073 || RMSE_ax: 14.660 || RMSE_x: 24.344 || RMSE_y: 23.839 || Cost: -12.604 || Recall: 0.975 || Precision: 0.998 || BatchNr.: 7400 || Time Upd.: 159.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.989 || 34.073 || 14.660 || 7400
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15977
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14061
# JoR: 2.808 || Eff_3d: 78.859 || Jaccard: 0.976 || Factor: 3.968 || RMSE_lat: 34.757 || RMSE_ax: 14.077 || RMSE_x: 24.987 || RMSE_y: 24.160 || Cost: -12.863 || Recall: 0.978 || Precision: 0.998 || BatchNr.: 7500 || Time Upd.: 158.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.859 || 34.757 || 14.077 || 7500
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16134
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14189
# JoR: 2.778 || Eff_3d: 78.645 || Jaccard: 0.981 || Factor: 4.058 || RMSE_lat: 35.331 || RMSE_ax: 14.177 || RMSE_x: 25.175 || RMSE_y: 24.789 || Cost: -12.706 || Recall: 0.985 || Precision: 0.996 || BatchNr.: 7600 || Time Upd.: 158.3 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.645 || 35.331 || 14.177 || 7600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15947
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14046
# JoR: 2.885 || Eff_3d: 79.171 || Jaccard: 0.975 || Factor: 3.966 || RMSE_lat: 33.794 || RMSE_ax: 14.725 || RMSE_x: 24.113 || RMSE_y: 23.676 || Cost: -11.898 || Recall: 0.977 || Precision: 0.998 || BatchNr.: 7700 || Time Upd.: 158.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.171 || 33.794 || 14.725 || 7700
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16124
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14187
# JoR: 2.823 || Eff_3d: 78.891 || Jaccard: 0.982 || Factor: 4.047 || RMSE_lat: 34.794 || RMSE_ax: 14.320 || RMSE_x: 24.841 || RMSE_y: 24.363 || Cost: -13.024 || Recall: 0.985 || Precision: 0.997 || BatchNr.: 7800 || Time Upd.: 158.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.891 || 34.794 || 14.320 || 7800
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16016
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14100
# JoR: 2.870 || Eff_3d: 79.376 || Jaccard: 0.978 || Factor: 3.994 || RMSE_lat: 34.073 || RMSE_ax: 13.511 || RMSE_x: 24.290 || RMSE_y: 23.894 || Cost: -13.143 || Recall: 0.980 || Precision: 0.998 || BatchNr.: 7900 || Time Upd.: 162.5 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.376 || 34.073 || 13.511 || 7900
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16208
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14245
# JoR: 2.824 || Eff_3d: 78.679 || Jaccard: 0.983 || Factor: 4.102 || RMSE_lat: 34.822 || RMSE_ax: 15.194 || RMSE_x: 24.818 || RMSE_y: 24.427 || Cost: -12.527 || Recall: 0.988 || Precision: 0.995 || BatchNr.: 8000 || Time Upd.: 163.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.679 || 34.822 || 15.194 || 8000
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16220
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14265
# JoR: 2.781 || Eff_3d: 78.710 || Jaccard: 0.987 || Factor: 4.100 || RMSE_lat: 35.481 || RMSE_ax: 13.898 || RMSE_x: 25.429 || RMSE_y: 24.744 || Cost: -12.591 || Recall: 0.990 || Precision: 0.996 || BatchNr.: 8100 || Time Upd.: 162.0 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.710 || 35.481 || 13.898 || 8100
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15966
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14054
# JoR: 2.884 || Eff_3d: 79.621 || Jaccard: 0.976 || Factor: 3.975 || RMSE_lat: 33.844 || RMSE_ax: 12.807 || RMSE_x: 24.103 || RMSE_y: 23.759 || Cost: -13.363 || Recall: 0.978 || Precision: 0.998 || BatchNr.: 8200 || Time Upd.: 161.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.621 || 33.844 || 12.807 || 8200
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:15953
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14065
# JoR: 2.874 || Eff_3d: 79.426 || Jaccard: 0.975 || Factor: 3.959 || RMSE_lat: 33.925 || RMSE_ax: 13.350 || RMSE_x: 24.133 || RMSE_y: 23.844 || Cost: -13.534 || Recall: 0.977 || Precision: 0.997 || BatchNr.: 8300 || Time Upd.: 162.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.426 || 33.925 || 13.350 || 8300
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16126
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14188
# JoR: 2.773 || Eff_3d: 78.832 || Jaccard: 0.977 || Factor: 4.062 || RMSE_lat: 35.244 || RMSE_ax: 13.292 || RMSE_x: 24.836 || RMSE_y: 25.006 || Cost: -13.592 || Recall: 0.983 || Precision: 0.994 || BatchNr.: 8400 || Time Upd.: 161.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.832 || 35.244 || 13.292 || 8400
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16046
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14124
# JoR: 2.777 || Eff_3d: 78.437 || Jaccard: 0.979 || Factor: 4.002 || RMSE_lat: 35.249 || RMSE_ax: 15.047 || RMSE_x: 24.940 || RMSE_y: 24.910 || Cost: -13.303 || Recall: 0.981 || Precision: 0.997 || BatchNr.: 8500 || Time Upd.: 161.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.437 || 35.249 || 15.047 || 8500
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16011
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14091
# JoR: 2.831 || Eff_3d: 79.343 || Jaccard: 0.978 || Factor: 3.978 || RMSE_lat: 34.538 || RMSE_ax: 12.643 || RMSE_x: 24.548 || RMSE_y: 24.296 || Cost: -13.557 || Recall: 0.980 || Precision: 0.998 || BatchNr.: 8600 || Time Upd.: 165.5 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.343 || 34.538 || 12.643 || 8600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16044
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14132
# JoR: 2.753 || Eff_3d: 78.520 || Jaccard: 0.979 || Factor: 3.988 || RMSE_lat: 35.576 || RMSE_ax: 14.059 || RMSE_x: 25.425 || RMSE_y: 24.885 || Cost: -13.314 || Recall: 0.982 || Precision: 0.997 || BatchNr.: 8700 || Time Upd.: 162.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.520 || 35.576 || 14.059 || 8700
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16024
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14115
# JoR: 2.859 || Eff_3d: 78.581 || Jaccard: 0.979 || Factor: 3.982 || RMSE_lat: 34.259 || RMSE_ax: 16.526 || RMSE_x: 24.521 || RMSE_y: 23.925 || Cost: -12.834 || Recall: 0.981 || Precision: 0.998 || BatchNr.: 8800 || Time Upd.: 161.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 78.581 || 34.259 || 16.526 || 8800
#
#
# ...
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.946 || 33.948 || 11.924 || 17400
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16154
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14248
# JoR: 2.873 || Eff_3d: 79.732 || Jaccard: 0.987 || Factor: 3.970 || RMSE_lat: 34.358 || RMSE_ax: 12.038 || RMSE_x: 24.460 || RMSE_y: 24.129 || Cost: -15.828 || Recall: 0.990 || Precision: 0.997 || BatchNr.: 17500 || Time Upd.: 162.7 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.732 || 34.358 || 12.038 || 17500
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16150
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14231
# JoR: 2.892 || Eff_3d: 79.917 || Jaccard: 0.987 || Factor: 3.990 || RMSE_lat: 34.144 || RMSE_ax: 11.728 || RMSE_x: 24.227 || RMSE_y: 24.059 || Cost: -16.247 || Recall: 0.989 || Precision: 0.998 || BatchNr.: 17600 || Time Upd.: 158.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.917 || 34.144 || 11.728 || 17600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16141
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14218
# JoR: 2.883 || Eff_3d: 79.828 || Jaccard: 0.986 || Factor: 3.977 || RMSE_lat: 34.203 || RMSE_ax: 11.907 || RMSE_x: 24.391 || RMSE_y: 23.977 || Cost: -15.838 || Recall: 0.988 || Precision: 0.998 || BatchNr.: 17700 || Time Upd.: 159.3 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.828 || 34.203 || 11.907 || 17700
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16173
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14233
# JoR: 2.925 || Eff_3d: 79.940 || Jaccard: 0.987 || Factor: 4.008 || RMSE_lat: 33.741 || RMSE_ax: 12.441 || RMSE_x: 23.994 || RMSE_y: 23.722 || Cost: -15.836 || Recall: 0.989 || Precision: 0.998 || BatchNr.: 17800 || Time Upd.: 162.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.940 || 33.741 || 12.441 || 17800
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16173
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14237
# JoR: 2.926 || Eff_3d: 80.116 || Jaccard: 0.987 || Factor: 4.006 || RMSE_lat: 33.752 || RMSE_ax: 11.718 || RMSE_x: 24.006 || RMSE_y: 23.725 || Cost: -15.705 || Recall: 0.990 || Precision: 0.998 || BatchNr.: 17900 || Time Upd.: 164.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 80.116 || 33.752 || 11.718 || 17900
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16159
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14244
# JoR: 2.910 || Eff_3d: 79.920 || Jaccard: 0.988 || Factor: 3.994 || RMSE_lat: 33.945 || RMSE_ax: 12.148 || RMSE_x: 24.081 || RMSE_y: 23.924 || Cost: -15.931 || Recall: 0.990 || Precision: 0.998 || BatchNr.: 18000 || Time Upd.: 171.7 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.920 || 33.945 || 12.148 || 18000
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16174
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14226
# JoR: 2.861 || Eff_3d: 79.738 || Jaccard: 0.986 || Factor: 4.003 || RMSE_lat: 34.474 || RMSE_ax: 11.735 || RMSE_x: 24.573 || RMSE_y: 24.179 || Cost: -15.851 || Recall: 0.989 || Precision: 0.998 || BatchNr.: 18100 || Time Upd.: 163.7 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.738 || 34.474 || 11.735 || 18100
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16159
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14240
# JoR: 2.798 || Eff_3d: 79.265 || Jaccard: 0.988 || Factor: 4.004 || RMSE_lat: 35.311 || RMSE_ax: 12.035 || RMSE_x: 25.401 || RMSE_y: 24.530 || Cost: -16.288 || Recall: 0.990 || Precision: 0.998 || BatchNr.: 18200 || Time Upd.: 165.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.265 || 35.311 || 12.035 || 18200
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16134
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14210
# JoR: 2.930 || Eff_3d: 80.124 || Jaccard: 0.986 || Factor: 3.987 || RMSE_lat: 33.652 || RMSE_ax: 11.811 || RMSE_x: 23.955 || RMSE_y: 23.636 || Cost: -15.820 || Recall: 0.988 || Precision: 0.998 || BatchNr.: 18300 || Time Upd.: 165.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 80.124 || 33.652 || 11.811 || 18300
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16154
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14247
# JoR: 2.893 || Eff_3d: 79.811 || Jaccard: 0.988 || Factor: 3.982 || RMSE_lat: 34.136 || RMSE_ax: 12.188 || RMSE_x: 24.337 || RMSE_y: 23.937 || Cost: -15.943 || Recall: 0.990 || Precision: 0.997 || BatchNr.: 18400 || Time Upd.: 164.3 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.811 || 34.136 || 12.188 || 18400
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16171
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14258
# JoR: 2.940 || Eff_3d: 80.167 || Jaccard: 0.988 || Factor: 3.993 || RMSE_lat: 33.620 || RMSE_ax: 11.831 || RMSE_x: 23.942 || RMSE_y: 23.602 || Cost: -16.242 || Recall: 0.991 || Precision: 0.997 || BatchNr.: 18500 || Time Upd.: 163.0 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 80.167 || 33.620 || 11.831 || 18500
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16164
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14238
# JoR: 2.940 || Eff_3d: 80.122 || Jaccard: 0.987 || Factor: 4.016 || RMSE_lat: 33.580 || RMSE_ax: 12.035 || RMSE_x: 23.877 || RMSE_y: 23.612 || Cost: -16.038 || Recall: 0.990 || Precision: 0.998 || BatchNr.: 18600 || Time Upd.: 162.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 80.122 || 33.580 || 12.035 || 18600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16157
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14252
# JoR: 2.943 || Eff_3d: 80.218 || Jaccard: 0.988 || Factor: 4.007 || RMSE_lat: 33.558 || RMSE_ax: 11.708 || RMSE_x: 23.835 || RMSE_y: 23.623 || Cost: -15.748 || Recall: 0.990 || Precision: 0.997 || BatchNr.: 18700 || Time Upd.: 176.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 80.218 || 33.558 || 11.708 || 18700
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16173
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14239
# JoR: 2.943 || Eff_3d: 80.262 || Jaccard: 0.988 || Factor: 3.988 || RMSE_lat: 33.556 || RMSE_ax: 11.537 || RMSE_x: 23.929 || RMSE_y: 23.524 || Cost: -16.044 || Recall: 0.990 || Precision: 0.998 || BatchNr.: 18800 || Time Upd.: 180.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 80.262 || 33.556 || 11.537 || 18800
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16103
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14213
# JoR: 2.899 || Eff_3d: 79.944 || Jaccard: 0.985 || Factor: 3.968 || RMSE_lat: 33.974 || RMSE_ax: 11.823 || RMSE_x: 24.218 || RMSE_y: 23.827 || Cost: -16.029 || Recall: 0.988 || Precision: 0.997 || BatchNr.: 18900 || Time Upd.: 174.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.944 || 33.974 || 11.823 || 18900
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16185
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14257
# JoR: 2.941 || Eff_3d: 80.186 || Jaccard: 0.987 || Factor: 3.995 || RMSE_lat: 33.579 || RMSE_ax: 11.784 || RMSE_x: 23.900 || RMSE_y: 23.587 || Cost: -16.050 || Recall: 0.990 || Precision: 0.997 || BatchNr.: 19000 || Time Upd.: 161.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 80.186 || 33.579 || 11.784 || 19000
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16165
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14236
# JoR: 2.941 || Eff_3d: 80.220 || Jaccard: 0.987 || Factor: 4.012 || RMSE_lat: 33.574 || RMSE_ax: 11.659 || RMSE_x: 23.921 || RMSE_y: 23.559 || Cost: -16.018 || Recall: 0.990 || Precision: 0.998 || BatchNr.: 19100 || Time Upd.: 163.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 80.220 || 33.574 || 11.659 || 19100
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16153
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14232
# JoR: 2.945 || Eff_3d: 80.314 || Jaccard: 0.987 || Factor: 3.987 || RMSE_lat: 33.513 || RMSE_ax: 11.362 || RMSE_x: 23.814 || RMSE_y: 23.580 || Cost: -16.160 || Recall: 0.989 || Precision: 0.998 || BatchNr.: 19200 || Time Upd.: 162.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 80.314 || 33.513 || 11.362 || 19200
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16180
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14260
# JoR: 2.925 || Eff_3d: 80.116 || Jaccard: 0.989 || Factor: 4.002 || RMSE_lat: 33.820 || RMSE_ax: 11.667 || RMSE_x: 24.111 || RMSE_y: 23.716 || Cost: -16.051 || Recall: 0.991 || Precision: 0.998 || BatchNr.: 19300 || Time Upd.: 162.5 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 80.116 || 33.820 || 11.667 || 19300
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16164
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14243
# JoR: 2.906 || Eff_3d: 79.949 || Jaccard: 0.987 || Factor: 4.000 || RMSE_lat: 33.950 || RMSE_ax: 11.952 || RMSE_x: 24.174 || RMSE_y: 23.837 || Cost: -15.698 || Recall: 0.989 || Precision: 0.997 || BatchNr.: 19400 || Time Upd.: 164.6 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.949 || 33.950 || 11.952 || 19400
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16133
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14235
# JoR: 2.897 || Eff_3d: 79.988 || Jaccard: 0.987 || Factor: 3.992 || RMSE_lat: 34.080 || RMSE_ax: 11.565 || RMSE_x: 24.243 || RMSE_y: 23.952 || Cost: -15.857 || Recall: 0.990 || Precision: 0.998 || BatchNr.: 19500 || Time Upd.: 170.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.988 || 34.080 || 11.565 || 19500
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16151
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14230
# JoR: 2.937 || Eff_3d: 80.239 || Jaccard: 0.987 || Factor: 4.005 || RMSE_lat: 33.617 || RMSE_ax: 11.481 || RMSE_x: 23.966 || RMSE_y: 23.574 || Cost: -16.131 || Recall: 0.989 || Precision: 0.998 || BatchNr.: 19600 || Time Upd.: 167.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 80.239 || 33.617 || 11.481 || 19600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16195
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14267
# JoR: 2.894 || Eff_3d: 79.725 || Jaccard: 0.989 || Factor: 4.032 || RMSE_lat: 34.189 || RMSE_ax: 12.509 || RMSE_x: 24.378 || RMSE_y: 23.971 || Cost: -15.955 || Recall: 0.992 || Precision: 0.998 || BatchNr.: 19700 || Time Upd.: 165.5 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.725 || 34.189 || 12.509 || 19700
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16189
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14260
# JoR: 2.943 || Eff_3d: 80.173 || Jaccard: 0.988 || Factor: 4.032 || RMSE_lat: 33.554 || RMSE_ax: 11.901 || RMSE_x: 23.908 || RMSE_y: 23.543 || Cost: -16.062 || Recall: 0.991 || Precision: 0.997 || BatchNr.: 19800 || Time Upd.: 164.7 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 80.173 || 33.554 || 11.901 || 19800
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16146
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14235
# JoR: 2.935 || Eff_3d: 79.955 || Jaccard: 0.987 || Factor: 3.999 || RMSE_lat: 33.627 || RMSE_ax: 12.610 || RMSE_x: 23.943 || RMSE_y: 23.612 || Cost: -16.062 || Recall: 0.989 || Precision: 0.998 || BatchNr.: 19900 || Time Upd.: 163.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 79.955 || 33.627 || 12.610 || 19900
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 16422, preds:16183
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 14352 ,preds: 14258
# JoR: 2.951 || Eff_3d: 80.290 || Jaccard: 0.988 || Factor: 4.003 || RMSE_lat: 33.481 || RMSE_ax: 11.584 || RMSE_x: 23.818 || RMSE_y: 23.530 || Cost: -16.117 || Recall: 0.991 || Precision: 0.997 || BatchNr.: 20000 || Time Upd.: 163.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 80.290 || 33.481 || 11.584 || 20000
#
#
# training finished!

# %%
print("Duration of training: ", duration, 's')
# Out:
# Duration of training:  6645.295006990433 s

# %%
def plot_od(od, label=None, col=None):
    """Produces a line plot from a ordered dictionary as used to store training process in the Model class
    
    Parameters
    ----------
    od: OrderedDict of floats
        DECODE model
    label: str
        Label
    col: 'str'
        Color
    """
    plt.plot(*zip(*sorted(od.items())), label=label, color=col)

def plot_train_record(model):
    plt.figure(figsize=(9,6),constrained_layout=True)
    plt.subplot(3,3,1);plot_od(model.recorder['rmse_lat']);plt.xlabel('iterations');plt.ylabel('RMSE_Lateral')
    plt.subplot(3,3,2);plot_od(model.recorder['rmse_ax']);plt.xlabel('iterations');plt.ylabel('RMSE_Axial')
    plt.subplot(3,3,3);plot_od(model.recorder['rmse_vol']);plt.xlabel('iterations');plt.ylabel('RMSE_Voxel')
    plt.subplot(3,3,4);plot_od(model.recorder['eff_lat']);plt.xlabel('iterations');plt.ylabel('lateral efficiency')
    plt.subplot(3,3,5);plot_od(model.recorder['eff_3d']);plt.xlabel('iterations');plt.ylabel('3D efficiency')
    plt.subplot(3,3,6);plot_od(model.recorder['recall']);plt.xlabel('iterations');plt.ylabel('recall')
    plt.subplot(3,3,7);plot_od(model.recorder['precision']);plt.xlabel('iterations');plt.ylabel('precision')
    plt.subplot(3,3,8);plot_od(model.recorder['jaccard']);plt.xlabel('iterations');plt.ylabel('jaccard')
    plt.subplot(3,3,9);plot_od(model.recorder['cost_hist']);plt.xlabel('iterations');plt.ylabel('cost')
    # plt.subplots_adjust(wspace=0.5,hspace=0.5)
    # plt.tight_layout()
    plt.show(block=True)

# %%
plot_train_record(model)

# %% [markdown]
# ### Evaluation data

# %%
eval_size_x = eval_params['eval_size']
eval_size_y = eval_params['eval_size']
density = eval_params['molecules_per_img']

prob_map = np.ones([1, eval_size_x, eval_size_y])
# no molecules on the boundary
prob_map[0, int(eval_params['margin_empty'] * eval_size_y): int((1-eval_params['margin_empty']) * eval_size_y),
            int(eval_params['margin_empty'] * eval_size_x): int((1-eval_params['margin_empty']) * eval_size_x)] += 1
prob_map = (prob_map / prob_map.sum()) * density

# %%
ground_truth = []
eval_imgs = np.zeros([1, eval_size_y, eval_size_x])
for j in range(eval_params['number_images']):
    imgs_sim, xyzi_mat, s_mask, psf_est, locs = model.data_generator.simulate_data(
            prob_map=gpu(prob_map), batch_size=1, local_context=model.local_context,
            photon_filter=False, photon_filter_threshold=0, P_locs_cse=False,
            iter_num=model._iter_count, train_size=eval_size_x)
    imgs_tmp = cpu(imgs_sim)[:, 1] if model.local_context else cpu(imgs_sim)[:, 0]
    eval_imgs = np.concatenate((eval_imgs, imgs_tmp), axis = 0)
    
    # pool all the xyzi values
    for i in range(xyzi_mat.shape[1]):
        ground_truth.append(
                [i + 1, j + 1, cpu(xyzi_mat[0, i, 0]) * model.data_generator.psf_params['pixel_size_xy'][0],
                cpu(xyzi_mat[0, i, 1]) * model.data_generator.psf_params['pixel_size_xy'][1],
                cpu(xyzi_mat[0, i, 2]) * model.data_generator.psf_params['z_scale'],
                cpu(xyzi_mat[0, i, 3]) * model.data_generator.psf_params['photon_scale']]
        )
    print('{}{}{}'.format('\rAlready simulated ', j+1, ' evaluation images'), end='')

eval_params['eval_imgs'] = eval_imgs[1:]
eval_params['ground_truth'] = ground_truth
eval_params['fov_size'] = [eval_size_x * model.data_generator.psf_params['pixel_size_xy'][0],
                          eval_size_y * model.data_generator.psf_params['pixel_size_xy'][1]]
print('\neval images shape:', eval_params['eval_imgs'].shape, 'contain', len(ground_truth), 'molecules,')
# Out:
# Already simulated 1024 evaluation images
# eval images shape: (1024, 128, 128) contain 4010 molecules,

# %%
eval_params['fov_size']
# Out:
# [8320, 8320]

# %%
plt.figure(constrained_layout=True)
ax_tmp = plt.subplot(1,1,1)
img_tmp = plt.imshow(eval_params['eval_imgs'][16])
plt.colorbar(mappable=img_tmp,ax=ax_tmp, fraction=0.046, pad=0.04)
plt.title('the first image of eval set,check the background')
# plt.tight_layout()
plt.show()
