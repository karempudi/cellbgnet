# %%
# %reload_ext autoreload
# %autoreload 2
# %reload_ext notexbook
# %texify
# Out:
# <style type="text/css">
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
# */
#
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#                          FONTS
#
#     FONT WEIGHT MAP:
#     ----------------
#     100: Ultra Light
#     200: Thin
#     300: Light
#     400: Regular (normal)
#     500: Medium
#     600: Semi-bold
#     700: Bold
#     800: Heavy
#     900: Black
#
#     Font faces:
#         - ====================================|=======================
#         -              Scope                  | Font Family Name
#         - ====================================| ======================
#         - Markdown Display (Computer Modern)    (CMU Serif)
#         - Markdown Display monospace            (CMU Typewriter Text)
#         - Markdown Edit    monospace            (Hack)
#         - Source Code      monospace            (Fira Code)
#         - ====================================| =======================
#
#  ======================================================  */
#
# /* Roboto Slab */
# @import url("https://fonts.googleapis.com/css2?family=Roboto+Slab:wght@100;200;300;400;500;600;700;800;900&display=swap");
# /*md-display-computer-modern --> CMU Serif*/
# @import url("https://fonts.cdnfonts.com/css/cmu-serif?styles=30038,30039,30037,30036");
# /*md-display-monospace --> CMU Typewriter Text*/
# @import url("https://fonts.cdnfonts.com/css/cmu-typewriter-text?styles=24833,24829,24830,24831,24832,24834");
# /*code-monospace --> Fira Code*/
# @import url("https://fonts.googleapis.com/css2?family=Fira+Code:wght@300;400;500&display=swap");
# /*md-edit-monospace --> Hack*/
# @import url("https://fonts.cdnfonts.com/css/hack?styles=20708,20707,20705,20706");
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
# ======================================================
#
#
#     ---------------------------------
#     Code Mirror - Code Cell Highlight
#     ---------------------------------
#
#     Define the Style for Code **and** Markdown editors (Themes)
#     Theme files are all located in the "themes" folder, and the
#     different styles for the Code and Markdown editors are
#     distinguished by a common prefix in the file names:
#
#         --> Code editors Themes: "themes/code_*"
#         --> Markdown Editor Themes: "themes/md_*"
#
#     Styles can be imported as separate CSS modules.
#
#     Current stylesheet (editor.css) defines the CSS rules
#     for notebook tags and classes. These rules are
#     all based to colors defined in external Theme files.
#
#     This would ease the definition of other custom CSS Editor themes
# */
#
# /* Code Editor theme */
#
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#
# The color palette is inspired by Light
#  Material Design theme
# Repo: https://github.com/JonaDuran/Material-Light-Theme/
# */
#
# :root {
#     /* Color Palette */
#     --ml-white: #ffffff;
#     --ml-light-white: #FAFAFA;
#     --ml-black: #24292E;
#     --ml-dark-blue : #01579B11;
#     --ml-dark-blue-2: #01579B22;
#     --ml-blue: #1565C0;
#     --ml-green: #2E7D32;
#     --ml-yellow: #A8601A;
#     --ml-cyan: #00838f;
#     --ml-magenta: #9C00B0;
#     --ml-red: #C0392B;
#     --ml-grey: #9E9E9E;
#     --ml-light-blue: #78909c;
#
#
#     /* Editor Theme */
#     --code-background-color: var(--ml-light-white);
#     --gutter-background: var(--ml-light-white);
#     --selection-background-color: var(--ml-dark-blue-2);
#     --line-numbers: var(--ml-grey);
#     --cursor: var(--ml-black);
#     --bracket: var(--ml-black);
#     --matching-bracket: var(--ml-blue);
#     --code-text-color: var(--ml-black);
#     --keywords: var(--ml-magenta);
#     --types: var(--ml-magenta);
#     --variables: var(--code-text-color);
#     --variables2: var(--ml-green);
#     --def: var(--ml-blue);
#     --property: var(--ml-blue);
#     --meta: var(--ml-light-blue);
#     --builtin: var(--ml-blue);
#     --attribute: var(--ml-blue);
#     --strings: var(--ml-yellow);
#     --strings2: var(--ml-grey);
#     --comments: var(--ml-grey);
#     --operator: var(--ml-magenta);
#     --numbers: var(--ml-red);
#     /* Dataframe */
#     --dataframe: var(--code-text-color);
#     --df-bg: var(--ml-light-white);
#     --df-thead: var(--ml-blue);
#     --df-thead-border: var(--ml-black);
#     --df-tr-hover: var(--selection-background-color);
#     --df-border: var(--ml-white);
#     --df-border-right: var(--ml-grey);
#     --df-th-bg: var(--ml-white);
#     /*ANSI Colours*/
#     --ansi-red: var(--ml-red);
#     --ansi-green: var(--ml-green);
#     --ansi-green-intense: var(--ml-grey);
#     --ansi-cyan: var(--ml-cyan);
#     --ansi-blue: var(--ml-blue);
# }
#
#
#
# /* Markdown Editor theme */
#
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#
#     Custom Theme for Markdown Editor
#     based on Material Clear Theme.
#
#  */
#
# :root {
#     /* Color Palette */
#     --md-ml-red: #C0392B;
#     --md-ml-yellow: #A8601A;
#     --md-ml-black: #24292E;
#     --md-ml-grey: #9E9E9E;
#     --md-ml-blue: #1565C0;
#     --md-ml-dark-blue: #01579B;
#     --md-ml-light-blue: #78909c;
#
#     /*  Editor Theme  */
#     --editor-text: var(--md-ml-black);
#     --header: var(--md-ml-dark-blue);
#     --quote: var(--md-ml-grey);
#     --link: var(--md-ml-blue);
#     --attribute: var(--md-ml-red);
#     --tag: var(--md-ml-yellow);
#     --string: var(--md-ml-yellow);
#     --delimiter: var(--md-ml-black);
#     --monospace: var(--md-ml-light-blue);
# }
#
#
#
#
#
#
#
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
# */
#
# /*
#     =================
#     Code Editor Theme
#     =================
# */
# div.output_error pre,
# div.output_result pre,
# div.output_stream pre {
#     color: var(--code-text-color) !important;
# }
#
# .cm-s-ipython.CodeMirror,
# .cm-s-jupyter.CodeMirror {
#     background: var(--code-background-color);
#     color: var(--code-text-color);
# }
#
# .cm-s-ipython div.CodeMirror-selected,
# .cm-s-jupyter div.CodeMirror-selected {
#     cursor: pointer;
#     background: var(--selection-background-color);
# }
#
# .cm-s-ipython .CodeMirror-gutters,
# .cm-s-jupyter .CodeMirror-gutters {
#     background: var(--gutter-background);
#     border-right: 0;
# }
#
# .cm-s-ipython .CodeMirror-linenumber,
# .cm-s-jupyter .CodeMirror-linenumber {
#     color: var(--line-numbers);
# }
#
# .cm-s-ipython .CodeMirror-cursor,
# .cm-s-jupyter .CodeMirror-cursor {
#     border-left: 1px solid var(--cursor) !important;
# }
#
# .cm-s-ipython span.cm-bracket,
# .cm-s-jupyter span.cm-bracket {
#     /*color: #828282;*/
#     color: var(--bracket);
# }
#
# span.CodeMirror-matchingbracket {
#     text-decoration: underline !important;
#     text-decoration-color: var(--matching-bracket) !important;
#     color: var(--matching-bracket) !important;
# }
#
# .cm-s-ipython span.cm-keyword,
# .cm-s-jupyter span.cm-keyword {
#     color: var(--keywords);
#     font-weight: 400;
# }
#
# .cm-s-ipython span.cm-variable,
# .cm-s-jupyter span.cm-variable {
#     color: var(--variables);
# }
#
# .cm-s-ipython span.cm-variable-2,
# .cm-s-jupyter span.cm-variable-2 {
#     color: var(--variables2);
# }
#
# .cm-s-ipython span.cm-def,
# .cm-s-jupyter span.cm-def {
#     color: var(--def);
# }
#
# .cm-s-ipython span.cm-property,
# .cm-s-jupyter span.cm-property {
#     color: var(--property);
# }
#
# .cm-s-ipython span.cm-meta,
# .cm-s-jupyter span.cm-meta {
#     color: var(--meta);
# }
#
# .cm-s-ipython span.cm-attribute,
# .cm-s-jupyter span.cm-attribute {
#     color: var(--attribute);
# }
#
# .cm-s-ipython span.cm-builtin,
# .cm-s-jupyter span.cm-builtin {
#     color: var(--builtin)
# }
#
# .cm-s-ipython span.cm-string,
# .cm-s-jupyter span.cm-string {
#     color: var(--strings);
# }
#
# .cm-s-ipython span.cm-string-2,
# .cm-s-jupyter span.cm-string-2 {
#     color

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import time
import sys
sys.setrecursionlimit(10000)
# %matplotlib qt5

# %%
import cellbgnet
import cellbgnet.utils
from cellbgnet.datasets import DataSimulator
from cellbgnet.utils.hardware import cpu, gpu
from cellbgnet.model import CellBGModel

# %%
param_file = '../../cellbgnet/utils/reference_files/reference.yaml'
param = cellbgnet.utils.param_io.ParamHandling().load_params(param_file)

# %%
psf_params = param.PSF.to_dict()
simulation_params = param.Simulation.to_dict()
hardware_params = param.Hardware.to_dict()
eval_params = param.Evaluation.to_dict()
train_size = simulation_params['train_size']

# %%
model = cellbgnet.model.CellBGModel(param)
# Out:
# training sliding windows on camera chip:
# Area num: 0, field_xy: [0, 127, 0, 127]
# Area num: 1, field_xy: [114, 241, 0, 127]
# Area num: 2, field_xy: [228, 355, 0, 127]
# Area num: 3, field_xy: [342, 469, 0, 127]
# Area num: 4, field_xy: [456, 583, 0, 127]
# Area num: 5, field_xy: [570, 697, 0, 127]
# Area num: 6, field_xy: [684, 811, 0, 127]
# Area num: 7, field_xy: [798, 925, 0, 127]
# Area num: 8, field_xy: [912, 1039, 0, 127]
# Area num: 9, field_xy: [1026, 1153, 0, 127]
# Area num: 10, field_xy: [1140, 1267, 0, 127]
# Area num: 11, field_xy: [1174, 1301, 0, 127]
# Area num: 12, field_xy: [0, 127, 114, 241]
# Area num: 13, field_xy: [114, 241, 114, 241]
# Area num: 14, field_xy: [228, 355, 114, 241]
# Area num: 15, field_xy: [342, 469, 114, 241]
# Area num: 16, field_xy: [456, 583, 114, 241]
# Area num: 17, field_xy: [570, 697, 114, 241]
# Area num: 18, field_xy: [684, 811, 114, 241]
# Area num: 19, field_xy: [798, 925, 114, 241]
# Area num: 20, field_xy: [912, 1039, 114, 241]
# Area num: 21, field_xy: [1026, 1153, 114, 241]
# Area num: 22, field_xy: [1140, 1267, 114, 241]
# Area num: 23, field_xy: [1174, 1301, 114, 241]
# Area num: 24, field_xy: [0, 127, 228, 355]
# Area num: 25, field_xy: [114, 241, 228, 355]
# Area num: 26, field_xy: [228, 355, 228, 355]
# Area num: 27, field_xy: [342, 469, 228, 355]
# Area num: 28, field_xy: [456, 583, 228, 355]
# Area num: 29, field_xy: [570, 697, 228, 355]
# Area num: 30, field_xy: [684, 811, 228, 355]
# Area num: 31, field_xy: [798, 925, 228, 355]
# Area num: 32, field_xy: [912, 1039, 228, 355]
# Area num: 33, field_xy: [1026, 1153, 228, 355]
# Area num: 34, field_xy: [1140, 1267, 228, 355]
# Area num: 35, field_xy: [1174, 1301, 228, 355]
# Area num: 36, field_xy: [0, 127, 342, 469]
# Area num: 37, field_xy: [114, 241, 342, 469]
# Area num: 38, field_xy: [228, 355, 342, 469]
# Area num: 39, field_xy: [342, 469, 342, 469]
# Area num: 40, field_xy: [456, 583, 342, 469]
# Area num: 41, field_xy: [570, 697, 342, 469]
# Area num: 42, field_xy: [684, 811, 342, 469]
# Area num: 43, field_xy: [798, 925, 342, 469]
# Area num: 44, field_xy: [912, 1039, 342, 469]
# Area num: 45, field_xy: [1026, 1153, 342, 469]
# Area num: 46, field_xy: [1140, 1267, 342, 469]
# Area num: 47, field_xy: [1174, 1301, 342, 469]
# Area num: 48, field_xy: [0, 127, 456, 583]
# Area num: 49, field_xy: [114, 241, 456, 583]
# Area num: 50, field_xy: [228, 355, 456, 583]
# Area num: 51, field_xy: [342, 469, 456, 583]
# Area num: 52, field_xy: [456, 583, 456, 583]
# Area num: 53, field_xy: [570, 697, 456, 583]
# Area num: 54, field_xy: [684, 811, 456, 583]
# Area num: 55, field_xy: [798, 925, 456, 583]
# Area num: 56, field_xy: [912, 1039, 456, 583]
# Area num: 57, field_xy: [1026, 1153, 456, 583]
# Area num: 58, field_xy: [1140, 1267, 456, 583]
# Area num: 59, field_xy: [1174, 1301, 456, 583]
# Area num: 60, field_xy: [0, 127, 570, 697]
# Area num: 61, field_xy: [114, 241, 570, 697]
# Area num: 62, field_xy: [228, 355, 570, 697]
# Area num: 63, field_xy: [342, 469, 570, 697]
# Area num: 64, field_xy: [456, 583, 570, 697]
# Area num: 65, field_xy: [570, 697, 570, 697]
# Area num: 66, field_xy: [684, 811, 570, 697]
# Area num: 67, field_xy: [798, 925, 570, 697]
# Area num: 68, field_xy: [912, 1039, 570, 697]
# Area num: 69, field_xy: [1026, 1153, 570, 697]
# Area num: 70, field_xy: [1140, 1267, 570, 697]
# Area num: 71, field_xy: [1174, 1301, 570, 697]
# Area num: 72, field_xy: [0, 127, 684, 811]
# Area num: 73, field_xy: [114, 241, 684, 811]
# Area num: 74, field_xy: [228, 355, 684, 811]
# Area num: 75, field_xy: [342, 469, 684, 811]
# Area num: 76, field_xy: [456, 583, 684, 811]
# Area num: 77, field_xy: [570, 697, 684, 811]
# Area num: 78, field_xy: [684, 811, 684, 811]
# Area num: 79, field_xy: [798, 925, 684, 811]
# Area num: 80, field_xy: [912, 1039, 684, 811]
# Area num: 81, field_xy: [1026, 1153, 684, 811]
# Area num: 82, field_xy: [1140, 1267, 684, 811]
# Area num: 83, field_xy: [1174, 1301, 684, 811]
# Area num: 84, field_xy: [0, 127, 798, 925]
# Area num: 85, field_xy: [114, 241, 798, 925]
# Area num: 86, field_xy: [228, 355, 798, 925]
# Area num: 87, field_xy: [342, 469, 798, 925]
# Area num: 88, field_xy: [456, 583, 798, 925]
# Area num: 89, field_xy: [570, 697, 798, 925]
# Area num: 90, field_xy: [684, 811, 798, 925]
# Area num: 91, field_xy: [798, 925, 798, 925]
# Area num: 92, field_xy: [912, 1039, 798, 925]
# Area num: 93, field_xy: [1026, 1153, 798, 925]
# Area num: 94, field_xy: [1140, 1267, 798, 925]
# Area num: 95, field_xy: [1174, 1301, 798, 925]
# Area num: 96, field_xy: [0, 127, 912, 1039]
# Area num: 97, field_xy: [114, 241, 912, 1039]
# Area num: 98, field_xy: [228, 355, 912, 1039]
# Area num: 99, field_xy: [342, 469, 912, 1039]
# Area num: 100, field_xy: [456, 583, 912, 1039]
# Area num: 101, field_xy: [570, 697, 912, 1039]
# Area num: 102, field_xy: [684, 811, 912, 1039]
# Area num: 103, field_xy: [798, 925, 912, 1039]
# Area num: 104, field_xy: [912, 1039, 912, 1039]
# Area num: 105, field_xy: [1026, 1153, 912, 1039]
# Area num: 106, field_xy: [1140, 1267, 912, 1039]
# Area num: 107, field_xy: [1174, 1301, 912, 1039]
# Area num: 108, field_xy: [0, 127, 913, 1040]
# Area num: 109, field_xy: [114, 241, 913, 1040]
# Area num: 110, field_xy: [228, 355, 913, 1040]
# Area num: 111, field_xy: [342, 469, 913, 1040]
# Area num: 112, field_xy: [456, 583, 913, 1040]
# Area num: 113, field_xy: [570, 697, 913, 1040]
# Area num: 114, field_xy: [684, 811, 913, 1040]
# Area num: 115, field_xy: [798, 925, 913, 1040]
# Area num: 116, field_xy: [912, 1039, 913, 1040]
# Area num: 117, field_xy: [1026, 1153, 913, 1040]
# Area num: 118, field_xy: [1140, 1267, 913, 1040]
# Area num: 119, field_xy: [1174, 1301, 913, 1040]

# %%
model.init_recorder()
model.init_eval_data()
# Out:
# Eval image generation:   0%|                             | 0/30 [00:00<?, ?it/s]/home/pk/Documents/cellbgnet/cellbgnet/utils/hardware.py:9: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   return torch.cuda.FloatTensor(x.astype('float32'))
# Eval image generation: 100%|████████████████████| 30/30 [00:10<00:00,  2.77it/s]
# eval images shape: (30, 1041, 1302) contain 21339 molecules,

# %%
model.evaluation_params['eval_imgs'].shape
# Out:
# (30, 1041, 1302)

# %%
simulation_params
# Out:
# {'train_size': 128,
#  'train_type': 'cells',
#  'psf_intensity_normalization': True,
#  'density': 0.003125,
#  'non_cell_density': 10,
#  'margin_empty': 0.05,
#  'z_prior': [-1, 1],
#  'survival_prob': None,
#  'min_photon': 0.25,
#  'camera': 'sCMOS',
#  'camera_chip_size': [1041, 1302],
#  'perlin_noise': False,
#  'perlin_noise_factor': 0.2,
#  'perlin_noise_res': 64,
#  'baseline': 103.0,
#  'bg_values': 112.0,
#  'bg_width': 2,
#  'e_per_adu': 0.38,
#  'qe': 0.95,
#  'spurious_c': 0.0,
#  'sig_read': '/mnt/sda1/SMLAT/data/real_data/dark_images/RN_e_venus_upgraded.tiff',
#  'robust_training': False,
#  'cell_masks_dir': '/mnt/sda1/SMLAT/data/real_data/chromosome_dots/EXP-23-CA3045/pool_3045_ter_pos01/phase_venus_mask/',
#  'cell_masks_filetype': '.png',
#  'edt_noise_map_path': '/mnt/sda1/SMLAT/data/real_data/chromosome_dots/EXP-23-CA3045/edt_noise.pkl',
#  'min_edt': 0,
#  'max_edt': 6,
#  'augment': True}

# %%
start_time = time.time()
model.fit(batch_size=64, max_iters=10000, print_output=True, print_freq=100)
duration = time.time() - start_time
# Out:
# Started training ....
#  || Cost: 3495.410 || Time Upd.: 642.0 ms  || BatchNr.: 100
#  || Cost: 172.493 || Time Upd.: 652.5 ms  || BatchNr.: 200
#  || Cost: 75.823 || Time Upd.: 641.3 ms  || BatchNr.: 300
#  || Cost: 54.221 || Time Upd.: 654.4 ms  || BatchNr.: 400
#  || Cost: 36.623 || Time Upd.: 629.2 ms  || BatchNr.: 500
#  || Cost: 25.934 || Time Upd.: 638.8 ms  || BatchNr.: 600
#  || Cost: 25.618 || Time Upd.: 638.7 ms  || BatchNr.: 700
#  || Cost: 29.948 || Time Upd.: 629.7 ms  || BatchNr.: 800
#  || Cost: 20.675 || Time Upd.: 605.4 ms  || BatchNr.: 900
#  || Cost: 18.182 || Time Upd.: 604.7 ms  || BatchNr.: 1000
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 17144
# JoR: 2.147 || Eff_3d: 44.802 || Jaccard: 0.803 || Factor: 609.672 || RMSE_lat: 37.412 || RMSE_ax: 130.452 || RMSE_x: 25.504 || RMSE_y: 27.372 || Cost: 19.261 || Recall: 0.804 || Precision: 0.999 || BatchNr.: 1100 || Time Upd.: 599.3 ms
#  || Count Cost: 16.0578 || Localization Cost: 5.7230 || Bg Cost: 0.0822 || P_locs Cost: 15.0027saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 44.802 || 37.412 || 130.452 || 1100
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 18426
# JoR: 2.224 || Eff_3d: 43.163 || Jaccard: 0.860 || Factor: 760.489 || RMSE_lat: 38.662 || RMSE_ax: 142.355 || RMSE_x: 25.482 || RMSE_y: 29.076 || Cost: 9.938 || Recall: 0.862 || Precision: 0.997 || BatchNr.: 1200 || Time Upd.: 605.3 ms
#  || Count Cost: 14.7513 || Localization Cost: 0.0407 || Bg Cost: 0.0428 || P_locs Cost: 14.0908saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 43.163 || 38.662 || 142.355 || 1200
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19074
# JoR: 2.467 || Eff_3d: 48.407 || Jaccard: 0.871 || Factor: 876.295 || RMSE_lat: 35.302 || RMSE_ax: 128.629 || RMSE_x: 24.784 || RMSE_y: 25.140 || Cost: 14.641 || Recall: 0.882 || Precision: 0.985 || BatchNr.: 1300 || Time Upd.: 634.3 ms
#  || Count Cost: 15.2589 || Localization Cost: 3.1909 || Bg Cost: 0.0605 || P_locs Cost: 14.2503saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 48.407 || 35.302 || 128.629 || 1300
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 18337
# JoR: 2.712 || Eff_3d: 55.682 || Jaccard: 0.859 || Factor: 675.141 || RMSE_lat: 31.660 || RMSE_ax: 104.169 || RMSE_x: 22.647 || RMSE_y: 22.124 || Cost: 14.075 || Recall: 0.860 || Precision: 0.999 || BatchNr.: 1400 || Time Upd.: 692.8 ms
#  || Count Cost: 15.2079 || Localization Cost: 2.1597 || Bg Cost: 0.0669 || P_locs Cost: 14.0994saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 55.682 || 31.660 || 104.169 || 1400
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 18417
# JoR: 2.717 || Eff_3d: 57.463 || Jaccard: 0.863 || Factor: 646.566 || RMSE_lat: 31.768 || RMSE_ax: 97.191 || RMSE_x: 22.173 || RMSE_y: 22.750 || Cost: 8.679 || Recall: 0.864 || Precision: 0.999 || BatchNr.: 1500 || Time Upd.: 621.9 ms
#  || Count Cost: 14.5369 || Localization Cost: -0.7725 || Bg Cost: 0.0391 || P_locs Cost: 13.6696saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 57.463 || 31.768 || 97.191 || 1500
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19273
# JoR: 2.364 || Eff_3d: 53.708 || Jaccard: 0.888 || Factor: 805.311 || RMSE_lat: 37.559 || RMSE_ax: 104.407 || RMSE_x: 25.097 || RMSE_y: 27.944 || Cost: 8.884 || Recall: 0.896 || Precision: 0.990 || BatchNr.: 1600 || Time Upd.: 602.0 ms
#  || Count Cost: 14.6371 || Localization Cost: -0.4600 || Bg Cost: 0.0385 || P_locs Cost: 13.3356saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 53.708 || 37.559 || 104.407 || 1600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 16844
# JoR: 2.417 || Eff_3d: 53.238 || Jaccard: 0.790 || Factor: 533.515 || RMSE_lat: 32.689 || RMSE_ax: 100.981 || RMSE_x: 22.429 || RMSE_y: 23.780 || Cost: 9.470 || Recall: 0.790 || Precision: 1.000 || BatchNr.: 1700 || Time Upd.: 650.1 ms
#  || Count Cost: 15.1058 || Localization Cost: -0.4252 || Bg Cost: 0.0448 || P_locs Cost: 13.1498saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 53.238 || 32.689 || 100.981 || 1700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 15367
# JoR: 2.082 || Eff_3d: 38.631 || Jaccard: 0.720 || Factor: 484.946 || RMSE_lat: 34.581 || RMSE_ax: 146.128 || RMSE_x: 21.989 || RMSE_y: 26.690 || Cost: 6.268 || Recall: 0.721 || Precision: 0.999 || BatchNr.: 1800 || Time Upd.: 628.9 ms
#  || Count Cost: 16.9471 || Localization Cost: -3.3890 || Bg Cost: 0.0368 || P_locs Cost: 13.2864saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 38.631 || 34.581 || 146.128 || 1800
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19318
# JoR: 2.710 || Eff_3d: 56.468 || Jaccard: 0.902 || Factor: 733.992 || RMSE_lat: 33.278 || RMSE_ax: 102.867 || RMSE_x: 22.562 || RMSE_y: 24.462 || Cost: 9.607 || Recall: 0.904 || Precision: 0.997 || BatchNr.: 1900 || Time Upd.: 609.6 ms
#  || Count Cost: 15.9216 || Localization Cost: -0.4190 || Bg Cost: 0.0435 || P_locs Cost: 13.4473saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 56.468 || 33.278 || 102.867 || 1900
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19313
# JoR: 2.716 || Eff_3d: 59.610 || Jaccard: 0.904 || Factor: 735.074 || RMSE_lat: 33.295 || RMSE_ax: 90.250 || RMSE_x: 23.088 || RMSE_y: 23.989 || Cost: 7.707 || Recall: 0.905 || Precision: 0.999 || BatchNr.: 2000 || Time Upd.: 619.9 ms
#  || Count Cost: 14.1103 || Localization Cost: -1.2854 || Bg Cost: 0.0363 || P_locs Cost: 13.0706saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 59.610 || 33.295 || 90.250 || 2000
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19663
# JoR: 2.733 || Eff_3d: 59.024 || Jaccard: 0.917 || Factor: 799.206 || RMSE_lat: 33.553 || RMSE_ax: 93.313 || RMSE_x: 25.132 || RMSE_y: 22.230 || Cost: 7.692 || Recall: 0.920 || Precision: 0.997 || BatchNr.: 2100 || Time Upd.: 604.5 ms
#  || Count Cost: 14.1524 || Localization Cost: -1.6076 || Bg Cost: 0.0405 || P_locs Cost: 12.9180saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 59.024 || 33.553 || 93.313 || 2100
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 18228
# JoR: 2.732 || Eff_3d: 56.933 || Jaccard: 0.854 || Factor: 586.109 || RMSE_lat: 31.270 || RMSE_ax: 99.091 || RMSE_x: 22.154 || RMSE_y: 22.068 || Cost: 5.640 || Recall: 0.855 || Precision: 0.999 || BatchNr.: 2200 || Time Upd.: 638.5 ms
#  || Count Cost: 14.6532 || Localization Cost: -3.5026 || Bg Cost: 0.0378 || P_locs Cost: 12.7562saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 56.933 || 31.270 || 99.091 || 2200
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19445
# JoR: 2.769 || Eff_3d: 56.612 || Jaccard: 0.904 || Factor: 748.277 || RMSE_lat: 32.652 || RMSE_ax: 103.747 || RMSE_x: 23.221 || RMSE_y: 22.954 || Cost: 4.463 || Recall: 0.908 || Precision: 0.995 || BatchNr.: 2300 || Time Upd.: 640.8 ms
#  || Count Cost: 14.3623 || Localization Cost: -4.2153 || Bg Cost: 0.0330 || P_locs Cost: 12.6509saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 56.612 || 32.652 || 103.747 || 2300
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20092
# JoR: 2.739 || Eff_3d: 53.785 || Jaccard: 0.925 || Factor: 878.683 || RMSE_lat: 33.768 || RMSE_ax: 114.687 || RMSE_x: 22.507 || RMSE_y: 25.173 || Cost: 4.521 || Recall: 0.934 || Precision: 0.990 || BatchNr.: 2400 || Time Upd.: 603.1 ms
#  || Count Cost: 15.4561 || Localization Cost: -4.7420 || Bg Cost: 0.0380 || P_locs Cost: 12.5124saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 53.785 || 33.768 || 114.687 || 2400
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19687
# JoR: 2.715 || Eff_3d: 56.005 || Jaccard: 0.919 || Factor: 740.244 || RMSE_lat: 33.859 || RMSE_ax: 105.127 || RMSE_x: 24.543 || RMSE_y: 23.325 || Cost: 4.525 || Recall: 0.922 || Precision: 0.997 || BatchNr.: 2500 || Time Upd.: 633.2 ms
#  || Count Cost: 14.3880 || Localization Cost: -4.2291 || Bg Cost: 0.0341 || P_locs Cost: 12.5956saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 56.005 || 33.859 || 105.127 || 2500
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19242
# JoR: 2.895 || Eff_3d: 60.412 || Jaccard: 0.902 || Factor: 655.230 || RMSE_lat: 31.160 || RMSE_ax: 90.950 || RMSE_x: 22.367 || RMSE_y: 21.694 || Cost: 4.204 || Recall: 0.903 || Precision: 0.999 || BatchNr.: 2600 || Time Upd.: 601.8 ms
#  || Count Cost: 14.3380 || Localization Cost: -4.5413 || Bg Cost: 0.0345 || P_locs Cost: 12.4757saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 60.412 || 31.160 || 90.950 || 2600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19415
# JoR: 2.981 || Eff_3d: 62.400 || Jaccard: 0.910 || Factor: 642.513 || RMSE_lat: 30.528 || RMSE_ax: 84.859 || RMSE_x: 21.299 || RMSE_y: 21.870 || Cost: 4.154 || Recall: 0.911 || Precision: 0.999 || BatchNr.: 2700 || Time Upd.: 603.6 ms
#  || Count Cost: 14.3638 || Localization Cost: -4.5198 || Bg Cost: 0.0343 || P_locs Cost: 12.2311saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 62.400 || 30.528 || 84.859 || 2700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19821
# JoR: 2.926 || Eff_3d: 59.139 || Jaccard: 0.928 || Factor: 754.784 || RMSE_lat: 31.706 || RMSE_ax: 97.333 || RMSE_x: 22.591 || RMSE_y: 22.247 || Cost: 4.180 || Recall: 0.929 || Precision: 0.998 || BatchNr.: 2800 || Time Upd.: 600.2 ms
#  || Count Cost: 14.2309 || Localization Cost: -4.6759 || Bg Cost: 0.0374 || P_locs Cost: 12.0851saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 59.139 || 31.706 || 97.333 || 2800
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19438
# JoR: 2.738 || Eff_3d: 60.078 || Jaccard: 0.908 || Factor: 696.876 || RMSE_lat: 33.155 || RMSE_ax: 88.981 || RMSE_x: 22.858 || RMSE_y: 24.017 || Cost: 4.480 || Recall: 0.910 || Precision: 0.997 || BatchNr.: 2900 || Time Upd.: 602.8 ms
#  || Count Cost: 13.9891 || Localization Cost: -4.2333 || Bg Cost: 0.0357 || P_locs Cost: 12.2507saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 60.078 || 33.155 || 88.981 || 2900
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19453
# JoR: 2.913 || Eff_3d: 54.394 || Jaccard: 0.911 || Factor: 658.316 || RMSE_lat: 31.270 || RMSE_ax: 116.023 || RMSE_x: 22.199 || RMSE_y: 22.023 || Cost: 2.904 || Recall: 0.912 || Precision: 0.999 || BatchNr.: 3000 || Time Upd.: 605.7 ms
#  || Count Cost: 14.0526 || Localization Cost: -5.6708 || Bg Cost: 0.0344 || P_locs Cost: 12.0383saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 54.394 || 31.270 || 116.023 || 3000
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19928
# JoR: 2.916 || Eff_3d: 56.798 || Jaccard: 0.930 || Factor: 761.666 || RMSE_lat: 31.881 || RMSE_ax: 106.583 || RMSE_x: 23.113 || RMSE_y: 21.959 || Cost: 2.519 || Recall: 0.932 || Precision: 0.997 || BatchNr.: 3100 || Time Upd.: 601.0 ms
#  || Count Cost: 13.8764 || Localization Cost: -5.8226 || Bg Cost: 0.0317 || P_locs Cost: 12.1098saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 56.798 || 31.881 || 106.583 || 3100
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19490
# JoR: 3.062 || Eff_3d: 62.402 || Jaccard: 0.913 || Factor: 661.812 || RMSE_lat: 29.824 || RMSE_ax: 86.549 || RMSE_x: 21.256 || RMSE_y: 20.919 || Cost: 2.518 || Recall: 0.914 || Precision: 0.999 || BatchNr.: 3200 || Time Upd.: 600.3 ms
#  || Count Cost: 13.8401 || Localization Cost: -5.7809 || Bg Cost: 0.0309 || P_locs Cost: 12.2482saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 62.402 || 29.824 || 86.549 || 3200
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19713
# JoR: 3.021 || Eff_3d: 63.494 || Jaccard: 0.923 || Factor: 695.636 || RMSE_lat: 30.564 || RMSE_ax: 81.573 || RMSE_x: 21.690 || RMSE_y: 21.533 || Cost: 1.887 || Recall: 0.924 || Precision: 0.999 || BatchNr.: 3300 || Time Upd.: 602.4 ms
#  || Count Cost: 13.7038 || Localization Cost: -6.1769 || Bg Cost: 0.0290 || P_locs Cost: 12.0020saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 63.494 || 30.564 || 81.573 || 3300
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19025
# JoR: 3.021 || Eff_3d: 62.001 || Jaccard: 0.892 || Factor: 635.012 || RMSE_lat: 29.534 || RMSE_ax: 86.459 || RMSE_x: 20.691 || RMSE_y: 21.075 || Cost: 1.310 || Recall: 0.893 || Precision: 0.999 || BatchNr.: 3400 || Time Upd.: 597.7 ms
#  || Count Cost: 13.9019 || Localization Cost: -6.7636 || Bg Cost: 0.0284 || P_locs Cost: 12.0829saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 62.001 || 29.534 || 86.459 || 3400
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19812
# JoR: 2.941 || Eff_3d: 61.759 || Jaccard: 0.926 || Factor: 750.057 || RMSE_lat: 31.478 || RMSE_ax: 87.027 || RMSE_x: 21.865 || RMSE_y: 22.645 || Cost: 2.351 || Recall: 0.928 || Precision: 0.998 || BatchNr.: 3500 || Time Upd.: 601.5 ms
#  || Count Cost: 13.9121 || Localization Cost: -6.0560 || Bg Cost: 0.0329 || P_locs Cost: 11.9839saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 61.759 || 31.478 || 87.027 || 3500
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19644
# JoR: 3.064 || Eff_3d: 59.081 || Jaccard: 0.919 || Factor: 686.886 || RMSE_lat: 29.983 || RMSE_ax: 100.239 || RMSE_x: 21.160 || RMSE_y: 21.243 || Cost: -0.150 || Recall: 0.920 || Precision: 0.998 || BatchNr.: 3600 || Time Upd.: 601.8 ms
#  || Count Cost: 14.1104 || Localization Cost: -8.1471 || Bg Cost: 0.0282 || P_locs Cost: 11.6910saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 59.081 || 29.983 || 100.239 || 3600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19800
# JoR: 2.976 || Eff_3d: 62.002 || Jaccard: 0.927 || Factor: 687.010 || RMSE_lat: 31.150 || RMSE_ax: 86.790 || RMSE_x: 22.150 || RMSE_y: 21.901 || Cost: 1.982 || Recall: 0.928 || Precision: 0.999 || BatchNr.: 3700 || Time Upd.: 594.8 ms
#  || Count Cost: 15.1166 || Localization Cost: -6.5215 || Bg Cost: 0.0311 || P_locs Cost: 11.9641saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 62.002 || 31.150 || 86.790 || 3700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19346
# JoR: 2.601 || Eff_3d: 57.553 || Jaccard: 0.902 || Factor: 669.105 || RMSE_lat: 34.685 || RMSE_ax: 95.726 || RMSE_x: 24.492 || RMSE_y: 24.559 || Cost: 2.716 || Recall: 0.905 || Precision: 0.997 || BatchNr.: 3800 || Time Upd.: 598.6 ms
#  || Count Cost: 14.0770 || Localization Cost: -6.0490 || Bg Cost: 0.0365 || P_locs Cost: 12.1161saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 57.553 || 34.685 || 95.726 || 3800
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19953
# JoR: 3.047 || Eff_3d: 63.556 || Jaccard: 0.933 || Factor: 738.364 || RMSE_lat: 30.604 || RMSE_ax: 82.000 || RMSE_x: 21.756 || RMSE_y: 21.524 || Cost: 2.802 || Recall: 0.935 || Precision: 0.998 || BatchNr.: 3900 || Time Upd.: 601.0 ms
#  || Count Cost: 13.8508 || Localization Cost: -5.6574 || Bg Cost: 0.0333 || P_locs Cost: 12.0957saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 63.556 || 30.604 || 82.000 || 3900
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19940
# JoR: 2.912 || Eff_3d: 60.918 || Jaccard: 0.930 || Factor: 759.339 || RMSE_lat: 31.943 || RMSE_ax: 89.860 || RMSE_x: 22.982 || RMSE_y: 22.184 || Cost: 1.843 || Recall: 0.933 || Precision: 0.997 || BatchNr.: 4000 || Time Upd.: 598.2 ms
#  || Count Cost: 13.6490 || Localization Cost: -6.3941 || Bg Cost: 0.0320 || P_locs Cost: 11.7913saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 60.918 || 31.943 || 89.860 || 4000
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20010
# JoR: 2.923 || Eff_3d: 59.380 || Jaccard: 0.929 || Factor: 761.441 || RMSE_lat: 31.793 || RMSE_ax: 96.300 || RMSE_x: 22.957 || RMSE_y: 21.994 || Cost: 1.736 || Recall: 0.934 || Precision: 0.994 || BatchNr.: 4100 || Time Upd.: 653.5 ms
#  || Count Cost: 14.6437 || Localization Cost: -6.7116 || Bg Cost: 0.0311 || P_locs Cost: 12.1123saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 59.380 || 31.793 || 96.300 || 4100
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19792
# JoR: 3.064 || Eff_3d: 61.970 || Jaccard: 0.927 || Factor: 705.889 || RMSE_lat: 30.247 || RMSE_ax: 88.682 || RMSE_x: 21.850 || RMSE_y: 20.916 || Cost: 1.903 || Recall: 0.928 || Precision: 0.999 || BatchNr.: 4200 || Time Upd.: 660.9 ms
#  || Count Cost: 13.9943 || Localization Cost: -6.4424 || Bg Cost: 0.0327 || P_locs Cost: 11.7120saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 61.970 || 30.247 || 88.682 || 4200
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20087
# JoR: 2.965 || Eff_3d: 62.221 || Jaccard: 0.940 || Factor: 723.030 || RMSE_lat: 31.704 || RMSE_ax: 85.744 || RMSE_x: 21.511 || RMSE_y: 23.289 || Cost: 0.568 || Recall: 0.941 || Precision: 0.998 || BatchNr.: 4300 || Time Upd.: 664.7 ms
#  || Count Cost: 13.5877 || Localization Cost: -7.3245 || Bg Cost: 0.0282 || P_locs Cost: 11.6696saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 62.221 || 31.704 || 85.744 || 4300
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19735
# JoR: 3.058 || Eff_3d: 64.196 || Jaccard: 0.925 || Factor: 660.368 || RMSE_lat: 30.242 || RMSE_ax: 79.475 || RMSE_x: 21.581 || RMSE_y: 21.186 || Cost: 0.778 || Recall: 0.926 || Precision: 0.999 || BatchNr.: 4400 || Time Upd.: 637.4 ms
#  || Count Cost: 13.8368 || Localization Cost: -7.4491 || Bg Cost: 0.0312 || P_locs Cost: 11.8579saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 64.196 || 30.242 || 79.475 || 4400
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20086
# JoR: 3.056 || Eff_3d: 63.711 || Jaccard: 0.940 || Factor: 714.681 || RMSE_lat: 30.771 || RMSE_ax: 81.595 || RMSE_x: 22.147 || RMSE_y: 21.363 || Cost: 1.066 || Recall: 0.942 || Precision: 0.999 || BatchNr.: 4500 || Time Upd.: 625.5 ms
#  || Count Cost: 13.6178 || Localization Cost: -7.0842 || Bg Cost: 0.0313 || P_locs Cost: 11.6834saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 63.711 || 30.771 || 81.595 || 4500
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20019
# JoR: 3.079 || Eff_3d: 63.961 || Jaccard: 0.937 || Factor: 725.837 || RMSE_lat: 30.425 || RMSE_ax: 81.034 || RMSE_x: 21.710 || RMSE_y: 21.315 || Cost: 1.250 || Recall: 0.938 || Precision: 0.998 || BatchNr.: 4600 || Time Upd.: 598.2 ms
#  || Count Cost: 13.9471 || Localization Cost: -6.8394 || Bg Cost: 0.0294 || P_locs Cost: 11.8011saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 63.961 || 30.425 || 81.034 || 4600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20016
# JoR: 2.979 || Eff_3d: 62.425 || Jaccard: 0.935 || Factor: 743.834 || RMSE_lat: 31.378 || RMSE_ax: 85.220 || RMSE_x: 21.568 || RMSE_y: 22.791 || Cost: 0.394 || Recall: 0.937 || Precision: 0.997 || BatchNr.: 4700 || Time Upd.: 676.3 ms
#  || Count Cost: 13.8912 || Localization Cost: -7.5291 || Bg Cost: 0.0275 || P_locs Cost: 11.7872saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 62.425 || 31.378 || 85.220 || 4700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20057
# JoR: 2.994 || Eff_3d: 64.164 || Jaccard: 0.939 || Factor: 708.580 || RMSE_lat: 31.354 || RMSE_ax: 78.500 || RMSE_x: 20.863 || RMSE_y: 23.406 || Cost: -0.906 || Recall: 0.940 || Precision: 0.999 || BatchNr.: 4800 || Time Upd.: 620.9 ms
#  || Count Cost: 13.5731 || Localization Cost: -8.5487 || Bg Cost: 0.0258 || P_locs Cost: 11.4658saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 64.164 || 31.354 || 78.500 || 4800
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20090
# JoR: 3.127 || Eff_3d: 63.112 || Jaccard: 0.940 || Factor: 724.987 || RMSE_lat: 30.049 || RMSE_ax: 85.412 || RMSE_x: 21.273 || RMSE_y: 21.222 || Cost: 0.102 || Recall: 0.941 || Precision: 0.998 || BatchNr.: 4900 || Time Upd.: 601.2 ms
#  || Count Cost: 13.3667 || Localization Cost: -7.7755 || Bg Cost: 0.0294 || P_locs Cost: 11.4046saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 63.112 || 30.049 || 85.412 || 4900
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20011
# JoR: 3.203 || Eff_3d: 65.141 || Jaccard: 0.937 || Factor: 679.137 || RMSE_lat: 29.256 || RMSE_ax: 78.596 || RMSE_x: 20.729 || RMSE_y: 20.646 || Cost: 0.105 || Recall: 0.938 || Precision: 0.999 || BatchNr.: 5000 || Time Upd.: 636.2 ms
#  || Count Cost: 13.6554 || Localization Cost: -7.7214 || Bg Cost: 0.0274 || P_locs Cost: 11.6172saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.141 || 29.256 || 78.596 || 5000
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19783
# JoR: 3.182 || Eff_3d: 65.929 || Jaccard: 0.928 || Factor: 659.951 || RMSE_lat: 29.151 || RMSE_ax: 74.831 || RMSE_x: 21.184 || RMSE_y: 20.025 || Cost: -0.830 || Recall: 0.928 || Precision: 0.999 || BatchNr.: 5100 || Time Upd.: 650.7 ms
#  || Count Cost: 13.3065 || Localization Cost: -8.3098 || Bg Cost: 0.0250 || P_locs Cost: 11.2859saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.929 || 29.151 || 74.831 || 5100
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19978
# JoR: 3.180 || Eff_3d: 65.640 || Jaccard: 0.936 || Factor: 698.200 || RMSE_lat: 29.431 || RMSE_ax: 76.123 || RMSE_x: 20.937 || RMSE_y: 20.684 || Cost: -0.656 || Recall: 0.937 || Precision: 0.999 || BatchNr.: 5200 || Time Upd.: 616.5 ms
#  || Count Cost: 13.4420 || Localization Cost: -8.5078 || Bg Cost: 0.0288 || P_locs Cost: 11.4222saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.640 || 29.431 || 76.123 || 5200
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20029
# JoR: 3.093 || Eff_3d: 63.613 || Jaccard: 0.938 || Factor: 666.115 || RMSE_lat: 30.343 || RMSE_ax: 82.713 || RMSE_x: 21.200 || RMSE_y: 21.708 || Cost: 1.471 || Recall: 0.939 || Precision: 0.999 || BatchNr.: 5300 || Time Upd.: 623.0 ms
#  || Count Cost: 14.1326 || Localization Cost: -6.8520 || Bg Cost: 0.0325 || P_locs Cost: 11.6028saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 63.613 || 30.343 || 82.713 || 5300
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20139
# JoR: 3.191 || Eff_3d: 64.628 || Jaccard: 0.942 || Factor: 712.767 || RMSE_lat: 29.529 || RMSE_ax: 80.490 || RMSE_x: 21.052 || RMSE_y: 20.707 || Cost: -1.655 || Recall: 0.944 || Precision: 0.998 || BatchNr.: 5400 || Time Upd.: 621.1 ms
#  || Count Cost: 13.6504 || Localization Cost: -9.1659 || Bg Cost: 0.0246 || P_locs Cost: 11.2431saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 64.628 || 29.529 || 80.490 || 5400
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20042
# JoR: 3.157 || Eff_3d: 63.432 || Jaccard: 0.936 || Factor: 739.684 || RMSE_lat: 29.663 || RMSE_ax: 84.647 || RMSE_x: 21.230 || RMSE_y: 20.717 || Cost: -1.033 || Recall: 0.939 || Precision: 0.998 || BatchNr.: 5500 || Time Upd.: 604.2 ms
#  || Count Cost: 13.8195 || Localization Cost: -8.7400 || Bg Cost: 0.0258 || P_locs Cost: 11.5218saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 63.432 || 29.663 || 84.647 || 5500
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20042
# JoR: 3.166 || Eff_3d: 64.285 || Jaccard: 0.939 || Factor: 685.531 || RMSE_lat: 29.657 || RMSE_ax: 81.396 || RMSE_x: 21.210 || RMSE_y: 20.730 || Cost: -1.341 || Recall: 0.940 || Precision: 0.999 || BatchNr.: 5600 || Time Upd.: 597.9 ms
#  || Count Cost: 13.6239 || Localization Cost: -8.8761 || Bg Cost: 0.0246 || P_locs Cost: 11.3703saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 64.285 || 29.657 || 81.396 || 5600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19678
# JoR: 3.175 || Eff_3d: 65.443 || Jaccard: 0.923 || Factor: 635.742 || RMSE_lat: 29.065 || RMSE_ax: 76.544 || RMSE_x: 21.211 || RMSE_y: 19.872 || Cost: -1.469 || Recall: 0.923 || Precision: 1.000 || BatchNr.: 5700 || Time Upd.: 596.7 ms
#  || Count Cost: 13.5155 || Localization Cost: -9.0432 || Bg Cost: 0.0257 || P_locs Cost: 11.2730saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.443 || 29.065 || 76.544 || 5700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20169
# JoR: 3.171 || Eff_3d: 65.243 || Jaccard: 0.944 || Factor: 719.565 || RMSE_lat: 29.772 || RMSE_ax: 77.642 || RMSE_x: 21.187 || RMSE_y: 20.917 || Cost: -1.137 || Recall: 0.945 || Precision: 0.999 || BatchNr.: 5800 || Time Upd.: 600.9 ms
#  || Count Cost: 13.6868 || Localization Cost: -8.6618 || Bg Cost: 0.0243 || P_locs Cost: 11.3601saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.243 || 29.772 || 77.642 || 5800
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20158
# JoR: 3.191 || Eff_3d: 64.691 || Jaccard: 0.944 || Factor: 710.938 || RMSE_lat: 29.579 || RMSE_ax: 80.231 || RMSE_x: 20.804 || RMSE_y: 21.027 || Cost: -1.856 || Recall: 0.945 || Precision: 0.999 || BatchNr.: 5900 || Time Upd.: 602.0 ms
#  || Count Cost: 13.4390 || Localization Cost: -9.3410 || Bg Cost: 0.0246 || P_locs Cost: 11.3197saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 64.691 || 29.579 || 80.231 || 5900
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20084
# JoR: 3.204 || Eff_3d: 64.718 || Jaccard: 0.941 || Factor: 697.436 || RMSE_lat: 29.361 || RMSE_ax: 80.347 || RMSE_x: 20.586 || RMSE_y: 20.936 || Cost: -1.767 || Recall: 0.942 || Precision: 0.999 || BatchNr.: 6000 || Time Upd.: 600.2 ms
#  || Count Cost: 13.4841 || Localization Cost: -9.1946 || Bg Cost: 0.0239 || P_locs Cost: 11.2845saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 64.718 || 29.361 || 80.347 || 6000
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20303
# JoR: 3.141 || Eff_3d: 62.974 || Jaccard: 0.950 || Factor: 751.645 || RMSE_lat: 30.232 || RMSE_ax: 86.226 || RMSE_x: 21.574 || RMSE_y: 21.178 || Cost: -1.651 || Recall: 0.951 || Precision: 0.998 || BatchNr.: 6100 || Time Upd.: 599.1 ms
#  || Count Cost: 13.3908 || Localization Cost: -9.0557 || Bg Cost: 0.0237 || P_locs Cost: 11.3216saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 62.974 || 30.232 || 86.226 || 6100
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20039
# JoR: 3.251 || Eff_3d: 66.176 || Jaccard: 0.939 || Factor: 681.509 || RMSE_lat: 28.889 || RMSE_ax: 75.268 || RMSE_x: 20.567 || RMSE_y: 20.287 || Cost: -1.980 || Recall: 0.940 || Precision: 0.999 || BatchNr.: 6200 || Time Upd.: 599.7 ms
#  || Count Cost: 13.4143 || Localization Cost: -9.4112 || Bg Cost: 0.0243 || P_locs Cost: 11.2289saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 66.176 || 28.889 || 75.268 || 6200
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19886
# JoR: 3.194 || Eff_3d: 65.070 || Jaccard: 0.932 || Factor: 662.831 || RMSE_lat: 29.188 || RMSE_ax: 78.641 || RMSE_x: 20.871 || RMSE_y: 20.405 || Cost: -1.882 || Recall: 0.933 || Precision: 0.999 || BatchNr.: 6300 || Time Upd.: 596.1 ms
#  || Count Cost: 13.4619 || Localization Cost: -9.3863 || Bg Cost: 0.0248 || P_locs Cost: 11.3210saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.070 || 29.188 || 78.641 || 6300
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20106
# JoR: 3.220 || Eff_3d: 65.495 || Jaccard: 0.942 || Factor: 699.794 || RMSE_lat: 29.265 || RMSE_ax: 77.516 || RMSE_x: 20.951 || RMSE_y: 20.433 || Cost: -1.976 || Recall: 0.943 || Precision: 0.999 || BatchNr.: 6400 || Time Upd.: 602.6 ms
#  || Count Cost: 13.3876 || Localization Cost: -9.5191 || Bg Cost: 0.0258 || P_locs Cost: 11.2173saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.495 || 29.265 || 77.516 || 6400
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20151
# JoR: 3.225 || Eff_3d: 66.213 || Jaccard: 0.944 || Factor: 719.942 || RMSE_lat: 29.275 || RMSE_ax: 74.708 || RMSE_x: 20.868 || RMSE_y: 20.531 || Cost: -0.642 || Recall: 0.945 || Precision: 0.999 || BatchNr.: 6500 || Time Upd.: 604.6 ms
#  || Count Cost: 13.3521 || Localization Cost: -8.3853 || Bg Cost: 0.0283 || P_locs Cost: 11.2464saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 66.213 || 29.275 || 74.708 || 6500
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20151
# JoR: 3.219 || Eff_3d: 65.349 || Jaccard: 0.945 || Factor: 702.218 || RMSE_lat: 29.347 || RMSE_ax: 78.094 || RMSE_x: 20.873 || RMSE_y: 20.630 || Cost: -2.544 || Recall: 0.945 || Precision: 0.999 || BatchNr.: 6600 || Time Upd.: 603.4 ms
#  || Count Cost: 13.3825 || Localization Cost: -9.8589 || Bg Cost: 0.0232 || P_locs Cost: 11.1195saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.349 || 29.347 || 78.094 || 6600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20199
# JoR: 3.270 || Eff_3d: 66.218 || Jaccard: 0.944 || Factor: 736.537 || RMSE_lat: 28.883 || RMSE_ax: 75.492 || RMSE_x: 20.627 || RMSE_y: 20.218 || Cost: -0.973 || Recall: 0.946 || Precision: 0.998 || BatchNr.: 6700 || Time Upd.: 600.0 ms
#  || Count Cost: 13.4476 || Localization Cost: -8.6299 || Bg Cost: 0.0268 || P_locs Cost: 11.2853saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 66.218 || 28.883 || 75.492 || 6700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20115
# JoR: 3.280 || Eff_3d: 65.907 || Jaccard: 0.942 || Factor: 697.737 || RMSE_lat: 28.723 || RMSE_ax: 76.911 || RMSE_x: 20.533 || RMSE_y: 20.085 || Cost: -0.710 || Recall: 0.943 || Precision: 0.999 || BatchNr.: 6800 || Time Upd.: 600.7 ms
#  || Count Cost: 13.4379 || Localization Cost: -8.3340 || Bg Cost: 0.0264 || P_locs Cost: 11.3066saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.907 || 28.723 || 76.911 || 6800
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 19964
# JoR: 3.192 || Eff_3d: 66.159 || Jaccard: 0.936 || Factor: 673.952 || RMSE_lat: 29.333 || RMSE_ax: 74.238 || RMSE_x: 20.722 || RMSE_y: 20.761 || Cost: -2.071 || Recall: 0.937 || Precision: 0.999 || BatchNr.: 6900 || Time Upd.: 594.9 ms
#  || Count Cost: 13.1378 || Localization Cost: -9.4357 || Bg Cost: 0.0251 || P_locs Cost: 10.9080saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 66.159 || 29.333 || 74.238 || 6900
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20320
# JoR: 3.184 || Eff_3d: 64.584 || Jaccard: 0.951 || Factor: 738.162 || RMSE_lat: 29.857 || RMSE_ax: 80.535 || RMSE_x: 21.511 || RMSE_y: 20.706 || Cost: -2.736 || Recall: 0.952 || Precision: 0.998 || BatchNr.: 7000 || Time Upd.: 602.5 ms
#  || Count Cost: 13.3129 || Localization Cost: -10.0596 || Bg Cost: 0.0237 || P_locs Cost: 11.0752saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 64.584 || 29.857 || 80.535 || 7000
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20057
# JoR: 3.176 || Eff_3d: 65.185 || Jaccard: 0.940 || Factor: 703.641 || RMSE_lat: 29.585 || RMSE_ax: 77.937 || RMSE_x: 20.773 || RMSE_y: 21.066 || Cost: -1.295 || Recall: 0.940 || Precision: 0.999 || BatchNr.: 7100 || Time Upd.: 601.2 ms
#  || Count Cost: 13.5101 || Localization Cost: -8.9765 || Bg Cost: 0.0271 || P_locs Cost: 11.2455saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.185 || 29.585 || 77.937 || 7100
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20070
# JoR: 3.258 || Eff_3d: 66.110 || Jaccard: 0.940 || Factor: 687.950 || RMSE_lat: 28.861 || RMSE_ax: 75.683 || RMSE_x: 20.342 || RMSE_y: 20.473 || Cost: -2.654 || Recall: 0.941 || Precision: 0.999 || BatchNr.: 7200 || Time Upd.: 609.2 ms
#  || Count Cost: 13.2209 || Localization Cost: -10.0155 || Bg Cost: 0.0247 || P_locs Cost: 10.9508saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 66.110 || 28.861 || 75.683 || 7200
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20477
# JoR: 3.221 || Eff_3d: 65.366 || Jaccard: 0.956 || Factor: 782.215 || RMSE_lat: 29.688 || RMSE_ax: 78.024 || RMSE_x: 21.195 || RMSE_y: 20.788 || Cost: -2.449 || Recall: 0.959 || Precision: 0.997 || BatchNr.: 7300 || Time Upd.: 619.2 ms
#  || Count Cost: 13.4214 || Localization Cost: -9.7067 || Bg Cost: 0.0224 || P_locs Cost: 11.1203saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.366 || 29.688 || 78.024 || 7300
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20120
# JoR: 3.334 || Eff_3d: 66.813 || Jaccard: 0.943 || Factor: 668.272 || RMSE_lat: 28.280 || RMSE_ax: 74.176 || RMSE_x: 20.103 || RMSE_y: 19.891 || Cost: -3.120 || Recall: 0.944 || Precision: 0.999 || BatchNr.: 7400 || Time Upd.: 631.4 ms
#  || Count Cost: 13.2308 || Localization Cost: -10.3255 || Bg Cost: 0.0227 || P_locs Cost: 10.9765saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 66.813 || 28.280 || 74.176 || 7400
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20054
# JoR: 3.332 || Eff_3d: 66.890 || Jaccard: 0.940 || Factor: 648.232 || RMSE_lat: 28.210 || RMSE_ax: 73.794 || RMSE_x: 20.255 || RMSE_y: 19.635 || Cost: 11324.481 || Recall: 0.941 || Precision: 0.999 || BatchNr.: 7500 || Time Upd.: 615.7 ms
#  || Count Cost: 13.7205 || Localization Cost: -9.3373 || Bg Cost: 141.6033 || P_locs Cost: 11.2244saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 66.890 || 28.210 || 73.794 || 7500
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20094
# JoR: 3.246 || Eff_3d: 66.414 || Jaccard: 0.942 || Factor: 686.793 || RMSE_lat: 29.017 || RMSE_ax: 74.248 || RMSE_x: 20.551 || RMSE_y: 20.485 || Cost: -1.939 || Recall: 0.942 || Precision: 0.999 || BatchNr.: 7600 || Time Upd.: 632.7 ms
#  || Count Cost: 13.7618 || Localization Cost: -9.5024 || Bg Cost: 0.0253 || P_locs Cost: 11.1533saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 66.414 || 29.017 || 74.248 || 7600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20154
# JoR: 3.133 || Eff_3d: 65.331 || Jaccard: 0.945 || Factor: 711.851 || RMSE_lat: 30.154 || RMSE_ax: 76.566 || RMSE_x: 21.171 || RMSE_y: 21.472 || Cost: -2.595 || Recall: 0.945 || Precision: 0.999 || BatchNr.: 7700 || Time Upd.: 635.1 ms
#  || Count Cost: 13.3004 || Localization Cost: -9.9654 || Bg Cost: 0.0243 || P_locs Cost: 11.0742saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.331 || 30.154 || 76.566 || 7700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21339FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21304 ,preds: 20287
# ...
# after FOV and border segmentation,truth: 21464 ,preds: 19971
# JoR: 2.581 || Eff_3d: 65.784 || Jaccard: 0.928 || Factor: 705.744 || RMSE_lat: 35.970 || RMSE_ax: 61.868 || RMSE_x: 25.689 || RMSE_y: 25.178 || Cost: 18.436 || Recall: 0.929 || Precision: 0.999 || BatchNr.: 17800 || Time Upd.: 892.9 ms
#  || Count Cost: 26.8187 || Localization Cost: 4.5455 || Bg Cost: 0.0271 || P_locs Cost: 25.4344saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.784 || 35.970 || 61.868 || 17800
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 19956
# JoR: 2.558 || Eff_3d: 64.499 || Jaccard: 0.926 || Factor: 692.988 || RMSE_lat: 36.213 || RMSE_ax: 66.487 || RMSE_x: 26.190 || RMSE_y: 25.010 || Cost: 18.939 || Recall: 0.928 || Precision: 0.998 || BatchNr.: 17900 || Time Upd.: 872.2 ms
#  || Count Cost: 26.6294 || Localization Cost: 5.0154 || Bg Cost: 0.0285 || P_locs Cost: 25.2670saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 64.499 || 36.213 || 66.487 || 17900
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 19879
# JoR: 2.585 || Eff_3d: 64.287 || Jaccard: 0.924 || Factor: 693.290 || RMSE_lat: 35.760 || RMSE_ax: 68.080 || RMSE_x: 25.406 || RMSE_y: 25.165 || Cost: 18.854 || Recall: 0.925 || Precision: 0.999 || BatchNr.: 18000 || Time Upd.: 869.7 ms
#  || Count Cost: 26.7797 || Localization Cost: 4.9192 || Bg Cost: 0.0272 || P_locs Cost: 25.6242saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 64.287 || 35.760 || 68.080 || 18000
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 19904
# JoR: 2.581 || Eff_3d: 65.179 || Jaccard: 0.925 || Factor: 700.872 || RMSE_lat: 35.835 || RMSE_ax: 64.332 || RMSE_x: 25.481 || RMSE_y: 25.197 || Cost: 18.984 || Recall: 0.926 || Precision: 0.999 || BatchNr.: 18100 || Time Upd.: 874.0 ms
#  || Count Cost: 26.7493 || Localization Cost: 5.0722 || Bg Cost: 0.0272 || P_locs Cost: 25.5530saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.179 || 35.835 || 64.332 || 18100
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 20075
# JoR: 2.580 || Eff_3d: 65.506 || Jaccard: 0.932 || Factor: 711.900 || RMSE_lat: 36.143 || RMSE_ax: 63.002 || RMSE_x: 25.505 || RMSE_y: 25.609 || Cost: 18.621 || Recall: 0.934 || Precision: 0.998 || BatchNr.: 18200 || Time Upd.: 877.2 ms
#  || Count Cost: 26.8744 || Localization Cost: 4.6710 || Bg Cost: 0.0273 || P_locs Cost: 25.5566saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.506 || 36.143 || 63.002 || 18200
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 20189
# JoR: 2.587 || Eff_3d: 65.543 || Jaccard: 0.936 || Factor: 762.552 || RMSE_lat: 36.179 || RMSE_ax: 63.068 || RMSE_x: 26.013 || RMSE_y: 25.145 || Cost: 19.929 || Recall: 0.938 || Precision: 0.998 || BatchNr.: 18300 || Time Upd.: 879.1 ms
#  || Count Cost: 26.7713 || Localization Cost: 5.7369 || Bg Cost: 0.0309 || P_locs Cost: 25.4518saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.543 || 36.179 || 63.068 || 18300
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 19871
# JoR: 2.594 || Eff_3d: 66.092 || Jaccard: 0.923 || Factor: 697.643 || RMSE_lat: 35.587 || RMSE_ax: 60.895 || RMSE_x: 25.082 || RMSE_y: 25.245 || Cost: 18.376 || Recall: 0.924 || Precision: 0.998 || BatchNr.: 18400 || Time Upd.: 873.5 ms
#  || Count Cost: 26.5616 || Localization Cost: 4.5034 || Bg Cost: 0.0283 || P_locs Cost: 25.1955saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 66.092 || 35.587 || 60.895 || 18400
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 19774
# JoR: 2.545 || Eff_3d: 64.749 || Jaccard: 0.919 || Factor: 689.964 || RMSE_lat: 36.125 || RMSE_ax: 64.998 || RMSE_x: 25.704 || RMSE_y: 25.384 || Cost: 18.418 || Recall: 0.920 || Precision: 0.999 || BatchNr.: 18500 || Time Upd.: 873.9 ms
#  || Count Cost: 26.6748 || Localization Cost: 4.5949 || Bg Cost: 0.0268 || P_locs Cost: 25.3730saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 64.749 || 36.125 || 64.998 || 18500
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 19994
# JoR: 2.592 || Eff_3d: 65.725 || Jaccard: 0.928 || Factor: 725.056 || RMSE_lat: 35.812 || RMSE_ax: 62.413 || RMSE_x: 25.408 || RMSE_y: 25.237 || Cost: 18.082 || Recall: 0.930 || Precision: 0.998 || BatchNr.: 18600 || Time Upd.: 871.7 ms
#  || Count Cost: 26.6859 || Localization Cost: 4.2928 || Bg Cost: 0.0265 || P_locs Cost: 25.3280saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.725 || 35.812 || 62.413 || 18600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 20133
# JoR: 2.584 || Eff_3d: 64.144 || Jaccard: 0.935 || Factor: 739.437 || RMSE_lat: 36.177 || RMSE_ax: 68.678 || RMSE_x: 25.786 || RMSE_y: 25.375 || Cost: 21.579 || Recall: 0.936 || Precision: 0.998 || BatchNr.: 18700 || Time Upd.: 881.6 ms
#  || Count Cost: 27.0389 || Localization Cost: 7.0687 || Bg Cost: 0.0336 || P_locs Cost: 25.6473saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 64.144 || 36.177 || 68.678 || 18700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 20225
# JoR: 2.614 || Eff_3d: 65.623 || Jaccard: 0.939 || Factor: 762.197 || RMSE_lat: 35.924 || RMSE_ax: 63.464 || RMSE_x: 25.547 || RMSE_y: 25.257 || Cost: 23.104 || Recall: 0.941 || Precision: 0.998 || BatchNr.: 18800 || Time Upd.: 868.8 ms
#  || Count Cost: 27.1401 || Localization Cost: 7.4877 || Bg Cost: 0.0479 || P_locs Cost: 25.4273saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.623 || 35.924 || 63.464 || 18800
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 20107
# JoR: 2.587 || Eff_3d: 64.689 || Jaccard: 0.934 || Factor: 738.632 || RMSE_lat: 36.122 || RMSE_ax: 66.539 || RMSE_x: 25.691 || RMSE_y: 25.393 || Cost: 18.791 || Recall: 0.936 || Precision: 0.999 || BatchNr.: 18900 || Time Upd.: 880.7 ms
#  || Count Cost: 27.1071 || Localization Cost: 4.7006 || Bg Cost: 0.0280 || P_locs Cost: 25.7313saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 64.689 || 36.122 || 66.539 || 18900
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 19901
# JoR: 2.546 || Eff_3d: 64.529 || Jaccard: 0.924 || Factor: 704.127 || RMSE_lat: 36.283 || RMSE_ax: 65.995 || RMSE_x: 25.438 || RMSE_y: 25.872 || Cost: 17.968 || Recall: 0.925 || Precision: 0.998 || BatchNr.: 19000 || Time Upd.: 868.0 ms
#  || Count Cost: 26.3049 || Localization Cost: 4.3107 || Bg Cost: 0.0267 || P_locs Cost: 25.0290saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 64.529 || 36.283 || 65.995 || 19000
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 20003
# JoR: 2.619 || Eff_3d: 65.734 || Jaccard: 0.930 || Factor: 705.959 || RMSE_lat: 35.507 || RMSE_ax: 63.155 || RMSE_x: 25.327 || RMSE_y: 24.885 || Cost: 18.608 || Recall: 0.931 || Precision: 0.999 || BatchNr.: 19100 || Time Upd.: 872.6 ms
#  || Count Cost: 26.6413 || Localization Cost: 4.6994 || Bg Cost: 0.0281 || P_locs Cost: 25.3294saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.734 || 35.507 || 63.155 || 19100
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 20018
# JoR: 2.604 || Eff_3d: 65.593 || Jaccard: 0.930 || Factor: 718.977 || RMSE_lat: 35.725 || RMSE_ax: 63.315 || RMSE_x: 25.422 || RMSE_y: 25.100 || Cost: 17.879 || Recall: 0.931 || Precision: 0.999 || BatchNr.: 19200 || Time Upd.: 863.8 ms
#  || Count Cost: 26.4555 || Localization Cost: 4.1355 || Bg Cost: 0.0270 || P_locs Cost: 25.1681saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.593 || 35.725 || 63.315 || 19200
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 19878
# JoR: 2.597 || Eff_3d: 65.885 || Jaccard: 0.924 || Factor: 720.166 || RMSE_lat: 35.566 || RMSE_ax: 61.863 || RMSE_x: 25.295 || RMSE_y: 25.002 || Cost: 18.271 || Recall: 0.925 || Precision: 0.999 || BatchNr.: 19300 || Time Upd.: 872.8 ms
#  || Count Cost: 26.8151 || Localization Cost: 4.4229 || Bg Cost: 0.0262 || P_locs Cost: 25.5654saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.885 || 35.566 || 61.863 || 19300
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 19951
# JoR: 2.592 || Eff_3d: 66.113 || Jaccard: 0.927 || Factor: 722.271 || RMSE_lat: 35.783 || RMSE_ax: 60.813 || RMSE_x: 25.487 || RMSE_y: 25.116 || Cost: 19.153 || Recall: 0.928 || Precision: 0.999 || BatchNr.: 19400 || Time Upd.: 886.5 ms
#  || Count Cost: 27.0549 || Localization Cost: 5.0959 || Bg Cost: 0.0272 || P_locs Cost: 25.8911saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 66.113 || 35.783 || 60.813 || 19400
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 19770
# JoR: 2.592 || Eff_3d: 65.232 || Jaccard: 0.920 || Factor: 677.759 || RMSE_lat: 35.480 || RMSE_ax: 64.339 || RMSE_x: 25.191 || RMSE_y: 24.985 || Cost: 18.407 || Recall: 0.920 || Precision: 0.999 || BatchNr.: 19500 || Time Upd.: 874.2 ms
#  || Count Cost: 26.5768 || Localization Cost: 4.6448 || Bg Cost: 0.0269 || P_locs Cost: 25.1876saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.232 || 35.480 || 64.339 || 19500
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 19800
# JoR: 2.584 || Eff_3d: 65.644 || Jaccard: 0.920 || Factor: 682.396 || RMSE_lat: 35.597 || RMSE_ax: 62.435 || RMSE_x: 25.245 || RMSE_y: 25.096 || Cost: 18.796 || Recall: 0.921 || Precision: 0.999 || BatchNr.: 19600 || Time Upd.: 876.6 ms
#  || Count Cost: 27.1511 || Localization Cost: 4.7599 || Bg Cost: 0.0269 || P_locs Cost: 25.8097saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.644 || 35.597 || 62.435 || 19600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 19912
# JoR: 2.623 || Eff_3d: 66.002 || Jaccard: 0.926 || Factor: 714.071 || RMSE_lat: 35.295 || RMSE_ax: 62.103 || RMSE_x: 25.206 || RMSE_y: 24.707 || Cost: 17.800 || Recall: 0.927 || Precision: 0.999 || BatchNr.: 19700 || Time Upd.: 873.2 ms
#  || Count Cost: 26.5461 || Localization Cost: 4.1277 || Bg Cost: 0.0256 || P_locs Cost: 25.2694saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 66.002 || 35.295 || 62.103 || 19700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 20062
# JoR: 2.544 || Eff_3d: 64.580 || Jaccard: 0.931 || Factor: 744.235 || RMSE_lat: 36.617 || RMSE_ax: 65.760 || RMSE_x: 26.007 || RMSE_y: 25.777 || Cost: 18.537 || Recall: 0.933 || Precision: 0.998 || BatchNr.: 19800 || Time Upd.: 878.1 ms
#  || Count Cost: 27.0775 || Localization Cost: 4.5841 || Bg Cost: 0.0269 || P_locs Cost: 25.5461saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 64.580 || 36.617 || 65.760 || 19800
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 19913
# JoR: 2.635 || Eff_3d: 66.088 || Jaccard: 0.925 || Factor: 696.403 || RMSE_lat: 35.110 || RMSE_ax: 62.087 || RMSE_x: 24.938 || RMSE_y: 24.715 || Cost: 17.736 || Recall: 0.926 || Precision: 0.999 || BatchNr.: 19900 || Time Upd.: 865.8 ms
#  || Count Cost: 26.1907 || Localization Cost: 4.1757 || Bg Cost: 0.0263 || P_locs Cost: 24.8840saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 66.088 || 35.110 || 62.087 || 19900
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 21494FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 21464 ,preds: 20117
# JoR: 2.593 || Eff_3d: 65.495 || Jaccard: 0.934 || Factor: 739.130 || RMSE_lat: 36.019 || RMSE_ax: 63.424 || RMSE_x: 25.838 || RMSE_y: 25.095 || Cost: 17.990 || Recall: 0.936 || Precision: 0.998 || BatchNr.: 20000 || Time Upd.: 876.2 ms
#  || Count Cost: 26.6891 || Localization Cost: 4.2578 || Bg Cost: 0.0258 || P_locs Cost: 25.3295saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 65.495 || 36.019 || 63.424 || 20000
#
#
# training finished!

# %%
1 + 1
# Out:
# 2

# %%
from cellbgnet.utils.plot_funcs import plot_train_record

# %%
plot_train_record(model)
