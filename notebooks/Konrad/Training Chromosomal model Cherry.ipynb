# %%
# %reload_ext autoreload
# %autoreload 2
# %reload_ext notexbook
# %texify
# Out:
# <style type="text/css">
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
# */
#
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#                          FONTS
#
#     FONT WEIGHT MAP:
#     ----------------
#     100: Ultra Light
#     200: Thin
#     300: Light
#     400: Regular (normal)
#     500: Medium
#     600: Semi-bold
#     700: Bold
#     800: Heavy
#     900: Black
#
#     Font faces:
#         - ====================================|=======================
#         -              Scope                  | Font Family Name
#         - ====================================| ======================
#         - Markdown Display (Computer Modern)    (CMU Serif)
#         - Markdown Display monospace            (CMU Typewriter Text)
#         - Markdown Edit    monospace            (Hack)
#         - Source Code      monospace            (Fira Code)
#         - ====================================| =======================
#
#  ======================================================  */
#
# /* Roboto Slab */
# @import url("https://fonts.googleapis.com/css2?family=Roboto+Slab:wght@100;200;300;400;500;600;700;800;900&display=swap");
# /*md-display-computer-modern --> CMU Serif*/
# @import url("https://fonts.cdnfonts.com/css/cmu-serif?styles=30038,30039,30037,30036");
# /*md-display-monospace --> CMU Typewriter Text*/
# @import url("https://fonts.cdnfonts.com/css/cmu-typewriter-text?styles=24833,24829,24830,24831,24832,24834");
# /*code-monospace --> Fira Code*/
# @import url("https://fonts.googleapis.com/css2?family=Fira+Code:wght@300;400;500&display=swap");
# /*md-edit-monospace --> Hack*/
# @import url("https://fonts.cdnfonts.com/css/hack?styles=20708,20707,20705,20706");
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
# ======================================================
#
#
#     ---------------------------------
#     Code Mirror - Code Cell Highlight
#     ---------------------------------
#
#     Define the Style for Code **and** Markdown editors (Themes)
#     Theme files are all located in the "themes" folder, and the
#     different styles for the Code and Markdown editors are
#     distinguished by a common prefix in the file names:
#
#         --> Code editors Themes: "themes/code_*"
#         --> Markdown Editor Themes: "themes/md_*"
#
#     Styles can be imported as separate CSS modules.
#
#     Current stylesheet (editor.css) defines the CSS rules
#     for notebook tags and classes. These rules are
#     all based to colors defined in external Theme files.
#
#     This would ease the definition of other custom CSS Editor themes
# */
#
# /* Code Editor theme */
#
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#
# The color palette is inspired by Light
#  Material Design theme
# Repo: https://github.com/JonaDuran/Material-Light-Theme/
# */
#
# :root {
#     /* Color Palette */
#     --ml-white: #ffffff;
#     --ml-light-white: #FAFAFA;
#     --ml-black: #24292E;
#     --ml-dark-blue : #01579B11;
#     --ml-dark-blue-2: #01579B22;
#     --ml-blue: #1565C0;
#     --ml-green: #2E7D32;
#     --ml-yellow: #A8601A;
#     --ml-cyan: #00838f;
#     --ml-magenta: #9C00B0;
#     --ml-red: #C0392B;
#     --ml-grey: #9E9E9E;
#     --ml-light-blue: #78909c;
#
#
#     /* Editor Theme */
#     --code-background-color: var(--ml-light-white);
#     --gutter-background: var(--ml-light-white);
#     --selection-background-color: var(--ml-dark-blue-2);
#     --line-numbers: var(--ml-grey);
#     --cursor: var(--ml-black);
#     --bracket: var(--ml-black);
#     --matching-bracket: var(--ml-blue);
#     --code-text-color: var(--ml-black);
#     --keywords: var(--ml-magenta);
#     --types: var(--ml-magenta);
#     --variables: var(--code-text-color);
#     --variables2: var(--ml-green);
#     --def: var(--ml-blue);
#     --property: var(--ml-blue);
#     --meta: var(--ml-light-blue);
#     --builtin: var(--ml-blue);
#     --attribute: var(--ml-blue);
#     --strings: var(--ml-yellow);
#     --strings2: var(--ml-grey);
#     --comments: var(--ml-grey);
#     --operator: var(--ml-magenta);
#     --numbers: var(--ml-red);
#     /* Dataframe */
#     --dataframe: var(--code-text-color);
#     --df-bg: var(--ml-light-white);
#     --df-thead: var(--ml-blue);
#     --df-thead-border: var(--ml-black);
#     --df-tr-hover: var(--selection-background-color);
#     --df-border: var(--ml-white);
#     --df-border-right: var(--ml-grey);
#     --df-th-bg: var(--ml-white);
#     /*ANSI Colours*/
#     --ansi-red: var(--ml-red);
#     --ansi-green: var(--ml-green);
#     --ansi-green-intense: var(--ml-grey);
#     --ansi-cyan: var(--ml-cyan);
#     --ansi-blue: var(--ml-blue);
# }
#
#
#
# /* Markdown Editor theme */
#
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#
#     Custom Theme for Markdown Editor
#     based on Material Clear Theme.
#
#  */
#
# :root {
#     /* Color Palette */
#     --md-ml-red: #C0392B;
#     --md-ml-yellow: #A8601A;
#     --md-ml-black: #24292E;
#     --md-ml-grey: #9E9E9E;
#     --md-ml-blue: #1565C0;
#     --md-ml-dark-blue: #01579B;
#     --md-ml-light-blue: #78909c;
#
#     /*  Editor Theme  */
#     --editor-text: var(--md-ml-black);
#     --header: var(--md-ml-dark-blue);
#     --quote: var(--md-ml-grey);
#     --link: var(--md-ml-blue);
#     --attribute: var(--md-ml-red);
#     --tag: var(--md-ml-yellow);
#     --string: var(--md-ml-yellow);
#     --delimiter: var(--md-ml-black);
#     --monospace: var(--md-ml-light-blue);
# }
#
#
#
#
#
#
#
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
# */
#
# /*
#     =================
#     Code Editor Theme
#     =================
# */
# div.output_error pre,
# div.output_result pre,
# div.output_stream pre {
#     color: var(--code-text-color) !important;
# }
#
# .cm-s-ipython.CodeMirror,
# .cm-s-jupyter.CodeMirror {
#     background: var(--code-background-color);
#     color: var(--code-text-color);
# }
#
# .cm-s-ipython div.CodeMirror-selected,
# .cm-s-jupyter div.CodeMirror-selected {
#     cursor: pointer;
#     background: var(--selection-background-color);
# }
#
# .cm-s-ipython .CodeMirror-gutters,
# .cm-s-jupyter .CodeMirror-gutters {
#     background: var(--gutter-background);
#     border-right: 0;
# }
#
# .cm-s-ipython .CodeMirror-linenumber,
# .cm-s-jupyter .CodeMirror-linenumber {
#     color: var(--line-numbers);
# }
#
# .cm-s-ipython .CodeMirror-cursor,
# .cm-s-jupyter .CodeMirror-cursor {
#     border-left: 1px solid var(--cursor) !important;
# }
#
# .cm-s-ipython span.cm-bracket,
# .cm-s-jupyter span.cm-bracket {
#     /*color: #828282;*/
#     color: var(--bracket);
# }
#
# span.CodeMirror-matchingbracket {
#     text-decoration: underline !important;
#     text-decoration-color: var(--matching-bracket) !important;
#     color: var(--matching-bracket) !important;
# }
#
# .cm-s-ipython span.cm-keyword,
# .cm-s-jupyter span.cm-keyword {
#     color: var(--keywords);
#     font-weight: 400;
# }
#
# .cm-s-ipython span.cm-variable,
# .cm-s-jupyter span.cm-variable {
#     color: var(--variables);
# }
#
# .cm-s-ipython span.cm-variable-2,
# .cm-s-jupyter span.cm-variable-2 {
#     color: var(--variables2);
# }
#
# .cm-s-ipython span.cm-def,
# .cm-s-jupyter span.cm-def {
#     color: var(--def);
# }
#
# .cm-s-ipython span.cm-property,
# .cm-s-jupyter span.cm-property {
#     color: var(--property);
# }
#
# .cm-s-ipython span.cm-meta,
# .cm-s-jupyter span.cm-meta {
#     color: var(--meta);
# }
#
# .cm-s-ipython span.cm-attribute,
# .cm-s-jupyter span.cm-attribute {
#     color: var(--attribute);
# }
#
# .cm-s-ipython span.cm-builtin,
# .cm-s-jupyter span.cm-builtin {
#     color: var(--builtin)
# }
#
# .cm-s-ipython span.cm-string,
# .cm-s-jupyter span.cm-string {
#     color: var(--strings);
# }
#
# .cm-s-ipython span.cm-string-2,
# .cm-s-jupyter span.cm-string-2 {
#     color

# %% [markdown]
# #### Train an example model

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import time
import sys
sys.setrecursionlimit(10000)
# %matplotlib qt5

# %%
import cellbgnet
import cellbgnet.utils
from cellbgnet.datasets import DataSimulator
from cellbgnet.utils.hardware import cpu, gpu
from cellbgnet.model import CellBGModel

# %% [markdown]
# ##### All the parameters are in the param file, you can look at them if you want

# %%
param_file = '../../cellbgnet/utils/reference_files/reference_cherry.yaml'
param = cellbgnet.utils.param_io.ParamHandling().load_params(param_file)

# %%
param
# Out:
# namespace(Simulation=namespace(train_size=128,
#                                train_type='cells',
#                                psf_intensity_normalization=True,
#                                density=0.003125,
#                                non_cell_density=10,
#                                margin_empty=0.05,
#                                z_prior=[-1, 1],
#                                survival_prob=None,
#                                min_photon=0.25,
#                                camera='sCMOS',
#                                camera_chip_size=[1041, 1302],
#                                perlin_noise=False,
#                                perlin_noise_factor=0.2,
#                                perlin_noise_res=64,
#                                baseline=103.0,
#                                bg_values=273.0,
#                                bg_width=2,
#                                e_per_adu=0.38,
#                                qe=0.95,
#                                spurious_c=0.0,
#                                sig_read='/mnt/sda1/SMLAT/data/real_data/dark_images/RN_e_venus_upgraded.tiff',
#                                robust_training=False,
#                                cell_masks_dir='/mnt/sda1/SMLAT/data/real_data/only_beads/EXP-24-CB4791/Run/pool_CB4791_pos76/phase_cherry_mask_dilated/',
#                                cell_masks_filetype='.png',
#                                edt_noise_map_path='/mnt/sda1/SMLAT/data/real_data/only_beads/EXP-24-CB4791/Run/pool_CB4791_pos76/edt_noise_cherry.pkl',
#                                min_edt=0,
#                                max_edt=7,
#                                augment=True),
#           Network=namespace(n_filters=48,
#                             n_stages=2,
#                             padding=1,
#                             kernel_size=3,
#                             sig_pred=True,
#                             psf_pred=True,
#                             local_context=False,
#                             use_coordconv=True,
#                             factor=300.0,
#                             offset=273.0),
#           Train=namespace(lr=0.0006,
#                           w_decay=0.1,
#                           lr_decay=0.9,
#                           step_size=4000,
#                           batch_size=16,
#                           max_iters=50000,
#                           print_output=True,
#                           print_freq=100,
#                           photon_filter=True,
#                           photon_filter_threshold=100,
#                           P_locs_cse=True,
#                           robust_training=False,
#                           clip_gradient_max_norm=0.03),
#           PSF=namespace(calib_file='/mnt/sda1/SMLAT/data/real_data/only_beads/EXP-24-CB4791/splines25nm/cherry.mat',
#                         psf_size=40,
#                         photon_scale=3000,
#                         z_scale=600,
#                         pixel_size_xy=[65, 65]),
#           Evaluation=namespace(number_images=30,
#                                use_cell_masks=True,
#                                density_in_cells=0.003125,
#                                cell_masks_dir='/mnt/sda1/SMLAT/data/real_data/only_beads/EXP-24-CB4791/Run/pool_CB4791_pos76/phase_cherry_mask_dilated/',
#                                cell_masks_filetype='.png',
#                                edt_noise_map_path='/mnt/sda1/SMLAT/data/real_data/only_beads/EXP-24-CB4791/Run/pool_CB4791_pos76/edt_noise_cherry.pkl',
#                                eval_size=[1041, 1302],
#                                molecules_per_img=100,
#                                margin_empty=0.05,
#                                candidate_threshold=0.2,
#                                nms_threshold=0.5,
#                                print_result=False,
#                                batch_size=16,
#                                padded_background=273.0),
#           Hardware=namespace(device='cuda:0',
#                              device_simulation='cuda:0',
#                              num_worker_train=4,
#                              torch_threads=4,
#                              unix_niceness=0),
#           InOut=namespace(experiment_out='/mnt/sda1/SMLAT/training_runs/',
#                           calibration_file='',
#                           filename='/mnt/sda1/SMLAT/training_runs/psf_march21_cherry_20k_run2'),
#           Meta=namespace(version=None))

# %%
model = cellbgnet.model.CellBGModel(param)
# Out:
# training sliding windows on camera chip:
# Area num: 0, field_xy: [0, 127, 0, 127]
# Area num: 1, field_xy: [114, 241, 0, 127]
# Area num: 2, field_xy: [228, 355, 0, 127]
# Area num: 3, field_xy: [342, 469, 0, 127]
# Area num: 4, field_xy: [456, 583, 0, 127]
# Area num: 5, field_xy: [570, 697, 0, 127]
# Area num: 6, field_xy: [684, 811, 0, 127]
# Area num: 7, field_xy: [798, 925, 0, 127]
# Area num: 8, field_xy: [912, 1039, 0, 127]
# Area num: 9, field_xy: [1026, 1153, 0, 127]
# Area num: 10, field_xy: [1140, 1267, 0, 127]
# Area num: 11, field_xy: [1174, 1301, 0, 127]
# Area num: 12, field_xy: [0, 127, 114, 241]
# Area num: 13, field_xy: [114, 241, 114, 241]
# Area num: 14, field_xy: [228, 355, 114, 241]
# Area num: 15, field_xy: [342, 469, 114, 241]
# Area num: 16, field_xy: [456, 583, 114, 241]
# Area num: 17, field_xy: [570, 697, 114, 241]
# Area num: 18, field_xy: [684, 811, 114, 241]
# Area num: 19, field_xy: [798, 925, 114, 241]
# Area num: 20, field_xy: [912, 1039, 114, 241]
# Area num: 21, field_xy: [1026, 1153, 114, 241]
# Area num: 22, field_xy: [1140, 1267, 114, 241]
# Area num: 23, field_xy: [1174, 1301, 114, 241]
# Area num: 24, field_xy: [0, 127, 228, 355]
# Area num: 25, field_xy: [114, 241, 228, 355]
# Area num: 26, field_xy: [228, 355, 228, 355]
# Area num: 27, field_xy: [342, 469, 228, 355]
# Area num: 28, field_xy: [456, 583, 228, 355]
# Area num: 29, field_xy: [570, 697, 228, 355]
# Area num: 30, field_xy: [684, 811, 228, 355]
# Area num: 31, field_xy: [798, 925, 228, 355]
# Area num: 32, field_xy: [912, 1039, 228, 355]
# Area num: 33, field_xy: [1026, 1153, 228, 355]
# Area num: 34, field_xy: [1140, 1267, 228, 355]
# Area num: 35, field_xy: [1174, 1301, 228, 355]
# Area num: 36, field_xy: [0, 127, 342, 469]
# Area num: 37, field_xy: [114, 241, 342, 469]
# Area num: 38, field_xy: [228, 355, 342, 469]
# Area num: 39, field_xy: [342, 469, 342, 469]
# Area num: 40, field_xy: [456, 583, 342, 469]
# Area num: 41, field_xy: [570, 697, 342, 469]
# Area num: 42, field_xy: [684, 811, 342, 469]
# Area num: 43, field_xy: [798, 925, 342, 469]
# Area num: 44, field_xy: [912, 1039, 342, 469]
# Area num: 45, field_xy: [1026, 1153, 342, 469]
# Area num: 46, field_xy: [1140, 1267, 342, 469]
# Area num: 47, field_xy: [1174, 1301, 342, 469]
# Area num: 48, field_xy: [0, 127, 456, 583]
# Area num: 49, field_xy: [114, 241, 456, 583]
# Area num: 50, field_xy: [228, 355, 456, 583]
# Area num: 51, field_xy: [342, 469, 456, 583]
# Area num: 52, field_xy: [456, 583, 456, 583]
# Area num: 53, field_xy: [570, 697, 456, 583]
# Area num: 54, field_xy: [684, 811, 456, 583]
# Area num: 55, field_xy: [798, 925, 456, 583]
# Area num: 56, field_xy: [912, 1039, 456, 583]
# Area num: 57, field_xy: [1026, 1153, 456, 583]
# Area num: 58, field_xy: [1140, 1267, 456, 583]
# Area num: 59, field_xy: [1174, 1301, 456, 583]
# Area num: 60, field_xy: [0, 127, 570, 697]
# Area num: 61, field_xy: [114, 241, 570, 697]
# Area num: 62, field_xy: [228, 355, 570, 697]
# Area num: 63, field_xy: [342, 469, 570, 697]
# Area num: 64, field_xy: [456, 583, 570, 697]
# Area num: 65, field_xy: [570, 697, 570, 697]
# Area num: 66, field_xy: [684, 811, 570, 697]
# Area num: 67, field_xy: [798, 925, 570, 697]
# Area num: 68, field_xy: [912, 1039, 570, 697]
# Area num: 69, field_xy: [1026, 1153, 570, 697]
# Area num: 70, field_xy: [1140, 1267, 570, 697]
# Area num: 71, field_xy: [1174, 1301, 570, 697]
# Area num: 72, field_xy: [0, 127, 684, 811]
# Area num: 73, field_xy: [114, 241, 684, 811]
# Area num: 74, field_xy: [228, 355, 684, 811]
# Area num: 75, field_xy: [342, 469, 684, 811]
# Area num: 76, field_xy: [456, 583, 684, 811]
# Area num: 77, field_xy: [570, 697, 684, 811]
# Area num: 78, field_xy: [684, 811, 684, 811]
# Area num: 79, field_xy: [798, 925, 684, 811]
# Area num: 80, field_xy: [912, 1039, 684, 811]
# Area num: 81, field_xy: [1026, 1153, 684, 811]
# Area num: 82, field_xy: [1140, 1267, 684, 811]
# Area num: 83, field_xy: [1174, 1301, 684, 811]
# Area num: 84, field_xy: [0, 127, 798, 925]
# Area num: 85, field_xy: [114, 241, 798, 925]
# Area num: 86, field_xy: [228, 355, 798, 925]
# Area num: 87, field_xy: [342, 469, 798, 925]
# Area num: 88, field_xy: [456, 583, 798, 925]
# Area num: 89, field_xy: [570, 697, 798, 925]
# Area num: 90, field_xy: [684, 811, 798, 925]
# Area num: 91, field_xy: [798, 925, 798, 925]
# Area num: 92, field_xy: [912, 1039, 798, 925]
# Area num: 93, field_xy: [1026, 1153, 798, 925]
# Area num: 94, field_xy: [1140, 1267, 798, 925]
# Area num: 95, field_xy: [1174, 1301, 798, 925]
# Area num: 96, field_xy: [0, 127, 912, 1039]
# Area num: 97, field_xy: [114, 241, 912, 1039]
# Area num: 98, field_xy: [228, 355, 912, 1039]
# Area num: 99, field_xy: [342, 469, 912, 1039]
# Area num: 100, field_xy: [456, 583, 912, 1039]
# Area num: 101, field_xy: [570, 697, 912, 1039]
# Area num: 102, field_xy: [684, 811, 912, 1039]
# Area num: 103, field_xy: [798, 925, 912, 1039]
# Area num: 104, field_xy: [912, 1039, 912, 1039]
# Area num: 105, field_xy: [1026, 1153, 912, 1039]
# Area num: 106, field_xy: [1140, 1267, 912, 1039]
# Area num: 107, field_xy: [1174, 1301, 912, 1039]
# Area num: 108, field_xy: [0, 127, 913, 1040]
# Area num: 109, field_xy: [114, 241, 913, 1040]
# Area num: 110, field_xy: [228, 355, 913, 1040]
# Area num: 111, field_xy: [342, 469, 913, 1040]
# Area num: 112, field_xy: [456, 583, 913, 1040]
# Area num: 113, field_xy: [570, 697, 913, 1040]
# Area num: 114, field_xy: [684, 811, 913, 1040]
# Area num: 115, field_xy: [798, 925, 913, 1040]
# Area num: 116, field_xy: [912, 1039, 913, 1040]
# Area num: 117, field_xy: [1026, 1153, 913, 1040]
# Area num: 118, field_xy: [1140, 1267, 913, 1040]
# Area num: 119, field_xy: [1174, 1301, 913, 1040]

# %%
model.init_recorder()
model.init_eval_data()
# Out:
# Eval image generation:   0%|                                                                | 0/30 [00:00<?, ?it/s]/home/pk/Documents/cellbgnet/cellbgnet/utils/hardware.py:9: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   return torch.cuda.FloatTensor(x.astype('float32'))
# Eval image generation: 100%|███████████████████████████████████████████████████████| 30/30 [00:08<00:00,  3.34it/s]
# eval images shape: (30, 1041, 1302) contain 14450 molecules,

# %%
start_time = time.time()
model.fit(batch_size=32, max_iters=20000, print_output=True, print_freq=100)
duration = time.time() - start_time
# Out:
# Started training ....
#  || Cost: 5629.194 || Time Upd.: 371.7 ms  || BatchNr.: 100
#  || Cost: 350.426 || Time Upd.: 372.7 ms  || BatchNr.: 200
#  || Cost: 132.276 || Time Upd.: 347.7 ms  || BatchNr.: 300
#  || Cost: 88.171 || Time Upd.: 344.9 ms  || BatchNr.: 400
#  || Cost: 83.248 || Time Upd.: 346.3 ms  || BatchNr.: 500
#  || Cost: 73.008 || Time Upd.: 345.6 ms  || BatchNr.: 600
#  || Cost: 68.015 || Time Upd.: 341.9 ms  || BatchNr.: 700
#  || Cost: 79.804 || Time Upd.: 363.8 ms  || BatchNr.: 800
#  || Cost: 60.759 || Time Upd.: 364.9 ms  || BatchNr.: 900
#  || Cost: 79.423 || Time Upd.: 345.7 ms  || BatchNr.: 1000
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 9423
# JoR: 1.170 || Eff_3d: 20.593 || Jaccard: 0.638 || Factor: 513.855 || RMSE_lat: 54.532 || RMSE_ax: 172.129 || RMSE_x: 39.335 || RMSE_y: 37.769 || Cost: 63.924 || Recall: 0.646 || Precision: 0.981 || BatchNr.: 1100 || Time Upd.: 344.9 ms
#  || Count Cost: 20.2166 || Localization Cost: 35.0317 || Bg Cost: 0.2194 || P_locs Cost: 29.1835saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 20.593 || 54.532 || 172.129 || 1100
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11950
# JoR: 1.172 || Eff_3d: 19.687 || Jaccard: 0.758 || Factor: 909.361 || RMSE_lat: 64.666 || RMSE_ax: 176.659 || RMSE_x: 43.795 || RMSE_y: 47.579 || Cost: 59.793 || Recall: 0.792 || Precision: 0.947 || BatchNr.: 1200 || Time Upd.: 345.3 ms
#  || Count Cost: 19.6009 || Localization Cost: 32.8890 || Bg Cost: 0.1985 || P_locs Cost: 28.4147saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 19.687 || 64.666 || 176.659 || 1200
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10670
# JoR: 1.206 || Eff_3d: 22.580 || Jaccard: 0.729 || Factor: 545.114 || RMSE_lat: 60.481 || RMSE_ax: 168.686 || RMSE_x: 46.209 || RMSE_y: 39.021 || Cost: 54.772 || Recall: 0.736 || Precision: 0.987 || BatchNr.: 1300 || Time Upd.: 342.7 ms
#  || Count Cost: 20.1548 || Localization Cost: 31.0320 || Bg Cost: 0.1601 || P_locs Cost: 27.6066saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 22.580 || 60.481 || 168.686 || 1300
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 8316
# JoR: 1.207 || Eff_3d: 21.566 || Jaccard: 0.572 || Factor: 445.229 || RMSE_lat: 47.430 || RMSE_ax: 165.214 || RMSE_x: 34.130 || RMSE_y: 32.936 || Cost: 54.229 || Recall: 0.576 || Precision: 0.990 || BatchNr.: 1400 || Time Upd.: 343.7 ms
#  || Count Cost: 19.6388 || Localization Cost: 31.0374 || Bg Cost: 0.1547 || P_locs Cost: 27.5428saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 21.566 || 47.430 || 165.214 || 1400
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 8624
# JoR: 1.008 || Eff_3d: 8.709 || Jaccard: 0.581 || Factor: 466.303 || RMSE_lat: 57.684 || RMSE_ax: 206.271 || RMSE_x: 37.269 || RMSE_y: 44.029 || Cost: 56.713 || Recall: 0.589 || Precision: 0.977 || BatchNr.: 1500 || Time Upd.: 345.1 ms
#  || Count Cost: 21.2167 || Localization Cost: 31.1935 || Bg Cost: 0.1797 || P_locs Cost: 27.5872saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 8.709 || 57.684 || 206.271 || 1500
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10038
# JoR: 1.335 || Eff_3d: 23.153 || Jaccard: 0.687 || Factor: 466.631 || RMSE_lat: 51.481 || RMSE_ax: 176.147 || RMSE_x: 36.995 || RMSE_y: 35.800 || Cost: 59.773 || Recall: 0.693 || Precision: 0.988 || BatchNr.: 1600 || Time Upd.: 345.1 ms
#  || Count Cost: 19.2627 || Localization Cost: 31.7524 || Bg Cost: 0.2162 || P_locs Cost: 27.4904saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 23.153 || 51.481 || 176.147 || 1600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 9671
# JoR: 1.276 || Eff_3d: 24.471 || Jaccard: 0.658 || Factor: 459.945 || RMSE_lat: 51.612 || RMSE_ax: 164.725 || RMSE_x: 37.221 || RMSE_y: 35.755 || Cost: 51.194 || Recall: 0.666 || Precision: 0.984 || BatchNr.: 1700 || Time Upd.: 343.7 ms
#  || Count Cost: 19.3682 || Localization Cost: 29.3952 || Bg Cost: 0.1397 || P_locs Cost: 26.9885saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 24.471 || 51.612 || 164.725 || 1700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 8164
# JoR: 1.195 || Eff_3d: 21.502 || Jaccard: 0.561 || Factor: 366.480 || RMSE_lat: 46.948 || RMSE_ax: 163.351 || RMSE_x: 34.424 || RMSE_y: 31.924 || Cost: 52.113 || Recall: 0.565 || Precision: 0.989 || BatchNr.: 1800 || Time Upd.: 345.3 ms
#  || Count Cost: 20.4572 || Localization Cost: 28.9583 || Bg Cost: 0.1547 || P_locs Cost: 26.7344saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 21.502 || 46.948 || 163.351 || 1800
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 9902
# JoR: 1.269 || Eff_3d: 24.987 || Jaccard: 0.675 || Factor: 416.338 || RMSE_lat: 53.183 || RMSE_ax: 162.927 || RMSE_x: 39.208 || RMSE_y: 35.932 || Cost: 51.542 || Recall: 0.682 || Precision: 0.985 || BatchNr.: 1900 || Time Upd.: 344.9 ms
#  || Count Cost: 19.5282 || Localization Cost: 29.2186 || Bg Cost: 0.1464 || P_locs Cost: 26.8365saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 24.987 || 53.183 || 162.927 || 1900
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10305
# JoR: 1.343 || Eff_3d: 27.390 || Jaccard: 0.704 || Factor: 480.691 || RMSE_lat: 52.444 || RMSE_ax: 159.407 || RMSE_x: 38.513 || RMSE_y: 35.596 || Cost: 49.237 || Recall: 0.711 || Precision: 0.987 || BatchNr.: 2000 || Time Upd.: 343.4 ms
#  || Count Cost: 18.8022 || Localization Cost: 27.8949 || Bg Cost: 0.1378 || P_locs Cost: 26.2340saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 27.390 || 52.444 || 159.407 || 2000
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 9873
# JoR: 1.341 || Eff_3d: 26.839 || Jaccard: 0.682 || Factor: 442.635 || RMSE_lat: 50.864 || RMSE_ax: 160.563 || RMSE_x: 36.957 || RMSE_y: 34.947 || Cost: 49.754 || Recall: 0.686 || Precision: 0.993 || BatchNr.: 2100 || Time Upd.: 345.4 ms
#  || Count Cost: 18.3870 || Localization Cost: 28.1110 || Bg Cost: 0.1429 || P_locs Cost: 26.1198saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 26.839 || 50.864 || 160.563 || 2100
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10668
# JoR: 1.393 || Eff_3d: 28.134 || Jaccard: 0.731 || Factor: 593.330 || RMSE_lat: 52.474 || RMSE_ax: 160.765 || RMSE_x: 38.032 || RMSE_y: 36.153 || Cost: 52.064 || Recall: 0.737 || Precision: 0.988 || BatchNr.: 2200 || Time Upd.: 348.4 ms
#  || Count Cost: 20.6554 || Localization Cost: 28.9628 || Bg Cost: 0.1527 || P_locs Cost: 27.0048saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 28.134 || 52.474 || 160.765 || 2200
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 9848
# JoR: 1.336 || Eff_3d: 28.090 || Jaccard: 0.679 || Factor: 488.613 || RMSE_lat: 50.804 || RMSE_ax: 154.631 || RMSE_x: 37.118 || RMSE_y: 34.689 || Cost: 50.164 || Recall: 0.683 || Precision: 0.991 || BatchNr.: 2300 || Time Upd.: 344.0 ms
#  || Count Cost: 20.4496 || Localization Cost: 28.1203 || Bg Cost: 0.1409 || P_locs Cost: 26.7306saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are :
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10985
# JoR: 1.460 || Eff_3d: 30.632 || Jaccard: 0.753 || Factor: 480.078 || RMSE_lat: 51.555 || RMSE_ax: 155.457 || RMSE_x: 37.420 || RMSE_y: 35.463 || Cost: 45.797 || Recall: 0.759 || Precision: 0.989 || BatchNr.: 5600 || Time Upd.: 341.9 ms
#  || Count Cost: 18.3083 || Localization Cost: 25.5532 || Bg Cost: 0.1279 || P_locs Cost: 25.4069saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 30.632 || 51.555 || 155.457 || 5600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10674
# JoR: 1.422 || Eff_3d: 28.551 || Jaccard: 0.733 || Factor: 435.897 || RMSE_lat: 51.562 || RMSE_ax: 161.037 || RMSE_x: 37.492 || RMSE_y: 35.397 || Cost: 44.579 || Recall: 0.739 || Precision: 0.990 || BatchNr.: 5700 || Time Upd.: 342.6 ms
#  || Count Cost: 18.2885 || Localization Cost: 25.2423 || Bg Cost: 0.1165 || P_locs Cost: 25.4333saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 28.551 || 51.562 || 161.037 || 5700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11068
# JoR: 1.464 || Eff_3d: 29.565 || Jaccard: 0.755 || Factor: 527.610 || RMSE_lat: 51.564 || RMSE_ax: 160.247 || RMSE_x: 37.496 || RMSE_y: 35.396 || Cost: 44.791 || Recall: 0.763 || Precision: 0.986 || BatchNr.: 5800 || Time Upd.: 341.9 ms
#  || Count Cost: 18.0894 || Localization Cost: 25.4385 || Bg Cost: 0.1178 || P_locs Cost: 25.2549saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 29.565 || 51.564 || 160.247 || 5800
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11133
# JoR: 1.446 || Eff_3d: 30.386 || Jaccard: 0.761 || Factor: 489.743 || RMSE_lat: 52.628 || RMSE_ax: 155.705 || RMSE_x: 38.906 || RMSE_y: 35.442 || Cost: 47.067 || Recall: 0.769 || Precision: 0.987 || BatchNr.: 5900 || Time Upd.: 346.2 ms
#  || Count Cost: 18.7653 || Localization Cost: 26.1826 || Bg Cost: 0.1336 || P_locs Cost: 25.7865saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 30.386 || 52.628 || 155.705 || 5900
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10754
# JoR: 1.421 || Eff_3d: 29.793 || Jaccard: 0.737 || Factor: 445.508 || RMSE_lat: 51.902 || RMSE_ax: 155.869 || RMSE_x: 37.881 || RMSE_y: 35.481 || Cost: 45.961 || Recall: 0.744 || Precision: 0.989 || BatchNr.: 6000 || Time Upd.: 343.0 ms
#  || Count Cost: 18.1946 || Localization Cost: 25.3217 || Bg Cost: 0.1333 || P_locs Cost: 25.3544saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 29.793 || 51.902 || 155.869 || 6000
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11425
# JoR: 1.457 || Eff_3d: 30.394 || Jaccard: 0.780 || Factor: 509.966 || RMSE_lat: 53.547 || RMSE_ax: 156.581 || RMSE_x: 38.263 || RMSE_y: 37.460 || Cost: 45.597 || Recall: 0.788 || Precision: 0.987 || BatchNr.: 6100 || Time Upd.: 345.5 ms
#  || Count Cost: 18.5313 || Localization Cost: 25.6889 || Bg Cost: 0.1222 || P_locs Cost: 25.7195saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 30.394 || 53.547 || 156.581 || 6100
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10626
# JoR: 1.422 || Eff_3d: 30.260 || Jaccard: 0.730 || Factor: 440.936 || RMSE_lat: 51.327 || RMSE_ax: 153.722 || RMSE_x: 37.559 || RMSE_y: 34.982 || Cost: 44.781 || Recall: 0.735 || Precision: 0.990 || BatchNr.: 6200 || Time Upd.: 343.9 ms
#  || Count Cost: 18.3567 || Localization Cost: 25.2890 || Bg Cost: 0.1181 || P_locs Cost: 25.4932saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 30.260 || 51.327 || 153.722 || 6200
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10352
# JoR: 1.419 || Eff_3d: 30.242 || Jaccard: 0.713 || Factor: 446.013 || RMSE_lat: 50.234 || RMSE_ax: 152.837 || RMSE_x: 36.638 || RMSE_y: 34.367 || Cost: 46.167 || Recall: 0.717 || Precision: 0.991 || BatchNr.: 6300 || Time Upd.: 346.2 ms
#  || Count Cost: 19.5541 || Localization Cost: 26.0512 || Bg Cost: 0.1209 || P_locs Cost: 26.1221saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 30.242 || 50.234 || 152.837 || 6300
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10497
# JoR: 1.435 || Eff_3d: 30.763 || Jaccard: 0.722 || Factor: 459.963 || RMSE_lat: 50.318 || RMSE_ax: 152.152 || RMSE_x: 36.642 || RMSE_y: 34.486 || Cost: 49.507 || Recall: 0.727 || Precision: 0.990 || BatchNr.: 6400 || Time Upd.: 345.2 ms
#  || Count Cost: 18.9083 || Localization Cost: 26.9214 || Bg Cost: 0.1545 || P_locs Cost: 25.7766saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 30.763 || 50.318 || 152.152 || 6400
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11239
# JoR: 1.455 || Eff_3d: 29.831 || Jaccard: 0.771 || Factor: 483.261 || RMSE_lat: 52.981 || RMSE_ax: 158.739 || RMSE_x: 38.695 || RMSE_y: 36.190 || Cost: 45.014 || Recall: 0.777 || Precision: 0.989 || BatchNr.: 6500 || Time Upd.: 345.8 ms
#  || Count Cost: 18.3479 || Localization Cost: 25.4720 || Bg Cost: 0.1185 || P_locs Cost: 25.5551saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 29.831 || 52.981 || 158.739 || 6500
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11222
# JoR: 1.454 || Eff_3d: 29.390 || Jaccard: 0.765 || Factor: 468.436 || RMSE_lat: 52.602 || RMSE_ax: 160.438 || RMSE_x: 38.596 || RMSE_y: 35.740 || Cost: 44.900 || Recall: 0.773 || Precision: 0.985 || BatchNr.: 6600 || Time Upd.: 344.3 ms
#  || Count Cost: 18.3621 || Localization Cost: 25.2883 || Bg Cost: 0.1195 || P_locs Cost: 25.5198saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 29.390 || 52.602 || 160.438 || 6600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10656
# JoR: 1.430 || Eff_3d: 30.916 || Jaccard: 0.733 || Factor: 413.278 || RMSE_lat: 51.227 || RMSE_ax: 151.601 || RMSE_x: 36.612 || RMSE_y: 35.830 || Cost: 44.770 || Recall: 0.738 || Precision: 0.990 || BatchNr.: 6700 || Time Upd.: 343.6 ms
#  || Count Cost: 18.5783 || Localization Cost: 25.4109 || Bg Cost: 0.1152 || P_locs Cost: 25.6930saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 30.916 || 51.227 || 151.601 || 6700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11798
# JoR: 1.488 || Eff_3d: 30.918 || Jaccard: 0.802 || Factor: 521.186 || RMSE_lat: 53.907 || RMSE_ax: 156.580 || RMSE_x: 39.233 || RMSE_y: 36.969 || Cost: 47.355 || Recall: 0.812 || Precision: 0.985 || BatchNr.: 6800 || Time Upd.: 343.0 ms
#  || Count Cost: 18.7140 || Localization Cost: 26.0147 || Bg Cost: 0.1405 || P_locs Cost: 25.4286saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 30.918 || 53.907 || 156.580 || 6800
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds:
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10966
# JoR: 1.462 || Eff_3d: 31.484 || Jaccard: 0.751 || Factor: 448.909 || RMSE_lat: 51.346 || RMSE_ax: 151.915 || RMSE_x: 37.501 || RMSE_y: 35.072 || Cost: 46.403 || Recall: 0.758 || Precision: 0.988 || BatchNr.: 7500 || Time Upd.: 343.8 ms
#  || Count Cost: 18.1745 || Localization Cost: 25.3717 || Bg Cost: 0.1381 || P_locs Cost: 25.3930saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 31.484 || 51.346 || 151.915 || 7500
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10744
# JoR: 1.418 || Eff_3d: 30.317 || Jaccard: 0.733 || Factor: 446.859 || RMSE_lat: 51.726 || RMSE_ax: 153.359 || RMSE_x: 37.741 || RMSE_y: 35.371 || Cost: 46.752 || Recall: 0.741 || Precision: 0.986 || BatchNr.: 7600 || Time Upd.: 347.0 ms
#  || Count Cost: 19.0681 || Localization Cost: 26.0182 || Bg Cost: 0.1306 || P_locs Cost: 25.8785saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 30.317 || 51.726 || 153.359 || 7600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10590
# JoR: 1.419 || Eff_3d: 30.291 || Jaccard: 0.728 || Factor: 437.167 || RMSE_lat: 51.281 || RMSE_ax: 153.335 || RMSE_x: 37.381 || RMSE_y: 35.105 || Cost: 44.446 || Recall: 0.733 || Precision: 0.990 || BatchNr.: 7700 || Time Upd.: 343.8 ms
#  || Count Cost: 18.1762 || Localization Cost: 24.9676 || Bg Cost: 0.1191 || P_locs Cost: 25.2627saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 30.291 || 51.281 || 153.335 || 7700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# ...
#  || Count Cost: 17.8256 || Localization Cost: 23.2864 || Bg Cost: 0.1108 || P_locs Cost: 24.4785saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 32.394 || 51.766 || 150.651 || 17800
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10871
# JoR: 1.466 || Eff_3d: 32.412 || Jaccard: 0.746 || Factor: 451.110 || RMSE_lat: 50.856 || RMSE_ax: 148.161 || RMSE_x: 37.061 || RMSE_y: 34.826 || Cost: 43.263 || Recall: 0.752 || Precision: 0.989 || BatchNr.: 17900 || Time Upd.: 383.7 ms
#  || Count Cost: 18.2624 || Localization Cost: 24.2009 || Bg Cost: 0.1138 || P_locs Cost: 25.2265saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 32.412 || 50.856 || 148.161 || 17900
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11453
# JoR: 1.502 || Eff_3d: 31.998 || Jaccard: 0.781 || Factor: 466.458 || RMSE_lat: 51.985 || RMSE_ax: 153.039 || RMSE_x: 37.740 || RMSE_y: 35.750 || Cost: 43.234 || Recall: 0.790 || Precision: 0.986 || BatchNr.: 18000 || Time Upd.: 394.5 ms
#  || Count Cost: 18.2114 || Localization Cost: 24.0633 || Bg Cost: 0.1155 || P_locs Cost: 25.1649saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 31.998 || 51.985 || 153.039 || 18000
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11476
# JoR: 1.463 || Eff_3d: 29.500 || Jaccard: 0.778 || Factor: 475.530 || RMSE_lat: 53.165 || RMSE_ax: 160.755 || RMSE_x: 38.804 || RMSE_y: 36.343 || Cost: 42.563 || Recall: 0.789 || Precision: 0.983 || BatchNr.: 18100 || Time Upd.: 373.8 ms
#  || Count Cost: 17.8550 || Localization Cost: 23.5326 || Bg Cost: 0.1161 || P_locs Cost: 24.6796saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 29.500 || 53.165 || 160.755 || 18100
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11187
# JoR: 1.503 || Eff_3d: 32.287 || Jaccard: 0.766 || Factor: 451.471 || RMSE_lat: 50.990 || RMSE_ax: 151.655 || RMSE_x: 36.916 || RMSE_y: 35.174 || Cost: 42.395 || Recall: 0.773 || Precision: 0.988 || BatchNr.: 18200 || Time Upd.: 375.1 ms
#  || Count Cost: 17.9904 || Localization Cost: 23.7273 || Bg Cost: 0.1112 || P_locs Cost: 24.7086saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 32.287 || 50.990 || 151.655 || 18200
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11170
# JoR: 1.495 || Eff_3d: 32.298 || Jaccard: 0.767 || Factor: 465.348 || RMSE_lat: 51.274 || RMSE_ax: 151.114 || RMSE_x: 37.420 || RMSE_y: 35.054 || Cost: 42.559 || Recall: 0.773 || Precision: 0.990 || BatchNr.: 18300 || Time Upd.: 363.9 ms
#  || Count Cost: 18.2809 || Localization Cost: 23.8121 || Bg Cost: 0.1104 || P_locs Cost: 25.0479saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 32.298 || 51.274 || 151.114 || 18300
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11324
# JoR: 1.511 || Eff_3d: 32.423 || Jaccard: 0.776 || Factor: 470.498 || RMSE_lat: 51.342 || RMSE_ax: 151.750 || RMSE_x: 37.596 || RMSE_y: 34.964 || Cost: 42.322 || Recall: 0.783 || Precision: 0.988 || BatchNr.: 18400 || Time Upd.: 357.8 ms
#  || Count Cost: 18.2682 || Localization Cost: 23.6927 || Bg Cost: 0.1091 || P_locs Cost: 25.0063saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 32.423 || 51.342 || 151.750 || 18400
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10742
# JoR: 1.481 || Eff_3d: 31.706 || Jaccard: 0.740 || Factor: 440.703 || RMSE_lat: 50.004 || RMSE_ax: 151.854 || RMSE_x: 36.301 || RMSE_y: 34.389 || Cost: 43.067 || Recall: 0.745 || Precision: 0.992 || BatchNr.: 18500 || Time Upd.: 365.1 ms
#  || Count Cost: 18.2723 || Localization Cost: 23.9759 || Bg Cost: 0.1148 || P_locs Cost: 25.0203saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 31.706 || 50.004 || 151.854 || 18500
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11810
# JoR: 1.515 || Eff_3d: 31.505 || Jaccard: 0.806 || Factor: 487.369 || RMSE_lat: 53.197 || RMSE_ax: 155.951 || RMSE_x: 38.803 || RMSE_y: 36.390 || Cost: 42.187 || Recall: 0.815 || Precision: 0.986 || BatchNr.: 18600 || Time Upd.: 366.2 ms
#  || Count Cost: 18.3160 || Localization Cost: 23.7470 || Bg Cost: 0.1063 || P_locs Cost: 25.0832saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 31.505 || 53.197 || 155.951 || 18600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11435
# JoR: 1.507 || Eff_3d: 32.466 || Jaccard: 0.783 || Factor: 476.092 || RMSE_lat: 51.953 || RMSE_ax: 151.426 || RMSE_x: 37.791 || RMSE_y: 35.650 || Cost: 44.039 || Recall: 0.790 || Precision: 0.988 || BatchNr.: 18700 || Time Upd.: 365.0 ms
#  || Count Cost: 18.4322 || Localization Cost: 24.6208 || Bg Cost: 0.1172 || P_locs Cost: 25.4290saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 32.466 || 51.953 || 151.426 || 18700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10968
# JoR: 1.474 || Eff_3d: 32.303 || Jaccard: 0.753 || Factor: 447.267 || RMSE_lat: 51.095 || RMSE_ax: 149.344 || RMSE_x: 37.814 || RMSE_y: 34.363 || Cost: 42.488 || Recall: 0.759 || Precision: 0.990 || BatchNr.: 18800 || Time Upd.: 375.9 ms
#  || Count Cost: 18.3554 || Localization Cost: 23.8587 || Bg Cost: 0.1080 || P_locs Cost: 25.2807saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are :
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 10738
# JoR: 1.459 || Eff_3d: 31.489 || Jaccard: 0.738 || Factor: 432.874 || RMSE_lat: 50.550 || RMSE_ax: 151.320 || RMSE_x: 36.681 || RMSE_y: 34.782 || Cost: 42.115 || Recall: 0.743 || Precision: 0.990 || BatchNr.: 19500 || Time Upd.: 359.3 ms
#  || Count Cost: 17.8676 || Localization Cost: 23.5779 || Bg Cost: 0.1098 || P_locs Cost: 24.7193saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 31.489 || 50.550 || 151.320 || 19500
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11069
# JoR: 1.492 || Eff_3d: 32.095 || Jaccard: 0.760 || Factor: 460.515 || RMSE_lat: 50.941 || RMSE_ax: 151.562 || RMSE_x: 37.104 || RMSE_y: 34.903 || Cost: 42.636 || Recall: 0.766 || Precision: 0.990 || BatchNr.: 19600 || Time Upd.: 407.6 ms
#  || Count Cost: 18.2290 || Localization Cost: 23.8425 || Bg Cost: 0.1113 || P_locs Cost: 24.9810saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 32.095 || 50.941 || 151.562 || 19600
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11115
# JoR: 1.505 || Eff_3d: 32.209 || Jaccard: 0.763 || Factor: 466.425 || RMSE_lat: 50.704 || RMSE_ax: 152.038 || RMSE_x: 36.986 || RMSE_y: 34.683 || Cost: 42.009 || Recall: 0.769 || Precision: 0.990 || BatchNr.: 19700 || Time Upd.: 353.7 ms
#  || Count Cost: 17.9128 || Localization Cost: 23.3554 || Bg Cost: 0.1118 || P_locs Cost: 24.4983saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 32.209 || 50.704 || 152.038 || 19700
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11513
# JoR: 1.489 || Eff_3d: 31.276 || Jaccard: 0.782 || Factor: 488.779 || RMSE_lat: 52.488 || RMSE_ax: 155.189 || RMSE_x: 38.117 || RMSE_y: 36.084 || Cost: 42.234 || Recall: 0.792 || Precision: 0.984 || BatchNr.: 19800 || Time Upd.: 364.4 ms
#  || Count Cost: 17.9906 || Localization Cost: 23.5138 || Bg Cost: 0.1121 || P_locs Cost: 24.6253saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 31.276 || 52.488 || 155.189 || 19800
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11627
# JoR: 1.497 || Eff_3d: 31.533 || Jaccard: 0.792 || Factor: 491.855 || RMSE_lat: 52.876 || RMSE_ax: 154.672 || RMSE_x: 38.346 || RMSE_y: 36.407 || Cost: 42.873 || Recall: 0.801 || Precision: 0.985 || BatchNr.: 19900 || Time Upd.: 364.0 ms
#  || Count Cost: 18.2060 || Localization Cost: 23.9477 || Bg Cost: 0.1126 || P_locs Cost: 25.1113saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 31.533 || 52.876 || 154.672 || 19900
#
#
# processing area:99/99, input field_xy:[1258 1301 1001 1040], use_coordconv:True, retain locs in area:[1278, 1301, 1021, 1040]
#
# evaluation on 30 images, contain ground truth: 14450FOV: x=[0, 84630] y=[0, 67665]
# after FOV and border segmentation,truth: 14298 ,preds: 11306
# JoR: 1.514 || Eff_3d: 32.840 || Jaccard: 0.776 || Factor: 470.183 || RMSE_lat: 51.268 || RMSE_ax: 150.217 || RMSE_x: 37.339 || RMSE_y: 35.132 || Cost: 41.793 || Recall: 0.782 || Precision: 0.990 || BatchNr.: 20000 || Time Upd.: 375.0 ms
#  || Count Cost: 18.0343 || Localization Cost: 23.4796 || Bg Cost: 0.1064 || P_locs Cost: 24.7895saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 32.840 || 51.268 || 150.217 || 20000
#
#
# training finished!
