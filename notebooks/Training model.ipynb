# %%
# %reload_ext autoreload
# %autoreload 2
# %reload_ext notexbook
# %texify
# Out:
# <style type="text/css">
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
# */
#
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#                          FONTS
#
#     FONT WEIGHT MAP:
#     ----------------
#     100: Ultra Light
#     200: Thin
#     300: Light
#     400: Regular (normal)
#     500: Medium
#     600: Semi-bold
#     700: Bold
#     800: Heavy
#     900: Black
#
#     Font faces:
#         - ====================================|=======================
#         -              Scope                  | Font Family Name
#         - ====================================| ======================
#         - Markdown Display (Computer Modern)    (CMU Serif)
#         - Markdown Display monospace            (CMU Typewriter Text)
#         - Markdown Edit    monospace            (Hack)
#         - Source Code      monospace            (Fira Code)
#         - ====================================| =======================
#
#  ======================================================  */
#
# /* Roboto Slab */
# @import url("https://fonts.googleapis.com/css2?family=Roboto+Slab:wght@100;200;300;400;500;600;700;800;900&display=swap");
# /*md-display-computer-modern --> CMU Serif*/
# @import url("https://fonts.cdnfonts.com/css/cmu-serif?styles=30038,30039,30037,30036");
# /*md-display-monospace --> CMU Typewriter Text*/
# @import url("https://fonts.cdnfonts.com/css/cmu-typewriter-text?styles=24833,24829,24830,24831,24832,24834");
# /*code-monospace --> Fira Code*/
# @import url("https://fonts.googleapis.com/css2?family=Fira+Code:wght@300;400;500&display=swap");
# /*md-edit-monospace --> Hack*/
# @import url("https://fonts.cdnfonts.com/css/hack?styles=20708,20707,20705,20706");
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
# ======================================================
#
#
#     ---------------------------------
#     Code Mirror - Code Cell Highlight
#     ---------------------------------
#
#     Define the Style for Code **and** Markdown editors (Themes)
#     Theme files are all located in the "themes" folder, and the
#     different styles for the Code and Markdown editors are
#     distinguished by a common prefix in the file names:
#
#         --> Code editors Themes: "themes/code_*"
#         --> Markdown Editor Themes: "themes/md_*"
#
#     Styles can be imported as separate CSS modules.
#
#     Current stylesheet (editor.css) defines the CSS rules
#     for notebook tags and classes. These rules are
#     all based to colors defined in external Theme files.
#
#     This would ease the definition of other custom CSS Editor themes
# */
#
# /* Code Editor theme */
#
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#
# The color palette is inspired by Light
#  Material Design theme
# Repo: https://github.com/JonaDuran/Material-Light-Theme/
# */
#
# :root {
#     /* Color Palette */
#     --ml-white: #ffffff;
#     --ml-light-white: #FAFAFA;
#     --ml-black: #24292E;
#     --ml-dark-blue : #01579B11;
#     --ml-dark-blue-2: #01579B22;
#     --ml-blue: #1565C0;
#     --ml-green: #2E7D32;
#     --ml-yellow: #A8601A;
#     --ml-cyan: #00838f;
#     --ml-magenta: #9C00B0;
#     --ml-red: #C0392B;
#     --ml-grey: #9E9E9E;
#     --ml-light-blue: #78909c;
#
#
#     /* Editor Theme */
#     --code-background-color: var(--ml-light-white);
#     --gutter-background: var(--ml-light-white);
#     --selection-background-color: var(--ml-dark-blue-2);
#     --line-numbers: var(--ml-grey);
#     --cursor: var(--ml-black);
#     --bracket: var(--ml-black);
#     --matching-bracket: var(--ml-blue);
#     --code-text-color: var(--ml-black);
#     --keywords: var(--ml-magenta);
#     --types: var(--ml-magenta);
#     --variables: var(--code-text-color);
#     --variables2: var(--ml-green);
#     --def: var(--ml-blue);
#     --property: var(--ml-blue);
#     --meta: var(--ml-light-blue);
#     --builtin: var(--ml-blue);
#     --attribute: var(--ml-blue);
#     --strings: var(--ml-yellow);
#     --strings2: var(--ml-grey);
#     --comments: var(--ml-grey);
#     --operator: var(--ml-magenta);
#     --numbers: var(--ml-red);
#     /* Dataframe */
#     --dataframe: var(--code-text-color);
#     --df-bg: var(--ml-light-white);
#     --df-thead: var(--ml-blue);
#     --df-thead-border: var(--ml-black);
#     --df-tr-hover: var(--selection-background-color);
#     --df-border: var(--ml-white);
#     --df-border-right: var(--ml-grey);
#     --df-th-bg: var(--ml-white);
#     /*ANSI Colours*/
#     --ansi-red: var(--ml-red);
#     --ansi-green: var(--ml-green);
#     --ansi-green-intense: var(--ml-grey);
#     --ansi-cyan: var(--ml-cyan);
#     --ansi-blue: var(--ml-blue);
# }
#
#
#
# /* Markdown Editor theme */
#
#     /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
#
#  ======================================================
#
#     Custom Theme for Markdown Editor
#     based on Material Clear Theme.
#
#  */
#
# :root {
#     /* Color Palette */
#     --md-ml-red: #C0392B;
#     --md-ml-yellow: #A8601A;
#     --md-ml-black: #24292E;
#     --md-ml-grey: #9E9E9E;
#     --md-ml-blue: #1565C0;
#     --md-ml-dark-blue: #01579B;
#     --md-ml-light-blue: #78909c;
#
#     /*  Editor Theme  */
#     --editor-text: var(--md-ml-black);
#     --header: var(--md-ml-dark-blue);
#     --quote: var(--md-ml-grey);
#     --link: var(--md-ml-blue);
#     --attribute: var(--md-ml-red);
#     --tag: var(--md-ml-yellow);
#     --string: var(--md-ml-yellow);
#     --delimiter: var(--md-ml-black);
#     --monospace: var(--md-ml-light-blue);
# }
#
#
#
#
#
#
#
# /*
# Author: Valerio Maggio < @leriomaggio >
# Code: https://github.com/leriomaggio/notexbook-jupyter-theme
# License: Apache License 2.0
# */
#
# /*
#     =================
#     Code Editor Theme
#     =================
# */
# div.output_error pre,
# div.output_result pre,
# div.output_stream pre {
#     color: var(--code-text-color) !important;
# }
#
# .cm-s-ipython.CodeMirror,
# .cm-s-jupyter.CodeMirror {
#     background: var(--code-background-color);
#     color: var(--code-text-color);
# }
#
# .cm-s-ipython div.CodeMirror-selected,
# .cm-s-jupyter div.CodeMirror-selected {
#     cursor: pointer;
#     background: var(--selection-background-color);
# }
#
# .cm-s-ipython .CodeMirror-gutters,
# .cm-s-jupyter .CodeMirror-gutters {
#     background: var(--gutter-background);
#     border-right: 0;
# }
#
# .cm-s-ipython .CodeMirror-linenumber,
# .cm-s-jupyter .CodeMirror-linenumber {
#     color: var(--line-numbers);
# }
#
# .cm-s-ipython .CodeMirror-cursor,
# .cm-s-jupyter .CodeMirror-cursor {
#     border-left: 1px solid var(--cursor) !important;
# }
#
# .cm-s-ipython span.cm-bracket,
# .cm-s-jupyter span.cm-bracket {
#     /*color: #828282;*/
#     color: var(--bracket);
# }
#
# span.CodeMirror-matchingbracket {
#     text-decoration: underline !important;
#     text-decoration-color: var(--matching-bracket) !important;
#     color: var(--matching-bracket) !important;
# }
#
# .cm-s-ipython span.cm-keyword,
# .cm-s-jupyter span.cm-keyword {
#     color: var(--keywords);
#     font-weight: 400;
# }
#
# .cm-s-ipython span.cm-variable,
# .cm-s-jupyter span.cm-variable {
#     color: var(--variables);
# }
#
# .cm-s-ipython span.cm-variable-2,
# .cm-s-jupyter span.cm-variable-2 {
#     color: var(--variables2);
# }
#
# .cm-s-ipython span.cm-def,
# .cm-s-jupyter span.cm-def {
#     color: var(--def);
# }
#
# .cm-s-ipython span.cm-property,
# .cm-s-jupyter span.cm-property {
#     color: var(--property);
# }
#
# .cm-s-ipython span.cm-meta,
# .cm-s-jupyter span.cm-meta {
#     color: var(--meta);
# }
#
# .cm-s-ipython span.cm-attribute,
# .cm-s-jupyter span.cm-attribute {
#     color: var(--attribute);
# }
#
# .cm-s-ipython span.cm-builtin,
# .cm-s-jupyter span.cm-builtin {
#     color: var(--builtin)
# }
#
# .cm-s-ipython span.cm-string,
# .cm-s-jupyter span.cm-string {
#     color: var(--strings);
# }
#
# .cm-s-ipython span.cm-string-2,
# .cm-s-jupyter span.cm-string-2 {
#     color

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import time
import sys
sys.setrecursionlimit(10000)
# %matplotlib qt5

# %%
import cellbgnet
import cellbgnet.utils
from cellbgnet.datasets import DataSimulator
from cellbgnet.utils.hardware import cpu, gpu
from cellbgnet.model import CellBGModel

# %%
param_file = '../cellbgnet/utils/reference_files/reference.yaml'
param = cellbgnet.utils.param_io.ParamHandling().load_params(param_file)

# %%
psf_params = param.PSF.to_dict()
simulation_params = param.Simulation.to_dict()
hardware_params = param.Hardware.to_dict()
eval_params = param.Evaluation.to_dict()
train_size = simulation_params['train_size']

# %%
model = cellbgnet.model.CellBGModel(param)

# %%
model.init_recorder()
model.init_eval_data()
# Out:
# Already simulated 4096 evaluation images
# eval images shape: (4096, 128, 128) contain 40970 molecules,

# %%
model.evaluation_params['eval_imgs'].shape
# Out:
# (4096, 128, 128)

# %%
plt.figure()
plt.imshow(model.evaluation_params['eval_imgs'][24])
plt.colorbar()
plt.show()

# %%
simulation_params
# Out:
# {'train_size': 128,
#  'use_cell_bg': False,
#  'density': 10,
#  'margin_empty': 0.05,
#  'z_prior': [-1, 1],
#  'survival_prob': None,
#  'min_photon': 0.3,
#  'camera': 'sCMOS',
#  'perlin_noise': False,
#  'perlin_noise_factor': 0.2,
#  'perlin_noise_res': 64,
#  'baseline': 100,
#  'bg_values': 115.0,
#  'e_per_adu': 0.25,
#  'qe': 0.95,
#  'spurious_c': 0.0,
#  'sig_read': 1.2,
#  'robust_training': False}

# %%
start_time = time.time()
model.fit(batch_size=32, max_iters=20000, print_output=True, print_freq=100)
duration = time.time() - start_time
# Out:
# Started training ....
#  || Cost: 430.458 || Time Upd.: 201.9 ms  || BatchNr.: 100
#  || Cost: 164.780 || Time Upd.: 186.6 ms  || BatchNr.: 200
#  || Cost: 97.368 || Time Upd.: 184.4 ms  || BatchNr.: 300
#  || Cost: 80.859 || Time Upd.: 184.4 ms  || BatchNr.: 400
#  || Cost: 71.206 || Time Upd.: 184.5 ms  || BatchNr.: 500
#  || Cost: 61.079 || Time Upd.: 182.8 ms  || BatchNr.: 600
#  || Cost: 56.620 || Time Upd.: 187.3 ms  || BatchNr.: 700
#  || Cost: 50.544 || Time Upd.: 184.2 ms  || BatchNr.: 800
#  || Cost: 49.915 || Time Upd.: 183.6 ms  || BatchNr.: 900
#  || Cost: 44.847 || Time Upd.: 185.6 ms  || BatchNr.: 1000
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:34805
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 30782
# JoR: 1.475 || Eff_3d: 54.285 || Jaccard: 0.830 || Factor: 10.628 || RMSE_lat: 56.289 || RMSE_ax: 55.746 || RMSE_x: 42.577 || RMSE_y: 36.819 || Cost: 43.438 || Recall: 0.841 || Precision: 0.985 || BatchNr.: 1100 || Cost: 43.438 || Time Upd.: 185.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 54.285 || 56.289 || 55.746 || 1100
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:33758
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 29900
# JoR: 1.557 || Eff_3d: 58.331 || Jaccard: 0.792 || Factor: 10.410 || RMSE_lat: 50.858 || RMSE_ax: 38.533 || RMSE_x: 35.583 || RMSE_y: 36.337 || Cost: 41.709 || Recall: 0.808 || Precision: 0.975 || BatchNr.: 1200 || Cost: 41.709 || Time Upd.: 187.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 58.331 || 50.858 || 38.533 || 1200
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:28638
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 25233
# JoR: 1.357 || Eff_3d: 50.992 || Jaccard: 0.687 || Factor: 9.666 || RMSE_lat: 50.599 || RMSE_ax: 44.825 || RMSE_x: 34.450 || RMSE_y: 37.060 || Cost: 42.498 || Recall: 0.692 || Precision: 0.989 || BatchNr.: 1300 || Cost: 42.498 || Time Upd.: 189.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 50.992 || 50.599 || 44.825 || 1300
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:32540
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 28824
# JoR: 1.519 || Eff_3d: 56.636 || Jaccard: 0.776 || Factor: 9.924 || RMSE_lat: 51.068 || RMSE_ax: 42.702 || RMSE_x: 36.421 || RMSE_y: 35.798 || Cost: 40.928 || Recall: 0.786 || Precision: 0.983 || BatchNr.: 1400 || Cost: 40.928 || Time Upd.: 191.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 56.636 || 51.068 || 42.702 || 1400
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:34586
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 30698
# JoR: 1.610 || Eff_3d: 58.212 || Jaccard: 0.814 || Factor: 10.776 || RMSE_lat: 50.572 || RMSE_ax: 46.321 || RMSE_x: 35.672 || RMSE_y: 35.847 || Cost: 37.649 || Recall: 0.831 || Precision: 0.976 || BatchNr.: 1500 || Cost: 37.649 || Time Upd.: 191.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 58.212 || 50.572 || 46.321 || 1500
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:36207
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 32156
# JoR: 1.682 || Eff_3d: 61.814 || Jaccard: 0.847 || Factor: 10.718 || RMSE_lat: 50.378 || RMSE_ax: 36.369 || RMSE_x: 35.770 || RMSE_y: 35.474 || Cost: 36.383 || Recall: 0.868 || Precision: 0.973 || BatchNr.: 1600 || Cost: 36.383 || Time Upd.: 188.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 61.814 || 50.378 || 36.369 || 1600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:34020
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 30110
# JoR: 1.507 || Eff_3d: 55.736 || Jaccard: 0.812 || Factor: 10.043 || RMSE_lat: 53.870 || RMSE_ax: 50.438 || RMSE_x: 39.674 || RMSE_y: 36.442 || Cost: 34.807 || Recall: 0.822 || Precision: 0.985 || BatchNr.: 1700 || Cost: 34.807 || Time Upd.: 187.6 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 55.736 || 53.870 || 50.438 || 1700
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:34572
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 30576
# JoR: 1.553 || Eff_3d: 57.878 || Jaccard: 0.803 || Factor: 10.460 || RMSE_lat: 51.703 || RMSE_ax: 42.308 || RMSE_x: 37.241 || RMSE_y: 35.865 || Cost: 37.151 || Recall: 0.823 || Precision: 0.971 || BatchNr.: 1800 || Cost: 37.151 || Time Upd.: 176.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 57.878 || 51.703 || 42.308 || 1800
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:32814
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 29032
# JoR: 1.506 || Eff_3d: 55.441 || Jaccard: 0.774 || Factor: 10.017 || RMSE_lat: 51.381 || RMSE_ax: 48.040 || RMSE_x: 36.048 || RMSE_y: 36.614 || Cost: 33.752 || Recall: 0.788 || Precision: 0.978 || BatchNr.: 1900 || Cost: 33.752 || Time Upd.: 176.7 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 55.441 || 51.381 || 48.040 || 1900
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:33068
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 29274
# JoR: 1.575 || Eff_3d: 59.227 || Jaccard: 0.792 || Factor: 10.226 || RMSE_lat: 50.318 || RMSE_ax: 34.852 || RMSE_x: 34.829 || RMSE_y: 36.316 || Cost: 36.855 || Recall: 0.801 || Precision: 0.987 || BatchNr.: 2000 || Cost: 36.855 || Time Upd.: 177.3 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 59.227 || 50.318 || 34.852 || 2000
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:38441
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 34135
# JoR: 1.630 || Eff_3d: 60.778 || Jaccard: 0.884 || Factor: 11.646 || RMSE_lat: 54.227 || RMSE_ax: 39.700 || RMSE_x: 39.624 || RMSE_y: 37.021 || Cost: 32.456 || Recall: 0.913 || Precision: 0.965 || BatchNr.: 2100 || Cost: 32.456 || Time Upd.: 177.7 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 60.778 || 54.227 || 39.700 || 2100
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:30017
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 26743
# JoR: 1.503 || Eff_3d: 55.324 || Jaccard: 0.733 || Factor: 9.186 || RMSE_lat: 48.776 || RMSE_ax: 41.420 || RMSE_x: 33.990 || RMSE_y: 34.983 || Cost: 31.977 || Recall: 0.737 || Precision: 0.994 || BatchNr.: 2200 || Cost: 31.977 || Time Upd.: 177.6 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 55.324 || 48.776 || 41.420 || 2200
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
# evaluation on 4096 images, contain ground truth: 40970, preds:33744
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 30002
# JoR: 1.576 || Eff_3d: 58.298 || Jaccard: 0.812 || Factor: 10.069 || RMSE_lat: 51.563 || RMSE_ax: 43.013 || RMSE_x: 36.143 || RMSE_y: 36.775 || Cost: 30.025 || Recall: 0.821 || Precision: 0.987 || BatchNr.: 2300 || Cost: 30.025 || Time Upd.: 177.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 58.298 || 51.563 || 43.013 || 2300
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:35580
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 31700
# JoR: 1.524 || Eff_3d: 58.356 || Jaccard: 0.855 || Factor: 10.236 || RMSE_lat: 56.091 || RMSE_ax: 41.526 || RMSE_x: 42.227 || RMSE_y: 36.919 || Cost: 32.564 || Recall: 0.866 || Precision: 0.985 || BatchNr.: 2400 || Cost: 32.564 || Time Upd.: 176.6 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are :
ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 61.294 || 51.570 || 43.841 || 8500
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:31868
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 29731
# JoR: 1.650 || Eff_3d: 60.834 || Jaccard: 0.817 || Factor: 9.656 || RMSE_lat: 49.524 || RMSE_ax: 35.716 || RMSE_x: 35.167 || RMSE_y: 34.869 || Cost: 19.775 || Recall: 0.821 || Precision: 0.995 || BatchNr.: 8600 || Cost: 19.775 || Time Upd.: 176.5 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 60.834 || 49.524 || 35.716 || 8600
#
#
# ...
# JoR: 1.639 || Eff_3d: 58.685 || Jaccard: 0.874 || Factor: 10.173 || RMSE_lat: 53.350 || RMSE_ax: 49.650 || RMSE_x: 38.216 || RMSE_y: 37.227 || Cost: 16.458 || Recall: 0.879 || Precision: 0.995 || BatchNr.: 17500 || Cost: 16.458 || Time Upd.: 178.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 58.685 || 53.350 || 49.650 || 17500
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:33551
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 31545
# JoR: 1.568 || Eff_3d: 55.591 || Jaccard: 0.863 || Factor: 12.246 || RMSE_lat: 55.023 || RMSE_ax: 58.034 || RMSE_x: 38.369 || RMSE_y: 39.438 || Cost: 15.982 || Recall: 0.868 || Precision: 0.992 || BatchNr.: 17600 || Cost: 15.982 || Time Upd.: 176.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 55.591 || 55.023 || 58.034 || 17600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:35099
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 33056
# JoR: 1.710 || Eff_3d: 60.552 || Jaccard: 0.905 || Factor: 11.384 || RMSE_lat: 52.907 || RMSE_ax: 46.517 || RMSE_x: 37.367 || RMSE_y: 37.455 || Cost: 17.112 || Recall: 0.910 || Precision: 0.993 || BatchNr.: 17700 || Cost: 17.112 || Time Upd.: 179.6 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 60.552 || 52.907 || 46.517 || 17700
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:35038
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 32625
# JoR: 1.656 || Eff_3d: 58.210 || Jaccard: 0.895 || Factor: 11.624 || RMSE_lat: 54.012 || RMSE_ax: 53.057 || RMSE_x: 37.208 || RMSE_y: 39.151 || Cost: 16.503 || Recall: 0.899 || Precision: 0.994 || BatchNr.: 17800 || Cost: 16.503 || Time Upd.: 178.6 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 58.210 || 54.012 || 53.057 || 17800
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:35405
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 33252
# JoR: 1.648 || Eff_3d: 58.991 || Jaccard: 0.908 || Factor: 10.585 || RMSE_lat: 55.084 || RMSE_ax: 48.987 || RMSE_x: 37.429 || RMSE_y: 40.415 || Cost: 16.666 || Recall: 0.915 || Precision: 0.992 || BatchNr.: 17900 || Cost: 16.666 || Time Upd.: 176.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 58.991 || 55.084 || 48.987 || 17900
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:34397
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 32277
# JoR: 1.648 || Eff_3d: 57.230 || Jaccard: 0.882 || Factor: 10.562 || RMSE_lat: 53.488 || RMSE_ax: 56.772 || RMSE_x: 37.514 || RMSE_y: 38.126 || Cost: 16.202 || Recall: 0.888 || Precision: 0.992 || BatchNr.: 18000 || Cost: 16.202 || Time Upd.: 179.5 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 57.230 || 53.488 || 56.772 || 18000
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:34647
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 32493
# JoR: 1.632 || Eff_3d: 57.818 || Jaccard: 0.889 || Factor: 10.628 || RMSE_lat: 54.446 || RMSE_ax: 53.101 || RMSE_x: 37.198 || RMSE_y: 39.758 || Cost: 16.194 || Recall: 0.895 || Precision: 0.993 || BatchNr.: 18100 || Cost: 16.194 || Time Upd.: 178.7 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 57.818 || 54.446 || 53.101 || 18100
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:34222
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 32084
# JoR: 1.651 || Eff_3d: 59.652 || Jaccard: 0.875 || Factor: 10.378 || RMSE_lat: 53.001 || RMSE_ax: 46.167 || RMSE_x: 37.675 || RMSE_y: 37.278 || Cost: 15.908 || Recall: 0.882 || Precision: 0.991 || BatchNr.: 18200 || Cost: 15.908 || Time Upd.: 178.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 59.652 || 53.001 || 46.167 || 18200
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:32613
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 30606
# JoR: 1.567 || Eff_3d: 56.225 || Jaccard: 0.839 || Factor: 11.752 || RMSE_lat: 53.551 || RMSE_ax: 54.457 || RMSE_x: 37.240 || RMSE_y: 38.483 || Cost: 16.763 || Recall: 0.843 || Precision: 0.994 || BatchNr.: 18300 || Cost: 16.763 || Time Upd.: 177.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 56.225 || 53.551 || 54.457 || 18300
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:35208
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 33079
# JoR: 1.757 || Eff_3d: 61.672 || Jaccard: 0.904 || Factor: 10.581 || RMSE_lat: 51.433 || RMSE_ax: 44.678 || RMSE_x: 35.923 || RMSE_y: 36.809 || Cost: 16.579 || Recall: 0.910 || Precision: 0.992 || BatchNr.: 18400 || Cost: 16.579 || Time Upd.: 178.9 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 61.672 || 51.433 || 44.678 || 18400
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:35294
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 33045
# JoR: 1.704 || Eff_3d: 59.668 || Jaccard: 0.904 || Factor: 10.514 || RMSE_lat: 53.050 || RMSE_ax: 49.910 || RMSE_x: 36.767 || RMSE_y: 38.242 || Cost: 16.673 || Recall: 0.910 || Precision: 0.993 || BatchNr.: 18500 || Cost: 16.673 || Time Upd.: 179.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 59.668 || 53.050 || 49.910 || 18500
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:35054
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 32992
# JoR: 1.711 || Eff_3d: 59.704 || Jaccard: 0.903 || Factor: 10.728 || RMSE_lat: 52.743 || RMSE_ax: 50.261 || RMSE_x: 36.956 || RMSE_y: 37.631 || Cost: 16.001 || Recall: 0.908 || Precision: 0.993 || BatchNr.: 18600 || Cost: 16.001 || Time Upd.: 176.8 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 59.704 || 52.743 || 50.261 || 18600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:34524
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 32210
# JoR: 1.650 || Eff_3d: 59.451 || Jaccard: 0.882 || Factor: 11.499 || RMSE_lat: 53.448 || RMSE_ax: 47.141 || RMSE_x: 37.140 || RMSE_y: 38.437 || Cost: 17.441 || Recall: 0.887 || Precision: 0.993 || BatchNr.: 18700 || Cost: 17.441 || Time Upd.: 177.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 59.451 || 53.448 || 47.141 || 18700
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:34766
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 32501
# JoR: 1.617 || Eff_3d: 57.488 || Jaccard: 0.887 || Factor: 11.575 || RMSE_lat: 54.828 || RMSE_ax: 53.478 || RMSE_x: 37.948 || RMSE_y: 39.573 || Cost: 16.959 || Recall: 0.894 || Precision: 0.991 || BatchNr.: 18800 || Cost: 16.959 || Time Upd.: 176.6 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 57.488 || 54.828 || 53.478 || 18800
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:34535
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds:
ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 59.748 || 53.736 || 47.567 || 19600
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:35721
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 33547
# JoR: 1.725 || Eff_3d: 60.890 || Jaccard: 0.915 || Factor: 10.596 || RMSE_lat: 53.061 || RMSE_ax: 45.954 || RMSE_x: 36.956 || RMSE_y: 38.076 || Cost: 16.082 || Recall: 0.923 || Precision: 0.992 || BatchNr.: 19700 || Cost: 16.082 || Time Upd.: 177.6 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 60.890 || 53.061 || 45.954 || 19700
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:34832
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 32651
# JoR: 1.705 || Eff_3d: 60.834 || Jaccard: 0.893 || Factor: 10.534 || RMSE_lat: 52.392 || RMSE_ax: 44.902 || RMSE_x: 37.293 || RMSE_y: 36.798 || Cost: 15.588 || Recall: 0.899 || Precision: 0.993 || BatchNr.: 19800 || Cost: 15.588 || Time Upd.: 177.1 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 60.834 || 52.392 || 44.902 || 19800
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:34132
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 32105
# JoR: 1.645 || Eff_3d: 58.709 || Jaccard: 0.881 || Factor: 10.272 || RMSE_lat: 53.549 || RMSE_ax: 50.108 || RMSE_x: 36.661 || RMSE_y: 39.032 || Cost: 15.805 || Recall: 0.885 || Precision: 0.994 || BatchNr.: 19900 || Cost: 15.805 || Time Upd.: 179.2 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 58.709 || 53.549 || 50.108 || 19900
#
#
# processing area:1/1, input field_xy:[  0 127   0 127], use_coordconv:False, retain locs in area:[0, 127, 0, 127]
#
# evaluation on 4096 images, contain ground truth: 40970, preds:34744
# FOV: x=[0, 8320] y=[0, 8320]
# after FOV and border segmentation,truth: 36058 ,preds: 32703
# JoR: 1.689 || Eff_3d: 60.441 || Jaccard: 0.892 || Factor: 10.734 || RMSE_lat: 52.820 || RMSE_ax: 45.576 || RMSE_x: 37.325 || RMSE_y: 37.374 || Cost: 16.539 || Recall: 0.899 || Precision: 0.991 || BatchNr.: 20000 || Cost: 16.539 || Time Upd.: 178.4 ms
# saving this model, eff_3d, rmse_lat, rmse_ax and BatchNr are : 60.441 || 52.820 || 45.576 || 20000
#
#
# training finished!

# %%
print("Duration of training: ", duration, 's')
# Out:
# Duration of training:  7435.543351173401 s

# %%
def plot_od(od, label=None, col=None):
    """Produces a line plot from a ordered dictionary as used to store training process in the Model class
    
    Parameters
    ----------
    od: OrderedDict of floats
        DECODE model
    label: str
        Label
    col: 'str'
        Color
    """
    plt.plot(*zip(*sorted(od.items())), label=label, color=col)

def plot_train_record(model):
    plt.figure(figsize=(9,6),constrained_layout=True)
    plt.subplot(3,3,1);plot_od(model.recorder['rmse_lat']);plt.xlabel('iterations');plt.ylabel('RMSE_Lateral')
    plt.subplot(3,3,2);plot_od(model.recorder['rmse_ax']);plt.xlabel('iterations');plt.ylabel('RMSE_Axial')
    plt.subplot(3,3,3);plot_od(model.recorder['rmse_vol']);plt.xlabel('iterations');plt.ylabel('RMSE_Voxel')
    plt.subplot(3,3,4);plot_od(model.recorder['eff_lat']);plt.xlabel('iterations');plt.ylabel('lateral efficiency')
    plt.subplot(3,3,5);plot_od(model.recorder['eff_3d']);plt.xlabel('iterations');plt.ylabel('3D efficiency')
    plt.subplot(3,3,6);plot_od(model.recorder['recall']);plt.xlabel('iterations');plt.ylabel('recall')
    plt.subplot(3,3,7);plot_od(model.recorder['precision']);plt.xlabel('iterations');plt.ylabel('precision')
    plt.subplot(3,3,8);plot_od(model.recorder['jaccard']);plt.xlabel('iterations');plt.ylabel('jaccard')
    plt.subplot(3,3,9);plot_od(model.recorder['cost_hist']);plt.xlabel('iterations');plt.ylabel('cost')
    # plt.subplots_adjust(wspace=0.5,hspace=0.5)
    # plt.tight_layout()
    plt.show()

# %%
plot_train_record(model)

# %%
1 + 1

# %% [markdown]
# ### Evaluation data

# %%
eval_size_x = eval_params['eval_size']
eval_size_y = eval_params['eval_size']
density = eval_params['molecules_per_img']

prob_map = np.ones([1, eval_size_x, eval_size_y])
# no molecules on the boundary
prob_map[0, int(eval_params['margin_empty'] * eval_size_y): int((1-eval_params['margin_empty']) * eval_size_y),
            int(eval_params['margin_empty'] * eval_size_x): int((1-eval_params['margin_empty']) * eval_size_x)] += 1
prob_map = (prob_map / prob_map.sum()) * density

# %%
ground_truth = []
eval_imgs = np.zeros([1, eval_size_y, eval_size_x])
for j in range(eval_params['number_images']):
    imgs_sim, xyzi_mat, s_mask, psf_est, locs = model.data_generator.simulate_data(
            prob_map=gpu(prob_map), batch_size=1, local_context=model.local_context,
            photon_filter=False, photon_filter_threshold=0, P_locs_cse=False,
            iter_num=model._iter_count, train_size=eval_size_x)
    imgs_tmp = cpu(imgs_sim)[:, 1] if model.local_context else cpu(imgs_sim)[:, 0]
    eval_imgs = np.concatenate((eval_imgs, imgs_tmp), axis = 0)
    
    # pool all the xyzi values
    for i in range(xyzi_mat.shape[1]):
        ground_truth.append(
                [i + 1, j + 1, cpu(xyzi_mat[0, i, 0]) * model.data_generator.psf_params['pixel_size_xy'][0],
                cpu(xyzi_mat[0, i, 1]) * model.data_generator.psf_params['pixel_size_xy'][1],
                cpu(xyzi_mat[0, i, 2]) * model.data_generator.psf_params['z_scale'],
                cpu(xyzi_mat[0, i, 3]) * model.data_generator.psf_params['photon_scale']]
        )
    print('{}{}{}'.format('\rAlready simulated ', j+1, ' evaluation images'), end='')

eval_params['eval_imgs'] = eval_imgs[1:]
eval_params['ground_truth'] = ground_truth
eval_params['fov_size'] = [eval_size_x * model.data_generator.psf_params['pixel_size_xy'][0],
                          eval_size_y * model.data_generator.psf_params['pixel_size_xy'][1]]
print('\neval images shape:', eval_params['eval_imgs'].shape, 'contain', len(ground_truth), 'molecules,')
# Out:
# Already simulated 1024 evaluation images
# eval images shape: (1024, 128, 128) contain 4010 molecules,

# %%
eval_params['fov_size']
# Out:
# [8320, 8320]

# %%
plt.figure(constrained_layout=True)
ax_tmp = plt.subplot(1,1,1)
img_tmp = plt.imshow(eval_params['eval_imgs'][16])
plt.colorbar(mappable=img_tmp,ax=ax_tmp, fraction=0.046, pad=0.04)
plt.title('the first image of eval set,check the background')
# plt.tight_layout()
plt.show()
